# %%
# %load_ext autoreload
# %autoreload 2


import modish
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

sns.set(style='ticks', context='talk', rc={'font.sans-serif':'Arial', 'pdf.fonttype': 42})

# %matplotlib inline


folder = '/home/obotvinnik/Dropbox/figures2/singlecell_pnm/figure3_modalities_functional'

import flotilla

study = flotilla.embark('singlecell_pnm_figure2_modalities')
not_outliers = study.splicing.singles.index.difference(study.splicing.outliers.index)

psi = study.splicing.singles.ix[not_outliers]
grouped = psi.groupby(study.sample_id_to_phenotype)
psi_filtered = grouped.apply(lambda x: x.dropna(axis=1, thresh=20))
modality_order = ['~0', 'middle', '~1', 'bimodal', 'ambiguous']
modality_colors = dict(zip(modality_order, sns.color_palette('deep')))

modality_factorplot_kws = dict(hue_order=modality_order, order=study.phenotype_order)
# Out:
# 2015-09-29 17:42:45	Reading datapackage from /home/obotvinnik/flotilla_projects/singlecell_pnm_figure2_modalities/datapackage.json
# 2015-09-29 17:42:45	Parsing datapackage to create a Study object
# 2015-09-29 17:43:37	Initializing Study
# 2015-09-29 17:43:37	Initializing Predictor configuration manager for Study
# 2015-09-29 17:43:37	Predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# 2015-09-29 17:43:37	Added ExtraTreesClassifier to default predictors
# 2015-09-29 17:43:37	Predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# 2015-09-29 17:43:37	Added ExtraTreesRegressor to default predictors
# 2015-09-29 17:43:37	Predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# 2015-09-29 17:43:37	Added GradientBoostingClassifier to default predictors
# 2015-09-29 17:43:37	Predictor GradientBoostingRegressor is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# 2015-09-29 17:43:37	Added GradientBoostingRegressor to default predictors
# 2015-09-29 17:43:42	Building Gene Ontology database...
# 2015-09-29 17:43:51		Done.
# 2015-09-29 17:43:52	Loading metadata
# 2015-09-29 17:43:52	Loading expression data
# 2015-09-29 17:43:52	Initializing expression
# 2015-09-29 17:43:52	Done initializing expression
# 2015-09-29 17:43:54	Loading splicing data
# 2015-09-29 17:43:54	Initializing splicing
# 2015-09-29 17:43:54	Done initializing splicing
# 2015-09-29 17:43:54	Successfully initialized a Study object!

# %% [markdown]
# ### Make BED files of modality trios across celltypes

# %%
bed_folder = '/projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/'
! mkdir $bed_folder
# Out:
# mkdir: cannot create directory `/projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/': File exists

# %%
# %%time 
import pybedtools

DIR = '/projects/ps-yeolab/obotvinnik/singlecell_pnms'

exon_bedfile = '{}/skipped_exon_exon2.bed'.format(DIR)
exon_bed = pybedtools.BedTool(exon_bedfile)

for phenotype, phenotype_df in study.supplemental.modalities_tidy.groupby('phenotype'):
    background_events = set(phenotype_df.event_name)
    for modality, modality_df in phenotype_df.groupby('modality'):
        event_names = set(modality_df.event_name)
        format_args = bed_folder, phenotype, modality
        filtered_bed = exon_bed.filter(lambda x: x.name in event_names)
        filtered_filename = '{}/skipped_exon_exon2_{}_{}.bed'.format(*format_args)
        filtered_bed.saveas(filtered_filename)

        background_bed = exon_bed.filter(lambda x: x.name not in event_names and x.name in background_events)
        background_filename = '{}/skipped_exon_exon2_{}_{}_background.bed'.format(*format_args)
        background_bed.saveas(background_filename)

        ! wc -l $filtered_filename
        ! wc -l $background_filename
# Out:
# 1071 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_MN_bimodal.bed
# 9028 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_MN_bimodal_background.bed
# 1378 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_MN_~0.bed
# 8721 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_MN_~0_background.bed
# 7650 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_MN_~1.bed
# 2449 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_MN_~1_background.bed
# 2015 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_NPC_bimodal.bed
# 15932 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_NPC_bimodal_background.bed
# 2407 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_NPC_~0.bed
# 15540 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_NPC_~0_background.bed
# 13525 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_NPC_~1.bed
# 4422 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_NPC_~1_background.bed
# 3220 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_iPSC_bimodal.bed
# 22080 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_iPSC_bimodal_background.bed
# 44 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_iPSC_multimodal.bed
# 25256 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_iPSC_multimodal_background.bed
# 3471 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_iPSC_~0.bed
# 21829 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_iPSC_~0_background.bed
# 18565 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_iPSC_~1.bed
# 6735 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities//skipped_exon_exon2_iPSC_~1_background.bed
# CPU times: user 10.2 s, sys: 340 ms, total: 10.6 s
# Wall time: 13.2 s

# %% [markdown]
# ### Make stacked violinplots of modalities

# %%
# import matplotlib as mpl

# for modalities, s in modality_across_celltypes.groupby(modality_across_celltypes):
#     print modalities, s.shape
    
#     fig, ax = plt.subplots(figsize=(2.5, 2.5))
    
#     if s.shape[0] <= 100:
#         events = s.index
#     else:
#         events = np.random.choice(s.index, size=100, replace=False)
#     modalities_split = modalities.split(',')
#     color = [modality_colors[x] for x in modalities_split]
    
#     for event in events:
#         try:
#             study.splicing._violinplot(event, phenotype_groupby=study.sample_id_to_phenotype,
#                                        sample_ids=singles_no_outliers_ids, stripplot=False, get_pooled=False,
#                                       phenotype_order=study.phenotype_order, ax=ax, color=color,
#                                       bw=0.2, ylim=(0, 1), yticks=(0, 0.5, 1), ylabel='$\Psi$')
#         except ValueError:
#             continue
            
#     ax.set(title='', xticklabels=study.phenotype_order, xlabel='')
#     sns.despine()
#     alpha = max(1./(len(events)+1.), 0.1)
    
#     # Add transparency
#     polycollections = [x for x in ax.collections if isinstance(x, mpl.collections.PolyCollection)]
#     for polycollection in polycollections:
#         polycollection.set_alpha(alpha)
#     fig.tight_layout()
#     fig.savefig('{}/stacked_violinplots_{}.pdf'.format(folder, modalities))

# %% [markdown]
# ## GO enrichment

# %%
modality_group_sizes = modality_across_celltypes.groupby(modality_across_celltypes).size()
modality_group_sizes.sort(ascending=False)
modality_group_sizes
# Out:
# ~0,~0,~0                     10263
# ~1,~1,~1                      7405
# bimodal,bimodal,bimodal       1376
# ~0,~0,bimodal                  819
# bimodal,~0,~0                  803
# ~1,~1,bimodal                  702
# ~1,bimodal,bimodal             378
# ~0,bimodal,~0                  276
# bimodal,bimodal,~0             259
# ~0,bimodal,bimodal             242
# bimodal,~0,bimodal             239
# ~1,bimodal,~1                  217
# bimodal,~1,~1                  131
# bimodal,bimodal,~1              99
# bimodal,~1,bimodal              89
# ambiguous,bimodal,bimodal       34
# ~0,bimodal,~1                   11
# ~0,~0,~1                         8
# ~1,~1,~0                         7
# ~1,bimodal,~0                    7
# ambiguous,bimodal,~0             4
# middle,bimodal,bimodal           2
# ~0,~1,~1                         2
# ~1,ambiguous,bimodal             2
# ~1,~0,~0                         2
# ambiguous,bimodal,~1             2
# ~0,ambiguous,bimodal             2
# middle,~1,bimodal                1
# bimodal,~0,~1                    1
# ambiguous,~1,bimodal             1
# ambiguous,~0,bimodal             1
# dtype: int64

# %%
study.splicing.feature_expression_id_col = 'ensembl_id'

# %%
from flotilla.visualize.gene_ontology import plot_go_enrichment

background = study.splicing.splicing_to_expression_id(modality_across_celltypes.index)

go_dfs = []

for modalities, s in modality_across_celltypes.groupby(modality_across_celltypes):
    print modalities, s.shape
    modality_genes = study.splicing.splicing_to_expression_id(s.index)
    go = study.go_enrichment(modality_genes, background, p_value_cutoff=1)
    if go is None or go.empty:
        print '\t... empty GO enrichment!'
        continue
    fig, ax = plt.subplots(figsize=(8, 4))
    ax = plot_go_enrichment(data=go, max_categories=5)
    prefix = '{}/modality_go_enrichment_across_celltypes_{}'.format(folder, modalities)
    go.to_csv('{}.csv'.format(prefix))
    go['modalities'] = modalities
    go_dfs.append(go)
    
    print go.head()
    ax.set_title('{}, n={}'.format(modalities, s.shape[0]))
    fig = plt.gcf()
    fig.tight_layout()
    fig.savefig('{}.pdf'.format(prefix))
go_df = pd.concat(go_dfs)
# Out:
# ambiguous,bimodal,bimodal (34,)
#                               features_of_interest_in_go_term  \
# GO:0005654  ENSG00000170144,ENSG00000141552,ENSG0000008523...
# GO:0005634  ENSG00000170144,ENSG00000151500,ENSG0000016971...
# GO:0003676  ENSG00000169714,ENSG00000125944,ENSG0000017014...
# GO:0005515  ENSG00000123562,ENSG00000112514,ENSG0000014155...
# GO:0000166  ENSG00000125944,ENSG00000170144,ENSG0000013875...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005654     HNRNPA3,ANAPC11,TAF9,HNRNPR,HNRNPD,TCEB1,NOLC1
# GO:0005634  HNRNPA3,THYN1,CNBP,ACP1,TAF9,HNRNPR,MORF4L2,RP...
# GO:0003676                   CNBP,HNRNPR,HNRNPA3,G3BP2,HNRNPD
# GO:0005515  MORF4L2,CUTA,ANAPC11,ACP1,TAF9,HNRNPR,HNRNPD,T...
# GO:0000166                        HNRNPR,HNRNPA3,G3BP2,HNRNPD
#
#                      go_domain               go_name  n_background_in_go_term  \
# GO:0005654  cellular_component           nucleoplasm                      195
# GO:0005634  cellular_component               nucleus                      606
# GO:0003676  molecular_function  nucleic acid binding                      153
# GO:0005515  molecular_function       protein binding                      837
# GO:0000166  molecular_function    nucleotide binding                      126
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005654                                  7                         1060
# GO:0005634                                  9                         5678
# GO:0003676                                  5                         1364
# GO:0005515                                  9                         9884
# GO:0000166                                  4                          818
#
#                  p_value  bonferonni_corrected_p_value  \
# GO:0005654  1.423358e-10                  2.277373e-09
# GO:0005634  3.774233e-09                  6.038773e-08
# GO:0003676  4.642594e-08                  7.428151e-07
# GO:0005515  7.973281e-08                  1.275725e-06
# GO:0000166  6.395195e-07                  1.023231e-05
#
#                            modalities
# GO:0005654  ambiguous,bimodal,bimodal
# GO:0005634  ambiguous,bimodal,bimodal
# GO:0003676  ambiguous,bimodal,bimodal
# GO:0005515  ambiguous,bimodal,bimodal
# GO:0000166  ambiguous,bimodal,bimodal
# ambiguous,bimodal,~0 (4,)
# 	... empty GO enrichment!
# ambiguous,bimodal,~1 (2,)
# 	... empty GO enrichment!
# ambiguous,~0,bimodal (1,)
# 	... empty GO enrichment!
# ambiguous,~1,bimodal (1,)
# 	... empty GO enrichment!
# bimodal,bimodal,bimodal (1376,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000152234,ENSG00000124733,ENSG0000011371...
# GO:0005634  ENSG00000133134,ENSG00000096746,ENSG0000019789...
# GO:0005737  ENSG00000120265,ENSG00000133134,ENSG0000019789...
# GO:0005829  ENSG00000113712,ENSG00000243678,ENSG0000013072...
# GO:0003676  ENSG00000124177,ENSG00000177683,ENSG0000009674...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  ATP5A1,MEA1,CSNK1A1,MORF4L2,KMT2E,RBM4,NME1-NM...
# GO:0005634  BEX2,HNRNPH3,ADH5,RBM4,NME1-NME2,THAP5,ZNF644,...
# GO:0005737  PCMT1,BEX2,ADH5,RBM4,DGUOK,MEA1,POLR2H,METAP2,...
# GO:0005829  CSNK1A1,NME1-NME2,CHMP2A,DGUOK,RPS8,RPS18,SRP1...
# GO:0003676  CHD6,THAP5,HNRNPH3,DDX50,TRA2A,RBM4,ATRX,SRSF7...
#
#                      go_domain               go_name  n_background_in_go_term  \
# GO:0005515  molecular_function       protein binding                      837
# GO:0005634  cellular_component               nucleus                      606
# GO:0005737  cellular_component             cytoplasm                      585
# GO:0005829  cellular_component               cytosol                      428
# GO:0003676  molecular_function  nucleic acid binding                      153
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005515                                242                         9884
# GO:0005634                                190                         5678
# GO:0005737                                171                         5053
# GO:0005829                                122                         2542
# GO:0003676                                 68                         1364
#
#                   p_value  bonferonni_corrected_p_value  \
# GO:0005515  4.676010e-104                 1.832996e-101
# GO:0005634   5.358108e-88                  2.100378e-85
# GO:0005737   8.321215e-74                  3.261916e-71
# GO:0005829   1.854697e-51                  7.270414e-49
# GO:0003676   7.806252e-44                  3.060051e-41
#
#                          modalities
# GO:0005515  bimodal,bimodal,bimodal
# GO:0005634  bimodal,bimodal,bimodal
# GO:0005737  bimodal,bimodal,bimodal
# GO:0005829  bimodal,bimodal,bimodal
# GO:0003676  bimodal,bimodal,bimodal
# bimodal,bimodal,~0 (259,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000123545,ENSG00000164548,ENSG0000004135...
# GO:0005634  ENSG00000164924,ENSG00000124593,ENSG0000016296...
# GO:0005737  ENSG00000164924,ENSG00000131236,ENSG0000013867...
# GO:0005829  ENSG00000100387,ENSG00000138674,ENSG0000014830...
# GO:0006355  ENSG00000162961,ENSG00000169714,ENSG0000008522...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  NDUFAF4,TRA2A,PSMA4,EIF4A1,STAU2,NAP1L4,RPL11,...
# GO:0005634  YWHAZ,PRICKLE4,DPY30,TRA2A,RP11-463D19.2,KDM5B...
# GO:0005737  YWHAZ,CAP1,SEC31A,PPP1R7,DGUOK,USP9Y,PSMA4,RIM...
# GO:0005829  RBX1,SEC31A,RPL7A,CNBP,DGUOK,PSMA4,EIF4A1,OAZ1...
# GO:0006355  DPY30,CNBP,ATRX,ZNF644,CDK11A,ZNF207,ZNF33A,CC...
#
#                      go_domain                                     go_name  \
# GO:0005515  molecular_function                             protein binding
# GO:0005634  cellular_component                                     nucleus
# GO:0005737  cellular_component                                   cytoplasm
# GO:0005829  cellular_component                                     cytosol
# GO:0006355  biological_process  regulation of transcription, DNA-dependent
#
#             n_background_in_go_term  n_features_of_interest_in_go_term  \
# GO:0005515                      837                                 94
# GO:0005634                      606                                 79
# GO:0005737                      585                                 66
# GO:0005829                      428                                 50
# GO:0006355                      113                                 24
#
#             n_features_total_in_go_term       p_value  \
# GO:0005515                         9884  2.163808e-69
# GO:0005634                         5678  5.590554e-63
# GO:0005737                         5053  3.265228e-48
# GO:0005829                         2542  2.304381e-37
# GO:0006355                         2106  1.379404e-25
#
#             bonferonni_corrected_p_value          modalities
# GO:0005515                  3.656835e-67  bimodal,bimodal,~0
# GO:0005634                  9.448037e-61  bimodal,bimodal,~0
# GO:0005737                  5.518235e-46  bimodal,bimodal,~0
# GO:0005829                  3.894403e-35  bimodal,bimodal,~0
# GO:0006355                  2.331192e-23  bimodal,bimodal,~0
# bimodal,bimodal,~1 (99,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000085224,ENSG00000015479,ENSG0000008746...
# GO:0005634  ENSG00000085224,ENSG00000015479,ENSG0000001024...
# GO:0003677  ENSG00000010244,ENSG00000003756,ENSG0000011132...
# GO:0005737  ENSG00000122203,ENSG00000107874,ENSG0000013373...
# GO:0008270  ENSG00000010244,ENSG00000003756,ENSG0000020575...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  ATRX,MATR3,GNAS,DYNC1I2,ANKUB1,LCMT1,CD200,PDZ...
# GO:0005634  ATRX,MATR3,ZNF207,IMPA1,TUBB,FIBP,HNRNPUL2-BSC...
# GO:0003677  ZNF207,RBM5,CDK2AP1,ORC4,BCLAF1,ATF2,EIF4A2,AT...
# GO:0005737  KIAA1191,CUEDC2,IMPA1,CDK2AP1,CIRBP,DIABLO,BCL...
# GO:0008270  ZNF207,RBM5,CRYZL1,ATRX,MATR3,ATF2,PHF20,MTF2,...
#
#                      go_domain           go_name  n_background_in_go_term  \
# GO:0005515  molecular_function   protein binding                      837
# GO:0005634  cellular_component           nucleus                      606
# GO:0003677  molecular_function       DNA binding                      169
# GO:0005737  cellular_component         cytoplasm                      585
# GO:0008270  molecular_function  zinc ion binding                      123
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005515                                 30                         9884
# GO:0005634                                 24                         5678
# GO:0003677                                 13                         2282
# GO:0005737                                 17                         5053
# GO:0008270                                  9                         2200
#
#                  p_value  bonferonni_corrected_p_value          modalities
# GO:0005515  2.316019e-21                  6.484854e-20  bimodal,bimodal,~1
# GO:0005634  2.516165e-18                  7.045262e-17  bimodal,bimodal,~1
# GO:0003677  9.833114e-15                  2.753272e-13  bimodal,bimodal,~1
# GO:0005737  2.977333e-11                  8.336533e-10  bimodal,bimodal,~1
# GO:0008270  9.129585e-11                  2.556284e-09  bimodal,bimodal,~1
# bimodal,~0,bimodal (239,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000088930,ENSG00000163159,ENSG0000016371...
# GO:0005737  ENSG00000158427,ENSG00000205581,ENSG0000014376...
# GO:0005634  ENSG00000115524,ENSG00000258677,ENSG0000019722...
# GO:0005829  ENSG00000113558,ENSG00000143761,ENSG0000013424...
# GO:0005739  ENSG00000197223,ENSG00000164919,ENSG0000006551...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  XRN2,VPS72,U2SURP,NEDD8,STAU2,LAMTOR5,NDUFAF3,...
# GO:0005737  TMSB15B,HMGN1,ARF1,LAMTOR5,FEZ1,DGUOK,GPBP1,EN...
# GO:0005634  SF3B1,RP11-463D19.2,C1D,NASP,ARF1,LUC7L3,XRN2,...
# GO:0005829  SKP1,ARF1,LAMTOR5,DGUOK,CDC26,RPS4Y1,RPL36A,PS...
# GO:0005739  C1D,COX6C,NDUFB4,DGUOK,MRPL36,CCDC90B,CPOX,TXN...
#
#                      go_domain          go_name  n_background_in_go_term  \
# GO:0005515  molecular_function  protein binding                      837
# GO:0005737  cellular_component        cytoplasm                      585
# GO:0005634  cellular_component          nucleus                      606
# GO:0005829  cellular_component          cytosol                      428
# GO:0005739  cellular_component    mitochondrion                      279
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005515                                 95                         9884
# GO:0005737                                 77                         5053
# GO:0005634                                 75                         5678
# GO:0005829                                 45                         2542
# GO:0005739                                 31                         1502
#
#                  p_value  bonferonni_corrected_p_value          modalities
# GO:0005515  1.867096e-74                  3.267419e-72  bimodal,~0,bimodal
# GO:0005737  1.141094e-64                  1.996915e-62  bimodal,~0,bimodal
# GO:0005634  7.182918e-61                  1.257011e-58  bimodal,~0,bimodal
# GO:0005829  2.701466e-33                  4.727565e-31  bimodal,~0,bimodal
# GO:0005739  3.369688e-24                  5.896953e-22  bimodal,~0,bimodal
# bimodal,~0,~0 (803,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000124177,ENSG00000113712,ENSG0000012356...
# GO:0005634  ENSG00000106245,ENSG00000173933,ENSG0000024367...
# GO:0005829  ENSG00000113712,ENSG00000198431,ENSG0000024367...
# GO:0005737  ENSG00000167515,ENSG00000173933,ENSG0000019843...
# GO:0010467  ENSG00000197958,ENSG00000182899,ENSG0000004135...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  CHD6,CSNK1A1,MORF4L2,RBM4,NME1-NME2,ACVR2A,PSM...
# GO:0005634  BUD31,RBM4,NME1-NME2,PSMA4,NEDD8,UBE2L3,MAGOHB...
# GO:0005829  CSNK1A1,TXNRD1,NME1-NME2,PSMA4,RPL12,RPL35,TPI...
# GO:0005737  TRAPPC2L,RBM4,TXNRD1,ACVR2A,PSMA4,UBE2L3,RPL35...
# GO:0010467  RPL12,RPL35A,PSMA4,RPL35,RPL19,RPS18,RPL11,SPC...
#
#                      go_domain          go_name  n_background_in_go_term  \
# GO:0005515  molecular_function  protein binding                      837
# GO:0005634  cellular_component          nucleus                      606
# GO:0005829  cellular_component          cytosol                      428
# GO:0005737  cellular_component        cytoplasm                      585
# GO:0010467  biological_process  gene expression                      273
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005515                                256                         9884
# GO:0005634                                195                         5678
# GO:0005829                                149                         2542
# GO:0005737                                168                         5053
# GO:0010467                                109                          771
#
#                   p_value  bonferonni_corrected_p_value     modalities
# GO:0005515  3.799425e-175                 1.546366e-172  bimodal,~0,~0
# GO:0005634  4.727681e-136                 1.924166e-133  bimodal,~0,~0
# GO:0005829  7.197589e-109                 2.929419e-106  bimodal,~0,~0
# GO:0005737  2.014589e-107                 8.199378e-105  bimodal,~0,~0
# GO:0010467   4.062290e-87                  1.653352e-84  bimodal,~0,~0
# bimodal,~0,~1 (1,)
# 	... empty GO enrichment!
# bimodal,~1,bimodal (89,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000160948,ENSG00000115685,ENSG0000010904...
# GO:0005737  ENSG00000158427,ENSG00000160310,ENSG0000016094...
# GO:0005634  ENSG00000258677,ENSG00000115685,ENSG0000014403...
# GO:0007010  ENSG00000158427,ENSG00000146247,ENSG0000016306...
# GO:0005886  ENSG00000160948,ENSG00000138138,ENSG0000000612...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  VPS28,PPP1R7,WSB1,FEZ1,BBIP1,STAU2,GNAS,DYNC1I...
# GO:0005737  TMSB15B,PRMT2,VPS28,PPP1R7,TPRKB,FEZ1,LRRC49,S...
# GO:0005634  RP11-463D19.2,PPP1R7,TPRKB,PHIP,PRMT2,NDUFAF3,...
# GO:0007010                             TMSB15B,PHIP,SGCB,BPTF
# GO:0005886             VPS28,ATAD1,AP2B1,FEZ1,SYT1,GNAS,NUCB2
#
#                      go_domain                    go_name  \
# GO:0005515  molecular_function            protein binding
# GO:0005737  cellular_component                  cytoplasm
# GO:0005634  cellular_component                    nucleus
# GO:0007010  biological_process  cytoskeleton organization
# GO:0005886  cellular_component            plasma membrane
#
#             n_background_in_go_term  n_features_of_interest_in_go_term  \
# GO:0005515                      837                                 29
# GO:0005737                      585                                 21
# GO:0005634                      606                                 16
# GO:0007010                       13                                  4
# GO:0005886                      144                                  7
#
#             n_features_total_in_go_term       p_value  \
# GO:0005515                         9884  8.448852e-22
# GO:0005737                         5053  2.007949e-16
# GO:0005634                         5678  7.669340e-11
# GO:0007010                          131  7.680216e-10
# GO:0005886                         3897  6.287267e-08
#
#             bonferonni_corrected_p_value          modalities
# GO:0005515                  2.281190e-20  bimodal,~1,bimodal
# GO:0005737                  5.421462e-15  bimodal,~1,bimodal
# GO:0005634                  2.070722e-09  bimodal,~1,bimodal
# GO:0007010                  2.073658e-08  bimodal,~1,bimodal
# GO:0005886                  1.697562e-06  bimodal,~1,bimodal
# bimodal,~1,~1 (131,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000242265,ENSG00000115685,ENSG0000010222...
# GO:0005737  ENSG00000242265,ENSG00000115685,ENSG0000010222...
# GO:0005634  ENSG00000138293,ENSG00000115685,ENSG0000010222...
# GO:0005829  ENSG00000135720,ENSG00000160948,ENSG0000009314...
# GO:0016020  ENSG00000113851,ENSG00000121989,ENSG0000025846...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  PEG10,PPP1R7,USP11,SMC1A,ACVR2A,OLA1,LRRC40,NA...
# GO:0005737  PEG10,PPP1R7,USP11,CLK1,ACVR2A,ACTR1A,OLA1,SMC...
# GO:0005634  NCOA4,PPP1R7,USP11,CLK1,SMC1A,CEP57,INIP,RBM25...
# GO:0005829  DYNC1LI2,VPS28,ECHDC1,CLASP1,PRKAR1A,CRYZL1,SC...
# GO:0016020      CRBN,ACVR2A,RP11-1012A1.4,NKTR,ATF2,KTN1,NAPG
#
#                      go_domain          go_name  n_background_in_go_term  \
# GO:0005515  molecular_function  protein binding                      837
# GO:0005737  cellular_component        cytoplasm                      585
# GO:0005634  cellular_component          nucleus                      606
# GO:0005829  cellular_component          cytosol                      428
# GO:0016020  cellular_component         membrane                       94
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005515                                 35                         9884
# GO:0005737                                 25                         5053
# GO:0005634                                 22                         5678
# GO:0005829                                 14                         2542
# GO:0016020                                  7                         2489
#
#                  p_value  bonferonni_corrected_p_value     modalities
# GO:0005515  2.989141e-22                  1.584245e-20  bimodal,~1,~1
# GO:0005737  1.750616e-16                  9.278263e-15  bimodal,~1,~1
# GO:0005634  3.139371e-13                  1.663867e-11  bimodal,~1,~1
# GO:0005829  1.577318e-08                  8.359784e-07  bimodal,~1,~1
# GO:0016020  5.188573e-08                  2.749944e-06  bimodal,~1,~1
# middle,bimodal,bimodal (2,)
# 	... empty GO enrichment!
# middle,~1,bimodal (1,)
# 	... empty GO enrichment!
# ~0,ambiguous,bimodal (2,)
# 	... empty GO enrichment!
# ~0,bimodal,bimodal (242,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000124177,ENSG00000100387,ENSG0000018852...
# GO:0005634  ENSG00000124177,ENSG00000205581,ENSG0000010624...
# GO:0005737  ENSG00000159131,ENSG00000188529,ENSG0000012102...
# GO:0003677  ENSG00000124177,ENSG00000107625,ENSG0000008522...
# GO:0005524  ENSG00000124177,ENSG00000159131,ENSG0000010762...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  CHD6,RBX1,SRSF10,CAMLG,ZNF326,WHSC1L1,NOP58,AT...
# GO:0005634  CHD6,HMGN1,BUD31,DDX50,NOP58,ATRX,LSMD1,PCBD1,...
# GO:0005737  GART,SRSF10,COPS5,BEX4,MCTS1,HMGN1,NOP58,LSMD1...
# GO:0003677  CHD6,DDX50,ATRX,POLR2H,DDX3X,CSDE1,ZNF326,HP1B...
# GO:0005524  CHD6,GART,DDX50,UBE2K,ATRX,DGUOK,DDX3X,RARS2,C...
#
#                      go_domain          go_name  n_background_in_go_term  \
# GO:0005515  molecular_function  protein binding                      837
# GO:0005634  cellular_component          nucleus                      606
# GO:0005737  cellular_component        cytoplasm                      585
# GO:0003677  molecular_function      DNA binding                      169
# GO:0005524  molecular_function      ATP binding                      173
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005515                                 79                         9884
# GO:0005634                                 66                         5678
# GO:0005737                                 64                         5053
# GO:0003677                                 25                         2282
# GO:0005524                                 24                         1662
#
#                  p_value  bonferonni_corrected_p_value          modalities
# GO:0005515  1.730868e-55                  2.180894e-53  ~0,bimodal,bimodal
# GO:0005634  3.726149e-50                  4.694948e-48  ~0,bimodal,bimodal
# GO:0005737  9.783213e-49                  1.232685e-46  ~0,bimodal,bimodal
# GO:0003677  2.446222e-23                  3.082239e-21  ~0,bimodal,bimodal
# GO:0005524  8.707265e-22                  1.097115e-19  ~0,bimodal,bimodal
# ~0,bimodal,~0 (276,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000131711,ENSG00000148484,ENSG0000012356...
# GO:0005634  ENSG00000081721,ENSG00000170035,ENSG0000013313...
# GO:0005737  ENSG00000081721,ENSG00000120265,ENSG0000013313...
# GO:0005829  ENSG00000131711,ENSG00000148484,ENSG0000019711...
# GO:0008270  ENSG00000092140,ENSG00000081721,ENSG0000013653...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  MAP1B,RSU1,MORF4L2,COPS5,PPIL3,KDM5B,DAP3,LSM1...
# GO:0005634  DUSP12,UBE2E3,BEX2,COPS5,KDM5B,DAP3,PCBP2,SF3B...
# GO:0005737  DUSP12,PCMT1,BEX2,COPS5,USP9Y,PCBP2,CHD4,PPP1R...
# GO:0005829  MAP1B,RSU1,PCBP2,RPL37A,RPL31,AK1,AKAP9,GNAS,R...
# GO:0008270  G2E3,DUSP12,MARCH7,ZC3H11A,BPTF,ZMYM5,CRYZL1,K...
#
#                      go_domain           go_name  n_background_in_go_term  \
# GO:0005515  molecular_function   protein binding                      837
# GO:0005634  cellular_component           nucleus                      606
# GO:0005737  cellular_component         cytoplasm                      585
# GO:0005829  cellular_component           cytosol                      428
# GO:0008270  molecular_function  zinc ion binding                      123
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005515                                 82                         9884
# GO:0005634                                 68                         5678
# GO:0005737                                 64                         5053
# GO:0005829                                 43                         2542
# GO:0008270                                 20                         2200
#
#                  p_value  bonferonni_corrected_p_value     modalities
# GO:0005515  8.612069e-54                  1.119569e-51  ~0,bimodal,~0
# GO:0005634  2.436968e-48                  3.168059e-46  ~0,bimodal,~0
# GO:0005737  8.972115e-45                  1.166375e-42  ~0,bimodal,~0
# GO:0005829  8.810446e-29                  1.145358e-26  ~0,bimodal,~0
# GO:0008270  7.714816e-19                  1.002926e-16  ~0,bimodal,~0
# ~0,bimodal,~1 (11,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000070831,ENSG00000163875,ENSG0000020484...
# GO:0005737  ENSG00000070831,ENSG00000163875,ENSG0000020484...
#
#            features_of_interest_in_go_term_gene_symbols           go_domain  \
# GO:0005515                CDC42,MEAF6,DCTN1,ANKUB1,PFN2  molecular_function
# GO:0005737                       CDC42,MEAF6,DCTN1,PFN2  cellular_component
#
#                     go_name  n_background_in_go_term  \
# GO:0005515  protein binding                      837
# GO:0005737        cytoplasm                      585
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005515                                  5                         9884
# GO:0005737                                  4                         5053
#
#                  p_value  bonferonni_corrected_p_value     modalities
# GO:0005515  8.992028e-07                      0.000002  ~0,bimodal,~1
# GO:0005737  4.105414e-06                      0.000008  ~0,bimodal,~1
# ~0,~0,bimodal (819,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000116586,ENSG00000162664,ENSG0000017393...
# GO:0005737  ENSG00000166986,ENSG00000173933,ENSG0000019843...
# GO:0005634  ENSG00000106245,ENSG00000162664,ENSG0000025867...
# GO:0005829  ENSG00000166986,ENSG00000198431,ENSG0000011495...
# GO:0005739  ENSG00000130770,ENSG00000243147,ENSG0000010376...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  LAMTOR2,ZNF326,RBM4,SERBP1,XRN2,ACVR2A,WDR61,S...
# GO:0005737  MARS,RBM4,TXNRD1,ACVR2A,GART,WDR61,HMGCS1,PPIG...
# GO:0005634  BUD31,ZNF326,RP11-463D19.2,RBM4,SERBP1,XRN2,ZN...
# GO:0005829  MARS,TXNRD1,DGUOK,KLC1,ARF1,SRRM1,PSMD1,CDC42,...
# GO:0005739  ATPIF1,MRPL33,RAB11A,MARS,FDPS,PNKD,MRPL52,FUN...
#
#                      go_domain          go_name  n_background_in_go_term  \
# GO:0005515  molecular_function  protein binding                      837
# GO:0005737  cellular_component        cytoplasm                      585
# GO:0005634  cellular_component          nucleus                      606
# GO:0005829  cellular_component          cytosol                      428
# GO:0005739  cellular_component    mitochondrion                      279
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005515                                227                         9884
# GO:0005737                                168                         5053
# GO:0005634                                165                         5678
# GO:0005829                                 91                         2542
# GO:0005739                                 73                         1502
#
#                   p_value  bonferonni_corrected_p_value     modalities
# GO:0005515  6.952557e-141                 2.683687e-138  ~0,~0,bimodal
# GO:0005737  2.940399e-107                 1.134994e-104  ~0,~0,bimodal
# GO:0005634  3.484542e-101                  1.345033e-98  ~0,~0,bimodal
# GO:0005829   1.169417e-45                  4.513950e-43  ~0,~0,bimodal
# GO:0005739   1.353258e-43                  5.223576e-41  ~0,~0,bimodal
# ~0,~0,~0 (10263,)
#                               features_of_interest_in_go_term  \
# GO:0097193  ENSG00000213190,ENSG00000215301,ENSG0000018404...
# GO:0030049  ENSG00000092841,ENSG00000026025,ENSG0000014354...
# GO:0022857  ENSG00000165629,ENSG00000167863,ENSG0000011645...
# GO:0021766  ENSG00000108953,ENSG00000164405,ENSG0000019659...
# GO:0006119  ENSG00000165629,ENSG00000140740,ENSG0000001025...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0097193                   MLLT11,DDX3X,DIABLO,APOPT1,BNIP3
# GO:0030049                           MYL6,VIM,TPM3,TPM1,MYL6B
# GO:0022857  ATP5C1,ATP5H,ATP5F1,ATP5E,ATP5A1,ATP5I,ATP5J2,...
# GO:0021766               YWHAE,UQCRQ,HDAC2,NME2,NME1,MDK,MKKS
# GO:0006119               ATP5C1,UQCRC2,UQCRC1,UQCRH,AK2,UQCRB
#
#                      go_domain                                go_name  \
# GO:0097193  biological_process  intrinsic apoptotic signaling pathway
# GO:0030049  biological_process                muscle filament sliding
# GO:0022857  molecular_function     transmembrane transporter activity
# GO:0021766  biological_process                hippocampus development
# GO:0006119  biological_process              oxidative phosphorylation
#
#             n_background_in_go_term  n_features_of_interest_in_go_term  \
# GO:0097193                        5                                  5
# GO:0030049                        5                                  5
# GO:0022857                       12                                 12
# GO:0021766                        7                                  7
# GO:0006119                        6                                  6
#
#             n_features_total_in_go_term  p_value  \
# GO:0097193                           25        0
# GO:0030049                           37        0
# GO:0022857                           72        0
# GO:0021766                           42        0
# GO:0006119                           14        0
#
#             bonferonni_corrected_p_value modalities
# GO:0097193                             0   ~0,~0,~0
# GO:0030049                             0   ~0,~0,~0
# GO:0022857                             0   ~0,~0,~0
# GO:0021766                             0   ~0,~0,~0
# GO:0006119                             0   ~0,~0,~0
# ~0,~0,~1 (8,)
#                             features_of_interest_in_go_term  \
# GO:0005737  ENSG00000070831,ENSG00000163875,ENSG00000133884
# GO:0005515  ENSG00000070831,ENSG00000163875,ENSG00000133884
#
#            features_of_interest_in_go_term_gene_symbols           go_domain  \
# GO:0005737                             CDC42,MEAF6,DPF2  cellular_component
# GO:0005515                             CDC42,MEAF6,DPF2  molecular_function
#
#                     go_name  n_background_in_go_term  \
# GO:0005737        cytoplasm                      585
# GO:0005515  protein binding                      837
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005737                                  3                         5053
# GO:0005515                                  3                         9884
#
#              p_value  bonferonni_corrected_p_value modalities
# GO:0005737  0.000017                      0.000034   ~0,~0,~1
# GO:0005515  0.000070                      0.000139   ~0,~0,~1
# ~0,~1,~1 (2,)
# 	... empty GO enrichment!
# ~1,ambiguous,bimodal (2,)
# 	... empty GO enrichment!
# ~1,bimodal,bimodal (378,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000152234,ENSG00000162664,ENSG0000024367...
# GO:0005634  ENSG00000162664,ENSG00000243678,ENSG0000016388...
# GO:0005737  ENSG00000205581,ENSG00000113013,ENSG0000007075...
# GO:0005829  ENSG00000148484,ENSG00000135930,ENSG0000016971...
# GO:0003723  ENSG00000170144,ENSG00000232119,ENSG0000019711...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  ATP5A1,ZNF326,NME1-NME2,NSL1,RPL11,OCIAD1,RPL1...
# GO:0005634  ZNF326,NME1-NME2,POLR2H,NSL1,SNURF,DCUN1D4,SLT...
# GO:0005737  HMGN1,HSPA9,PABPC1,HNRNPK,EIF4E2,UBE2K,NSL1,DG...
# GO:0005829  RSU1,EIF4E2,CNBP,RPL35A,NME1-NME2,ECHDC1,DGUOK...
# GO:0003723  HNRNPA3,MCTS1,PCBP2,RPL8,RPL31,HNRNPK,DDX3X,CS...
#
#                      go_domain          go_name  n_background_in_go_term  \
# GO:0005515  molecular_function  protein binding                      837
# GO:0005634  cellular_component          nucleus                      606
# GO:0005737  cellular_component        cytoplasm                      585
# GO:0005829  cellular_component          cytosol                      428
# GO:0003723  molecular_function      RNA binding                      204
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005515                                105                         9884
# GO:0005634                                 86                         5678
# GO:0005737                                 77                         5053
# GO:0005829                                 63                         2542
# GO:0003723                                 45                          703
#
#                  p_value  bonferonni_corrected_p_value          modalities
# GO:0005515  8.117952e-65                  1.436877e-62  ~1,bimodal,bimodal
# GO:0005634  2.541201e-57                  4.497926e-55  ~1,bimodal,bimodal
# GO:0005737  9.152073e-49                  1.619917e-46  ~1,bimodal,bimodal
# GO:0005829  5.093933e-43                  9.016262e-41  ~1,bimodal,bimodal
# GO:0003723  2.005789e-39                  3.550246e-37  ~1,bimodal,bimodal
# ~1,bimodal,~0 (7,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000206199,ENSG00000174748,ENSG0000020484...
# GO:0005829    ENSG00000204843,ENSG00000156976,ENSG00000174748
# GO:0005737    ENSG00000086666,ENSG00000204843,ENSG00000070087
#
#            features_of_interest_in_go_term_gene_symbols           go_domain  \
# GO:0005515        ANKUB1,RPL15,DCTN1,EIF4A2,ZFAND6,PFN2  molecular_function
# GO:0005829                           DCTN1,EIF4A2,RPL15  cellular_component
# GO:0005737                            ZFAND6,DCTN1,PFN2  cellular_component
#
#                     go_name  n_background_in_go_term  \
# GO:0005515  protein binding                      837
# GO:0005829          cytosol                      428
# GO:0005737        cytoplasm                      585
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005515                                  6                         9884
# GO:0005829                                  3                         2542
# GO:0005737                                  3                         5053
#
#                  p_value  bonferonni_corrected_p_value     modalities
# GO:0005515  1.261850e-09                  3.785550e-09  ~1,bimodal,~0
# GO:0005829  8.836399e-06                  2.650920e-05  ~1,bimodal,~0
# GO:0005737  3.020265e-05                  9.060794e-05  ~1,bimodal,~0
# ~1,bimodal,~1 (217,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000148484,ENSG00000123545,ENSG0000012356...
# GO:0005634  ENSG00000133134,ENSG00000117139,ENSG0000024367...
# GO:0005737  ENSG00000133134,ENSG00000111642,ENSG0000008571...
# GO:0006351  ENSG00000163320,ENSG00000131051,ENSG0000012356...
# GO:0006355  ENSG00000163320,ENSG00000131051,ENSG0000010496...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  RSU1,NDUFAF4,MORF4L2,KDM5B,NME1-NME2,SF3B2,CPN...
# GO:0005634  BEX2,KDM5B,NME1-NME2,CHD4,MORF4L2,CDK11A,PTOV1...
# GO:0005737  BEX2,CHD4,CPNE3,CDK11A,TP53BP1,AKAP9,GNAS,SRP1...
# GO:0006351  CGGBP1,RBM39,MORF4L2,PTOV1,BAZ2B,KDM5B,NME1-NM...
# GO:0006355  CGGBP1,RBM39,PTOV1,BACH1,NME1-NME2,CHD4,TCEAL4...
#
#                      go_domain                                     go_name  \
# GO:0005515  molecular_function                             protein binding
# GO:0005634  cellular_component                                     nucleus
# GO:0005737  cellular_component                                   cytoplasm
# GO:0006351  biological_process                transcription, DNA-dependent
# GO:0006355  biological_process  regulation of transcription, DNA-dependent
#
#             n_background_in_go_term  n_features_of_interest_in_go_term  \
# GO:0005515                      837                                 59
# GO:0005634                      606                                 46
# GO:0005737                      585                                 39
# GO:0006351                      151                                 17
# GO:0006355                      113                                 15
#
#             n_features_total_in_go_term       p_value  \
# GO:0005515                         9884  1.004351e-36
# GO:0005634                         5678  4.134322e-30
# GO:0005737                         5053  1.382286e-23
# GO:0006351                         2018  2.615238e-15
# GO:0006355                         2106  6.022234e-15
#
#             bonferonni_corrected_p_value     modalities
# GO:0005515                  8.034810e-35  ~1,bimodal,~1
# GO:0005634                  3.307458e-28  ~1,bimodal,~1
# GO:0005737                  1.105829e-21  ~1,bimodal,~1
# GO:0006351                  2.092191e-13  ~1,bimodal,~1
# GO:0006355                  4.817787e-13  ~1,bimodal,~1
# ~1,~0,~0 (2,)
# 	... empty GO enrichment!
# ~1,~1,bimodal (702,)
#                               features_of_interest_in_go_term  \
# GO:0005515  ENSG00000116586,ENSG00000173933,ENSG0000008893...
# GO:0005634  ENSG00000258677,ENSG00000173933,ENSG0000012248...
# GO:0005737  ENSG00000166986,ENSG00000173933,ENSG0000012248...
# GO:0005739  ENSG00000109180,ENSG00000135900,ENSG0000016698...
# GO:0005829  ENSG00000074201,ENSG00000166986,ENSG0000010635...
#
#                  features_of_interest_in_go_term_gene_symbols  \
# GO:0005515  LAMTOR2,RBM4,XRN2,ACVR2A,VPS72,NSFL1C,NGFRAP1,...
# GO:0005634  RP11-463D19.2,RBM4,RPAP2,XRN2,VPS72,ZNF644,NSF...
# GO:0005737  MARS,RBM4,RPAP2,ACVR2A,POLR2H,NGFRAP1,CSDE1,ME...
# GO:0005739  OCIAD1,MRPL44,MARS,PTCD1,PMPCB,PNKD,MRPL52,MRP...
# GO:0005829  CLNS1A,MARS,LSM5,VPS36,EIF2B3,PCBD1,PCBP2,CDC2...
#
#                      go_domain          go_name  n_background_in_go_term  \
# GO:0005515  molecular_function  protein binding                      837
# GO:0005634  cellular_component          nucleus                      606
# GO:0005737  cellular_component        cytoplasm                      585
# GO:0005739  cellular_component    mitochondrion                      279
# GO:0005829  cellular_component          cytosol                      428
#
#             n_features_of_interest_in_go_term  n_features_total_in_go_term  \
# GO:0005515                                149                         9884
# GO:0005634                                121                         5678
# GO:0005737                                114                         5053
# GO:0005739                                 60                         1502
# GO:0005829                                 65                         2542
#
#                  p_value  bonferonni_corrected_p_value     modalities
# GO:0005515  2.108567e-73                  5.693131e-71  ~1,~1,bimodal
# GO:0005634  3.148397e-65                  8.500673e-63  ~1,~1,bimodal
# GO:0005737  3.129706e-60                  8.450205e-58  ~1,~1,bimodal
# GO:0005739  8.588691e-35                  2.318947e-32  ~1,~1,bimodal
# GO:0005829  4.663333e-28                  1.259100e-25  ~1,~1,bimodal
# ~1,~1,~0 (7,)
# 	... empty GO enrichment!
# ~1,~1,~1 (7405,)
#                               features_of_interest_in_go_term  \
# GO:0000028  ENSG00000137154,ENSG00000184779,ENSG0000016802...
# GO:0016323  ENSG00000117335,ENSG00000120509,ENSG0000008082...
# GO:0016281  ENSG00000110321,ENSG00000151247,ENSG0000006304...
# GO:0016272  ENSG00000143256,ENSG00000155959,ENSG0000010113...
# GO:0016209  ENSG00000126432,ENSG00000122378,ENSG0000011759...
#
#            features_of_interest_in_go_term_gene_symbols           go_domain  \
# GO:0000028           RPS6,RPS17,RPSA,RPS17L,RPS25,RPS14  biological_process
# GO:0016323          CD46,PDZD11,HSP90AA1,CXADR,HSP90AB1  cellular_component
# GO:0016281      EIF4G2,EIF4E,EIF4B,EIF4G3,EIF4A1,EIF4A2  cellular_component
# GO:0016272             PFDN2,VBP1,PFDN4,PFDN5,PFDN1,UXT  cellular_component
# GO:0016209        PRDX5,FAM213A,PRDX6,PRDX2,PRDX3,PRDX1  molecular_function
#
#                                                       go_name  \
# GO:0000028                   ribosomal small subunit assembly
# GO:0016323                        basolateral plasma membrane
# GO:0016281  eukaryotic translation initiation factor 4F co...
# GO:0016272                                  prefoldin complex
# GO:0016209                               antioxidant activity
#
#             n_background_in_go_term  n_features_of_interest_in_go_term  \
# GO:0000028                        6                                  6
# GO:0016323                        5                                  5
# GO:0016281                        6                                  6
# GO:0016272                        6                                  6
# GO:0016209                        6                                  6
#
#             n_features_total_in_go_term  p_value  \
# GO:0000028                            8        0
# GO:0016323                          144        0
# GO:0016281                           10        0
# GO:0016272                           15        0
# GO:0016209                           33        0
#
#             bonferonni_corrected_p_value modalities
# GO:0000028                             0   ~1,~1,~1
# GO:0016323                             0   ~1,~1,~1
# GO:0016281                             0   ~1,~1,~1
# GO:0016272                             0   ~1,~1,~1
# GO:0016209                             0   ~1,~1,~1

# %%
g = sns.FacetGrid(go_df_subset, row='modalities', size=2, aspect=3, 
                  row_order=relevant_modality_groups.index, sharey=False)
g.map_dataframe(plot_go_enrichment, x_col=u'bonferonni_corrected_p_value', max_categories=5, color='lightgrey')
g.set(title='')
g.fig.savefig('{}/modalities_across_celltypes_go_enrichment.pdf'.format(folder))

# %% [markdown]
# ### Enrichment of this modality, within phenotype
#
# i.e. *"What GO categories are iPSC bimodal events enriched for, compared to other modalities in iPSC?"*

# %%
for (phenotype), phenotype_df in study.supplemental.modalities_tidy.groupby(['phenotype']):
    print phenotype
    background = study.splicing.splicing_to_expression_id(phenotype_df.event_name)
    for modality, modality_df in phenotype_df.groupby('modality'):
        print '\t', modality
        modality_genes = study.splicing.splicing_to_expression_id(modality_df.event_name)
        go = study.go_enrichment(modality_genes, background, p_value_cutoff=0.01)
        if go is None or go.empty:
            print '... empty GO enrichment!'
            continue
        fig, ax = plt.subplots(figsize=(8, 4))
        ax = plot_go_enrichment(data=go)
        ax.set_title('{} {}'.format(phenotype, modality))
        fig = plt.gcf()
        fig.tight_layout()
        fig.savefig('{}/modality_go_enrichment_within_celltype_{}_{}.pdf'.format(folder, modality, phenotype))
# Out:
# MN
# 	bimodal
# 	~0
# 	~1
# NPC
# 	ambiguous
# ... empty GO enrichment!
# 	bimodal
# 	~0
# 	~1
# iPSC
# 	ambiguous
# 	bimodal
# 	middle
# ... empty GO enrichment!
# 	~0
# 	~1

# %% [markdown]
# ### Enrichment of this modality, across phenotypes
#
# i.e. *"What GO categories are iPSC bimodal events enriched for, compared to bimodal events in NPC and MN?"*

# %%
import itertools

modalities_all_celltypes = study.supplemental.modalities_tidy.groupby('event_name').filter(
    lambda x: len(x)==len(study.phenotype_order))

for (phenotype), phenotype_df in modalities_all_celltypes.groupby(['modality']):
    print phenotype
    background = study.splicing.splicing_to_expression_id(phenotype_df.event_name)
    for modality, modality_df in phenotype_df.groupby('phenotype'):
        print '\t', modality
        modality_genes = study.splicing.splicing_to_expression_id(modality_df.event_name)
        go = study.go_enrichment(modality_genes, background, p_value_cutoff=0.01)
        if go is None or go.empty:
            print '\t... empty GO enrichment!'
            continue
        fig, ax = plt.subplots(figsize=(8, 4))
        ax = plot_go_enrichment(data=go)
        ax.set_title('{} {}'.format(phenotype, modality))
        fig = plt.gcf()
#         fig.tight_layout()
        fig.savefig('{}/modality_go_enrichment_across_celltypes_{}_{}.pdf'.format(folder, modality, phenotype))
# Out:
# bimodal
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-a11348570658> in <module>()
#       6 for (phenotype), phenotype_df in modalities_all_celltypes.groupby(['modality']):
#       7     print phenotype
# ----> 8     background = study.splicing.splicing_to_expression_id(phenotype_df.event_name)
#       9     for modality, modality_df in phenotype_df.groupby('phenotype'):
#      10         print '\t', modality
#
# /home/obotvinnik/workspace-git/flotilla/flotilla/data_model/splicing.pyc in splicing_to_expression_id(self, feature_ids)
#     536     def splicing_to_expression_id(self, feature_ids):
#     537         """Get the gene ids corresponding to the splicing ids provided"""
# --> 538         return list(chain(*self.feature_data[self.feature_expression_id_col][
#     539             feature_ids].str.split(',').dropna().values))
#     540
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1082         res = cache.get(item)
#    1083         if res is None:
# -> 1084             values = self._data.get(item)
#    1085             res = self._box_item_values(item, values)
#    1086             cache[item] = res
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    2849
#    2850             if not isnull(item):
# -> 2851                 loc = self.items.get_loc(item)
#    2852             else:
#    2853                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method)
#    1570         """
#    1571         if method is None:
# -> 1572             return self._engine.get_loc(_values_from_object(key))
#    1573
#    1574         indexer = self.get_indexer([key], method=method)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3824)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3704)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12280)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12231)()
#
# KeyError: u'ensembl_gene'

# %% [markdown]
# ### Enrichment of this modality vs all other modalities across phenotypes
#
# i.e. *"What GO categories are bimodal events in iPSC, NPC and MN enriched for, over other modalities in those celltypes?"*

# %%
import itertools

background = study.splicing.splicing_to_expression_id(modalities_all_celltypes.event_name)


for (group), df1 in modalities_all_celltypes.groupby(['modality']):
    print group
    foreground = study.splicing.splicing_to_expression_id(df1.event_name)
    go = study.go_enrichment(foreground, background, p_value_cutoff=0.1)
    if go is None or go.empty:
        print '\t... empty GO enrichment!'
        continue

    ax = plot_go_enrichment(data=go)
    ax.set_title(group)
    fig = plt.gcf()
    fig.tight_layout()
    fig.savefig('{}/modality_go_enrichment_across_celltypes_{}.pdf'.format(folder, group))
# Out:
# ambiguous
# bimodal
# middle
# 	... empty GO enrichment!
# ~0
# ~1

# %% [markdown]
# ### Enrichment of events which change (or don't change) modality

# %%
changing_modalities = modalities_all_celltypes_no_constitutive.groupby('event_name').filter(
    lambda x: x.modality.unique().shape[0] > 1)

# %% [markdown]
# ### Make bed files of modality exons

# %%
# %%time 
import pybedtools

bed_folder = '/projects/ps-yeolab/obotvinnik/singlecell_pnms/figure3_modalities/'

DIR = '/projects/ps-yeolab/obotvinnik/singlecell_pnms'

# upstream400 = pybedtools.BedTool('{}/se_mxe_alt_exon_upstream400.bed'.format(DIR))
# downstream400 = pybedtools.BedTool('{}/se_mxe_alt_exon_downstream400.bed'.format(DIR))e
exon_5p = pybedtools.BedTool('{}/exon_5p.bed'.format(DIR))
exon_3p = pybedtools.BedTool('{}/exon_3p.bed'.format(DIR))

exons = {'exon_5p': exon_5p, 'exon_3p': exon_3p}

for (phenotype, modality), df in study.supplemental.modalities_tidy.groupby(['phenotype', 'modality']):
    event_names = set(df.event_name.values)
    for name, bed in exons.items():
        phenotype_modality_bed = bed.filter(lambda x: x.name in event_names)
        filename = '{}/{}_exonbody_{}_{}.bed'.format(bed_folder, name, phenotype, modality)
        phenotype_modality_bed.saveas(filename)
        ! wc -l $filename

# %%
mkdir /home/obotvinnik/projects/singlecell_pnms/analysis/homer/
# Out:
# mkdir: cannot create directory `/home/obotvinnik/projects/singlecell_pnms/analysis/homer/': File exists

# %% [markdown]
# ## HOMER enrichment

# %%
homer_dir = '/home/obotvinnik/projects/singlecell_pnms/analysis/homer'

# %% [markdown]
# ### First extract upstream/downstream intron sequences

# %%
import os
import glob
import pybedtools

nt = 400

bed_folder = '/projects/ps-yeolab/obotvinnik/singlecell_pnms/figure3_modalities/'

for bedfile in glob.iglob('{}/exon*p_exonbody*.bed'.format(bed_folder)):
    basename = os.path.basename(bedfile)
    print basename
    prefix = basename.split('.bed')[0]
    bed = pybedtools.BedTool(bedfile)
    
    if basename.startswith('exon_5p'):
        # Get downstream intron
        intron = bed.flank(l=0, r=nt, s=True, g=pybedtools.chromsizes('hg19'))
        name = 'downstream'
    else:
        intron = bed.flank(l=nt, r=0, s=True, g=pybedtools.chromsizes('hg19'))
        name = 'upstream'
    
    # Saved every exon that was exactly upstream or downstream of a junction,
    # So when taking the flanking sequence, there's a lot of repetition
    unique = pybedtools.BedTool(list(set(x for x in intron)))
    
    
    print '\t', len(intron), len(unique)
    saveas = '{}/{}_{}{}.bed'.format(homer_dir, prefix, name, nt)
    print '\t', saveas
    unique.saveas(saveas)
# Out:
# exon_5p_exonbody_MN_bimodal.bed
# 	30297 2480
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_bimodal_downstream400.bed
# exon_3p_exonbody_iPSC_~0.bed
# 	83691 14300
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_~0_upstream400.bed
# exon_5p_exonbody_iPSC_~0.bed
# 	140881 14910
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_~0_downstream400.bed
# exon_5p_exonbody_MN_ambiguous.bed
# 	0 0
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_ambiguous_downstream400.bed
# exon_5p_exonbody_MN_constitutively0.bed
# 	88455 9375
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_constitutively0_downstream400.bed
# exon_3p_exonbody_MN_~0.bed
# 	21035 3408
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_~0_upstream400.bed
# exon_3p_exonbody_iPSC_constitutively1.bed
# 	99526 20030
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_constitutively1_upstream400.bed
# exon_3p_exonbody_iPSC_bimodal.bed
# 	46599 7776
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_bimodal_upstream400.bed
# exon_3p_exonbody_MN_bimodal.bed
# 	16016 2476
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_bimodal_upstream400.bed
# exon_5p_exonbody_NPC_bimodal.bed
# 	46211 4022
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_bimodal_downstream400.bed
# exon_5p_exonbody_iPSC_~1.bed
# 	60557 8698
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_~1_downstream400.bed
# exon_3p_exonbody_iPSC_~1.bed
# 	50298 8685
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_~1_upstream400.bed
# exon_3p_exonbody_iPSC_middle.bed
# 	17 2
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_middle_upstream400.bed
# exon_5p_exonbody_iPSC_ambiguous.bed
# 	251 25
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_ambiguous_downstream400.bed
# exon_3p_exonbody_NPC_middle.bed
# 	9 1
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_middle_upstream400.bed
# exon_3p_exonbody_MN_middle.bed
# 	0 0
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_middle_upstream400.bed
# exon_3p_exonbody_NPC_bimodal.bed
# 	28631 4051
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_bimodal_upstream400.bed
# exon_3p_exonbody_MN_~1.bed
# 	13799 2129
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_~1_upstream400.bed
# exon_3p_exonbody_iPSC_constitutively0.bed
# 	66322 12009
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_constitutively0_upstream400.bed
# exon_5p_exonbody_MN_constitutively1.bed
# 	34534 8162
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_constitutively1_downstream400.bed
# exon_5p_exonbody_iPSC_middle.bed
# 	19 3
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_middle_downstream400.bed
# exon_5p_exonbody_NPC_middle.bed
# 	3 3
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_middle_downstream400.bed
# exon_5p_exonbody_MN_middle.bed
# 	0 0
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_middle_downstream400.bed
# exon_5p_exonbody_iPSC_constitutively1.bed
# 	70889 20030
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_constitutively1_downstream400.bed
# exon_3p_exonbody_MN_ambiguous.bed
# 	1 1
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_ambiguous_upstream400.bed
# exon_5p_exonbody_NPC_~0.bed
# 	79110 7608
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_~0_downstream400.bed
# exon_5p_exonbody_iPSC_bimodal.bed
# 	77239 7813
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_bimodal_downstream400.bed
# exon_3p_exonbody_MN_constitutively1.bed
# 	50305 8199
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_constitutively1_upstream400.bed
# exon_5p_exonbody_MN_~0.bed
# 	34678 3468
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_~0_downstream400.bed
# exon_3p_exonbody_NPC_constitutively0.bed
# 	69797 12003
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_constitutively0_upstream400.bed
# exon_3p_exonbody_NPC_~0.bed
# 	48301 7304
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_~0_upstream400.bed
# exon_5p_exonbody_NPC_constitutively0.bed
# 	108514 12556
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_constitutively0_downstream400.bed
# exon_5p_exonbody_NPC_ambiguous.bed
# 	3 3
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_ambiguous_downstream400.bed
# exon_3p_exonbody_NPC_ambiguous.bed
# 	3 3
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_ambiguous_upstream400.bed
# exon_3p_exonbody_iPSC_ambiguous.bed
# 	258 30
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_ambiguous_upstream400.bed
# exon_3p_exonbody_MN_constitutively0.bed
# 	55409 9029
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_constitutively0_upstream400.bed
# exon_5p_exonbody_MN_~1.bed
# 	18958 2148
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_~1_downstream400.bed
# exon_5p_exonbody_NPC_~1.bed
# 	38027 4675
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_~1_downstream400.bed
# exon_5p_exonbody_iPSC_constitutively0.bed
# 	102605 12705
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_constitutively0_downstream400.bed
# exon_5p_exonbody_NPC_constitutively1.bed
# 	48632 12033
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_constitutively1_downstream400.bed
# exon_3p_exonbody_NPC_~1.bed
# 	29753 4667
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_~1_upstream400.bed
# exon_3p_exonbody_NPC_constitutively1.bed
# 	66831 12027
# 	/home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_constitutively1_upstream400.bed

# %% [markdown]
# ### Enrichment of modality trios
#
# #### Background:  all other modality trios

# %%
import os
from gscripts.qtools import Submitter
import glob


findMotifsGenome = '/home/yeo-lab/software/homer/bin/findMotifsGenome.pl'
n_processors = 4
homer_flags = '-rna -len 4,5,6,7 -mset vertebrates -mis 1 -p {}'.format(n_processors)

commands = []


for bedfile in glob.iglob('{}/exon_*p_exonbody*.bed'.format(homer_dir)):
    if 'background' in bedfile:
        continue
    
    basename = os.path.basename(bedfile)
    prefix = basename.split('.')[0]
    modality = prefix.split('_')[4]
    if modality.startswith('constitutively'):
        continue
    
    background = bedfile.replace(modality, modality+ '_background')
    out_dir = bedfile.replace('.bed', '_vs_other_modality_trios')
    command = '{} {} hg19 {} -bg {} {}'.format(
        findMotifsGenome, bedfile, out_dir, background, homer_flags)
    print '\n', command
    commands.append(command)
#     ! $command
jobname = 'homer_vs_other_modality_trios'
sub = Submitter(commands, jobname, walltime='2:00:00', queue='home-scrm',
               ppn=n_processors, write_and_submit=True, array=True,
               out_filename='{}/{}.out'.format(homer_dir, jobname),
               err_filename='{}/{}.err'.format(homer_dir, jobname),
               )

# %% [markdown]
# ### Enrichment of phenotype-specific modalities
#
# #### Background: constitutively spliced exons

# %%
import os
from gscripts.qtools import Submitter
import glob


findMotifsGenome = '/home/yeo-lab/software/homer/bin/findMotifsGenome.pl'
n_processors = 4
homer_flags = '-rna -len 4,5,6,7 -mset vertebrates -mis 1 -p {}'.format(n_processors)

commands = []


for bedfile in glob.iglob('{}/exon_*p_exonbody*.bed'.format(homer_dir)):

    basename = os.path.basename(bedfile)
    prefix = basename.split('.')[0]
    modality = prefix.split('_')[4]
    if modality.startswith('constitutively'):
        continue
    
    background = bedfile.replace(modality, 'constitutively1')
    out_dir = bedfile.replace('.bed', '_vs_constitutively1')
    command = '{} {} hg19 {} -bg {} {}'.format(
        findMotifsGenome, bedfile, out_dir, background, homer_flags)
    print '\n', command
    commands.append(command)
#     ! $command
jobname = 'homer_vs_constitutively1'
sub = Submitter(commands, jobname, walltime='2:00:00', queue='home-scrm',
               ppn=n_processors, write_and_submit=True, array=True,
               out_filename='{}/{}.out'.format(homer_dir, jobname),
               err_filename='{}/{}.err'.format(homer_dir, jobname),
               )
# Out:
# running 30 tasks as an array-job.
# job ID: 3133883
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_bimodal_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_bimodal_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_~0_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_~0_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_~1_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_~1_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_~1_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_~1_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_bimodal_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_bimodal_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_~1_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_~1_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_~1_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_~1_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_~0_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_~0_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_bimodal_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_bimodal_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_middle_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_middle_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_~0_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_~0_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_middle_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_middle_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_middle_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_middle_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_ambiguous_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_ambiguous_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_ambiguous_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_ambiguous_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_ambiguous_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_ambiguous_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_ambiguous_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_ambiguous_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_ambiguous_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_ambiguous_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_~0_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_~0_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_~1_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_~1_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_ambiguous_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_ambiguous_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_bimodal_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_bimodal_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_bimodal_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_bimodal_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_middle_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_middle_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_~0_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_~0_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_middle_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_middle_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_~0_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_~0_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_~1_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_~1_downstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_constitutively1_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_middle_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_middle_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_bimodal_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_bimodal_upstream400_vs_constitutively1 -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_constitutively1_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4

# %% [markdown]
# #### Background: All other modalities, within that celltype

# %%
import os
import fileinput

from gscripts.qtools import Submitter
import glob
import itertools

findMotifsGenome = '/home/yeo-lab/software/homer/bin/findMotifsGenome.pl'
n_processors = 4
homer_flags = '-rna -len 4,5,6,7 -mset vertebrates -mis 1 -p {}'.format(n_processors)

commands = []


for bedfile in glob.iglob('{}/exon_*p_exonbody*.bed'.format(homer_dir)):

    basename = os.path.basename(bedfile)
    prefix = basename.split('.')[0]
    modality = prefix.split('_')[4]
    if modality.startswith('constitutively') or 'other' in basename or 'background' in basename:
        continue
    
    background = bedfile.replace(modality, modality + '_alternative_background')
    background_filenames = (x for x in glob.iglob(bedfile.replace(modality, '*'))
                           if modality not in x and 'constitutively' not in x)
    if not os.path.exists(background):
        with open(background, 'w') as f:
            for filename in background_filenames:
                with open(filename) as g:
                    for line in g:
                        f.write(line)
    
    out_dir = bedfile.replace('.bed', '_vs_alternative_background')
    if os.path.exists('{}/homerResults.html'):
        print 'Already finished {}, moving on'.format(basename)
        continue
    command = '{} {} hg19 {} -bg {} {}'.format(
        findMotifsGenome, bedfile, out_dir, background, homer_flags)
    print '\n', command
    commands.append(command)
#     ! $command
jobname = 'homer_vs_alternative_background'
sub = Submitter(commands, jobname, walltime='4:00:00', queue='home-scrm',
               ppn=n_processors, write_and_submit=True, array=True,
               out_filename='{}/{}.out'.format(homer_dir, jobname),
               err_filename='{}/{}.err'.format(homer_dir, jobname),)
# Out:
# running 30 tasks as an array-job.
# job ID: 3156772
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_bimodal_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_bimodal_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_bimodal_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_~0_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_~0_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_~0_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_~1_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_~1_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_~1_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_~1_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_~1_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_~1_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_bimodal_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_bimodal_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_bimodal_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_~1_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_~1_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_~1_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_~1_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_~1_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_~1_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_~0_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_~0_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_~0_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_bimodal_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_bimodal_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_bimodal_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_middle_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_middle_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_middle_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_~0_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_~0_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_~0_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_middle_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_middle_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_middle_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_middle_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_middle_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_middle_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_ambiguous_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_ambiguous_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_ambiguous_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_ambiguous_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_ambiguous_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_ambiguous_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_ambiguous_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_ambiguous_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_ambiguous_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_ambiguous_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_ambiguous_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_ambiguous_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_ambiguous_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_ambiguous_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_ambiguous_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_~0_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_~0_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_~0_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_~1_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_~1_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_~1_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_ambiguous_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_ambiguous_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_ambiguous_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_bimodal_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_bimodal_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_bimodal_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_bimodal_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_bimodal_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_iPSC_bimodal_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_middle_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_middle_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_middle_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_~0_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_~0_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_~0_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_middle_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_middle_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_NPC_middle_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_~0_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_~0_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_iPSC_~0_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_~1_downstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_~1_downstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_5p_exonbody_MN_~1_alternative_background_downstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_middle_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_middle_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_NPC_middle_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
#
# /home/yeo-lab/software/homer/bin/findMotifsGenome.pl /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_bimodal_upstream400.bed hg19 /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_bimodal_upstream400_vs_alternative_background -bg /home/obotvinnik/projects/singlecell_pnms/analysis/homer/exon_3p_exonbody_MN_bimodal_alternative_background_upstream400.bed -rna -len 4,5,6,7 -mset vertebrates -mis 1 -p 4
