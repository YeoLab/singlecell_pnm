# %%
from __future__ import print_function

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import six

from anchor.visualize import MODALITY_TO_COLOR, MODALITY_ORDER, MODALITY_PALETTE
modality_order = MODALITY_ORDER

sns.set(style='ticks', context='paper', rc={'font.sans-serif':'Arial', 'pdf.fonttype': 42})

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

folder = 'figures' #'/home/obotvinnik/Dropbox/figures2/singlecell_pnm/figure4_voyages'

import flotilla

flotilla_dir = '/projects/ps-yeolab/obotvinnik/flotilla_projects'
study = flotilla.embark('singlecell_pnm_figure4_voyages', flotilla_dir=flotilla_dir)
# Out:
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:810: UserWarning: Found matplotlib configuration in ~/.matplotlib/. To conform with the XDG base directory standard, this configuration location has been deprecated on Linux, and the new location is now /home/obotvinnik/.config/matplotlib/. Please move your configuration there to ensure that matplotlib will continue to find it in the future.
#   _get_xdg_config_dir())
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/flotilla/__init__.py:65: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   load_species_data=load_species_data)
# 2016-08-26 17:20:57	Reading datapackage from /projects/ps-yeolab/obotvinnik/flotilla_projects/singlecell_pnm_figure4_voyages/datapackage.json
# 2016-08-26 17:20:57	Parsing datapackage to create a Study object
# https://s3-us-west-2.amazonaws.com/flotilla-projects/ercc/ERCC_Controls.txt has not been downloaded before.
# 	Downloading now to /home/obotvinnik/flotilla_projects/hg19/ERCC_Controls.txt
# 2016-08-26 17:21:27 	Initializing Study
# 2016-08-26 17:21:27 	Initializing Predictor configuration manager for Study
# 2016-08-26 17:21:27	Predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# 2016-08-26 17:21:27	Added ExtraTreesClassifier to default predictors
# 2016-08-26 17:21:27	Predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# 2016-08-26 17:21:27	Added ExtraTreesRegressor to default predictors
# 2016-08-26 17:21:27	Predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# 2016-08-26 17:21:27	Added GradientBoostingClassifier to default predictors
# 2016-08-26 17:21:27	Predictor GradientBoostingRegressor is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# 2016-08-26 17:21:27	Added GradientBoostingRegressor to default predictors
# 2016-08-26 17:21:32 	Building Gene Ontology database...
# 2016-08-26 17:21:42 		Done
# 2016-08-26 17:21:42 	Loading metadata
# 2016-08-26 17:21:42	Loading expression data
# 2016-08-26 17:21:42	Initializing expression
# 2016-08-26 17:21:43	Done initializing expression
# 2016-08-26 17:21:45	Loading splicing data
# 2016-08-26 17:21:45	Initializing splicing
# 2016-08-26 17:21:45	Done initializing splicing
# 2016-08-26 17:21:45	Successfully initialized a Study object!
# Error loading species hg19 data: HTTP Error 404: Not Found

# %%
singles = study.expression.singles
print(singles.shape)
singles.head()
# Out:
# (206, 18594)
#         ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# CVN_01         9.583297                0         3.691144         0.000000
# CVN_02         5.338678                0         0.000000         0.000000
# CVN_03         0.146438                0         0.000000         1.262223
# CVN_04         8.422662                0         2.593897         0.000000
# CVN_05         7.531459                0         5.124018         0.262705
#
#         ENSG00000000460  ENSG00000001036  ENSG00000001084  ENSG00000001167  \
# CVN_01         0.000000         2.748821                0         1.722466
# CVN_02         0.113387         0.000000                0         0.503710
# CVN_03         0.000000         0.000000                0         0.291712
# CVN_04         0.000000         6.688600                0         8.181010
# CVN_05         4.346173         0.397903                0         6.262296
#
#         ENSG00000001460  ENSG00000001461       ...         ENSGR0000185960  \
# CVN_01                0         0.000000       ...                0.080647
# CVN_02                0         1.451580       ...                0.495262
# CVN_03                0         0.000000       ...                0.000000
# CVN_04                0         1.155126       ...                0.562974
# CVN_05                0         0.614197       ...                0.353069
#
#         ENSGR0000197976  ENSGR0000198223  ENSGR0000205755  ENSGR0000214717  \
# CVN_01         0.291587         1.017003         0.080984         6.998972
# CVN_02         0.000000         0.568696         0.000000         0.000000
# CVN_03         0.000000         0.330164         0.263555         0.000000
# CVN_04         0.000000         0.223287         0.140263         0.195424
# CVN_05         0.000000         0.646603         0.260183         6.631383
#
#         ENSGR0000223511  ENSGR0000226179  ENSGR0000236017  ENSGR0000236871  \
# CVN_01         0.153573         0.119524         0.663759         0.000000
# CVN_02         0.000000         0.116144         0.000000         0.087565
# CVN_03         0.000000         0.000000         0.000000         0.000000
# CVN_04         0.000000         1.601383         0.000000         0.205765
# CVN_05         0.000000         0.096939         0.166200         0.133075
#
#         ENSGR0000270726
# CVN_01         2.905205
# CVN_02         3.746504
# CVN_03         0.000000
# CVN_04         1.533982
# CVN_05         0.553417
#
# [5 rows x 18594 columns]

# %%
rbp_ids = study.expression.feature_data.query('gerstberger2014_rbp_target_mrna').index
# rbp_ids = rbp_ids.inter

rbps = singles.loc[:, rbp_ids].dropna(how='all', axis=1)
rbps = rbps.rename(columns=study.expression.feature_data.loc[rbps.columns, 'gene_name'])
print(rbps.shape)
rbps.head()
# Out:
# (206, 617)
#             RBM5      RBM6      UPF1    POLR2J     DHX33     GCFC2     LUC7L  \
# CVN_01  9.632477  7.355568  0.000000  9.270282  6.620909  6.635573  6.099283
# CVN_02  1.910852  5.621305  0.000000  8.174082  2.162719  0.389330  7.134951
# CVN_03  9.136361  7.099151  0.000000  0.377099  0.000000  0.403142  6.093339
# CVN_04  7.415742  8.484946  0.942291  7.457089  5.672974  3.706861  1.254225
# CVN_05  5.526858  8.506642  0.000000  6.809510  0.571635  0.215866  7.487106
#
#            CSDE1    AKAP8L     PTBP1    ...     L1TD1      ISY1      EIF6  \
# CVN_01  4.832525  0.000000  0.000000    ...         0  5.635442  3.038290
# CVN_02  4.580972  0.000000  0.000000    ...         0  1.367631  8.963380
# CVN_03  8.385265  0.000000  4.474832    ...         0  0.000000  6.450662
# CVN_04  7.842809  0.000000  0.517420    ...         0  0.000000  3.506323
# CVN_05  6.825916  1.303676  3.352287    ...         0  0.836093  5.179903
#
#            RBM12   EIF5AL1     PRKDC     MEX3A  DND1  RP11-529K1.3    LUC7L2
# CVN_01  8.041079  0.000000  7.972421  0.000000     0             0  1.579465
# CVN_02  0.000000  0.368939  3.558279  5.633004     0             0  0.000000
# CVN_03  3.612967  0.187608  5.015034  6.880000     0             0  0.000000
# CVN_04  0.000000  0.192557  7.674764  4.224704     0             0  4.391355
# CVN_05  6.882865  0.310887  6.765751  5.110217     0             0  4.778114
#
# [5 rows x 617 columns]

# %%
study.supplemental.cisbp_t_statistic.head()
# Out:
#                                                upstream200nt_MN_bimodal_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                               9.773922
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                           -8.180691
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                           11.299489
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                             18.073469
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                             2.553233
#
#                                                downstream200nt_MN_bimodal_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                 8.763746
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                            -10.528870
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                              9.324577
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                               13.702882
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                               5.596075
#
#                                                upstream200nt_MN_excluded_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                4.795954
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                            -1.257287
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                             3.122422
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                              10.643815
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                              8.629404
#
#                                                downstream200nt_MN_excluded_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                  3.865158
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                              -3.050041
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                               8.590319
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                                13.299264
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                                3.975156
#
#                                                upstream200nt_MN_included_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                               -8.386800
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                             6.865188
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                           -10.129265
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                             -17.551504
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                             -6.750704
#
#                                                downstream200nt_MN_included_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                 -6.125987
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                               8.923962
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                             -10.461790
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                               -15.811573
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                               -5.877951
#
#                                                upstream200nt_MN_uncategorized_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                    -0.735882
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                                 -0.918928
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                                  1.083059
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                                    1.368047
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                                   0.997941
#
#                                                downstream200nt_MN_uncategorized_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                      -4.469174
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                                   -7.885387
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                                   -4.393504
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                                      0.009569
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                                    -2.672161
#
#                                                upstream200nt_NPC_bimodal_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                9.318185
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                            -9.858018
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                            10.518245
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                              18.780338
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                              2.197799
#
#                                                downstream200nt_NPC_bimodal_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                  7.858505
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                             -13.803576
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                               9.016198
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                                17.767501
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                                3.593859
#
#                                                                    ...                       \
# RBP Motif                                                          ...
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                         ...
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                      ...
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                      ...
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                        ...
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                       ...
#
#                                                upstream200nt_iPSC_bimodal_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                 7.974251
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                             -4.303502
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                              8.598927
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                               15.861790
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                              -0.557489
#
#                                                downstream200nt_iPSC_bimodal_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                   5.171420
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                               -6.865831
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                                8.265806
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                                 14.981211
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                                -1.238760
#
#                                                upstream200nt_iPSC_excluded_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                  7.428721
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                              -4.668265
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                               9.252545
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                                14.453472
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                                8.742782
#
#                                                downstream200nt_iPSC_excluded_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                    5.222785
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                                -4.452394
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                                 8.709587
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                                  14.581558
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                                  5.551199
#
#                                                upstream200nt_iPSC_included_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                 -8.556934
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                               7.931694
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                             -10.638675
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                               -16.942974
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                               -6.510902
#
#                                                downstream200nt_iPSC_included_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                   -5.584638
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                                 8.072544
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                               -10.649338
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                                 -17.197455
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                                 -3.915456
#
#                                                upstream200nt_iPSC_middle_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                0.203737
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                            -0.265219
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                           -10.536098
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                               0.675730
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                             -1.438530
#
#                                                downstream200nt_iPSC_middle_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                  2.262695
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                              -0.757155
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                              -0.487599
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                                 0.113204
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                               -0.236097
#
#                                                upstream200nt_iPSC_uncategorized_placental  \
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                       1.754803
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                                   -1.123094
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                                    5.943301
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                                      6.950149
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                                     6.437776
#
#                                                downstream200nt_iPSC_uncategorized_placental
# RBP Motif
# M001_0.6_A1CF_ENSG00000148584_Homo_sapiens                                         2.792677
# M002_0.6_ANKRD17_ENSG00000132466_Homo_sapiens                                     -9.189221
# M004_0.6_BRUNOL4_ENSG00000101489_Homo_sapiens                                      7.286519
# M012_0.6_CPEB3_ENSG00000107864_Homo_sapiens                                        7.413431
# M013_0.6_DAZAP1_ENSG00000071626_Homo_sapiens                                       5.716095
#
# [5 rows x 26 columns]

# %%
rbp_ids_from_cisbp = np.unique(study.supplemental.cisbp_t_statistic.index.map(lambda x: x.split('_')[2]))
print(len(rbps_from_cisbp))
rbps_from_cisbp[:10]
# Out:
# 206
#         A1CF  A2BP1  ANKRD17  BRUNOL4  BRUNOL6  CELF3     CNOT4     CPEB3  \
# CVN_01   NaN    NaN      NaN      NaN      NaN      0  7.233485  0.000000
# CVN_02   NaN    NaN      NaN      NaN      NaN      0  4.879603  0.000000
# CVN_03   NaN    NaN      NaN      NaN      NaN      0  7.652487  0.428858
# CVN_04   NaN    NaN      NaN      NaN      NaN      0  6.105268  0.000000
# CVN_05   NaN    NaN      NaN      NaN      NaN      0  6.732688  0.000000
# CVN_06   NaN    NaN      NaN      NaN      NaN      0  4.669258  0.000000
# CVN_07   NaN    NaN      NaN      NaN      NaN      0  4.325689  2.565899
# CVN_08   NaN    NaN      NaN      NaN      NaN      0  2.186473  0.000000
# CVN_09   NaN    NaN      NaN      NaN      NaN      0  4.314043  0.000000
# CVN_11   NaN    NaN      NaN      NaN      NaN      0  0.701317  6.665108
#
#            CPEB4  CSDA   ...         TIA1     U2AF2  YBX2  YTHDC1  ZC3H10  \
# CVN_01  0.000000   NaN   ...     7.026116  5.736244   NaN     NaN     NaN
# CVN_02  0.333624   NaN   ...     8.690803  5.724255   NaN     NaN     NaN
# CVN_03  0.000000   NaN   ...     2.690654  5.303773   NaN     NaN     NaN
# CVN_04  4.874669   NaN   ...     3.425095  0.000000   NaN     NaN     NaN
# CVN_05  0.111414   NaN   ...     4.482617  0.000000   NaN     NaN     NaN
# CVN_06  0.000000   NaN   ...     7.843566  5.020844   NaN     NaN     NaN
# CVN_07  7.002634   NaN   ...     7.357777  0.859692   NaN     NaN     NaN
# CVN_08  0.000000   NaN   ...     6.854457  4.320788   NaN     NaN     NaN
# CVN_09  0.000000   NaN   ...     7.645677  3.329139   NaN     NaN     NaN
# CVN_11  2.830933   NaN   ...     7.268732  2.584900   NaN     NaN     NaN
#
#         ZCRB1  ZFP36    ZNF638  hnRNPK  hnRNPLL
# CVN_01    NaN    NaN  5.290836     NaN      NaN
# CVN_02    NaN    NaN  3.562133     NaN      NaN
# CVN_03    NaN    NaN  7.693465     NaN      NaN
# CVN_04    NaN    NaN  5.666363     NaN      NaN
# CVN_05    NaN    NaN  9.573912     NaN      NaN
# CVN_06    NaN    NaN  8.215463     NaN      NaN
# CVN_07    NaN    NaN  6.864290     NaN      NaN
# CVN_08    NaN    NaN  7.383695     NaN      NaN
# CVN_09    NaN    NaN  7.409346     NaN      NaN
# CVN_11    NaN    NaN  7.088468     NaN      NaN
#
# [10 rows x 102 columns]

# %%
rbps_from_cisbp = rbps.loc[:, rbp_ids_from_cisbp].dropna(axis=1, how='all')
print(rbps_from_cisbp.shape)
rbps_from_cisbp.head()
# Out:
# (206, 72)
#         CELF3     CNOT4     CPEB3     CPEB4    DAZAP1     EIF4B    ELAVL1  \
# CVN_01      0  7.233485  0.000000  0.000000  0.000000  5.163261  2.444243
# CVN_02      0  4.879603  0.000000  0.333624  0.000000  9.723629  4.127881
# CVN_03      0  7.652487  0.428858  0.000000  0.000000  9.359005  0.214760
# CVN_04      0  6.105268  0.000000  4.874669  4.934498  7.885165  1.701833
# CVN_05      0  6.732688  0.000000  0.111414  4.821812  8.586082  4.824111
#
#           ELAVL2    ELAVL3     ENOX1    ...        SRSF1    SRSF12      SRSF3  \
# CVN_01  0.000000  1.320773  0.139995    ...     5.549024  7.083640   9.353299
# CVN_02  0.000000  2.163985  7.408754    ...     3.866734  0.271520   9.522150
# CVN_03  0.099024  0.000000  0.000000    ...     8.410303  0.000000  10.710512
# CVN_04  0.499377  2.862622  0.000000    ...     5.115515  0.714159   8.782503
# CVN_05  4.835903  0.632811  0.000000    ...     5.947478  5.224788   9.623903
#
#            SRSF4     SRSF7     SRSF9    TARDBP      TIA1     U2AF2    ZNF638
# CVN_01  0.952352  9.396547  6.873653  5.201547  7.026116  5.736244  5.290836
# CVN_02  5.966842  9.548953  7.071452  4.294477  8.690803  5.724255  3.562133
# CVN_03  0.000000  8.096230  2.281369  6.074763  2.690654  5.303773  7.693465
# CVN_04  8.506716  8.668910  5.974415  7.119329  3.425095  0.000000  5.666363
# CVN_05  5.881956  9.567581  7.794448  8.485026  4.482617  0.000000  9.573912
#
# [5 rows x 72 columns]

# %%
min_cells = 20

# %%
psi = study.splicing.singles.groupby(study.sample_id_to_phenotype).apply(lambda x: x.dropna(thresh=min_cells, axis=1))
print(psi.shape)
psi.head()
# Out:
# (196, 5950)
#            exon:chr10:101480744-101480825:-@exon:chr10:101478103-101478257:-@exon:chr10:101476105-101476218:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chr10:101507014-101507147:+@exon:chr10:101510126-101510153:+@exon:chr10:101514286-101514391:+  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chr10:101997779-101997988:-@exon:chr10:101996607-101996726:-@exon:chr10:101995424-101995521:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chr10:102020723-102020801:-@exon:chr10:102019975-102020076:-@exon:chr10:102016019-102016233:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chr10:102114184-102114389:+@exon:chr10:102116289-102116521:+@exon:chr10:102120491-102124591:+  \
# sample_id
# CVN_01                                                     1
# CVN_02                                                     1
# CVN_03                                                     1
# CVN_04                                                     1
# CVN_05                                                     1
#
#            exon:chr10:102286732-102286831:-@exon:chr10:102286156-102286311:-@exon:chr10:102283500-102283686:-  \
# sample_id
# CVN_01                                                     1
# CVN_02                                                     1
# CVN_03                                                     1
# CVN_04                                                     1
# CVN_05                                                     1
#
#            exon:chr10:102747070-102747240:-@exon:chr10:102746847-102746953:-@exon:chr10:102746506-102746732:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                     1
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chr10:103348082-103348157:+@exon:chr10:103354415-103354495:+@exon:chr10:103360495-103360619:+  \
# sample_id
# CVN_01                                              1.000000
# CVN_02                                              1.000000
# CVN_03                                              1.000000
# CVN_04                                              1.000000
# CVN_05                                              0.328671
#
#            exon:chr10:103360960-103361093:+@exon:chr10:103364897-103364969:+@exon:chr10:103368592-103368694:+  \
# sample_id
# CVN_01                                                     0
# CVN_02                                                     0
# CVN_03                                                     0
# CVN_04                                                     0
# CVN_05                                                     0
#
#            exon:chr10:103360960-103361093:+@exon:chr10:103364897-103364969:+@exon:chr10:103368592-103368694:+@exon:chr10:103369124-103369425:+  \
# sample_id
# CVN_01                                                     0
# CVN_02                                                     0
# CVN_03                                                     0
# CVN_04                                                     0
# CVN_05                                                     0
#
#                                                   ...                                           \
# sample_id                                         ...
# CVN_01                                            ...
# CVN_02                                            ...
# CVN_03                                            ...
# CVN_04                                            ...
# CVN_05                                            ...
#
#            exon:chrY:15024875-15024974:+@exon:chrY:15025630-15025765:+@exon:chrY:15026476-15026561:+  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chrY:15026476-15026561:+@exon:chrY:15026796-15026894:+@exon:chrY:15026979-15027139:+  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chrY:15027542-15027686:+@exon:chrY:15027795-15027939:+@exon:chrY:15028173-15028354:+  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chrY:15028429-15028546:+@exon:chrY:15028819-15028972:+@exon:chrY:15029315-15029454:+  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chrY:22744476-22744579:+@exon:chrY:22746360-22746410:+@exon:chrY:22749910-22749991:+  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                     1
# CVN_03                                                     1
# CVN_04                                                   NaN
# CVN_05                                                     1
#
#            exon:chrY:2709527-2709668:+@exon:chrY:2710206-2710283:+@exon:chrY:2712118-2712298:+  \
# sample_id
# CVN_01                                                     1
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                     1
# CVN_05                                                     1
#
#            exon:chrY:2710206-2710283:+@exon:chrY:2712118-2712298:+@exon:chrY:2713687-2713784:+  \
# sample_id
# CVN_01                                                     1
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                     1
# CVN_05                                                     1
#
#            exon:chrY:2712118-2712298:+@exon:chrY:2713687-2713784:+@exon:chrY:2722641-2722812:+  \
# sample_id
# CVN_01                                                     1
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                     1
# CVN_05                                                     1
#
#            exon:chrY:2713687-2713784:+@exon:chrY:2722641-2722812:+@exon:chrY:2733129-2733286:+  \
# sample_id
# CVN_01                                                     1
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                     1
# CVN_05                                                     1
#
#            exon:chrY:2722641-2722812:+@exon:chrY:2733129-2733286:+@exon:chrY:2734834-2734903:+
# sample_id
# CVN_01                                                     1
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                     1
# CVN_05                                                     1
#
# [5 rows x 5950 columns]

# %%
var = psi.groupby(study.sample_id_to_phenotype).var()
print(var.shape)
var.head()
# Out:
# (3, 5950)
#            exon:chr10:101480744-101480825:-@exon:chr10:101478103-101478257:-@exon:chr10:101476105-101476218:-  \
# phenotype
# MN                                                       NaN
# NPC                                                      NaN
# iPSC                                                0.026042
#
#            exon:chr10:101507014-101507147:+@exon:chr10:101510126-101510153:+@exon:chr10:101514286-101514391:+  \
# phenotype
# MN                                                       NaN
# NPC                                                      NaN
# iPSC                                                0.120688
#
#            exon:chr10:101997779-101997988:-@exon:chr10:101996607-101996726:-@exon:chr10:101995424-101995521:-  \
# phenotype
# MN                                                       NaN
# NPC                                                      NaN
# iPSC                                                 0.00437
#
#            exon:chr10:102020723-102020801:-@exon:chr10:102019975-102020076:-@exon:chr10:102016019-102016233:-  \
# phenotype
# MN                                                       NaN
# NPC                                                      NaN
# iPSC                                                 0.11954
#
#            exon:chr10:102114184-102114389:+@exon:chr10:102116289-102116521:+@exon:chr10:102120491-102124591:+  \
# phenotype
# MN                                                  0.031219
# NPC                                                 0.052259
# iPSC                                                0.004267
#
#            exon:chr10:102286732-102286831:-@exon:chr10:102286156-102286311:-@exon:chr10:102283500-102283686:-  \
# phenotype
# MN                                                  0.000000
# NPC                                                 0.000048
# iPSC                                                0.000097
#
#            exon:chr10:102747070-102747240:-@exon:chr10:102746847-102746953:-@exon:chr10:102746506-102746732:-  \
# phenotype
# MN                                                       NaN
# NPC                                                  0.03125
# iPSC                                                 0.02776
#
#            exon:chr10:103348082-103348157:+@exon:chr10:103354415-103354495:+@exon:chr10:103360495-103360619:+  \
# phenotype
# MN                                                       NaN
# NPC                                                 0.012519
# iPSC                                                0.000000
#
#            exon:chr10:103360960-103361093:+@exon:chr10:103364897-103364969:+@exon:chr10:103368592-103368694:+  \
# phenotype
# MN                                                       NaN
# NPC                                                 0.054253
# iPSC                                                0.006056
#
#            exon:chr10:103360960-103361093:+@exon:chr10:103364897-103364969:+@exon:chr10:103368592-103368694:+@exon:chr10:103369124-103369425:+  \
# phenotype
# MN                                                       NaN
# NPC                                                 0.000000
# iPSC                                                0.030303
#
#                                                   ...                                           \
# phenotype                                         ...
# MN                                                ...
# NPC                                               ...
# iPSC                                              ...
#
#            exon:chrY:15024875-15024974:+@exon:chrY:15025630-15025765:+@exon:chrY:15026476-15026561:+  \
# phenotype
# MN                                                       NaN
# NPC                                                      NaN
# iPSC                                                       0
#
#            exon:chrY:15026476-15026561:+@exon:chrY:15026796-15026894:+@exon:chrY:15026979-15027139:+  \
# phenotype
# MN                                                       NaN
# NPC                                                      NaN
# iPSC                                                       0
#
#            exon:chrY:15027542-15027686:+@exon:chrY:15027795-15027939:+@exon:chrY:15028173-15028354:+  \
# phenotype
# MN                                                       NaN
# NPC                                                      NaN
# iPSC                                                0.011891
#
#            exon:chrY:15028429-15028546:+@exon:chrY:15028819-15028972:+@exon:chrY:15029315-15029454:+  \
# phenotype
# MN                                                       NaN
# NPC                                                      NaN
# iPSC                                                       0
#
#            exon:chrY:22744476-22744579:+@exon:chrY:22746360-22746410:+@exon:chrY:22749910-22749991:+  \
# phenotype
# MN                                                       NaN
# NPC                                                 0.010907
# iPSC                                                0.002145
#
#            exon:chrY:2709527-2709668:+@exon:chrY:2710206-2710283:+@exon:chrY:2712118-2712298:+  \
# phenotype
# MN                                                         0
# NPC                                                        0
# iPSC                                                       0
#
#            exon:chrY:2710206-2710283:+@exon:chrY:2712118-2712298:+@exon:chrY:2713687-2713784:+  \
# phenotype
# MN                                                  0.000000
# NPC                                                 0.000000
# iPSC                                                0.000067
#
#            exon:chrY:2712118-2712298:+@exon:chrY:2713687-2713784:+@exon:chrY:2722641-2722812:+  \
# phenotype
# MN                                                  0.000000
# NPC                                                 0.000723
# iPSC                                                0.000000
#
#            exon:chrY:2713687-2713784:+@exon:chrY:2722641-2722812:+@exon:chrY:2733129-2733286:+  \
# phenotype
# MN                                                  0.000000
# NPC                                                 0.000000
# iPSC                                                0.000003
#
#            exon:chrY:2722641-2722812:+@exon:chrY:2733129-2733286:+@exon:chrY:2734834-2734903:+
# phenotype
# MN                                                  0.000000
# NPC                                                 0.000000
# iPSC                                                0.000201
#
# [3 rows x 5950 columns]

# %%
for phenotype, row in var.iterrows():
    sns.distplot(row.dropna())

# %%
psi_filtered = psi.groupby(study.sample_id_to_phenotype).apply(lambda x: x.loc[:, x.var() > 0.1])
print(psi_filtered.shape)
psi_filtered.head()
# Out:
# (196, 478)
#            exon:chr10:101507014-101507147:+@exon:chr10:101510126-101510153:+@exon:chr10:101514286-101514391:+  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chr10:102020723-102020801:-@exon:chr10:102019975-102020076:-@exon:chr10:102016019-102016233:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chr10:1094804-1095110:-@exon:chr10:1089939-1090111:-@exon:chr10:1089241-1089333:-  \
# sample_id
# CVN_01                                              0.749526
# CVN_02                                              1.000000
# CVN_03                                              0.966330
# CVN_04                                              1.000000
# CVN_05                                                   NaN
#
#            exon:chr10:115933774-115933961:-@exon:chr10:115932900-115933024:-@exon:chr10:115921367-115923088:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chr10:120101782-120101827:-@exon:chr10:120101239-120101439:-@exon:chr10:120095694-120095935:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                              0.604167
# CVN_05                                                   NaN
#
#            exon:chr10:16794538-16794652:-@exon:chr10:16737022-16737154:-@exon:chr10:16632610-16635495:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                              0.517073
# CVN_03                                                   NaN
# CVN_04                                              0.383459
# CVN_05                                              1.000000
#
#            exon:chr10:16859314-16859453:-@exon:chr10:16858972-16859083:-@exon:chr10:16824033-16824083:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                     1
# CVN_03                                                   NaN
# CVN_04                                                     0
# CVN_05                                                     1
#
#            exon:chr10:21827762-21827841:+@exon:chr10:21846550-21846753:+@exon:chr10:21875223-21875277:+  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chr10:51565205-51565296:+@exon:chr10:51579128-51579282:+@exon:chr10:51580556-51580696:+  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chr10:65024411-65024524:-@exon:chr10:64979638-64979743:-@exon:chr10:64976967-64977091:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#                                                      ...                                              \
# sample_id                                            ...
# CVN_01                                               ...
# CVN_02                                               ...
# CVN_03                                               ...
# CVN_04                                               ...
# CVN_05                                               ...
#
#            exon:chrX:102940099-102940188:-@exon:chrX:102939609-102939657:-@exon:chrX:102933427-102933528:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chrX:102940099-102940188:-@exon:chrX:102939609-102939657:-@exon:chrX:102933427-102933579:-  \
# sample_id
# CVN_01                                                     1
# CVN_02                                                     0
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                     1
#
#            exon:chrX:103217248-103217296:+@exon:chrX:103218801-103218867:+@exon:chrX:103219079-103219195:+  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chrX:122757638-122757822:-@exon:chrX:122757495-122757560:-@exon:chrX:122756956-122757134:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chrX:14891108-14891184:-@exon:chrX:14887045-14887165:-@exon:chrX:14882682-14883702:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chrX:151999541-151999661:+@exon:chrX:152000178-152000244:+@exon:chrX:152014826-152014976:+  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chrX:69509710-69509795:-@exon:chrX:69509372-69509443:-@exon:chrX:69509105-69509204:-  \
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
#            exon:chrX:76952065-76952192:-@exon:chrX:76949313-76949426:-@exon:chrX:76944311-76944420:-  \
# sample_id
# CVN_01                                              0.388235
# CVN_02                                              0.000000
# CVN_03                                              0.000000
# CVN_04                                              1.000000
# CVN_05                                                   NaN
#
#            exon:chrX:77041468-77041702:-@exon:chrX:76972608-76972720:-@exon:chrX:76954062-76954117:-  \
# sample_id
# CVN_01                                                     1
# CVN_02                                                   NaN
# CVN_03                                                     0
# CVN_04                                                     1
# CVN_05                                                     1
#
#            exon:chrX:78622602-78622856:-@exon:chrX:78618920-78619051:-@exon:chrX:78618439-78618636:-
# sample_id
# CVN_01                                                   NaN
# CVN_02                                                   NaN
# CVN_03                                                   NaN
# CVN_04                                                   NaN
# CVN_05                                                   NaN
#
# [5 rows x 478 columns]

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV

# %%
# %%time
regressors = {}


for phenotype, phenotype_psi in psi_filtered.groupby(study.sample_id_to_phenotype):
    print(phenotype, phenotype_psi.shape)
    phenotype_psi = phenotype_psi.dropna(axis=1, how='all')
    phenotype_psi = phenotype_psi.dropna(axis=0, how='all')
    print('\t', phenotype, phenotype_psi.shape)

    for event_id, event in phenotype_psi.iteritems():
        event = event.dropna()
        target = event > 0.5
        key = phenotype, event_id
        phenotype_expression = rbps.loc[event.index]

        regressor = LogisticRegression()
        regressor.fit(phenotype_expression.values, target.values)
        
        regressors[key] = regressor
# Out:
# MN (66, 478)
# 	 MN (66, 102)
# NPC (71, 478)
# 	 NPC (71, 169)
# iPSC (59, 478)
# 	 iPSC (59, 328)
# CPU times: user 2.71 s, sys: 0 ns, total: 2.71 s
# Wall time: 2.71 s

# %%
fig, ax = plt.subplots(figsize=(2, 2))

ax.plot(event, target, 'o')

# %%
# %%time
all_regressorcvs = {}

for phenotype, phenotype_psi in psi_filtered.groupby(study.sample_id_to_phenotype):
    print(phenotype, phenotype_psi.shape)
    phenotype_psi = phenotype_psi.dropna(axis=1, how='all')
    phenotype_psi = phenotype_psi.dropna(axis=0, how='all')
    print('\t', phenotype, phenotype_psi.shape)

    for event_id, event in phenotype_psi.iteritems():
        event = event.dropna()
        target = event > 0.5
        key = phenotype, event_id
        phenotype_expression = rbps_from_cisbp.loc[event.index]

        regressorcv = LogisticRegressionCV()
        regressorcv.fit(phenotype_expression.values, target.values)
        
        all_regressorcvs[key] = regressorcv
# Out:
# MN (66, 478)
# 	 MN (66, 102)
# NPC (71, 478)
# 	 NPC (71, 169)
# iPSC (59, 478)
# 	 iPSC (59, 328)
# CPU times: user 3min 19s, sys: 12 ms, total: 3min 19s
# Wall time: 3min 19s

# %%
pkm_events = study.splicing.maybe_renamed_to_feature_id('PKM')
pkm_events
# Out:
# Index([u'exon:chr15:72499069-72499221:-@exon:chr15:72494795-72494961:-@exon:chr15:72492849-72492996:-',
#        u'exon:chr15:72499069-72499221:-@exon:chr15:72495363-72495529:-@exon:chr15:72492815-72492996:-',
#        u'exon:chr15:72523457-72523547:-@exon:chr15:72513509-72513625:-@exon:chr15:72511285-72511451:-',
#        u'exon:chr15:72499069-72499221:-@exon:chr15:72495363-72495529:-@exon:chr15:72494795-72494961:-@exon:chr15:72492815-72492996:-'],
#       dtype='object')

# %%
pkm_mxe_event = 'exon:chr15:72499069-72499221:-@exon:chr15:72495363-72495529:-@exon:chr15:72494795-72494961:-@exon:chr15:72492815-72492996:-'

# %%
regressorcvs = regressorcvs[('MN', pkm_mxe_event)]

# %%
rbps.shape
# Out:
# (206, 617)

# %%
coef = pd.DataFrame(regressorcvs.coef_, columns=rbps_from_cisbp.columns).loc[0]
coef
# Out:
# CELF3        0.092282
# CNOT4       -0.018099
# CPEB3        0.012615
# CPEB4        0.022889
# DAZAP1       0.049415
# EIF4B        0.043229
# ELAVL1       0.121464
# ELAVL2       0.159643
# ELAVL3       0.063218
# ENOX1       -0.096810
# ESRP1       -0.007664
# FMR1         0.095352
# FXR1         0.063131
# FXR2         0.000991
# G3BP2       -0.016171
# HNRNPA1     -0.016610
# HNRNPA1L2    0.037760
# HNRNPA2B1   -0.034962
# HNRNPC      -0.057900
# HNRNPD       0.033152
# HNRNPH2     -0.054931
# HNRNPL      -0.019905
# HNRNPR       0.009727
# IGF2BP1     -0.082082
# IGF2BP2     -0.065210
# IGF2BP3     -0.055281
# KHDRBS1     -0.022500
# KHDRBS2      0.062246
# KHDRBS3      0.242553
# LIN28A       0.017864
#                ...
# PUM2        -0.094747
# QKI          0.033413
# RALY         0.064723
# RBFOX2       0.048523
# RBM3        -0.025207
# RBM38        0.043117
# RBM41       -0.092752
# RBM42        0.032256
# RBM45        0.040274
# RBM47       -0.005124
# RBM4B        0.120616
# RBM5         0.020054
# RBM6         0.015613
# RBM8A       -0.001195
# RBMS1       -0.051531
# RBMS3       -0.159191
# RBMX         0.070253
# SAMD4A      -0.036408
# SF3B4       -0.041827
# SFPQ         0.007982
# SRSF1       -0.000233
# SRSF12       0.099921
# SRSF3       -0.007751
# SRSF4       -0.082265
# SRSF7        0.040225
# SRSF9       -0.038404
# TARDBP      -0.071473
# TIA1         0.025856
# U2AF2       -0.079488
# ZNF638       0.018585
# Name: 0, dtype: float64

# %%
sns.distplot(coef)

# %%
coef[coef.abs() > 0.05]
# Out:
# CELF3      0.092282
# ELAVL1     0.121464
# ELAVL2     0.159643
# ELAVL3     0.063218
# ENOX1     -0.096810
# FMR1       0.095352
# FXR1       0.063131
# HNRNPC    -0.057900
# HNRNPH2   -0.054931
# IGF2BP1   -0.082082
# IGF2BP2   -0.065210
# IGF2BP3   -0.055281
# KHDRBS2    0.062246
# KHDRBS3    0.242553
# MEX3B      0.086728
# MSI2       0.130305
# NOVA1      0.064287
# PABPC1L    0.050439
# PABPC4    -0.096910
# PPRC1     -0.123603
# PUM1      -0.108991
# PUM2      -0.094747
# RALY       0.064723
# RBM41     -0.092752
# RBM4B      0.120616
# RBMS1     -0.051531
# RBMS3     -0.159191
# RBMX       0.070253
# SRSF12     0.099921
# SRSF4     -0.082265
# TARDBP    -0.071473
# U2AF2     -0.079488
# Name: 0, dtype: float64

# %%
enah_event = study.splicing.maybe_renamed_to_feature_id('ENAH')[0]

event = enah_event

regressorcv = all_regressorcvs[('iPSC', event)]
coef = pd.DataFrame(regressorcv.coef_, columns=rbps_from_cisbp.columns).loc[0]

sns.distplot(coef)
coef[coef.abs() > 0.05]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-3e863201494c> in <module>()
#       3 event = enah_event
#       4
# ----> 5 regressorcv = all_regressorcvs[('iPSC', event)]
#       6 coef = pd.DataFrame(regressorcv.coef_, columns=rbps_from_cisbp.columns).loc[0]
#       7
#
# KeyError: ('iPSC', 'exon:chr1:225695653-225695719:-@exon:chr1:225692693-225692755:-@exon:chr1:225688694-225688772:-')

# %%
s = study.splicing.singles[enah_event].dropna()
s.groupby(study.sample_id_to_phenotype).size()
# Out:
# phenotype
# MN      10
# NPC     14
# iPSC    27
# dtype: int64
