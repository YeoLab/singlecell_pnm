# %%
import pandas as pd

# %load_ext autoreload
# %autoreload 2

folder = '/projects/ps-yeolab/obotvinnik/singlecell_pnms'

alt_exons_bedfile = '{}/exon2.bed'.format(folder)
constitutive_bedfile = '{}/constitutive_exons.bed'.format(folder)

bedfiles = alt_exons_bedfile, constitutive_bedfile

splicing_feature_data = pd.read_csv('{}/splicing_feature_data.csv'.format(folder), index_col=0)
splicing_feature_data.head()
# Out:
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:784: UserWarning: Found matplotlib configuration in ~/.matplotlib/. To conform with the XDG base directory standard, this configuration location has been deprecated on Linux, and the new location is now /home/obotvinnik/.config/matplotlib/. Please move your configuration there to ensure that matplotlib will continue to find it in the future.
#   _get_xdg_config_dir())
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (11,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#                                                     criteria  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...      best
# exon:chr10:100193697-100193848:-@exon:chr10:100...  only one
# exon:chr10:100195392-100195529:-@exon:chr10:100...      best
# exon:chr10:101165513-101165617:-@exon:chr10:101...  only one
# exon:chr10:101419263-101419345:+@exon:chr10:101...  only one
#
#                                                    criteria_additional  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...    appris_principal
# exon:chr10:100193697-100193848:-@exon:chr10:100...                 NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...    appris_principal
# exon:chr10:101165513-101165617:-@exon:chr10:101...                 NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                 NaN
#
#                                                             criteria_full  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  best,appris_principal
# exon:chr10:100193697-100193848:-@exon:chr10:100...               only one
# exon:chr10:100195392-100195529:-@exon:chr10:100...  best,appris_principal
# exon:chr10:101165513-101165617:-@exon:chr10:101...               only one
# exon:chr10:101419263-101419345:+@exon:chr10:101...               only one
#
#                                                          ensembl_id  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100193697-100193848:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100195392-100195529:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:101165513-101165617:-@exon:chr10:101...  ENSG00000120053
# exon:chr10:101419263-101419345:+@exon:chr10:101...  ENSG00000198018
#
#                                                                                exon1  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  exon:chr10:100190328-100190427:-
# exon:chr10:100193697-100193848:-@exon:chr10:100...  exon:chr10:100193697-100193848:-
# exon:chr10:100195392-100195529:-@exon:chr10:100...  exon:chr10:100195392-100195529:-
# exon:chr10:101165513-101165617:-@exon:chr10:101...  exon:chr10:101165513-101165617:-
# exon:chr10:101419263-101419345:+@exon:chr10:101...  exon:chr10:101419263-101419345:+
#
#                                                     exon1_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100193697-100193848:-@exon:chr10:100...           152
# exon:chr10:100195392-100195529:-@exon:chr10:100...           138
# exon:chr10:101165513-101165617:-@exon:chr10:101...           105
# exon:chr10:101419263-101419345:+@exon:chr10:101...            83
#
#                                                                                exon2  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  exon:chr10:100189548-100189646:-
# exon:chr10:100193697-100193848:-@exon:chr10:100...  exon:chr10:100190888-100191048:-
# exon:chr10:100195392-100195529:-@exon:chr10:100...  exon:chr10:100195029-100195171:-
# exon:chr10:101165513-101165617:-@exon:chr10:101...  exon:chr10:101163481-101163631:-
# exon:chr10:101419263-101419345:+@exon:chr10:101...  exon:chr10:101419619-101419721:+
#
#                                                     exon2_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100193697-100193848:-@exon:chr10:100...           161
# exon:chr10:100195392-100195529:-@exon:chr10:100...           143
# exon:chr10:101165513-101165617:-@exon:chr10:101...           151
# exon:chr10:101419263-101419345:+@exon:chr10:101...           103
#
#                                                                                exon3  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  exon:chr10:100189330-100189399:-
# exon:chr10:100193697-100193848:-@exon:chr10:100...  exon:chr10:100190328-100190427:-
# exon:chr10:100195392-100195529:-@exon:chr10:100...  exon:chr10:100193697-100193848:-
# exon:chr10:101165513-101165617:-@exon:chr10:101...  exon:chr10:101163226-101163391:-
# exon:chr10:101419263-101419345:+@exon:chr10:101...  exon:chr10:101421203-101421385:+
#
#                                                     exon3_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...            70
# exon:chr10:100193697-100193848:-@exon:chr10:100...           100
# exon:chr10:100195392-100195529:-@exon:chr10:100...           152
# exon:chr10:101165513-101165617:-@exon:chr10:101...           166
# exon:chr10:101419263-101419345:+@exon:chr10:101...           183
#
#                                                             ...           \
# event_id                                                    ...
# exon:chr10:100190328-100190427:-@exon:chr10:100...          ...
# exon:chr10:100193697-100193848:-@exon:chr10:100...          ...
# exon:chr10:100195392-100195529:-@exon:chr10:100...          ...
# exon:chr10:101165513-101165617:-@exon:chr10:101...          ...
# exon:chr10:101419263-101419345:+@exon:chr10:101...          ...
#
#                                                    isoform1_protein_secondary_structure_helix  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                                        NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                                        NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                                        NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                                        NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                                        NaN
#
#                                                     isoform1_protein_secondary_structure_sheet  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                                         NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                                         NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                                         NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                                         NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                                         NaN
#
#                                                    isoform1_protein_secondary_structure_turn  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                                       NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                                       NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                                       NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                                       NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                                       NaN
#
#                                                    isoform2_protein_secondary_structure_helix  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                                   0.202247
# exon:chr10:100193697-100193848:-@exon:chr10:100...                                        NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                                        NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                                   0.328571
# exon:chr10:101419263-101419345:+@exon:chr10:101...                                        NaN
#
#                                                     isoform2_protein_secondary_structure_sheet  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                                    0.247191
# exon:chr10:100193697-100193848:-@exon:chr10:100...                                         NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                                         NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                                    0.250000
# exon:chr10:101419263-101419345:+@exon:chr10:101...                                         NaN
#
#                                                    isoform2_protein_secondary_structure_turn  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                                  0.370787
# exon:chr10:100193697-100193848:-@exon:chr10:100...                                       NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                                       NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                                  0.264286
# exon:chr10:101419263-101419345:+@exon:chr10:101...                                       NaN
#
#                                                    isoform1_aromaticity  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                  NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                  NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                  NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                  NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                  NaN
#
#                                                    isoform2_aromaticity  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...             0.056180
# exon:chr10:100193697-100193848:-@exon:chr10:100...                  NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                  NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...             0.135714
# exon:chr10:101419263-101419345:+@exon:chr10:101...                  NaN
#
#                                                    isoform1_iupred_score  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                   NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                   NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                   NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                   NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                   NaN
#
#                                                    isoform2_iupred_score
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...              0.638962
# exon:chr10:100193697-100193848:-@exon:chr10:100...                   NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                   NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...              0.223048
# exon:chr10:101419263-101419345:+@exon:chr10:101...                   NaN
#
# [5 rows x 53 columns]

# %%
# import pybedtools
# constitutive_bed = pybedtools.BedTool(constitutive_bedfile)
# names = [x.name for x in constitutive_bed]

# constitutive_feature_data = pd.DataFrame(index=names)

# %%
hg19_fasta = '/projects/ps-yeolab/genomes/hg19/gencode/v19/GRCh37.p13.genome.fa'

# %% [markdown]
# ## Splice site strength

# %%
# from poshsplice.splicestrength import score_exons


# constitutive_scores = score_exons(constitutive_bedfile, 'hg19', hg19_fasta)
# constitutive_scores.head()

# %%
from poshsplice.splicestrength import score_exons


alt_exons_scores = score_exons(alt_exons_bedfile, 'hg19', hg19_fasta)
alt_exons_scores.head()
# Out:
#                                                     splice_site_3p_score  \
# exon:chr10:100190328-100190427:-@exon:chr10:100...                  7.77
# exon:chr10:100193697-100193848:-@exon:chr10:100...                  9.08
# exon:chr10:100195392-100195529:-@exon:chr10:100...                  7.92
# exon:chr10:101165513-101165617:-@exon:chr10:101...                 10.79
# exon:chr10:101419263-101419345:+@exon:chr10:101...                  5.04
#
#                                                          splice_site_3p_seq  \
# exon:chr10:100190328-100190427:-@exon:chr10:100...  CTCTCCCCTGCCCTGCACAGCCT
# exon:chr10:100193697-100193848:-@exon:chr10:100...  TCCCTTCCTGCCCTGGCTAGGCC
# exon:chr10:100195392-100195529:-@exon:chr10:100...  TGGCCTGCCTGTGCCTGCAGTTT
# exon:chr10:101165513-101165617:-@exon:chr10:101...  CTCACTTTGCTTCCCCGCAGCAC
# exon:chr10:101419263-101419345:+@exon:chr10:101...  CTGAAATCAAATCTTTCTAGGCT
#
#                                                     splice_site_5p_score  \
# exon:chr10:100190328-100190427:-@exon:chr10:100...                  6.96
# exon:chr10:100193697-100193848:-@exon:chr10:100...                  7.96
# exon:chr10:100195392-100195529:-@exon:chr10:100...                  6.05
# exon:chr10:101165513-101165617:-@exon:chr10:101...                  8.34
# exon:chr10:101419263-101419345:+@exon:chr10:101...                  9.31
#
#                                                    splice_site_5p_seq
# exon:chr10:100190328-100190427:-@exon:chr10:100...          ACGGTGTGT
# exon:chr10:100193697-100193848:-@exon:chr10:100...          TAGGTGAGC
# exon:chr10:100195392-100195529:-@exon:chr10:100...          GGAGTGAGT
# exon:chr10:101165513-101165617:-@exon:chr10:101...          ACAGTGAGT
# exon:chr10:101419263-101419345:+@exon:chr10:101...          TAGGTAAGG

# %%
alt_exons_scores.tail()
# Out:
#                                                     splice_site_3p_score  \
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...                 11.41
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...                  9.46
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...                 11.80
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...                  6.92
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...                  6.63
#
#                                                          splice_site_3p_seq  \
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...  TTTTTTCTTTTTCCTTTTAGCTG
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...  GAGTTTCGTGTCCTTTTCAGGCC
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...  CCTTTCCTTGTCTTCTACAGGCA
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...  TTATACCCTTTTGTGATCAGATG
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...  TTTCCTTGCTGTGTTTATAGTAC
#
#                                                     splice_site_5p_score  \
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...                  9.67
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...                  5.91
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...                  9.08
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...                  9.79
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...                 10.86
#
#                                                    splice_site_5p_seq
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...          AAGGTACCG
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...          TTTGTGAGT
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...          TGGGTAAGG
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...          AAGGTATGT
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...          CAGGTAAGT

# %% [markdown]
# ### Add alternative exon socres to Splicing feature data

# %%
alt_exons_scores.columns = alt_exons_scores.columns.map(lambda x: "exon2_" + x)
alt_exons_scores.head()
# Out:
#                                                     exon2_splice_site_3p_score  \
# exon:chr10:100190328-100190427:-@exon:chr10:100...                        7.77
# exon:chr10:100193697-100193848:-@exon:chr10:100...                        9.08
# exon:chr10:100195392-100195529:-@exon:chr10:100...                        7.92
# exon:chr10:101165513-101165617:-@exon:chr10:101...                       10.79
# exon:chr10:101419263-101419345:+@exon:chr10:101...                        5.04
#
#                                                    exon2_splice_site_3p_seq  \
# exon:chr10:100190328-100190427:-@exon:chr10:100...  CTCTCCCCTGCCCTGCACAGCCT
# exon:chr10:100193697-100193848:-@exon:chr10:100...  TCCCTTCCTGCCCTGGCTAGGCC
# exon:chr10:100195392-100195529:-@exon:chr10:100...  TGGCCTGCCTGTGCCTGCAGTTT
# exon:chr10:101165513-101165617:-@exon:chr10:101...  CTCACTTTGCTTCCCCGCAGCAC
# exon:chr10:101419263-101419345:+@exon:chr10:101...  CTGAAATCAAATCTTTCTAGGCT
#
#                                                     exon2_splice_site_5p_score  \
# exon:chr10:100190328-100190427:-@exon:chr10:100...                        6.96
# exon:chr10:100193697-100193848:-@exon:chr10:100...                        7.96
# exon:chr10:100195392-100195529:-@exon:chr10:100...                        6.05
# exon:chr10:101165513-101165617:-@exon:chr10:101...                        8.34
# exon:chr10:101419263-101419345:+@exon:chr10:101...                        9.31
#
#                                                    exon2_splice_site_5p_seq
# exon:chr10:100190328-100190427:-@exon:chr10:100...                ACGGTGTGT
# exon:chr10:100193697-100193848:-@exon:chr10:100...                TAGGTGAGC
# exon:chr10:100195392-100195529:-@exon:chr10:100...                GGAGTGAGT
# exon:chr10:101165513-101165617:-@exon:chr10:101...                ACAGTGAGT
# exon:chr10:101419263-101419345:+@exon:chr10:101...                TAGGTAAGG

# %%
join_cols = alt_exons_scores.columns.difference(splicing_feature_data.columns)
if len(join_cols) > 0:
    splicing_feature_data = splicing_feature_data.join(alt_exons_scores[join_cols], how='outer')
splicing_feature_data.head()
# Out:
#                                                     criteria  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...      best
# exon:chr10:100193697-100193848:-@exon:chr10:100...  only one
# exon:chr10:100195392-100195529:-@exon:chr10:100...      best
# exon:chr10:101165513-101165617:-@exon:chr10:101...  only one
# exon:chr10:101419263-101419345:+@exon:chr10:101...  only one
#
#                                                    criteria_additional  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...    appris_principal
# exon:chr10:100193697-100193848:-@exon:chr10:100...                 NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...    appris_principal
# exon:chr10:101165513-101165617:-@exon:chr10:101...                 NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                 NaN
#
#                                                             criteria_full  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  best,appris_principal
# exon:chr10:100193697-100193848:-@exon:chr10:100...               only one
# exon:chr10:100195392-100195529:-@exon:chr10:100...  best,appris_principal
# exon:chr10:101165513-101165617:-@exon:chr10:101...               only one
# exon:chr10:101419263-101419345:+@exon:chr10:101...               only one
#
#                                                          ensembl_id  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100193697-100193848:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100195392-100195529:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:101165513-101165617:-@exon:chr10:101...  ENSG00000120053
# exon:chr10:101419263-101419345:+@exon:chr10:101...  ENSG00000198018
#
#                                                                                exon1  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  exon:chr10:100190328-100190427:-
# exon:chr10:100193697-100193848:-@exon:chr10:100...  exon:chr10:100193697-100193848:-
# exon:chr10:100195392-100195529:-@exon:chr10:100...  exon:chr10:100195392-100195529:-
# exon:chr10:101165513-101165617:-@exon:chr10:101...  exon:chr10:101165513-101165617:-
# exon:chr10:101419263-101419345:+@exon:chr10:101...  exon:chr10:101419263-101419345:+
#
#                                                     exon1_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100193697-100193848:-@exon:chr10:100...           152
# exon:chr10:100195392-100195529:-@exon:chr10:100...           138
# exon:chr10:101165513-101165617:-@exon:chr10:101...           105
# exon:chr10:101419263-101419345:+@exon:chr10:101...            83
#
#                                                                                exon2  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  exon:chr10:100189548-100189646:-
# exon:chr10:100193697-100193848:-@exon:chr10:100...  exon:chr10:100190888-100191048:-
# exon:chr10:100195392-100195529:-@exon:chr10:100...  exon:chr10:100195029-100195171:-
# exon:chr10:101165513-101165617:-@exon:chr10:101...  exon:chr10:101163481-101163631:-
# exon:chr10:101419263-101419345:+@exon:chr10:101...  exon:chr10:101419619-101419721:+
#
#                                                     exon2_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100193697-100193848:-@exon:chr10:100...           161
# exon:chr10:100195392-100195529:-@exon:chr10:100...           143
# exon:chr10:101165513-101165617:-@exon:chr10:101...           151
# exon:chr10:101419263-101419345:+@exon:chr10:101...           103
#
#                                                                                exon3  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  exon:chr10:100189330-100189399:-
# exon:chr10:100193697-100193848:-@exon:chr10:100...  exon:chr10:100190328-100190427:-
# exon:chr10:100195392-100195529:-@exon:chr10:100...  exon:chr10:100193697-100193848:-
# exon:chr10:101165513-101165617:-@exon:chr10:101...  exon:chr10:101163226-101163391:-
# exon:chr10:101419263-101419345:+@exon:chr10:101...  exon:chr10:101421203-101421385:+
#
#                                                     exon3_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...            70
# exon:chr10:100193697-100193848:-@exon:chr10:100...           100
# exon:chr10:100195392-100195529:-@exon:chr10:100...           152
# exon:chr10:101165513-101165617:-@exon:chr10:101...           166
# exon:chr10:101419263-101419345:+@exon:chr10:101...           183
#
#                                                              ...             \
# event_id                                                     ...
# exon:chr10:100190328-100190427:-@exon:chr10:100...           ...
# exon:chr10:100193697-100193848:-@exon:chr10:100...           ...
# exon:chr10:100195392-100195529:-@exon:chr10:100...           ...
# exon:chr10:101165513-101165617:-@exon:chr10:101...           ...
# exon:chr10:101419263-101419345:+@exon:chr10:101...           ...
#
#                                                    isoform2_protein_secondary_structure_sheet  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                                   0.247191
# exon:chr10:100193697-100193848:-@exon:chr10:100...                                        NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                                        NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                                   0.250000
# exon:chr10:101419263-101419345:+@exon:chr10:101...                                        NaN
#
#                                                     isoform2_protein_secondary_structure_turn  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                                   0.370787
# exon:chr10:100193697-100193848:-@exon:chr10:100...                                        NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                                        NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                                   0.264286
# exon:chr10:101419263-101419345:+@exon:chr10:101...                                        NaN
#
#                                                    isoform1_aromaticity  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                  NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                  NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                  NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                  NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                  NaN
#
#                                                    isoform2_aromaticity  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...             0.056180
# exon:chr10:100193697-100193848:-@exon:chr10:100...                  NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                  NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...             0.135714
# exon:chr10:101419263-101419345:+@exon:chr10:101...                  NaN
#
#                                                     isoform1_iupred_score  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                    NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                    NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                    NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                    NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                    NaN
#
#                                                    isoform2_iupred_score  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...              0.638962
# exon:chr10:100193697-100193848:-@exon:chr10:100...                   NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                   NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...              0.223048
# exon:chr10:101419263-101419345:+@exon:chr10:101...                   NaN
#
#                                                    exon2_splice_site_3p_score  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                       7.77
# exon:chr10:100193697-100193848:-@exon:chr10:100...                       9.08
# exon:chr10:100195392-100195529:-@exon:chr10:100...                       7.92
# exon:chr10:101165513-101165617:-@exon:chr10:101...                      10.79
# exon:chr10:101419263-101419345:+@exon:chr10:101...                       5.04
#
#                                                    exon2_splice_site_3p_seq  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  CTCTCCCCTGCCCTGCACAGCCT
# exon:chr10:100193697-100193848:-@exon:chr10:100...  TCCCTTCCTGCCCTGGCTAGGCC
# exon:chr10:100195392-100195529:-@exon:chr10:100...  TGGCCTGCCTGTGCCTGCAGTTT
# exon:chr10:101165513-101165617:-@exon:chr10:101...  CTCACTTTGCTTCCCCGCAGCAC
# exon:chr10:101419263-101419345:+@exon:chr10:101...  CTGAAATCAAATCTTTCTAGGCT
#
#                                                    exon2_splice_site_5p_score  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                       6.96
# exon:chr10:100193697-100193848:-@exon:chr10:100...                       7.96
# exon:chr10:100195392-100195529:-@exon:chr10:100...                       6.05
# exon:chr10:101165513-101165617:-@exon:chr10:101...                       8.34
# exon:chr10:101419263-101419345:+@exon:chr10:101...                       9.31
#
#                                                    exon2_splice_site_5p_seq
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                ACGGTGTGT
# exon:chr10:100193697-100193848:-@exon:chr10:100...                TAGGTGAGC
# exon:chr10:100195392-100195529:-@exon:chr10:100...                GGAGTGAGT
# exon:chr10:101165513-101165617:-@exon:chr10:101...                ACAGTGAGT
# exon:chr10:101419263-101419345:+@exon:chr10:101...                TAGGTAAGG
#
# [5 rows x 57 columns]

# %%
splicing

# %%
alt_exons_scores['exon_type'] = 'alternative'
constitutive_scores['exon_type'] = 'constitutive'

# %%
splice_site_scores = pd.concat([alt_exons_scores.reset_index(), constitutive_scores.reset_index()], ignore_index=True)
splice_site_scores.head()
# Out:
#                                                index  splice_site_3p_score  \
# 0  exon:chr10:100190328-100190427:-@exon:chr10:10...                  7.77
# 1  exon:chr10:100193697-100193848:-@exon:chr10:10...                  9.08
# 2  exon:chr10:100195392-100195529:-@exon:chr10:10...                  7.92
# 3  exon:chr10:101165513-101165617:-@exon:chr10:10...                 10.79
# 4  exon:chr10:101419263-101419345:+@exon:chr10:10...                  5.04
#
#         splice_site_3p_seq  splice_site_5p_score splice_site_5p_seq  \
# 0  CTCTCCCCTGCCCTGCACAGCCT                  6.96          ACGGTGTGT
# 1  TCCCTTCCTGCCCTGGCTAGGCC                  7.96          TAGGTGAGC
# 2  TGGCCTGCCTGTGCCTGCAGTTT                  6.05          GGAGTGAGT
# 3  CTCACTTTGCTTCCCCGCAGCAC                  8.34          ACAGTGAGT
# 4  CTGAAATCAAATCTTTCTAGGCT                  9.31          TAGGTAAGG
#
#      exon_type
# 0  alternative
# 1  alternative
# 2  alternative
# 3  alternative
# 4  alternative

# %%
splice_site_scores = splice_site_scores.rename(columns={'index': 'event_name'})

# %% [markdown]
# ### Make sure constitutive have, on average, higher splice site scores.

# %%
import seaborn as sns
# %matplotlib inline
sns.boxplot(x='exon_type', y='splice_site_3p_score', data=splice_site_scores)

# %%
sns.boxplot(x='exon_type', y='splice_site_5p_score', data=splice_site_scores)

# %%
alt_exons_scores = alt_exons_scores.drop('exon_type', axis=1)

# %%
# Out:
#                                                     exon2_splice_site_3p_score  \
# exon:chr10:100190328-100190427:-@exon:chr10:100...                        7.77
# exon:chr10:100193697-100193848:-@exon:chr10:100...                        9.08
# exon:chr10:100195392-100195529:-@exon:chr10:100...                        7.92
# exon:chr10:101165513-101165617:-@exon:chr10:101...                       10.79
# exon:chr10:101419263-101419345:+@exon:chr10:101...                        5.04
#
#                                                    exon2_splice_site_3p_seq  \
# exon:chr10:100190328-100190427:-@exon:chr10:100...  CTCTCCCCTGCCCTGCACAGCCT
# exon:chr10:100193697-100193848:-@exon:chr10:100...  TCCCTTCCTGCCCTGGCTAGGCC
# exon:chr10:100195392-100195529:-@exon:chr10:100...  TGGCCTGCCTGTGCCTGCAGTTT
# exon:chr10:101165513-101165617:-@exon:chr10:101...  CTCACTTTGCTTCCCCGCAGCAC
# exon:chr10:101419263-101419345:+@exon:chr10:101...  CTGAAATCAAATCTTTCTAGGCT
#
#                                                     exon2_splice_site_5p_score  \
# exon:chr10:100190328-100190427:-@exon:chr10:100...                        6.96
# exon:chr10:100193697-100193848:-@exon:chr10:100...                        7.96
# exon:chr10:100195392-100195529:-@exon:chr10:100...                        6.05
# exon:chr10:101165513-101165617:-@exon:chr10:101...                        8.34
# exon:chr10:101419263-101419345:+@exon:chr10:101...                        9.31
#
#                                                    exon2_splice_site_5p_seq
# exon:chr10:100190328-100190427:-@exon:chr10:100...                ACGGTGTGT
# exon:chr10:100193697-100193848:-@exon:chr10:100...                TAGGTGAGC
# exon:chr10:100195392-100195529:-@exon:chr10:100...                GGAGTGAGT
# exon:chr10:101165513-101165617:-@exon:chr10:101...                ACAGTGAGT
# exon:chr10:101419263-101419345:+@exon:chr10:101...                TAGGTAAGG

# %%
# Out:
#                                                     criteria  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...      best
# exon:chr10:100193697-100193848:-@exon:chr10:100...  only one
# exon:chr10:100195392-100195529:-@exon:chr10:100...      best
# exon:chr10:101165513-101165617:-@exon:chr10:101...  only one
# exon:chr10:101419263-101419345:+@exon:chr10:101...  only one
#
#                                                    criteria_additional  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...    appris_principal
# exon:chr10:100193697-100193848:-@exon:chr10:100...                 NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...    appris_principal
# exon:chr10:101165513-101165617:-@exon:chr10:101...                 NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                 NaN
#
#                                                             criteria_full  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  best,appris_principal
# exon:chr10:100193697-100193848:-@exon:chr10:100...               only one
# exon:chr10:100195392-100195529:-@exon:chr10:100...  best,appris_principal
# exon:chr10:101165513-101165617:-@exon:chr10:101...               only one
# exon:chr10:101419263-101419345:+@exon:chr10:101...               only one
#
#                                                          ensembl_id  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100193697-100193848:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100195392-100195529:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:101165513-101165617:-@exon:chr10:101...  ENSG00000120053
# exon:chr10:101419263-101419345:+@exon:chr10:101...  ENSG00000198018
#
#                                                                                exon1  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  exon:chr10:100190328-100190427:-
# exon:chr10:100193697-100193848:-@exon:chr10:100...  exon:chr10:100193697-100193848:-
# exon:chr10:100195392-100195529:-@exon:chr10:100...  exon:chr10:100195392-100195529:-
# exon:chr10:101165513-101165617:-@exon:chr10:101...  exon:chr10:101165513-101165617:-
# exon:chr10:101419263-101419345:+@exon:chr10:101...  exon:chr10:101419263-101419345:+
#
#                                                     exon1_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100193697-100193848:-@exon:chr10:100...           152
# exon:chr10:100195392-100195529:-@exon:chr10:100...           138
# exon:chr10:101165513-101165617:-@exon:chr10:101...           105
# exon:chr10:101419263-101419345:+@exon:chr10:101...            83
#
#                                                                                exon2  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  exon:chr10:100189548-100189646:-
# exon:chr10:100193697-100193848:-@exon:chr10:100...  exon:chr10:100190888-100191048:-
# exon:chr10:100195392-100195529:-@exon:chr10:100...  exon:chr10:100195029-100195171:-
# exon:chr10:101165513-101165617:-@exon:chr10:101...  exon:chr10:101163481-101163631:-
# exon:chr10:101419263-101419345:+@exon:chr10:101...  exon:chr10:101419619-101419721:+
#
#                                                     exon2_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100193697-100193848:-@exon:chr10:100...           161
# exon:chr10:100195392-100195529:-@exon:chr10:100...           143
# exon:chr10:101165513-101165617:-@exon:chr10:101...           151
# exon:chr10:101419263-101419345:+@exon:chr10:101...           103
#
#                                                                                exon3  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  exon:chr10:100189330-100189399:-
# exon:chr10:100193697-100193848:-@exon:chr10:100...  exon:chr10:100190328-100190427:-
# exon:chr10:100195392-100195529:-@exon:chr10:100...  exon:chr10:100193697-100193848:-
# exon:chr10:101165513-101165617:-@exon:chr10:101...  exon:chr10:101163226-101163391:-
# exon:chr10:101419263-101419345:+@exon:chr10:101...  exon:chr10:101421203-101421385:+
#
#                                                     exon3_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...            70
# exon:chr10:100193697-100193848:-@exon:chr10:100...           100
# exon:chr10:100195392-100195529:-@exon:chr10:100...           152
# exon:chr10:101165513-101165617:-@exon:chr10:101...           166
# exon:chr10:101419263-101419345:+@exon:chr10:101...           183
#
#                                                              ...             \
# event_id                                                     ...
# exon:chr10:100190328-100190427:-@exon:chr10:100...           ...
# exon:chr10:100193697-100193848:-@exon:chr10:100...           ...
# exon:chr10:100195392-100195529:-@exon:chr10:100...           ...
# exon:chr10:101165513-101165617:-@exon:chr10:101...           ...
# exon:chr10:101419263-101419345:+@exon:chr10:101...           ...
#
#                                                    junction_exons34  strand  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...              NaN       -
# exon:chr10:100193697-100193848:-@exon:chr10:100...              NaN       -
# exon:chr10:100195392-100195529:-@exon:chr10:100...              NaN       -
# exon:chr10:101165513-101165617:-@exon:chr10:101...              NaN       -
# exon:chr10:101419263-101419345:+@exon:chr10:101...              NaN       +
#
#                                                    exon2_divisible_by_3  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 True
# exon:chr10:100193697-100193848:-@exon:chr10:100...                False
# exon:chr10:100195392-100195529:-@exon:chr10:100...                False
# exon:chr10:101165513-101165617:-@exon:chr10:101...                False
# exon:chr10:101419263-101419345:+@exon:chr10:101...                False
#
#                                                      one_ensembl_id  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100193697-100193848:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100195392-100195529:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:101165513-101165617:-@exon:chr10:101...  ENSG00000120053
# exon:chr10:101419263-101419345:+@exon:chr10:101...  ENSG00000198018
#
#                                                     splice_type  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...           SE
# exon:chr10:100193697-100193848:-@exon:chr10:100...           SE
# exon:chr10:100195392-100195529:-@exon:chr10:100...           SE
# exon:chr10:101165513-101165617:-@exon:chr10:101...           SE
# exon:chr10:101419263-101419345:+@exon:chr10:101...           SE
#
#                                                    exon2_merkin2012_ancient  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                    False
# exon:chr10:100193697-100193848:-@exon:chr10:100...                    False
# exon:chr10:100195392-100195529:-@exon:chr10:100...                    False
# exon:chr10:101165513-101165617:-@exon:chr10:101...                    False
# exon:chr10:101419263-101419345:+@exon:chr10:101...                    False
#
#                                                    exon2_splice_site_3p_score  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                       7.77
# exon:chr10:100193697-100193848:-@exon:chr10:100...                       9.08
# exon:chr10:100195392-100195529:-@exon:chr10:100...                       7.92
# exon:chr10:101165513-101165617:-@exon:chr10:101...                      10.79
# exon:chr10:101419263-101419345:+@exon:chr10:101...                       5.04
#
#                                                    exon2_splice_site_3p_seq  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  CTCTCCCCTGCCCTGCACAGCCT
# exon:chr10:100193697-100193848:-@exon:chr10:100...  TCCCTTCCTGCCCTGGCTAGGCC
# exon:chr10:100195392-100195529:-@exon:chr10:100...  TGGCCTGCCTGTGCCTGCAGTTT
# exon:chr10:101165513-101165617:-@exon:chr10:101...  CTCACTTTGCTTCCCCGCAGCAC
# exon:chr10:101419263-101419345:+@exon:chr10:101...  CTGAAATCAAATCTTTCTAGGCT
#
#                                                    exon2_splice_site_5p_score  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                       6.96
# exon:chr10:100193697-100193848:-@exon:chr10:100...                       7.96
# exon:chr10:100195392-100195529:-@exon:chr10:100...                       6.05
# exon:chr10:101165513-101165617:-@exon:chr10:101...                       8.34
# exon:chr10:101419263-101419345:+@exon:chr10:101...                       9.31
#
#                                                    exon2_splice_site_5p_seq
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                ACGGTGTGT
# exon:chr10:100193697-100193848:-@exon:chr10:100...                TAGGTGAGC
# exon:chr10:100195392-100195529:-@exon:chr10:100...                GGAGTGAGT
# exon:chr10:101165513-101165617:-@exon:chr10:101...                ACAGTGAGT
# exon:chr10:101419263-101419345:+@exon:chr10:101...                TAGGTAAGG
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Exon conservation

# %% [markdown]
# ### Read output of exon conservation from [0.2.05]

# %%
import glob
import os
import pandas as pd

column_names = ['event_name', 'size', 'covered', 'sum', 'mean0', 'mean']

dfs = []
for bedfile in bedfiles:
    basename = os.path.basename(bedfile)
    
    prefix = basename.split('.bed')[0]
    prefix += '_phastcons_placental_mammal'

    outtab = '{}/{}'.format(folder, prefix + '.txt')
    
    df = pd.read_table(outtab, header=None, index_col=0, names=column_names)
    
    s = df['mean']
#     df = s.to_frame()
    
    if 'constitutive' in bedfile:
        pass
#         s.name = 'phastcons_placental_mammal'
#         constitutive_feature_data = constitutive_feature_data.join(s)
    else:
        s.name = prefix
        if s.name not in splicing_feature_data:
            splicing_feature_data = splicing_feature_data.join(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-de00523aea96> in <module>()
#      25     else:
#      26         s.name = prefix
# ---> 27         splicing_feature_data = splicing_feature_data.join(s)
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in join(self, other, on, how, lsuffix, rsuffix, sort)
#    4017         # For SparseDataFrame's benefit
#    4018         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 4019                                  rsuffix=rsuffix, sort=sort)
#    4020
#    4021     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    4031             return merge(self, other, left_on=on, how=how,
#    4032                          left_index=on is None, right_index=True,
# -> 4033                          suffixes=(lsuffix, rsuffix), sort=sort)
#    4034         else:
#    4035             if on is not None:
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy)
#      36                          right_index=right_index, sort=sort, suffixes=suffixes,
#      37                          copy=copy)
# ---> 38     return op.get_result()
#      39 if __debug__:
#      40     merge.__doc__ = _merge_doc % '\nleft : DataFrame'
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in get_result(self)
#     190
#     191         llabels, rlabels = items_overlap_with_suffix(ldata.items, lsuf,
# --> 192                                                      rdata.items, rsuf)
#     193
#     194         lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    3969         if not lsuffix and not rsuffix:
#    3970             raise ValueError('columns overlap but no suffix specified: %s' %
# -> 3971                              to_rename)
#    3972
#    3973         def lrenamer(x):
#
# ValueError: columns overlap but no suffix specified: Index([u'exon2_phastcons_placental_mammal'], dtype='object')

# %%
print splicing_feature_data.shape
# Out:
# (33693, 58)

# %%
splicing_feature_data.head()
# Out:
#                                                     criteria  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...      best
# exon:chr10:100193697-100193848:-@exon:chr10:100...  only one
# exon:chr10:100195392-100195529:-@exon:chr10:100...      best
# exon:chr10:101165513-101165617:-@exon:chr10:101...  only one
# exon:chr10:101419263-101419345:+@exon:chr10:101...  only one
#
#                                                    criteria_additional  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...    appris_principal
# exon:chr10:100193697-100193848:-@exon:chr10:100...                 NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...    appris_principal
# exon:chr10:101165513-101165617:-@exon:chr10:101...                 NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                 NaN
#
#                                                             criteria_full  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  best,appris_principal
# exon:chr10:100193697-100193848:-@exon:chr10:100...               only one
# exon:chr10:100195392-100195529:-@exon:chr10:100...  best,appris_principal
# exon:chr10:101165513-101165617:-@exon:chr10:101...               only one
# exon:chr10:101419263-101419345:+@exon:chr10:101...               only one
#
#                                                          ensembl_id  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100193697-100193848:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100195392-100195529:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:101165513-101165617:-@exon:chr10:101...  ENSG00000120053
# exon:chr10:101419263-101419345:+@exon:chr10:101...  ENSG00000198018
#
#                                                                                exon1  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  exon:chr10:100190328-100190427:-
# exon:chr10:100193697-100193848:-@exon:chr10:100...  exon:chr10:100193697-100193848:-
# exon:chr10:100195392-100195529:-@exon:chr10:100...  exon:chr10:100195392-100195529:-
# exon:chr10:101165513-101165617:-@exon:chr10:101...  exon:chr10:101165513-101165617:-
# exon:chr10:101419263-101419345:+@exon:chr10:101...  exon:chr10:101419263-101419345:+
#
#                                                     exon1_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100193697-100193848:-@exon:chr10:100...           152
# exon:chr10:100195392-100195529:-@exon:chr10:100...           138
# exon:chr10:101165513-101165617:-@exon:chr10:101...           105
# exon:chr10:101419263-101419345:+@exon:chr10:101...            83
#
#                                                                                exon2  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  exon:chr10:100189548-100189646:-
# exon:chr10:100193697-100193848:-@exon:chr10:100...  exon:chr10:100190888-100191048:-
# exon:chr10:100195392-100195529:-@exon:chr10:100...  exon:chr10:100195029-100195171:-
# exon:chr10:101165513-101165617:-@exon:chr10:101...  exon:chr10:101163481-101163631:-
# exon:chr10:101419263-101419345:+@exon:chr10:101...  exon:chr10:101419619-101419721:+
#
#                                                     exon2_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100193697-100193848:-@exon:chr10:100...           161
# exon:chr10:100195392-100195529:-@exon:chr10:100...           143
# exon:chr10:101165513-101165617:-@exon:chr10:101...           151
# exon:chr10:101419263-101419345:+@exon:chr10:101...           103
#
#                                                                                exon3  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  exon:chr10:100189330-100189399:-
# exon:chr10:100193697-100193848:-@exon:chr10:100...  exon:chr10:100190328-100190427:-
# exon:chr10:100195392-100195529:-@exon:chr10:100...  exon:chr10:100193697-100193848:-
# exon:chr10:101165513-101165617:-@exon:chr10:101...  exon:chr10:101163226-101163391:-
# exon:chr10:101419263-101419345:+@exon:chr10:101...  exon:chr10:101421203-101421385:+
#
#                                                     exon3_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...            70
# exon:chr10:100193697-100193848:-@exon:chr10:100...           100
# exon:chr10:100195392-100195529:-@exon:chr10:100...           152
# exon:chr10:101165513-101165617:-@exon:chr10:101...           166
# exon:chr10:101419263-101419345:+@exon:chr10:101...           183
#
#                                                                  ...                 \
# event_id                                                         ...
# exon:chr10:100190328-100190427:-@exon:chr10:100...               ...
# exon:chr10:100193697-100193848:-@exon:chr10:100...               ...
# exon:chr10:100195392-100195529:-@exon:chr10:100...               ...
# exon:chr10:101165513-101165617:-@exon:chr10:101...               ...
# exon:chr10:101419263-101419345:+@exon:chr10:101...               ...
#
#                                                    isoform2_protein_secondary_structure_turn  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                                  0.370787
# exon:chr10:100193697-100193848:-@exon:chr10:100...                                       NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                                       NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                                  0.264286
# exon:chr10:101419263-101419345:+@exon:chr10:101...                                       NaN
#
#                                                     isoform1_aromaticity  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                   NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                   NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                   NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                   NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                   NaN
#
#                                                    isoform2_aromaticity  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...             0.056180
# exon:chr10:100193697-100193848:-@exon:chr10:100...                  NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                  NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...             0.135714
# exon:chr10:101419263-101419345:+@exon:chr10:101...                  NaN
#
#                                                    isoform1_iupred_score  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                   NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                   NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                   NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...                   NaN
# exon:chr10:101419263-101419345:+@exon:chr10:101...                   NaN
#
#                                                     isoform2_iupred_score  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...               0.638962
# exon:chr10:100193697-100193848:-@exon:chr10:100...                    NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                    NaN
# exon:chr10:101165513-101165617:-@exon:chr10:101...               0.223048
# exon:chr10:101419263-101419345:+@exon:chr10:101...                    NaN
#
#                                                    exon2_splice_site_3p_score  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                       7.77
# exon:chr10:100193697-100193848:-@exon:chr10:100...                       9.08
# exon:chr10:100195392-100195529:-@exon:chr10:100...                       7.92
# exon:chr10:101165513-101165617:-@exon:chr10:101...                      10.79
# exon:chr10:101419263-101419345:+@exon:chr10:101...                       5.04
#
#                                                    exon2_splice_site_3p_seq  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  CTCTCCCCTGCCCTGCACAGCCT
# exon:chr10:100193697-100193848:-@exon:chr10:100...  TCCCTTCCTGCCCTGGCTAGGCC
# exon:chr10:100195392-100195529:-@exon:chr10:100...  TGGCCTGCCTGTGCCTGCAGTTT
# exon:chr10:101165513-101165617:-@exon:chr10:101...  CTCACTTTGCTTCCCCGCAGCAC
# exon:chr10:101419263-101419345:+@exon:chr10:101...  CTGAAATCAAATCTTTCTAGGCT
#
#                                                    exon2_splice_site_5p_score  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                       6.96
# exon:chr10:100193697-100193848:-@exon:chr10:100...                       7.96
# exon:chr10:100195392-100195529:-@exon:chr10:100...                       6.05
# exon:chr10:101165513-101165617:-@exon:chr10:101...                       8.34
# exon:chr10:101419263-101419345:+@exon:chr10:101...                       9.31
#
#                                                    exon2_splice_site_5p_seq  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                ACGGTGTGT
# exon:chr10:100193697-100193848:-@exon:chr10:100...                TAGGTGAGC
# exon:chr10:100195392-100195529:-@exon:chr10:100...                GGAGTGAGT
# exon:chr10:101165513-101165617:-@exon:chr10:101...                ACAGTGAGT
# exon:chr10:101419263-101419345:+@exon:chr10:101...                TAGGTAAGG
#
#                                                    exon2_phastcons_placental_mammal
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                         0.291112
# exon:chr10:100193697-100193848:-@exon:chr10:100...                         0.803519
# exon:chr10:100195392-100195529:-@exon:chr10:100...                         0.839394
# exon:chr10:101165513-101165617:-@exon:chr10:101...                         0.978780
# exon:chr10:101419263-101419345:+@exon:chr10:101...                         0.934804
#
# [5 rows x 58 columns]

# %%
splicing_feature_data.tail()
# Out:
#                                                     criteria  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...  only one
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...  only one
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...  only one
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...  only one
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...  only one
#
#                                                    criteria_additional  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...                 NaN
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...                 NaN
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...                 NaN
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...                 NaN
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...                 NaN
#
#                                                    criteria_full  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...      only one
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...      only one
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...      only one
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...      only one
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...      only one
#
#                                                          ensembl_id  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...  ENSGR0000169084
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...  ENSG00000129824
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...  ENSG00000129824
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...  ENSG00000129824
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...  ENSG00000129824
#
#                                                                           exon1  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...  exon:chrY:2293238-2293345:-
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...  exon:chrY:2709527-2709668:+
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...  exon:chrY:2710206-2710283:+
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...  exon:chrY:2712118-2712298:+
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...  exon:chrY:2713687-2713784:+
#
#                                                     exon1_length  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...           108
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...           142
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...            78
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...           181
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...            98
#
#                                                                           exon2  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...  exon:chrY:2276786-2276854:-
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...  exon:chrY:2710206-2710283:+
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...  exon:chrY:2712118-2712298:+
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...  exon:chrY:2713687-2713784:+
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...  exon:chrY:2722641-2722812:+
#
#                                                     exon2_length  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...            69
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...            78
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...           181
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...            98
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...           172
#
#                                                                           exon3  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...  exon:chrY:2260395-2260515:-
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...  exon:chrY:2712118-2712298:+
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...  exon:chrY:2713687-2713784:+
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...  exon:chrY:2722641-2722812:+
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...  exon:chrY:2733129-2733286:+
#
#                                                     exon3_length  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...           121
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...           181
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...            98
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...           172
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...           158
#
#                                                                  ...                 \
# event_id                                                         ...
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...               ...
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...               ...
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...               ...
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...               ...
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...               ...
#
#                                                    isoform2_protein_secondary_structure_turn  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...                                  0.217391
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...                                  0.203390
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...                                       NaN
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...                                       NaN
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...                                       NaN
#
#                                                     isoform1_aromaticity  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...                   NaN
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...                   NaN
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...                   NaN
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...                   NaN
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...                   NaN
#
#                                                    isoform2_aromaticity  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...             0.065217
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...             0.084746
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...                  NaN
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...                  NaN
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...                  NaN
#
#                                                    isoform1_iupred_score  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...                   NaN
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...                   NaN
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...                   NaN
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...                   NaN
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...                   NaN
#
#                                                     isoform2_iupred_score  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...               0.261901
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...               0.369364
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...               0.291594
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...               0.111193
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...               0.243487
#
#                                                    exon2_splice_site_3p_score  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...                      11.41
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...                       9.46
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...                      11.80
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...                       6.92
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...                       6.63
#
#                                                    exon2_splice_site_3p_seq  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...  TTTTTTCTTTTTCCTTTTAGCTG
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...  GAGTTTCGTGTCCTTTTCAGGCC
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...  CCTTTCCTTGTCTTCTACAGGCA
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...  TTATACCCTTTTGTGATCAGATG
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...  TTTCCTTGCTGTGTTTATAGTAC
#
#                                                    exon2_splice_site_5p_score  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...                       9.67
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...                       5.91
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...                       9.08
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...                       9.79
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...                      10.86
#
#                                                    exon2_splice_site_5p_seq  \
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...                AAGGTACCG
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...                TTTGTGAGT
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...                TGGGTAAGG
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...                AAGGTATGT
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...                CAGGTAAGT
#
#                                                    exon2_phastcons_placental_mammal
# event_id
# exon:chrY:2293238-2293345:-@exon:chrY:2276786-2...                         0.028882
# exon:chrY:2709527-2709668:+@exon:chrY:2710206-2...                         0.018844
# exon:chrY:2710206-2710283:+@exon:chrY:2712118-2...                         0.069050
# exon:chrY:2712118-2712298:+@exon:chrY:2713687-2...                         0.033577
# exon:chrY:2713687-2713784:+@exon:chrY:2722641-2...                         0.660287
#
# [5 rows x 58 columns]

# %% [markdown]
# ### Write the data!

# %%
splicing_feature_data.shape
# Out:
# (33693, 58)

# %%
splicing_feature_data.to_csv('{}/splicing_feature_data.csv'.format(folder))

# %%
folder
# Out:
# '/projects/ps-yeolab/obotvinnik/singlecell_pnms'
