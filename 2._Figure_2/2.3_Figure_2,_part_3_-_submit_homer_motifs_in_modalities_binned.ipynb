# %%
# %load_ext autoreload
# %autoreload 2


import modish
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

sns.set(style='ticks', context='talk', rc={'font.sans-serif':'Arial', 'pdf.fonttype': 42})

# %matplotlib inline


folder = '/home/obotvinnik/Dropbox/figures2/singlecell_pnm/figure2_modalities_motifs/binned'
! mkdir $folder

import flotilla
flotilla_dir = '/projects/ps-yeolab/obotvinnik/flotilla_projects'

study = flotilla.embark('singlecell_pnm_figure2_modalities_binned', flotilla_dir=flotilla_dir)
not_outliers = study.splicing.singles.index.difference(study.splicing.outliers.index)

psi = study.splicing.singles.ix[not_outliers]
grouped = psi.groupby(study.sample_id_to_phenotype)
psi_filtered = grouped.apply(lambda x: x.dropna(axis=1, thresh=20))
# Out:
# mkdir: cannot create directory `/home/obotvinnik/Dropbox/figures2/singlecell_pnm/figure2_modalities_motifs/binned': No such file or directory
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:784: UserWarning: Found matplotlib configuration in ~/.matplotlib/. To conform with the XDG base directory standard, this configuration location has been deprecated on Linux, and the new location is now /home/obotvinnik/.config/matplotlib/. Please move your configuration there to ensure that matplotlib will continue to find it in the future.
#   _get_xdg_config_dir())
# /home/obotvinnik/workspace-git/flotilla/flotilla/__init__.py:55: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   load_species_data=load_species_data)
# 2015-12-03 09:38:57	Reading datapackage from /projects/ps-yeolab/obotvinnik/flotilla_projects/singlecell_pnm_figure2_modalities_binned/datapackage.json
# 2015-12-03 09:38:57	Parsing datapackage to create a Study object
# 2015-12-03 09:39:41	Initializing Study
# 2015-12-03 09:39:41	Initializing Predictor configuration manager for Study
# 2015-12-03 09:39:41	Predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# 2015-12-03 09:39:41	Added ExtraTreesClassifier to default predictors
# 2015-12-03 09:39:41	Predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# 2015-12-03 09:39:41	Added ExtraTreesRegressor to default predictors
# 2015-12-03 09:39:41	Predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# 2015-12-03 09:39:41	Added GradientBoostingClassifier to default predictors
# 2015-12-03 09:39:41	Predictor GradientBoostingRegressor is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# 2015-12-03 09:39:41	Added GradientBoostingRegressor to default predictors
# 2015-12-03 09:39:46	Building Gene Ontology database...
# 2015-12-03 09:39:56		Done.
# 2015-12-03 09:39:56	Loading metadata
# 2015-12-03 09:39:56	Loading expression data
# 2015-12-03 09:39:56	Initializing expression
# 2015-12-03 09:39:57	Done initializing expression
# 2015-12-03 09:39:59	Loading splicing data
# 2015-12-03 09:39:59	Initializing splicing
# 2015-12-03 09:39:59	Done initializing splicing
# 2015-12-03 09:39:59	Successfully initialized a Study object!

# %% [markdown]
# ### Make BED files of each modality within each celltype
#
# Use the other modalities, within that celltype, as background.
#
#   - What properties are unique to events that are bimodal in iPSC, rather than ~0 or ~1?
#     - Foreground: Bimodal events in iPSC
#     - Background: All other events in iPSC

# %%
# %%time 

# bed_folder = '/projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities'
# ! mkdir $bed_folder
# import pybedtools

# DIR = '/projects/ps-yeolab/obotvinnik/singlecell_pnms'

# exon_bedfile = '{}/exon2.bed'.format(DIR)
# exon_bed = pybedtools.BedTool(exon_bedfile)



# for phenotype, phenotype_df in study.supplemental.modalities_tidy.groupby('phenotype'):
#     background_events = set(phenotype_df.event_name)
#     for modality, modality_df in phenotype_df.groupby('modality'):
#         event_names = set(modality_df.event_name)
#         format_args = bed_folder, phenotype, modality
#         filtered_bed = exon_bed.filter(lambda x: x.name in event_names)
#         filtered_filename = '{}/exon2_{}_{}.bed'.format(*format_args)
#         filtered_bed.saveas(filtered_filename)

#         background_bed = exon_bed.filter(lambda x: x.name not in event_names and x.name in background_events)
#         background_filename = '{}/exon2_{}_{}_background.bed'.format(*format_args)
#         background_bed.saveas(background_filename)

#         ! wc -l $filtered_filename
#         ! wc -l $background_filename

# %%
bed_folder = '/projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned'
! mkdir $bed_folder
# Out:
# mkdir: cannot create directory `/projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned': File exists

# %%
ls $bed_folder/homer
# Out:
# exon2_MN_bimodal/                               homer.err-17  homer.out-13
# exon2_MN_bimodal.bed/                           homer.err-18  homer.out-14
# exon2_MN_bimodal_downstream400_placental/       homer.err-19  homer.out-15
# exon2_MN_bimodal_downstream400_primate/         homer.err-2   homer.out-16
# exon2_MN_bimodal_placental/                     homer.err-20  homer.out-17
# exon2_MN_bimodal_primate/                       homer.err-21  homer.out-18
# exon2_MN_multimodal.bed/                        homer.err-22  homer.out-19
# exon2_MN_multimodal_downstream400_placental/    homer.err-23  homer.out-2
# exon2_MN_multimodal_downstream400_primate/      homer.err-24  homer.out-20
# exon2_MN_multimodal_placental/                  homer.err-25  homer.out-21
# exon2_MN_multimodal_primate/                    homer.err-26  homer.out-22
# exon2_MN_~0.bed/                                homer.err-27  homer.out-23
# exon2_MN_~0_downstream400_placental/            homer.err-28  homer.out-24
# exon2_MN_~0_downstream400_primate/              homer.err-29  homer.out-25
# exon2_MN_~0_placental/                          homer.err-3   homer.out-26
# exon2_MN_~0_primate/                            homer.err-30  homer.out-27
# exon2_MN_~1.bed/                                homer.err-31  homer.out-28
# exon2_MN_~1_downstream400_placental/            homer.err-32  homer.out-29
# exon2_MN_~1_downstream400_primate/              homer.err-33  homer.out-3
# exon2_MN_~1_placental/                          homer.err-34  homer.out-30
# exon2_MN_~1_primate/                            homer.err-35  homer.out-31
# exon2_NPC_bimodal.bed/                          homer.err-36  homer.out-32
# exon2_NPC_bimodal_downstream400_placental/      homer.err-37  homer.out-33
# exon2_NPC_bimodal_downstream400_primate/        homer.err-38  homer.out-34
# exon2_NPC_bimodal_placental/                    homer.err-39  homer.out-35
# exon2_NPC_bimodal_primate/                      homer.err-4   homer.out-36
# exon2_NPC_multimodal.bed/                       homer.err-40  homer.out-37
# exon2_NPC_multimodal_downstream400_placental/   homer.err-41  homer.out-38
# exon2_NPC_multimodal_downstream400_primate/     homer.err-42  homer.out-39
# exon2_NPC_multimodal_placental/                 homer.err-43  homer.out-4
# exon2_NPC_multimodal_primate/                   homer.err-44  homer.out-40
# exon2_NPC_~0.bed/                               homer.err-45  homer.out-41
# exon2_NPC_~0_downstream400_placental/           homer.err-46  homer.out-42
# exon2_NPC_~0_downstream400_primate/             homer.err-47  homer.out-43
# exon2_NPC_~0_placental/                         homer.err-48  homer.out-44
# exon2_NPC_~0_primate/                           homer.err-49  homer.out-45
# exon2_NPC_~1.bed/                               homer.err-5   homer.out-46
# exon2_NPC_~1_downstream400_placental/           homer.err-50  homer.out-47
# exon2_NPC_~1_downstream400_primate/             homer.err-51  homer.out-48
# exon2_NPC_~1_placental/                         homer.err-52  homer.out-49
# exon2_NPC_~1_primate/                           homer.err-53  homer.out-5
# exon2_iPSC_bimodal.bed/                         homer.err-54  homer.out-50
# exon2_iPSC_bimodal_downstream400_placental/     homer.err-55  homer.out-51
# exon2_iPSC_bimodal_downstream400_primate/       homer.err-56  homer.out-52
# exon2_iPSC_bimodal_placental/                   homer.err-57  homer.out-53
# exon2_iPSC_bimodal_primate/                     homer.err-58  homer.out-54
# exon2_iPSC_middle.bed/                          homer.err-59  homer.out-55
# exon2_iPSC_middle_downstream400_placental/      homer.err-6   homer.out-56
# exon2_iPSC_middle_downstream400_primate/        homer.err-60  homer.out-57
# exon2_iPSC_middle_placental/                    homer.err-61  homer.out-58
# exon2_iPSC_middle_primate/                      homer.err-62  homer.out-59
# exon2_iPSC_multimodal.bed/                      homer.err-63  homer.out-6
# exon2_iPSC_multimodal_downstream400_placental/  homer.err-64  homer.out-60
# exon2_iPSC_multimodal_downstream400_primate/    homer.err-65  homer.out-61
# exon2_iPSC_multimodal_placental/                homer.err-66  homer.out-62
# exon2_iPSC_multimodal_primate/                  homer.err-67  homer.out-63
# exon2_iPSC_~0.bed/                              homer.err-68  homer.out-64
# exon2_iPSC_~0_downstream400_placental/          homer.err-69  homer.out-65
# exon2_iPSC_~0_downstream400_primate/            homer.err-7   homer.out-66
# exon2_iPSC_~0_placental/                        homer.err-70  homer.out-67
# exon2_iPSC_~0_primate/                          homer.err-71  homer.out-68
# exon2_iPSC_~1.bed/                              homer.err-72  homer.out-69
# exon2_iPSC_~1_downstream400_placental/          homer.err-73  homer.out-7
# exon2_iPSC_~1_downstream400_primate/            homer.err-74  homer.out-70
# exon2_iPSC_~1_placental/                        homer.err-75  homer.out-71
# exon2_iPSC_~1_primate/                          homer.err-76  homer.out-72
# homer.err-1                                     homer.err-77  homer.out-73
# homer.err-10                                    homer.err-78  homer.out-74
# homer.err-11                                    homer.err-8   homer.out-75
# homer.err-12                                    homer.err-9   homer.out-76
# homer.err-13                                    homer.out-1   homer.out-77
# homer.err-14                                    homer.out-10  homer.out-78
# homer.err-15                                    homer.out-11  homer.out-8
# homer.err-16                                    homer.out-12  homer.out-9

# %%
! head $bed_folder/homer/homer.err-1
# Out:
# 	Position file = /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_foreground.bed
# 	Genome = hg19
# 	Output Directory = /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/homer/exon2_MN_bimodal.bed
# 	background position file: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_background.bed
# 	Operating in RNA mode
# 	Motif length set at 4,5,6,
# 	Will search for strings with 0 mismatches
# 	Using 4 CPUs
# 	Will not adjust sequences for CG content

# %%
import pyhomer

# %%
study.supplemental.modalities_tidy.groupby(['phenotype', 'modality']).size()
# Out:
# phenotype  modality
# MN         bimodal         99
#            multimodal      45
#            ~0             643
#            ~1            1809
# NPC        bimodal        177
#            multimodal      59
#            ~0            1261
#            ~1            3443
# iPSC       bimodal        306
#            middle           1
#            multimodal     213
#            ~0            1874
#            ~1            5239
# dtype: int64

# %%
kwargs = dict(asdf='aasdf', jkl=None)
kwargs
# Out:
# {'asdf': 'aasdf', 'jkl': None}

# %%
dict(filter(lambda x: x[1] is not None, kwargs.items()))
# Out:
# {'asdf': 'aasdf'}

# %%
import os

homer_dir = '{}/homer'.format(bed_folder)
# !mkdir -p $homer_dir

DIRECTIONS = 'upstream', 'downstream'


import pybedtools

DIR = '/projects/ps-yeolab/obotvinnik/singlecell_pnms'

exon_bedfile = '{}/exon2.bed'.format(DIR)
exon_bed = pybedtools.BedTool(exon_bedfile)

commands = []

findMotifsGenome = '/home/yeo-lab/software/homer/bin/findMotifsGenome.pl'
n_processors = 4
homer_flags = '-rna -len 4,5,6 -mset vertebrates -mis 0 -p {} -noweight'.format(n_processors)


primate_filename = '/projects/ps-yeolab/genomes/hg19/database/phastConsElements46wayPrimates.bed'
primate = pybedtools.BedTool(primate_filename)
placental_filename = '/projects/ps-yeolab/genomes/hg19/database/phastConsElements46wayPlacental.bed'
placental = pybedtools.BedTool(placental_filename)
conserved_regions = {'primate': primate, 'placental': placental}

genome = 'hg19'

nt = 400


for phenotype, phenotype_df in study.supplemental.modalities_tidy.groupby('phenotype'):
    background_events = set(phenotype_df.event_name)
    for modality, modality_df in phenotype_df.groupby('modality'):
        event_names = set(modality_df.event_name)
        format_args = bed_folder, phenotype, modality
        foreground_bed = exon_bed.filter(lambda x: x.name in event_names)
        foreground_filename = '{}/exon2_{}_{}_foreground.bed'.format(*format_args)
        foreground = pybedtools.BedTool(foreground_bed.saveas(foreground_filename))

        background_bed = exon_bed.filter(lambda x: x.name not in event_names and x.name in background_events)
        background_filename = '{}/exon2_{}_{}_background.bed'.format(*format_args)
        background = pybedtools.BedTool(background_bed.saveas(background_filename))
        
        pair = pyhomer.ForegroundBackgroundPair(foreground, background)
        print '\n', pair 
        
        suffix = os.path.basename(pair.foreground.fn).replace('_foreground.bed', '')
        out_dir = '{base_dir}/{suffix}'.format(base_dir=homer_dir, suffix=suffix)
#         command = pair.homer(homer_flags, findMotifsGenome, out_dir=out_dir)
#         commands.append(command)

        beds = {'background': background_bed, 'foreground': foreground_bed}
        
        for clade, conservation_bed in conserved_regions.items():
            conserved_pair = pair.intersect(conservation_bed, clade)
            print '\n', conserved_pair
            suffix = os.path.basename(conserved_pair.foreground.fn).replace('_foreground.bed', '')
            out_dir = '{base_dir}/{suffix}'.format(base_dir=homer_dir, suffix=suffix)
            command = pair.homer(homer_flags, findMotifsGenome, out_dir=out_dir)
            commands.append(command)
        
        for direction in DIRECTIONS:
            intron_pair = pair.flanking_intron('downstream', 'hg19', 400)
            print '\n', intron_pair
            suffix = os.path.basename(intron_pair.foreground.fn).replace('_foreground.bed', '')
            out_dir = '{base_dir}/{suffix}'.format(base_dir=homer_dir, suffix=suffix)
#             command = pair.homer(homer_flags, findMotifsGenome, out_dir=out_dir)
#             commands.append(command)

            for clade, conservation_bed in conserved_regions.items():
                conserved_introns = intron_pair.intersect(conservation_bed, clade)
                print '\n', conserved_introns
                suffix = os.path.basename(conserved_introns.foreground.fn).replace('_foreground.bed', '')
                out_dir = '{base_dir}/{suffix}'.format(base_dir=homer_dir, suffix=suffix)
                command = pair.homer(homer_flags, findMotifsGenome, out_dir=out_dir)
                commands.append(command)
# Out:
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_foreground.bed (99) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_background.bed (2497 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_placental_foreground.bed (153) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_placental_background.bed (4209 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_primate_foreground.bed (78) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_primate_background.bed (1869 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_downstream400_foreground.bed (99) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_downstream400_background.bed (2497 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_downstream400_placental_foreground.bed (241) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_downstream400_placental_background.bed (4441 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_downstream400_primate_foreground.bed (91) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_downstream400_primate_background.bed (2215 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_downstream400_foreground.bed (99) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_downstream400_background.bed (2497 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_downstream400_placental_foreground.bed (241) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_downstream400_placental_background.bed (4441 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_downstream400_primate_foreground.bed (91) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_downstream400_primate_background.bed (2215 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_foreground.bed (45) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_background.bed (2551 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_placental_foreground.bed (72) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_placental_background.bed (4290 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_primate_foreground.bed (40) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_primate_background.bed (1907 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_downstream400_foreground.bed (45) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_downstream400_background.bed (2551 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_downstream400_placental_foreground.bed (120) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_downstream400_placental_background.bed (4562 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_downstream400_primate_foreground.bed (53) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_downstream400_primate_background.bed (2253 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_downstream400_foreground.bed (45) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_downstream400_background.bed (2551 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_downstream400_placental_foreground.bed (120) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_downstream400_placental_background.bed (4562 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_downstream400_primate_foreground.bed (53) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_multimodal_downstream400_primate_background.bed (2253 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_foreground.bed (643) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_background.bed (1953 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_placental_foreground.bed (391) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_placental_background.bed (3971 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_primate_foreground.bed (176) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_primate_background.bed (1771 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_downstream400_foreground.bed (643) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_downstream400_background.bed (1953 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_downstream400_placental_foreground.bed (837) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_downstream400_placental_background.bed (3845 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_downstream400_primate_foreground.bed (298) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_downstream400_primate_background.bed (2008 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_downstream400_foreground.bed (643) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_downstream400_background.bed (1953 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_downstream400_placental_foreground.bed (837) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_downstream400_placental_background.bed (3845 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_downstream400_primate_foreground.bed (298) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~0_downstream400_primate_background.bed (2008 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_foreground.bed (1809) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_background.bed (787 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_placental_foreground.bed (3746) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_placental_background.bed (616 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_primate_foreground.bed (1653) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_primate_background.bed (294 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_downstream400_foreground.bed (1809) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_downstream400_background.bed (787 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_downstream400_placental_foreground.bed (3484) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_downstream400_placental_background.bed (1198 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_downstream400_primate_foreground.bed (1864) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_downstream400_primate_background.bed (442 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_downstream400_foreground.bed (1809) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_downstream400_background.bed (787 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_downstream400_placental_foreground.bed (3484) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_downstream400_placental_background.bed (1198 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_downstream400_primate_foreground.bed (1864) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_~1_downstream400_primate_background.bed (442 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_foreground.bed (177) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_background.bed (4763 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_placental_foreground.bed (313) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_placental_background.bed (8403 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_primate_foreground.bed (135) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_primate_background.bed (3542 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_downstream400_foreground.bed (177) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_downstream400_background.bed (4763 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_downstream400_placental_foreground.bed (441) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_downstream400_placental_background.bed (8174 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_downstream400_primate_foreground.bed (185) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_downstream400_primate_background.bed (4088 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_downstream400_foreground.bed (177) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_downstream400_background.bed (4763 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_downstream400_placental_foreground.bed (441) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_downstream400_placental_background.bed (8174 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_downstream400_primate_foreground.bed (185) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_bimodal_downstream400_primate_background.bed (4088 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_foreground.bed (59) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_background.bed (4881 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_placental_foreground.bed (126) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_placental_background.bed (8590 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_primate_foreground.bed (53) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_primate_background.bed (3624 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_downstream400_foreground.bed (59) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_downstream400_background.bed (4881 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_downstream400_placental_foreground.bed (177) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_downstream400_placental_background.bed (8438 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_downstream400_primate_foreground.bed (61) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_downstream400_primate_background.bed (4212 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_downstream400_foreground.bed (59) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_downstream400_background.bed (4881 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_downstream400_placental_foreground.bed (177) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_downstream400_placental_background.bed (8438 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_downstream400_primate_foreground.bed (61) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_multimodal_downstream400_primate_background.bed (4212 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_foreground.bed (1261) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_background.bed (3679 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_placental_foreground.bed (667) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_placental_background.bed (8049 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_primate_foreground.bed (347) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_primate_background.bed (3330 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_downstream400_foreground.bed (1261) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_downstream400_background.bed (3679 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_downstream400_placental_foreground.bed (1551) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_downstream400_placental_background.bed (7064 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_downstream400_primate_foreground.bed (568) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_downstream400_primate_background.bed (3705 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_downstream400_foreground.bed (1261) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_downstream400_background.bed (3679 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_downstream400_placental_foreground.bed (1551) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_downstream400_placental_background.bed (7064 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_downstream400_primate_foreground.bed (568) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~0_downstream400_primate_background.bed (3705 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_foreground.bed (3443) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_background.bed (1497 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_placental_foreground.bed (7610) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_placental_background.bed (1106 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_primate_foreground.bed (3142) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_primate_background.bed (535 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_downstream400_foreground.bed (3443) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_downstream400_background.bed (1497 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_downstream400_placental_foreground.bed (6446) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_downstream400_placental_background.bed (2169 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_downstream400_primate_foreground.bed (3459) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_downstream400_primate_background.bed (814 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_downstream400_foreground.bed (3443) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_downstream400_background.bed (1497 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_downstream400_placental_foreground.bed (6446) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_downstream400_placental_background.bed (2169 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_downstream400_primate_foreground.bed (3459) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_NPC_~1_downstream400_primate_background.bed (814 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_foreground.bed (306) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_background.bed (7327 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_placental_foreground.bed (660) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_placental_background.bed (13675 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_primate_foreground.bed (233) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_primate_background.bed (5432 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_downstream400_foreground.bed (306) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_downstream400_background.bed (7327 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_downstream400_placental_foreground.bed (643) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_downstream400_placental_background.bed (12561 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_downstream400_primate_foreground.bed (271) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_downstream400_primate_background.bed (6105 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_downstream400_foreground.bed (306) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_downstream400_background.bed (7327 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_downstream400_placental_foreground.bed (643) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_downstream400_placental_background.bed (12561 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_downstream400_primate_foreground.bed (271) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_bimodal_downstream400_primate_background.bed (6105 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_foreground.bed (1) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_background.bed (7632 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_placental_foreground.bed (1) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_placental_background.bed (14334 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_primate_foreground.bed (1) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_primate_background.bed (5664 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_downstream400_foreground.bed (1) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_downstream400_background.bed (7632 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_downstream400_placental_foreground.bed (5) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_downstream400_placental_background.bed (13199 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_downstream400_primate_foreground.bed (1) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_downstream400_primate_background.bed (6375 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_downstream400_foreground.bed (1) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_downstream400_background.bed (7632 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_downstream400_placental_foreground.bed (5) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_downstream400_placental_background.bed (13199 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_downstream400_primate_foreground.bed (1) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_middle_downstream400_primate_background.bed (6375 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_foreground.bed (213) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_background.bed (7420 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_placental_foreground.bed (349) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_placental_background.bed (13986 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_primate_foreground.bed (143) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_primate_background.bed (5522 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_downstream400_foreground.bed (213) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_downstream400_background.bed (7420 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_downstream400_placental_foreground.bed (455) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_downstream400_placental_background.bed (12749 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_downstream400_primate_foreground.bed (181) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_downstream400_primate_background.bed (6195 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_downstream400_foreground.bed (213) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_downstream400_background.bed (7420 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_downstream400_placental_foreground.bed (455) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_downstream400_placental_background.bed (12749 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_downstream400_primate_foreground.bed (181) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_multimodal_downstream400_primate_background.bed (6195 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_foreground.bed (1874) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_background.bed (5759 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_placental_foreground.bed (1081) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_placental_background.bed (13254 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_primate_foreground.bed (566) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_primate_background.bed (5099 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_downstream400_foreground.bed (1874) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_downstream400_background.bed (5759 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_downstream400_placental_foreground.bed (2513) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_downstream400_placental_background.bed (10691 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_downstream400_primate_foreground.bed (890) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_downstream400_primate_background.bed (5486 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_downstream400_foreground.bed (1874) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_downstream400_background.bed (5759 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_downstream400_placental_foreground.bed (2513) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_downstream400_placental_background.bed (10691 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_downstream400_primate_foreground.bed (890) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~0_downstream400_primate_background.bed (5486 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_foreground.bed (5239) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_background.bed (2394 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_placental_foreground.bed (12244) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_placental_background.bed (2091 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_primate_foreground.bed (4722) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_primate_background.bed (943 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_downstream400_foreground.bed (5239) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_downstream400_background.bed (2394 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_downstream400_placental_foreground.bed (9588) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_downstream400_placental_background.bed (3616 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_downstream400_primate_foreground.bed (5033) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_downstream400_primate_background.bed (1343 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_downstream400_foreground.bed (5239) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_downstream400_background.bed (2394 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_downstream400_placental_foreground.bed (9588) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_downstream400_placental_background.bed (3616 entries)
#
# ForegroundBackgroundPair:
# Foreground: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_downstream400_primate_foreground.bed (5033) entries
# Background: /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_iPSC_~1_downstream400_primate_background.bed (1343 entries)

# %%
len(commands)
# Out:
# 78

# %%
commands[0]
# Out:
# '/home/yeo-lab/software/homer/bin/findMotifsGenome.pl /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_foreground.bed hg19 /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/homer/exon2_MN_bimodal_placental -bg /projects/ps-yeolab/obotvinnik/singlecell_pnms/figure2_modalities/binned/exon2_MN_bimodal_background.bed -rna -len 4,5,6 -mset vertebrates -mis 0 -p 4 -noweight'

# %%
from gscripts.qtools import Submitter

jobname = 'homer'
sub = Submitter(commands, jobname, walltime='0:30:00', queue='home-scrm',
               ppn=n_processors, write_and_submit=True, array=True,
               out_filename='{}/{}.out'.format(homer_dir, jobname),
               err_filename='{}/{}.err'.format(homer_dir, jobname),)
# Out:
# running 78 tasks as an array-job.
# job ID: 3838653
