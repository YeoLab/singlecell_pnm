# %%
import pandas as pd

# %%
mxe_gencode_filename = '/home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/event.sorted.gencode.v19.bed'
mxe_gencode = pd.read_table(mxe_gencode_filename, header=None)
mxe_gencode.head()
# Out:
#      0       1       2                                                  3  4   \
# 0  chr1   17914   29370  isoform1=junction:chr1:18367-29320:-@exon:chr1...  .
# 1  chr1  677192  685396  isoform1=junction:chr1:679354-682074:-@novel_e...  .
# 2  chr1  678665  685396  isoform1=junction:chr1:679354-682074:-@novel_e...  .
# 3  chr1  762987  787490  isoform1=junction:chr1:763156-783033:+@exon:ch...  .
# 4  chr1  762987  784982  isoform1=junction:chr1:763156-783033:+@exon:ch...  .
#
#   5     6       7     8       9       10 11 12 13  \
# 0  -  chr1  HAVANA  gene   14363   29806  .  -  .
# 1  -  chr1  HAVANA  gene  677193  685396  .  -  .
# 2  -  chr1  HAVANA  gene  677193  685396  .  -  .
# 3  +  chr1  HAVANA  gene  762988  794826  .  +  .
# 4  +  chr1  HAVANA  gene  762988  794826  .  +  .
#
#                                                   14     15
# 0  gene_status "KNOWN"; havana_gene "OTTHUMG00000...  11456
# 1  gene_status "NOVEL"; havana_gene "OTTHUMG00000...   8204
# 2  gene_status "NOVEL"; havana_gene "OTTHUMG00000...   6731
# 3  gene_status "NOVEL"; havana_gene "OTTHUMG00000...  24503
# 4  gene_status "NOVEL"; havana_gene "OTTHUMG00000...  21995

# %%
def split_gtf_attributes(attributes):
    split = attributes.split('; ')
    pairs = [x.split(' ') for x in split]
    no_quotes = [map(lambda x: x.strip('";'), pair) for pair in pairs]
    mapping = dict(no_quotes)
    return mapping

# %%
# %%time

attributes = mxe_gencode[14].map(split_gtf_attributes).apply(pd.Series)
print(attributes.shape)
attributes.head()
# Out:
# (386635, 11)
#              gene_id       gene_name gene_status             gene_type  \
# 0  ENSG00000227232.4          WASH7P       KNOWN            pseudogene
# 1  ENSG00000235373.1   RP11-206L10.3       NOVEL               lincRNA
# 2  ENSG00000235373.1   RP11-206L10.3       NOVEL               lincRNA
# 3  ENSG00000228794.4  RP11-206L10.11       NOVEL  processed_transcript
# 4  ENSG00000228794.4  RP11-206L10.11       NOVEL  processed_transcript
#
#             havana_gene level  tag      transcript_id transcript_name  \
# 0  OTTHUMG00000000958.1     2  NaN  ENSG00000227232.4          WASH7P
# 1  OTTHUMG00000002407.1     2  NaN  ENSG00000235373.1   RP11-206L10.3
# 2  OTTHUMG00000002407.1     2  NaN  ENSG00000235373.1   RP11-206L10.3
# 3  OTTHUMG00000002468.5     2  NaN  ENSG00000228794.4  RP11-206L10.11
# 4  OTTHUMG00000002468.5     2  NaN  ENSG00000228794.4  RP11-206L10.11
#
#   transcript_status       transcript_type
# 0             KNOWN            pseudogene
# 1             NOVEL               lincRNA
# 2             NOVEL               lincRNA
# 3             NOVEL  processed_transcript
# 4             NOVEL  processed_transcript

# %%
attributes.index = mxe_gencode[3]
attributes.index.name = 'event_id'
attributes.head()
# Out:
#                                                               gene_id  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  ENSG00000227232.4
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
#
#                                                          gene_name  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...          WASH7P
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
#
#                                                    gene_status  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...       KNOWN
# isoform1=junction:chr1:679354-682074:-@novel_ex...       NOVEL
# isoform1=junction:chr1:679354-682074:-@novel_ex...       NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...       NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...       NOVEL
#
#                                                                gene_type  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...            pseudogene
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
#
#                                                              havana_gene  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  OTTHUMG00000000958.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  OTTHUMG00000002407.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  OTTHUMG00000002407.1
# isoform1=junction:chr1:763156-783033:+@exon:chr...  OTTHUMG00000002468.5
# isoform1=junction:chr1:763156-783033:+@exon:chr...  OTTHUMG00000002468.5
#
#                                                    level  tag  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...     2  NaN
# isoform1=junction:chr1:679354-682074:-@novel_ex...     2  NaN
# isoform1=junction:chr1:679354-682074:-@novel_ex...     2  NaN
# isoform1=junction:chr1:763156-783033:+@exon:chr...     2  NaN
# isoform1=junction:chr1:763156-783033:+@exon:chr...     2  NaN
#
#                                                         transcript_id  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  ENSG00000227232.4
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
#
#                                                    transcript_name  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...          WASH7P
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
#
#                                                    transcript_status  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...             KNOWN
# isoform1=junction:chr1:679354-682074:-@novel_ex...             NOVEL
# isoform1=junction:chr1:679354-682074:-@novel_ex...             NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...             NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...             NOVEL
#
#                                                          transcript_type
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...            pseudogene
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript

# %%
attributes.shape
# Out:
# (386635, 11)

# %%
attributes.shape[0] - attributes.index.duplicated().sum()
# Out:
# 18225

# %%
attributes_not_duplicated = attributes.loc[~attributes.index.duplicated()]
print(attributes_not_duplicated.shape)
attributes_not_duplicated.head()
# Out:
# (18225, 11)
#                                                               gene_id  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  ENSG00000227232.4
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
# isoform1=junction:chr1:764485-788050:+@exon:chr...  ENSG00000228794.4
#
#                                                          gene_name  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...          WASH7P
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
# isoform1=junction:chr1:764485-788050:+@exon:chr...  RP11-206L10.11
#
#                                                    gene_status  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...       KNOWN
# isoform1=junction:chr1:679354-682074:-@novel_ex...       NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...       NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...       NOVEL
# isoform1=junction:chr1:764485-788050:+@exon:chr...       NOVEL
#
#                                                                gene_type  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...            pseudogene
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
# isoform1=junction:chr1:764485-788050:+@exon:chr...  processed_transcript
#
#                                                              havana_gene  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  OTTHUMG00000000958.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  OTTHUMG00000002407.1
# isoform1=junction:chr1:763156-783033:+@exon:chr...  OTTHUMG00000002468.5
# isoform1=junction:chr1:763156-783033:+@exon:chr...  OTTHUMG00000002468.5
# isoform1=junction:chr1:764485-788050:+@exon:chr...  OTTHUMG00000002468.5
#
#                                                    level  tag  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...     2  NaN
# isoform1=junction:chr1:679354-682074:-@novel_ex...     2  NaN
# isoform1=junction:chr1:763156-783033:+@exon:chr...     2  NaN
# isoform1=junction:chr1:763156-783033:+@exon:chr...     2  NaN
# isoform1=junction:chr1:764485-788050:+@exon:chr...     2  NaN
#
#                                                         transcript_id  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  ENSG00000227232.4
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
# isoform1=junction:chr1:764485-788050:+@exon:chr...  ENSG00000228794.4
#
#                                                    transcript_name  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...          WASH7P
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
# isoform1=junction:chr1:764485-788050:+@exon:chr...  RP11-206L10.11
#
#                                                    transcript_status  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...             KNOWN
# isoform1=junction:chr1:679354-682074:-@novel_ex...             NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...             NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...             NOVEL
# isoform1=junction:chr1:764485-788050:+@exon:chr...             NOVEL
#
#                                                          transcript_type
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...            pseudogene
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
# isoform1=junction:chr1:764485-788050:+@exon:chr...  processed_transcript

# %%
ls /home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/events*
# Out:
# /home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/events.csv
# /home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/events.csv.back
# /home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/events.csv.bak

# %%
# ! cp /home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/events.csv \
#     /home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/events.csv.bak

# %%
mxe_events = pd.read_csv('/home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/events.csv', index_col=0)
print(mxe_events.shape)
mxe_events.head()
# Out:
# (325347, 5)
#                                                                              junction12  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212131:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212079:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212080-75212170:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212018-75212131:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180669235-180670691:-
#
#                                                                              junction13  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212222:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212222:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212080-75212209:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212018-75212157:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180668640-180670691:-
#
#                                                                              junction24  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212145-75212326:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212145-75212326:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212210-75212378:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212158-75212274:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180666583-180669169:-
#
#                                                                              junction34  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212301-75212326:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212288-75212326:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212301-75212378:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212223-75212274:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180666583-180668491:-
#
#                                                                                incompatible_junctions
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212326:+|junction:ch...
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212326:+|junction:ch...
# isoform1=junction:chr17:75212080-75212209:+@nov...  junction:chr17:75212080-75212378:+|junction:ch...
# isoform1=junction:chr17:75212018-75212157:+@nov...  junction:chr17:75212018-75212274:+|junction:ch...
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180666583-180670691:-|junction:c...

# %%
mxe_events_not_duplicated = mxe_events.drop_duplicates()
print(mxe_events_not_duplicated.shape)
mxe_events_not_duplicated.head()
# Out:
# (18257, 5)
#                                                                              junction12  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212131:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212079:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212080-75212170:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212018-75212131:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180669235-180670691:-
#
#                                                                              junction13  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212222:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212222:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212080-75212209:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212018-75212157:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180668640-180670691:-
#
#                                                                              junction24  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212145-75212326:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212145-75212326:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212210-75212378:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212158-75212274:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180666583-180669169:-
#
#                                                                              junction34  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212301-75212326:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212288-75212326:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212301-75212378:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212223-75212274:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180666583-180668491:-
#
#                                                                                incompatible_junctions
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212326:+|junction:ch...
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212326:+|junction:ch...
# isoform1=junction:chr17:75212080-75212209:+@nov...  junction:chr17:75212080-75212378:+|junction:ch...
# isoform1=junction:chr17:75212018-75212157:+@nov...  junction:chr17:75212018-75212274:+|junction:ch...
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180666583-180670691:-|junction:c...

# %%
mxe_events_attributes = mxe_events_not_duplicated.join(attributes_not_duplicated)
print(mxe_events_attributes.shape)
mxe_events_attributes.head()
# Out:
# (18257, 16)
#                                                                              junction12  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212131:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212079:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212080-75212170:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212018-75212131:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180669235-180670691:-
#
#                                                                              junction13  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212222:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212222:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212080-75212209:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212018-75212157:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180668640-180670691:-
#
#                                                                              junction24  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212145-75212326:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212145-75212326:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212210-75212378:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212158-75212274:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180666583-180669169:-
#
#                                                                              junction34  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212301-75212326:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212288-75212326:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212301-75212378:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212223-75212274:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180666583-180668491:-
#
#                                                                                incompatible_junctions  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212326:+|junction:ch...
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212326:+|junction:ch...
# isoform1=junction:chr17:75212080-75212209:+@nov...  junction:chr17:75212080-75212378:+|junction:ch...
# isoform1=junction:chr17:75212018-75212157:+@nov...  junction:chr17:75212018-75212274:+|junction:ch...
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180666583-180670691:-|junction:c...
#
#                                                                gene_id  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  ENSG00000129657.10
# isoform1=junction:chr17:75212018-75212222:+@nov...  ENSG00000129657.10
# isoform1=junction:chr17:75212080-75212209:+@nov...  ENSG00000129657.10
# isoform1=junction:chr17:75212018-75212157:+@nov...  ENSG00000129657.10
# isoform1=junction:chr5:180668640-180670691:-@ex...   ENSG00000272296.1
#
#                                                    gene_name gene_status  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   SEC14L1       KNOWN
# isoform1=junction:chr17:75212018-75212222:+@nov...   SEC14L1       KNOWN
# isoform1=junction:chr17:75212080-75212209:+@nov...   SEC14L1       KNOWN
# isoform1=junction:chr17:75212018-75212157:+@nov...   SEC14L1       KNOWN
# isoform1=junction:chr5:180668640-180670691:-@ex...  SNORD96A       KNOWN
#
#                                                          gene_type  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  protein_coding
# isoform1=junction:chr17:75212018-75212222:+@nov...  protein_coding
# isoform1=junction:chr17:75212080-75212209:+@nov...  protein_coding
# isoform1=junction:chr17:75212018-75212157:+@nov...  protein_coding
# isoform1=junction:chr5:180668640-180670691:-@ex...          snoRNA
#
#                                                               havana_gene  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  OTTHUMG00000177311.10
# isoform1=junction:chr17:75212018-75212222:+@nov...  OTTHUMG00000177311.10
# isoform1=junction:chr17:75212080-75212209:+@nov...  OTTHUMG00000177311.10
# isoform1=junction:chr17:75212018-75212157:+@nov...  OTTHUMG00000177311.10
# isoform1=junction:chr5:180668640-180670691:-@ex...                    NaN
#
#                                                    level  tag  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...     1  NaN
# isoform1=junction:chr17:75212018-75212222:+@nov...     1  NaN
# isoform1=junction:chr17:75212080-75212209:+@nov...     1  NaN
# isoform1=junction:chr17:75212018-75212157:+@nov...     1  NaN
# isoform1=junction:chr5:180668640-180670691:-@ex...     3  NaN
#
#                                                          transcript_id  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  ENSG00000129657.10
# isoform1=junction:chr17:75212018-75212222:+@nov...  ENSG00000129657.10
# isoform1=junction:chr17:75212080-75212209:+@nov...  ENSG00000129657.10
# isoform1=junction:chr17:75212018-75212157:+@nov...  ENSG00000129657.10
# isoform1=junction:chr5:180668640-180670691:-@ex...   ENSG00000272296.1
#
#                                                    transcript_name  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...         SEC14L1
# isoform1=junction:chr17:75212018-75212222:+@nov...         SEC14L1
# isoform1=junction:chr17:75212080-75212209:+@nov...         SEC14L1
# isoform1=junction:chr17:75212018-75212157:+@nov...         SEC14L1
# isoform1=junction:chr5:180668640-180670691:-@ex...        SNORD96A
#
#                                                    transcript_status  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...             KNOWN
# isoform1=junction:chr17:75212018-75212222:+@nov...             KNOWN
# isoform1=junction:chr17:75212080-75212209:+@nov...             KNOWN
# isoform1=junction:chr17:75212018-75212157:+@nov...             KNOWN
# isoform1=junction:chr5:180668640-180670691:-@ex...             KNOWN
#
#                                                    transcript_type
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  protein_coding
# isoform1=junction:chr17:75212018-75212222:+@nov...  protein_coding
# isoform1=junction:chr17:75212080-75212209:+@nov...  protein_coding
# isoform1=junction:chr17:75212018-75212157:+@nov...  protein_coding
# isoform1=junction:chr5:180668640-180670691:-@ex...          snoRNA

# %%
# ! head -n 5 /home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/exon*.bed

# %%
from outrigger.region import Region

# %%
mxe_exon_bed_template = '/home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/exon{}.bed'

exons = {}

for i in range(1, 5):
    exon = 'exon{}'.format(i)
    bed = mxe_exon_bed_template.format(i)
    exon_df = pd.read_table(bed, names=['chrom', 'start', 'stop', 'name', 'score', 'strand'])
    exon_regions = exon_df.apply(lambda row: Region('exon:{chrom}:{start}-{stop}:{strand}'.format(**row)), axis=1)
    exons[exon] = exon_regions
exon_regions_df = pd.DataFrame(exons)
exon_regions_df.head()
# Out:
#                                                exon1  \
# 0  outrigger.Region (exon:chr17:75211926-75212017:+)
# 1  outrigger.Region (exon:chr17:75211939-75212017:+)
# 2  outrigger.Region (exon:chr17:75212004-75212079:+)
# 3  outrigger.Region (exon:chr17:75211978-75212017:+)
# 4  outrigger.Region (exon:chr5:180670691-18067087...
#
#                                                exon2  \
# 0  outrigger.Region (exon:chr17:75212131-75212144:+)
# 1  outrigger.Region (exon:chr17:75212079-75212144:+)
# 2  outrigger.Region (exon:chr17:75212170-75212209:+)
# 3  outrigger.Region (exon:chr17:75212131-75212157:+)
# 4  outrigger.Region (exon:chr5:180669169-18066923...
#
#                                                exon3  \
# 0  outrigger.Region (exon:chr17:75212222-75212300:+)
# 1  outrigger.Region (exon:chr17:75212222-75212287:+)
# 2  outrigger.Region (exon:chr17:75212209-75212300:+)
# 3  outrigger.Region (exon:chr17:75212157-75212222:+)
# 4  outrigger.Region (exon:chr5:180668491-18066863...
#
#                                                exon4
# 0  outrigger.Region (exon:chr17:75212326-75212352:+)
# 1  outrigger.Region (exon:chr17:75212326-75212417:+)
# 2  outrigger.Region (exon:chr17:75212378-75212391:+)
# 3  outrigger.Region (exon:chr17:75212274-75212300:+)
# 4  outrigger.Region (exon:chr5:180666516-18066658...

# %%
exon_regions_df.shape
# Out:
# (325347, 4)

# %%
exon_str = exon_regions_df.applymap(lambda x: x.name)
exon_str.head()
# Out:
#                              exon1                            exon2  \
# 0   exon:chr17:75211926-75212017:+   exon:chr17:75212131-75212144:+
# 1   exon:chr17:75211939-75212017:+   exon:chr17:75212079-75212144:+
# 2   exon:chr17:75212004-75212079:+   exon:chr17:75212170-75212209:+
# 3   exon:chr17:75211978-75212017:+   exon:chr17:75212131-75212157:+
# 4  exon:chr5:180670691-180670872:-  exon:chr5:180669169-180669234:-
#
#                              exon3                            exon4
# 0   exon:chr17:75212222-75212300:+   exon:chr17:75212326-75212352:+
# 1   exon:chr17:75212222-75212287:+   exon:chr17:75212326-75212417:+
# 2   exon:chr17:75212209-75212300:+   exon:chr17:75212378-75212391:+
# 3   exon:chr17:75212157-75212222:+   exon:chr17:75212274-75212300:+
# 4  exon:chr5:180668491-180668639:-  exon:chr5:180666516-180666582:-

# %%
print(exon_str.shape)
# Out:
# (325347, 4)

# %%
exon_str_not_duplicated = exon_str.drop_duplicates()
print(exon_str_not_duplicated.shape)
exon_str_not_duplicated.head()
# Out:
# (325347, 4)
#                              exon1                            exon2  \
# 0   exon:chr17:75211926-75212017:+   exon:chr17:75212131-75212144:+
# 1   exon:chr17:75211939-75212017:+   exon:chr17:75212079-75212144:+
# 2   exon:chr17:75212004-75212079:+   exon:chr17:75212170-75212209:+
# 3   exon:chr17:75211978-75212017:+   exon:chr17:75212131-75212157:+
# 4  exon:chr5:180670691-180670872:-  exon:chr5:180669169-180669234:-
#
#                              exon3                            exon4
# 0   exon:chr17:75212222-75212300:+   exon:chr17:75212326-75212352:+
# 1   exon:chr17:75212222-75212287:+   exon:chr17:75212326-75212417:+
# 2   exon:chr17:75212209-75212300:+   exon:chr17:75212378-75212391:+
# 3   exon:chr17:75212157-75212222:+   exon:chr17:75212274-75212300:+
# 4  exon:chr5:180668491-180668639:-  exon:chr5:180666516-180666582:-

# %%
exon_str.index = mxe_events.index
print(exon_str.shape)
exon_str.head()
# Out:
# (325347, 4)
#                                                                               exon1  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75211926-75212017:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75211939-75212017:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   exon:chr17:75212004-75212079:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   exon:chr17:75211978-75212017:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  exon:chr5:180670691-180670872:-
#
#                                                                               exon2  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212131-75212144:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212079-75212144:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   exon:chr17:75212170-75212209:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   exon:chr17:75212131-75212157:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  exon:chr5:180669169-180669234:-
#
#                                                                               exon3  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212222-75212300:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212222-75212287:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   exon:chr17:75212209-75212300:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   exon:chr17:75212157-75212222:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  exon:chr5:180668491-180668639:-
#
#                                                                               exon4
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212326-75212352:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212326-75212417:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   exon:chr17:75212378-75212391:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   exon:chr17:75212274-75212300:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  exon:chr5:180666516-180666582:-

# %%
mxe_metadata = exon_str.join(mxe_events_attributes)
print(mxe_metadata.shape)
mxe_metadata.head()
# Out:
# (325347, 20)
#                                                                                exon1  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:102003454-102003534:-
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:102003454-102003529:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102013177-102013296:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102013177-102014376:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102013177-102013296:-
#
#                                                                                exon2  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101997778-101997988:-
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101997778-101997988:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102010004-102010070:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102010004-102010070:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102010004-102010070:-
#
#                                                                                exon3  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101996606-101996726:-
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101996606-101996726:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102003454-102003534:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102003454-102003534:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102003454-102003534:-
#
#                                                                                exon4  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101995423-101995521:-
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101995423-101995521:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:101997778-101997988:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:101997778-101997988:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:101997939-101997988:-
#
#                                                                               junction12  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101997989-102003454:-
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101997989-102003454:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102010071-102013177:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102010071-102013177:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102010071-102013177:-
#
#                                                                               junction13  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101996727-102003454:-
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101996727-102003454:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102003535-102013177:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102003535-102013177:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102003535-102013177:-
#
#                                                                               junction24  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-101997778:-
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-101997778:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102010004:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102010004:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102010004:-
#
#                                                                               junction34  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-101996606:-
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-101996606:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102003454:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102003454:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102003454:-
#
#                                                                                incompatible_junctions  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-102003454:-|junction:...
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-102003454:-|junction:...
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102013177:-|junction:...
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102013177:-|junction:...
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102013177:-|junction:...
#
#                                                               gene_id  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464.1
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224.1
#
#                                                    gene_name gene_status  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...   SNORA12       KNOWN
# isoform1=junction:chr10:101996727-102003454:-@e...   SNORA12       KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...     PHBP9       KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...     PHBP9       KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...     PHBP9       KNOWN
#
#                                                      gene_type  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...      snoRNA
# isoform1=junction:chr10:101996727-102003454:-@e...      snoRNA
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudogene
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudogene
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudogene
#
#                                                              havana_gene  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...                   NaN
# isoform1=junction:chr10:101996727-102003454:-@e...                   NaN
# isoform1=junction:chr10:102003535-102013177:-@e...  OTTHUMG00000018902.1
# isoform1=junction:chr10:102003535-102013177:-@e...  OTTHUMG00000018902.1
# isoform1=junction:chr10:102003535-102013177:-@e...  OTTHUMG00000018902.1
#
#                                                    level             tag  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...     3             NaN
# isoform1=junction:chr10:101996727-102003454:-@e...     3             NaN
# isoform1=junction:chr10:102003535-102013177:-@e...     1  pseudo_consens
# isoform1=junction:chr10:102003535-102013177:-@e...     1  pseudo_consens
# isoform1=junction:chr10:102003535-102013177:-@e...     1  pseudo_consens
#
#                                                         transcript_id  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464.1
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224.1
#
#                                                    transcript_name  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...         SNORA12
# isoform1=junction:chr10:101996727-102003454:-@e...         SNORA12
# isoform1=junction:chr10:102003535-102013177:-@e...           PHBP9
# isoform1=junction:chr10:102003535-102013177:-@e...           PHBP9
# isoform1=junction:chr10:102003535-102013177:-@e...           PHBP9
#
#                                                    transcript_status  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...             KNOWN
# isoform1=junction:chr10:101996727-102003454:-@e...             KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...             KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...             KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...             KNOWN
#
#                                                    transcript_type
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...          snoRNA
# isoform1=junction:chr10:101996727-102003454:-@e...          snoRNA
# isoform1=junction:chr10:102003535-102013177:-@e...      pseudogene
# isoform1=junction:chr10:102003535-102013177:-@e...      pseudogene
# isoform1=junction:chr10:102003535-102013177:-@e...      pseudogene

# %%
mxe_metadata['ensembl_id'] = mxe_metadata['gene_id'].str.split('.').str[0]
mxe_metadata.head()
# Out:
#                                                                                exon1  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:102003454-102003534:-
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:102003454-102003529:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102013177-102013296:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102013177-102014376:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102013177-102013296:-
#
#                                                                                exon2  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101997778-101997988:-
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101997778-101997988:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102010004-102010070:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102010004-102010070:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102010004-102010070:-
#
#                                                                                exon3  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101996606-101996726:-
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101996606-101996726:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102003454-102003534:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102003454-102003534:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102003454-102003534:-
#
#                                                                                exon4  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101995423-101995521:-
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101995423-101995521:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:101997778-101997988:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:101997778-101997988:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:101997939-101997988:-
#
#                                                                               junction12  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101997989-102003454:-
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101997989-102003454:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102010071-102013177:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102010071-102013177:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102010071-102013177:-
#
#                                                                               junction13  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101996727-102003454:-
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101996727-102003454:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102003535-102013177:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102003535-102013177:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102003535-102013177:-
#
#                                                                               junction24  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-101997778:-
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-101997778:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102010004:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102010004:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102010004:-
#
#                                                                               junction34  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-101996606:-
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-101996606:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102003454:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102003454:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102003454:-
#
#                                                                                incompatible_junctions  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-102003454:-|junction:...
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-102003454:-|junction:...
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102013177:-|junction:...
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102013177:-|junction:...
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102013177:-|junction:...
#
#                                                               gene_id  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464.1
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224.1
#
#                                                          ...         \
# event_id                                                 ...
# isoform1=junction:chr10:101996727-102003454:-@e...       ...
# isoform1=junction:chr10:101996727-102003454:-@e...       ...
# isoform1=junction:chr10:102003535-102013177:-@e...       ...
# isoform1=junction:chr10:102003535-102013177:-@e...       ...
# isoform1=junction:chr10:102003535-102013177:-@e...       ...
#
#                                                    gene_status   gene_type  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...       KNOWN      snoRNA
# isoform1=junction:chr10:101996727-102003454:-@e...       KNOWN      snoRNA
# isoform1=junction:chr10:102003535-102013177:-@e...       KNOWN  pseudogene
# isoform1=junction:chr10:102003535-102013177:-@e...       KNOWN  pseudogene
# isoform1=junction:chr10:102003535-102013177:-@e...       KNOWN  pseudogene
#
#                                                              havana_gene  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...                   NaN
# isoform1=junction:chr10:101996727-102003454:-@e...                   NaN
# isoform1=junction:chr10:102003535-102013177:-@e...  OTTHUMG00000018902.1
# isoform1=junction:chr10:102003535-102013177:-@e...  OTTHUMG00000018902.1
# isoform1=junction:chr10:102003535-102013177:-@e...  OTTHUMG00000018902.1
#
#                                                    level             tag  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...     3             NaN
# isoform1=junction:chr10:101996727-102003454:-@e...     3             NaN
# isoform1=junction:chr10:102003535-102013177:-@e...     1  pseudo_consens
# isoform1=junction:chr10:102003535-102013177:-@e...     1  pseudo_consens
# isoform1=junction:chr10:102003535-102013177:-@e...     1  pseudo_consens
#
#                                                         transcript_id  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464.1
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224.1
#
#                                                    transcript_name  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...         SNORA12
# isoform1=junction:chr10:101996727-102003454:-@e...         SNORA12
# isoform1=junction:chr10:102003535-102013177:-@e...           PHBP9
# isoform1=junction:chr10:102003535-102013177:-@e...           PHBP9
# isoform1=junction:chr10:102003535-102013177:-@e...           PHBP9
#
#                                                    transcript_status  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...             KNOWN
# isoform1=junction:chr10:101996727-102003454:-@e...             KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...             KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...             KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...             KNOWN
#
#                                                    transcript_type  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...          snoRNA
# isoform1=junction:chr10:101996727-102003454:-@e...          snoRNA
# isoform1=junction:chr10:102003535-102013177:-@e...      pseudogene
# isoform1=junction:chr10:102003535-102013177:-@e...      pseudogene
# isoform1=junction:chr10:102003535-102013177:-@e...      pseudogene
#
#                                                          ensembl_id
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224
#
# [5 rows x 21 columns]

# %%
mxe_metadata.to_csv('/projects/ps-yeolab/obotvinnik/singlecell_pnms/outrigger_v2/index/mxe/manual_metadata.csv')

# %%
mxe_metadata.query('gene_name == "PKM"').index.unique()
# Out:
# Index([u'isoform1=junction:chr15:72494962-72499068:-@exon:chr15:72494795-72494961:-@junction:chr15:72492997-72494794:-|isoform2=junction:chr15:72495530-72499068:-@exon:chr15:72495363-72495529:-@junction:chr15:72492997-72495362:-'], dtype='object', name=u'event_id')
