# %%
import pandas as pd

mxe_events = pd.read_csv('/home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/events.csv', index_col=0)
print(mxe_events.shape)
mxe_events.head(2)
# Out:
# (325347, 5)
#                                                                             junction12  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212131:+
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212079:+
#
#                                                                             junction13  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212222:+
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212222:+
#
#                                                                             junction24  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212145-75212326:+
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212145-75212326:+
#
#                                                                             junction34  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212301-75212326:+
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212288-75212326:+
#
#                                                                                incompatible_junctions
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212326:+|junction:ch...
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212326:+|junction:ch...

# %%
# mxe_events_not_duplicated = mxe_events.drop_duplicates()
# print(mxe_events_not_duplicated.shape)
# mxe_events_not_duplicated.head(2)

# %%
# ! head -n 5 /home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/exon*.bed

# %%
from outrigger.region import Region

# %%
mxe_exon_bed_template = '/home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/exon{}.bed'

exons = {}

for i in range(1, 5):
    exon = 'exon{}'.format(i)
    bed = mxe_exon_bed_template.format(i)
    exon_df = pd.read_table(bed, names=['chrom', 'start', 'stop', 'name', 'score', 'strand'])
    exon_regions = exon_df.apply(lambda row: Region('exon:{chrom}:{start}-{stop}:{strand}'.format(
                chrom=row.chrom, start=row.start+1, stop=row.stop, strand=row.strand)), axis=1)
    exons[exon] = exon_regions
exon_regions_df = pd.DataFrame(exons)
exon_regions_df.head()
# Out:
#                                                exon1  \
# 0  outrigger.Region (exon:chr17:75211927-75212017:+)
# 1  outrigger.Region (exon:chr17:75211940-75212017:+)
# 2  outrigger.Region (exon:chr17:75212005-75212079:+)
# 3  outrigger.Region (exon:chr17:75211979-75212017:+)
# 4  outrigger.Region (exon:chr5:180670692-18067087...
#
#                                                exon2  \
# 0  outrigger.Region (exon:chr17:75212132-75212144:+)
# 1  outrigger.Region (exon:chr17:75212080-75212144:+)
# 2  outrigger.Region (exon:chr17:75212171-75212209:+)
# 3  outrigger.Region (exon:chr17:75212132-75212157:+)
# 4  outrigger.Region (exon:chr5:180669170-18066923...
#
#                                                exon3  \
# 0  outrigger.Region (exon:chr17:75212223-75212300:+)
# 1  outrigger.Region (exon:chr17:75212223-75212287:+)
# 2  outrigger.Region (exon:chr17:75212210-75212300:+)
# 3  outrigger.Region (exon:chr17:75212158-75212222:+)
# 4  outrigger.Region (exon:chr5:180668492-18066863...
#
#                                                exon4
# 0  outrigger.Region (exon:chr17:75212327-75212352:+)
# 1  outrigger.Region (exon:chr17:75212327-75212417:+)
# 2  outrigger.Region (exon:chr17:75212379-75212391:+)
# 3  outrigger.Region (exon:chr17:75212275-75212300:+)
# 4  outrigger.Region (exon:chr5:180666517-18066658...

# %%
exon_regions_df.shape
# Out:
# (325347, 4)

# %%
exon_regions_df.index = mxe_events.index
print(exon_regions_df.shape)
exon_regions_df.head(2)
# Out:
# (325347, 4)
#                                                                                                 exon1  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75211927-75212017:+)
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75211940-75212017:+)
#
#                                                                                                 exon2  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75212132-75212144:+)
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75212080-75212144:+)
#
#                                                                                                 exon3  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75212223-75212300:+)
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75212223-75212287:+)
#
#                                                                                                 exon4
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75212327-75212352:+)
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75212327-75212417:+)

# %%
def make_introns(row):
    exon1 = row.iloc[0]
    exonN = row.iloc[-1]
    
    if exon1.strand == "+":
        start = exon1.stop
        stop = exonN.start
    elif exon1.strand == '-':
        start = exonN.stop
        stop = exon1.start
    return Region('intron:{chrom}:{start}-{stop}:{strand}'.format(
                chrom=exon1.chrom, start=start, stop=stop, strand=exon1.strand))

def event_location(row):
    exon1 = row.iloc[0]
    exonN = row.iloc[-1]
    
    if exon1.strand == "+":
        start = exon1.start
        stop = exonN.stop
    elif exon1.strand == '-':
        start = exonN.start
        stop = exon1.stop
    return Region('event:{chrom}:{start}-{stop}:{strand}'.format(
                chrom=exon1.chrom, start=start, stop=stop, strand=exon1.strand))


exon_regions_df['intron_location'] = exon_regions_df.apply(make_introns, axis=1)
exon_regions_df['event_location'] = exon_regions_df.apply(event_location, axis=1)
exon_regions_df.head(2)
# Out:
#                                                                                                 exon1  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75211927-75212017:+)
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75211940-75212017:+)
#
#                                                                                                 exon2  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75212132-75212144:+)
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75212080-75212144:+)
#
#                                                                                                 exon3  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75212223-75212300:+)
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75212223-75212287:+)
#
#                                                                                                 exon4  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75212327-75212352:+)
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (exon:chr17:75212327-75212417:+)
#
#                                                                                       intron_location  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (intron:chr17:75212017-752120...
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (intron:chr17:75212017-752120...
#
#                                                                                        event_location
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (event:chr17:75211927-7521201...
# isoform1=junction:chr17:75212018-75212222:+@nov...  outrigger.Region (event:chr17:75211940-7521201...

# %%
lengths = exon_regions_df.applymap(len)
lengths.columns = [x.split('_')[0] + '_length' for x in lengths.columns]
print(lengths.shape)
lengths.head()
# Out:
# (325347, 6)
#                                                     exon1_length  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...            91
# isoform1=junction:chr17:75212018-75212222:+@nov...            78
# isoform1=junction:chr17:75212080-75212209:+@nov...            75
# isoform1=junction:chr17:75212018-75212157:+@nov...            39
# isoform1=junction:chr5:180668640-180670691:-@ex...           181
#
#                                                     exon2_length  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...            13
# isoform1=junction:chr17:75212018-75212222:+@nov...            65
# isoform1=junction:chr17:75212080-75212209:+@nov...            39
# isoform1=junction:chr17:75212018-75212157:+@nov...            26
# isoform1=junction:chr5:180668640-180670691:-@ex...            65
#
#                                                     exon3_length  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...            78
# isoform1=junction:chr17:75212018-75212222:+@nov...            65
# isoform1=junction:chr17:75212080-75212209:+@nov...            91
# isoform1=junction:chr17:75212018-75212157:+@nov...            65
# isoform1=junction:chr5:180668640-180670691:-@ex...           148
#
#                                                     exon4_length  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...            26
# isoform1=junction:chr17:75212018-75212222:+@nov...            91
# isoform1=junction:chr17:75212080-75212209:+@nov...            13
# isoform1=junction:chr17:75212018-75212157:+@nov...            26
# isoform1=junction:chr5:180668640-180670691:-@ex...            66
#
#                                                     intron_length  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...              1
# isoform1=junction:chr17:75212018-75212222:+@nov...              1
# isoform1=junction:chr17:75212080-75212209:+@nov...              1
# isoform1=junction:chr17:75212018-75212157:+@nov...              1
# isoform1=junction:chr5:180668640-180670691:-@ex...              1
#
#                                                     event_length
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...            91
# isoform1=junction:chr17:75212018-75212222:+@nov...            78
# isoform1=junction:chr17:75212080-75212209:+@nov...            75
# isoform1=junction:chr17:75212018-75212157:+@nov...            39
# isoform1=junction:chr5:180668640-180670691:-@ex...           181

# %%
exon_str = exon_regions_df.applymap(lambda x: x.name)
exon_str.head()
# Out:
#                                                                               exon1  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75211927-75212017:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75211940-75212017:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   exon:chr17:75212005-75212079:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   exon:chr17:75211979-75212017:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  exon:chr5:180670692-180670872:-
#
#                                                                               exon2  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212132-75212144:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212080-75212144:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   exon:chr17:75212171-75212209:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   exon:chr17:75212132-75212157:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  exon:chr5:180669170-180669234:-
#
#                                                                               exon3  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212223-75212300:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212223-75212287:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   exon:chr17:75212210-75212300:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   exon:chr17:75212158-75212222:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  exon:chr5:180668492-180668639:-
#
#                                                                               exon4  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212327-75212352:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212327-75212417:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   exon:chr17:75212379-75212391:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   exon:chr17:75212275-75212300:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  exon:chr5:180666517-180666582:-
#
#                                                                       intron_location  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   intron:chr17:75212017-75212017:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   intron:chr17:75212017-75212017:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   intron:chr17:75212079-75212079:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   intron:chr17:75212017-75212017:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  intron:chr5:180670692-180670692:-
#
#                                                                       event_location
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   event:chr17:75211927-75212017:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   event:chr17:75211940-75212017:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   event:chr17:75212005-75212079:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   event:chr17:75211979-75212017:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  event:chr5:180670692-180670872:-

# %%
print(exon_str.shape)
# Out:
# (325347, 6)

# %%
event_location.shape
# Out:
# (386635,)

# %%
mxe_events_exons = pd.concat([mxe_events, exon_str], axis=1)
print(mxe_events_exons.shape)
mxe_events_exons.head()
# Out:
# (325347, 11)
#                                                                              junction12  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212131:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212079:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212080-75212170:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212018-75212131:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180669235-180670691:-
#
#                                                                              junction13  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212222:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212018-75212222:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212080-75212209:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212018-75212157:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180668640-180670691:-
#
#                                                                              junction24  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212145-75212326:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212145-75212326:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212210-75212378:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212158-75212274:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180666583-180669169:-
#
#                                                                              junction34  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212301-75212326:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   junction:chr17:75212288-75212326:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   junction:chr17:75212301-75212378:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   junction:chr17:75212223-75212274:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180666583-180668491:-
#
#                                                                                incompatible_junctions  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212326:+|junction:ch...
# isoform1=junction:chr17:75212018-75212222:+@nov...  junction:chr17:75212018-75212326:+|junction:ch...
# isoform1=junction:chr17:75212080-75212209:+@nov...  junction:chr17:75212080-75212378:+|junction:ch...
# isoform1=junction:chr17:75212018-75212157:+@nov...  junction:chr17:75212018-75212274:+|junction:ch...
# isoform1=junction:chr5:180668640-180670691:-@ex...  junction:chr5:180666583-180670691:-|junction:c...
#
#                                                                               exon1  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75211927-75212017:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75211940-75212017:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   exon:chr17:75212005-75212079:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   exon:chr17:75211979-75212017:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  exon:chr5:180670692-180670872:-
#
#                                                                               exon2  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212132-75212144:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212080-75212144:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   exon:chr17:75212171-75212209:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   exon:chr17:75212132-75212157:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  exon:chr5:180669170-180669234:-
#
#                                                                               exon3  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212223-75212300:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212223-75212287:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   exon:chr17:75212210-75212300:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   exon:chr17:75212158-75212222:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  exon:chr5:180668492-180668639:-
#
#                                                                               exon4  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212327-75212352:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   exon:chr17:75212327-75212417:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   exon:chr17:75212379-75212391:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   exon:chr17:75212275-75212300:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  exon:chr5:180666517-180666582:-
#
#                                                                       intron_location  \
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   intron:chr17:75212017-75212017:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   intron:chr17:75212017-75212017:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   intron:chr17:75212079-75212079:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   intron:chr17:75212017-75212017:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  intron:chr5:180670692-180670692:-
#
#                                                                       event_location
# event_id
# isoform1=junction:chr17:75212018-75212222:+@nov...   event:chr17:75211927-75212017:+
# isoform1=junction:chr17:75212018-75212222:+@nov...   event:chr17:75211940-75212017:+
# isoform1=junction:chr17:75212080-75212209:+@nov...   event:chr17:75212005-75212079:+
# isoform1=junction:chr17:75212018-75212157:+@nov...   event:chr17:75211979-75212017:+
# isoform1=junction:chr5:180668640-180670691:-@ex...  event:chr5:180670692-180670872:-

# %% [markdown]
# ## Combine with gencode information so we have the genes

# %%
mxe_gencode_filename = '/home/obotvinnik/projects/singlecell_pnms/analysis/outrigger_v2/index/mxe/event.sorted.gencode.v19.bed'
mxe_gencode = pd.read_table(mxe_gencode_filename, header=None)
mxe_gencode.head()
# Out:
#      0       1       2                                                  3  4   \
# 0  chr1   17914   29370  isoform1=junction:chr1:18367-29320:-@exon:chr1...  .
# 1  chr1  677192  685396  isoform1=junction:chr1:679354-682074:-@novel_e...  .
# 2  chr1  678665  685396  isoform1=junction:chr1:679354-682074:-@novel_e...  .
# 3  chr1  762987  787490  isoform1=junction:chr1:763156-783033:+@exon:ch...  .
# 4  chr1  762987  784982  isoform1=junction:chr1:763156-783033:+@exon:ch...  .
#
#   5     6       7     8       9       10 11 12 13  \
# 0  -  chr1  HAVANA  gene   14363   29806  .  -  .
# 1  -  chr1  HAVANA  gene  677193  685396  .  -  .
# 2  -  chr1  HAVANA  gene  677193  685396  .  -  .
# 3  +  chr1  HAVANA  gene  762988  794826  .  +  .
# 4  +  chr1  HAVANA  gene  762988  794826  .  +  .
#
#                                                   14     15
# 0  gene_status "KNOWN"; havana_gene "OTTHUMG00000...  11456
# 1  gene_status "NOVEL"; havana_gene "OTTHUMG00000...   8204
# 2  gene_status "NOVEL"; havana_gene "OTTHUMG00000...   6731
# 3  gene_status "NOVEL"; havana_gene "OTTHUMG00000...  24503
# 4  gene_status "NOVEL"; havana_gene "OTTHUMG00000...  21995

# %%
def split_gtf_attributes(attributes):
    split = attributes.split('; ')
    pairs = [x.split(' ') for x in split]
    no_quotes = [map(lambda x: x.strip('";'), pair) for pair in pairs]
    mapping = dict(no_quotes)
    return mapping

# %%
# %%time

attributes = mxe_gencode[14].map(split_gtf_attributes).apply(pd.Series)
print(attributes.shape)
attributes.head()
# Out:
# (386635, 11)
# CPU times: user 3min 8s, sys: 3.24 s, total: 3min 11s
# Wall time: 3min 11s

# %%
attributes.index = mxe_gencode[3]
attributes.index.name = 'event_id'
attributes.head()
# Out:
#                                                               gene_id  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  ENSG00000227232.4
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
#
#                                                          gene_name  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...          WASH7P
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
#
#                                                    gene_status  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...       KNOWN
# isoform1=junction:chr1:679354-682074:-@novel_ex...       NOVEL
# isoform1=junction:chr1:679354-682074:-@novel_ex...       NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...       NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...       NOVEL
#
#                                                                gene_type  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...            pseudogene
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
#
#                                                              havana_gene  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  OTTHUMG00000000958.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  OTTHUMG00000002407.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  OTTHUMG00000002407.1
# isoform1=junction:chr1:763156-783033:+@exon:chr...  OTTHUMG00000002468.5
# isoform1=junction:chr1:763156-783033:+@exon:chr...  OTTHUMG00000002468.5
#
#                                                    level  tag  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...     2  NaN
# isoform1=junction:chr1:679354-682074:-@novel_ex...     2  NaN
# isoform1=junction:chr1:679354-682074:-@novel_ex...     2  NaN
# isoform1=junction:chr1:763156-783033:+@exon:chr...     2  NaN
# isoform1=junction:chr1:763156-783033:+@exon:chr...     2  NaN
#
#                                                         transcript_id  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  ENSG00000227232.4
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
#
#                                                    transcript_name  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...          WASH7P
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
#
#                                                    transcript_status  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...             KNOWN
# isoform1=junction:chr1:679354-682074:-@novel_ex...             NOVEL
# isoform1=junction:chr1:679354-682074:-@novel_ex...             NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...             NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...             NOVEL
#
#                                                          transcript_type
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...            pseudogene
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript

# %%
attributes['ensembl_id'] = attributes['gene_id'].str.split('.').str[0]
attributes.head()
# Out:
#                                                               gene_id  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  ENSG00000227232.4
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
#
#                                                          gene_name  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...          WASH7P
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
#
#                                                    gene_status  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...       KNOWN
# isoform1=junction:chr1:679354-682074:-@novel_ex...       NOVEL
# isoform1=junction:chr1:679354-682074:-@novel_ex...       NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...       NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...       NOVEL
#
#                                                                gene_type  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...            pseudogene
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
#
#                                                              havana_gene  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  OTTHUMG00000000958.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  OTTHUMG00000002407.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  OTTHUMG00000002407.1
# isoform1=junction:chr1:763156-783033:+@exon:chr...  OTTHUMG00000002468.5
# isoform1=junction:chr1:763156-783033:+@exon:chr...  OTTHUMG00000002468.5
#
#                                                    level  tag  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...     2  NaN
# isoform1=junction:chr1:679354-682074:-@novel_ex...     2  NaN
# isoform1=junction:chr1:679354-682074:-@novel_ex...     2  NaN
# isoform1=junction:chr1:763156-783033:+@exon:chr...     2  NaN
# isoform1=junction:chr1:763156-783033:+@exon:chr...     2  NaN
#
#                                                         transcript_id  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  ENSG00000227232.4
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373.1
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794.4
#
#                                                    transcript_name  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...          WASH7P
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:679354-682074:-@novel_ex...   RP11-206L10.3
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
# isoform1=junction:chr1:763156-783033:+@exon:chr...  RP11-206L10.11
#
#                                                    transcript_status  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...             KNOWN
# isoform1=junction:chr1:679354-682074:-@novel_ex...             NOVEL
# isoform1=junction:chr1:679354-682074:-@novel_ex...             NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...             NOVEL
# isoform1=junction:chr1:763156-783033:+@exon:chr...             NOVEL
#
#                                                          transcript_type  \
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...            pseudogene
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:679354-682074:-@novel_ex...               lincRNA
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
# isoform1=junction:chr1:763156-783033:+@exon:chr...  processed_transcript
#
#                                                          ensembl_id
# event_id
# isoform1=junction:chr1:18367-29320:-@exon:chr1:...  ENSG00000227232
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373
# isoform1=junction:chr1:679354-682074:-@novel_ex...  ENSG00000235373
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794
# isoform1=junction:chr1:763156-783033:+@exon:chr...  ENSG00000228794

# %%
attributes_grouped = attributes.groupby(level=0, axis=0).apply(lambda df: df.apply(
        lambda x: ','.join(map(str, set(x.dropna().values)))))
print(attributes_grouped.shape)
attributes_grouped.head(2)
# Out:
# (18225, 12)
#                                                                                  gene_id  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464.1,ENSG00000095485.12
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000095485.12,ENSG00000230224.1
#
#                                                           gene_name  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  CWF19L1,SNORA12
# isoform1=junction:chr10:102003535-102013177:-@e...    CWF19L1,PHBP9
#
#                                                    gene_status  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...       KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...       KNOWN
#
#                                                                     gene_type  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...      snoRNA,protein_coding
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudogene,protein_coding
#
#                                                                                   havana_gene  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...                       OTTHUMG00000018901.5
# isoform1=junction:chr10:102003535-102013177:-@e...  OTTHUMG00000018901.5,OTTHUMG00000018902.1
#
#                                                    level  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...   3,2
# isoform1=junction:chr10:102003535-102013177:-@e...   1,2
#
#                                                                           tag  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...                 ncRNA_host
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudo_consens,ncRNA_host
#
#                                                                            transcript_id  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464.1,ENSG00000095485.12
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000095485.12,ENSG00000230224.1
#
#                                                     transcript_name  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  CWF19L1,SNORA12
# isoform1=junction:chr10:102003535-102013177:-@e...    CWF19L1,PHBP9
#
#                                                    transcript_status  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...             KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...             KNOWN
#
#                                                               transcript_type  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...      snoRNA,protein_coding
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudogene,protein_coding
#
#                                                                          ensembl_id
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464,ENSG00000095485
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224,ENSG00000095485

# %%
mxe_metadata = mxe_events_exons.join(attributes_grouped)
print(mxe_metadata.shape)
mxe_metadata.head()
# Out:
# (325347, 23)
#                                                                               junction12  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101997989-102003454:-
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101997989-102003454:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102010071-102013177:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102010071-102013177:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102010071-102013177:-
#
#                                                                               junction13  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101996727-102003454:-
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101996727-102003454:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102003535-102013177:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102003535-102013177:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:102003535-102013177:-
#
#                                                                               junction24  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-101997778:-
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-101997778:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102010004:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102010004:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102010004:-
#
#                                                                               junction34  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-101996606:-
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-101996606:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102003454:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102003454:-
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102003454:-
#
#                                                                                incompatible_junctions  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-102003454:-|junction:...
# isoform1=junction:chr10:101996727-102003454:-@e...  junction:chr10:101995522-102003454:-|junction:...
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102013177:-|junction:...
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102013177:-|junction:...
# isoform1=junction:chr10:102003535-102013177:-@e...  junction:chr10:101997989-102013177:-|junction:...
#
#                                                                                exon1  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:102003455-102003534:-
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:102003455-102003529:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102013178-102013296:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102013178-102014376:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102013178-102013296:-
#
#                                                                                exon2  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101997779-101997988:-
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101997779-101997988:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102010005-102010070:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102010005-102010070:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102010005-102010070:-
#
#                                                                                exon3  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101996607-101996726:-
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101996607-101996726:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102003455-102003534:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102003455-102003534:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:102003455-102003534:-
#
#                                                                                exon4  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101995424-101995521:-
# isoform1=junction:chr10:101996727-102003454:-@e...  exon:chr10:101995424-101995521:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:101997779-101997988:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:101997779-101997988:-
# isoform1=junction:chr10:102003535-102013177:-@e...  exon:chr10:101997940-101997988:-
#
#                                                                        intron_location  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  intron:chr10:102003455-102003455:-
# isoform1=junction:chr10:101996727-102003454:-@e...  intron:chr10:102003455-102003455:-
# isoform1=junction:chr10:102003535-102013177:-@e...  intron:chr10:102013178-102013178:-
# isoform1=junction:chr10:102003535-102013177:-@e...  intron:chr10:102013178-102013178:-
# isoform1=junction:chr10:102003535-102013177:-@e...  intron:chr10:102013178-102013178:-
#
#                                                                  ...                 \
# event_id                                                         ...
# isoform1=junction:chr10:101996727-102003454:-@e...               ...
# isoform1=junction:chr10:101996727-102003454:-@e...               ...
# isoform1=junction:chr10:102003535-102013177:-@e...               ...
# isoform1=junction:chr10:102003535-102013177:-@e...               ...
# isoform1=junction:chr10:102003535-102013177:-@e...               ...
#
#                                                    gene_status  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...       KNOWN
# isoform1=junction:chr10:101996727-102003454:-@e...       KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...       KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...       KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...       KNOWN
#
#                                                                     gene_type  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...      snoRNA,protein_coding
# isoform1=junction:chr10:101996727-102003454:-@e...      snoRNA,protein_coding
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudogene,protein_coding
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudogene,protein_coding
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudogene,protein_coding
#
#                                                                                   havana_gene  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...                       OTTHUMG00000018901.5
# isoform1=junction:chr10:101996727-102003454:-@e...                       OTTHUMG00000018901.5
# isoform1=junction:chr10:102003535-102013177:-@e...  OTTHUMG00000018901.5,OTTHUMG00000018902.1
# isoform1=junction:chr10:102003535-102013177:-@e...  OTTHUMG00000018901.5,OTTHUMG00000018902.1
# isoform1=junction:chr10:102003535-102013177:-@e...  OTTHUMG00000018901.5,OTTHUMG00000018902.1
#
#                                                    level  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...   3,2
# isoform1=junction:chr10:101996727-102003454:-@e...   3,2
# isoform1=junction:chr10:102003535-102013177:-@e...   1,2
# isoform1=junction:chr10:102003535-102013177:-@e...   1,2
# isoform1=junction:chr10:102003535-102013177:-@e...   1,2
#
#                                                                           tag  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...                 ncRNA_host
# isoform1=junction:chr10:101996727-102003454:-@e...                 ncRNA_host
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudo_consens,ncRNA_host
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudo_consens,ncRNA_host
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudo_consens,ncRNA_host
#
#                                                                            transcript_id  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464.1,ENSG00000095485.12
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464.1,ENSG00000095485.12
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000095485.12,ENSG00000230224.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000095485.12,ENSG00000230224.1
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000095485.12,ENSG00000230224.1
#
#                                                     transcript_name  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  CWF19L1,SNORA12
# isoform1=junction:chr10:101996727-102003454:-@e...  CWF19L1,SNORA12
# isoform1=junction:chr10:102003535-102013177:-@e...    CWF19L1,PHBP9
# isoform1=junction:chr10:102003535-102013177:-@e...    CWF19L1,PHBP9
# isoform1=junction:chr10:102003535-102013177:-@e...    CWF19L1,PHBP9
#
#                                                    transcript_status  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...             KNOWN
# isoform1=junction:chr10:101996727-102003454:-@e...             KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...             KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...             KNOWN
# isoform1=junction:chr10:102003535-102013177:-@e...             KNOWN
#
#                                                               transcript_type  \
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...      snoRNA,protein_coding
# isoform1=junction:chr10:101996727-102003454:-@e...      snoRNA,protein_coding
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudogene,protein_coding
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudogene,protein_coding
# isoform1=junction:chr10:102003535-102013177:-@e...  pseudogene,protein_coding
#
#                                                                          ensembl_id
# event_id
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464,ENSG00000095485
# isoform1=junction:chr10:101996727-102003454:-@e...  ENSG00000212464,ENSG00000095485
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224,ENSG00000095485
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224,ENSG00000095485
# isoform1=junction:chr10:102003535-102013177:-@e...  ENSG00000230224,ENSG00000095485
#
# [5 rows x 23 columns]

# %%
mxe_metadata.query('gene_name == "PKM"').index.unique()
# Out:
# Index([u'isoform1=junction:chr15:72494962-72499068:-@exon:chr15:72494795-72494961:-@junction:chr15:72492997-72494794:-|isoform2=junction:chr15:72495530-72499068:-@exon:chr15:72495363-72495529:-@junction:chr15:72492997-72495362:-'], dtype='object', name=u'event_id')

# %%
s = mxe_metadata['gene_name'].str.contains('SNAP25').dropna()

mxe_metadata.loc[s[s].index.unique()]
# Out:
#                                                                             junction12  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  junction:chr20:10199626-10207989:+
# isoform1=junction:chr20:10199626-10224622:+@nov...  junction:chr20:10199626-10207989:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10199626-10207989:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10199626-10207989:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10199626-10224622:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10199626-10224622:+
# isoform1=junction:chr20:10265421-10273808:+@exo...  junction:chr20:10265421-10273529:+
#
#                                                                             junction13  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  junction:chr20:10199626-10224622:+
# isoform1=junction:chr20:10199626-10224622:+@nov...  junction:chr20:10199626-10224622:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10199626-10241878:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10199626-10241878:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10199626-10241878:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10199626-10241878:+
# isoform1=junction:chr20:10265421-10273808:+@exo...  junction:chr20:10265421-10273808:+
#
#                                                                             junction24  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  junction:chr20:10208087-10256076:+
# isoform1=junction:chr20:10199626-10224622:+@nov...  junction:chr20:10208087-10256076:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10208087-10256076:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10208087-10256076:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10224683-10256076:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10224683-10256076:+
# isoform1=junction:chr20:10265421-10273808:+@exo...  junction:chr20:10273648-10277572:+
#
#                                                                             junction34  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  junction:chr20:10224683-10256076:+
# isoform1=junction:chr20:10199626-10224622:+@nov...  junction:chr20:10224683-10256076:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10241964-10256076:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10241964-10256076:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10241964-10256076:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10241964-10256076:+
# isoform1=junction:chr20:10265421-10273808:+@exo...  junction:chr20:10273927-10277572:+
#
#                                                                                incompatible_junctions  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  junction:chr20:10199626-10256076:+|junction:ch...
# isoform1=junction:chr20:10199626-10224622:+@nov...  junction:chr20:10199626-10256076:+|junction:ch...
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10199626-10256076:+|junction:ch...
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10199626-10256076:+|junction:ch...
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10199626-10256076:+|junction:ch...
# isoform1=junction:chr20:10199626-10241878:+@nov...  junction:chr20:10199626-10256076:+|junction:ch...
# isoform1=junction:chr20:10265421-10273808:+@exo...  junction:chr20:10265421-10277572:+|junction:ch...
#
#                                                                              exon1  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  exon:chr20:10199481-10199625:+
# isoform1=junction:chr20:10199626-10224622:+@nov...  exon:chr20:10199478-10199625:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10199478-10199625:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10199481-10199625:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10199481-10199625:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10199478-10199625:+
# isoform1=junction:chr20:10265421-10273808:+@exo...  exon:chr20:10265372-10265420:+
#
#                                                                              exon2  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  exon:chr20:10207990-10208086:+
# isoform1=junction:chr20:10199626-10224622:+@nov...  exon:chr20:10207990-10208086:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10207990-10208086:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10207990-10208086:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10224623-10224682:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10224623-10224682:+
# isoform1=junction:chr20:10265421-10273808:+@exo...  exon:chr20:10273530-10273647:+
#
#                                                                              exon3  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  exon:chr20:10224623-10224682:+
# isoform1=junction:chr20:10199626-10224622:+@nov...  exon:chr20:10224623-10224682:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10241879-10241963:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10241879-10241963:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10241879-10241963:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10241879-10241963:+
# isoform1=junction:chr20:10265421-10273808:+@exo...  exon:chr20:10273809-10273926:+
#
#                                                                              exon4  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  exon:chr20:10256077-10256211:+
# isoform1=junction:chr20:10199626-10224622:+@nov...  exon:chr20:10256077-10256211:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10256077-10256211:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10256077-10256211:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10256077-10256211:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  exon:chr20:10256077-10256211:+
# isoform1=junction:chr20:10265421-10273808:+@exo...  exon:chr20:10277573-10277698:+
#
#                                                                      intron_location  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  intron:chr20:10199625-10199625:+
# isoform1=junction:chr20:10199626-10224622:+@nov...  intron:chr20:10199625-10199625:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  intron:chr20:10199625-10199625:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  intron:chr20:10199625-10199625:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  intron:chr20:10199625-10199625:+
# isoform1=junction:chr20:10199626-10241878:+@nov...  intron:chr20:10199625-10199625:+
# isoform1=junction:chr20:10265421-10273808:+@exo...  intron:chr20:10265420-10265420:+
#
#                                                                  ...                 \
# event_id                                                         ...
# isoform1=junction:chr20:10199626-10224622:+@nov...               ...
# isoform1=junction:chr20:10199626-10224622:+@nov...               ...
# isoform1=junction:chr20:10199626-10241878:+@nov...               ...
# isoform1=junction:chr20:10199626-10241878:+@nov...               ...
# isoform1=junction:chr20:10199626-10241878:+@nov...               ...
# isoform1=junction:chr20:10199626-10241878:+@nov...               ...
# isoform1=junction:chr20:10265421-10273808:+@exo...               ...
#
#                                                    gene_status  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...       KNOWN
# isoform1=junction:chr20:10199626-10224622:+@nov...       KNOWN
# isoform1=junction:chr20:10199626-10241878:+@nov...       KNOWN
# isoform1=junction:chr20:10199626-10241878:+@nov...       KNOWN
# isoform1=junction:chr20:10199626-10241878:+@nov...       KNOWN
# isoform1=junction:chr20:10199626-10241878:+@nov...       KNOWN
# isoform1=junction:chr20:10265421-10273808:+@exo...       KNOWN
#
#                                                                    gene_type  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  antisense,protein_coding
# isoform1=junction:chr20:10199626-10224622:+@nov...  antisense,protein_coding
# isoform1=junction:chr20:10199626-10241878:+@nov...  antisense,protein_coding
# isoform1=junction:chr20:10199626-10241878:+@nov...  antisense,protein_coding
# isoform1=junction:chr20:10199626-10241878:+@nov...  antisense,protein_coding
# isoform1=junction:chr20:10199626-10241878:+@nov...  antisense,protein_coding
# isoform1=junction:chr20:10265421-10273808:+@exo...  antisense,protein_coding
#
#                                                                                   havana_gene  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  OTTHUMG00000031867.3,OTTHUMG00000031863.3
# isoform1=junction:chr20:10199626-10224622:+@nov...  OTTHUMG00000031867.3,OTTHUMG00000031863.3
# isoform1=junction:chr20:10199626-10241878:+@nov...  OTTHUMG00000031867.3,OTTHUMG00000031863.3
# isoform1=junction:chr20:10199626-10241878:+@nov...  OTTHUMG00000031867.3,OTTHUMG00000031863.3
# isoform1=junction:chr20:10199626-10241878:+@nov...  OTTHUMG00000031867.3,OTTHUMG00000031863.3
# isoform1=junction:chr20:10199626-10241878:+@nov...  OTTHUMG00000031867.3,OTTHUMG00000031863.3
# isoform1=junction:chr20:10265421-10273808:+@exo...  OTTHUMG00000031867.3,OTTHUMG00000031863.3
#
#                                                    level         tag  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...     2  ncRNA_host
# isoform1=junction:chr20:10199626-10224622:+@nov...     2  ncRNA_host
# isoform1=junction:chr20:10199626-10241878:+@nov...     2  ncRNA_host
# isoform1=junction:chr20:10199626-10241878:+@nov...     2  ncRNA_host
# isoform1=junction:chr20:10199626-10241878:+@nov...     2  ncRNA_host
# isoform1=junction:chr20:10199626-10241878:+@nov...     2  ncRNA_host
# isoform1=junction:chr20:10265421-10273808:+@exo...     2  ncRNA_host
#
#                                                                           transcript_id  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  ENSG00000132639.8,ENSG00000227906.3
# isoform1=junction:chr20:10199626-10224622:+@nov...  ENSG00000132639.8,ENSG00000227906.3
# isoform1=junction:chr20:10199626-10241878:+@nov...  ENSG00000132639.8,ENSG00000227906.3
# isoform1=junction:chr20:10199626-10241878:+@nov...  ENSG00000132639.8,ENSG00000227906.3
# isoform1=junction:chr20:10199626-10241878:+@nov...  ENSG00000132639.8,ENSG00000227906.3
# isoform1=junction:chr20:10199626-10241878:+@nov...  ENSG00000132639.8,ENSG00000227906.3
# isoform1=junction:chr20:10265421-10273808:+@exo...  ENSG00000132639.8,ENSG00000227906.3
#
#                                                       transcript_name  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  SNAP25,SNAP25-AS1
# isoform1=junction:chr20:10199626-10224622:+@nov...  SNAP25,SNAP25-AS1
# isoform1=junction:chr20:10199626-10241878:+@nov...  SNAP25,SNAP25-AS1
# isoform1=junction:chr20:10199626-10241878:+@nov...  SNAP25,SNAP25-AS1
# isoform1=junction:chr20:10199626-10241878:+@nov...  SNAP25,SNAP25-AS1
# isoform1=junction:chr20:10199626-10241878:+@nov...  SNAP25,SNAP25-AS1
# isoform1=junction:chr20:10265421-10273808:+@exo...  SNAP25,SNAP25-AS1
#
#                                                    transcript_status  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...             KNOWN
# isoform1=junction:chr20:10199626-10224622:+@nov...             KNOWN
# isoform1=junction:chr20:10199626-10241878:+@nov...             KNOWN
# isoform1=junction:chr20:10199626-10241878:+@nov...             KNOWN
# isoform1=junction:chr20:10199626-10241878:+@nov...             KNOWN
# isoform1=junction:chr20:10199626-10241878:+@nov...             KNOWN
# isoform1=junction:chr20:10265421-10273808:+@exo...             KNOWN
#
#                                                              transcript_type  \
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  antisense,protein_coding
# isoform1=junction:chr20:10199626-10224622:+@nov...  antisense,protein_coding
# isoform1=junction:chr20:10199626-10241878:+@nov...  antisense,protein_coding
# isoform1=junction:chr20:10199626-10241878:+@nov...  antisense,protein_coding
# isoform1=junction:chr20:10199626-10241878:+@nov...  antisense,protein_coding
# isoform1=junction:chr20:10199626-10241878:+@nov...  antisense,protein_coding
# isoform1=junction:chr20:10265421-10273808:+@exo...  antisense,protein_coding
#
#                                                                          ensembl_id
# event_id
# isoform1=junction:chr20:10199626-10224622:+@nov...  ENSG00000227906,ENSG00000132639
# isoform1=junction:chr20:10199626-10224622:+@nov...  ENSG00000227906,ENSG00000132639
# isoform1=junction:chr20:10199626-10241878:+@nov...  ENSG00000227906,ENSG00000132639
# isoform1=junction:chr20:10199626-10241878:+@nov...  ENSG00000227906,ENSG00000132639
# isoform1=junction:chr20:10199626-10241878:+@nov...  ENSG00000227906,ENSG00000132639
# isoform1=junction:chr20:10199626-10241878:+@nov...  ENSG00000227906,ENSG00000132639
# isoform1=junction:chr20:10265421-10273808:+@exo...  ENSG00000227906,ENSG00000132639
#
# [7 rows x 23 columns]

# %%
mxe_metadata['gene_name'].isnull().sum()
# Out:
# 46

# %%
mxe_metadata.to_csv('/projects/ps-yeolab/obotvinnik/singlecell_pnms/outrigger_v2/index/mxe/events_with_metadata.csv')
