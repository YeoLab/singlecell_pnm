# %%
import itertools

import pandas as pd
import gffutils
import pybedtools
import re
import numpy as np

v19db_filename = '/projects/ps-yeolab/genomes/hg19/gencode/v19/gencode.v19.annotation.gtf.db'
v19db = gffutils.FeatureDB(v19db_filename)

folder = '/projects/ps-yeolab/obotvinnik/singlecell_pnms'

exons_to_junctions = pd.read_csv('{}/exons_to_junctions_se.csv'.format(folder), index_col=[0, 1, 2], squeeze=True, header=None)
exons_to_junctions = exons_to_junctions.reset_index()
exons_to_junctions = exons_to_junctions.rename(columns={0: 'exon1', 1: 'exon2', 2: 'exon3', 3:'junctions'})
exons_to_junctions['junctions'] = exons_to_junctions.junctions.map(eval)
exons_to_junctions.head()
# Out:
#                               exon1                             exon2  \
# 0  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 1  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 2  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 3  exon:chr10:100193697-100193848:-  exon:chr10:100190888-100191048:-
# 4  exon:chr10:100195392-100195529:-  exon:chr10:100195029-100195171:-
#
#                               exon3  \
# 0  exon:chr10:100188908-100189399:-
# 1  exon:chr10:100188913-100189399:-
# 2  exon:chr10:100189330-100189399:-
# 3  exon:chr10:100190328-100190427:-
# 4  exon:chr10:100193697-100193848:-
#
#                                            junctions
# 0  (chr10:100189647-100190327:-, chr10:100189400-...
# 1  (chr10:100189647-100190327:-, chr10:100189400-...
# 2  (chr10:100189647-100190327:-, chr10:100189400-...
# 3  (chr10:100191049-100193696:-, chr10:100190428-...
# 4  (chr10:100195172-100195391:-, chr10:100193849-...

# %%
exons_to_junctions['event_id'] = exons_to_junctions['exon1'] + '@' \
    + exons_to_junctions['exon2'] + '@' + \
    exons_to_junctions['exon3']
exons_to_junctions.head()
# Out:
#                               exon1                             exon2  \
# 0  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 1  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 2  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 3  exon:chr10:100193697-100193848:-  exon:chr10:100190888-100191048:-
# 4  exon:chr10:100195392-100195529:-  exon:chr10:100195029-100195171:-
#
#                               exon3  \
# 0  exon:chr10:100188908-100189399:-
# 1  exon:chr10:100188913-100189399:-
# 2  exon:chr10:100189330-100189399:-
# 3  exon:chr10:100190328-100190427:-
# 4  exon:chr10:100193697-100193848:-
#
#                                            junctions  \
# 0  (chr10:100189647-100190327:-, chr10:100189400-...
# 1  (chr10:100189647-100190327:-, chr10:100189400-...
# 2  (chr10:100189647-100190327:-, chr10:100189400-...
# 3  (chr10:100191049-100193696:-, chr10:100190428-...
# 4  (chr10:100195172-100195391:-, chr10:100193849-...
#
#                                             event_id
# 0  exon:chr10:100190328-100190427:-@exon:chr10:10...
# 1  exon:chr10:100190328-100190427:-@exon:chr10:10...
# 2  exon:chr10:100190328-100190427:-@exon:chr10:10...
# 3  exon:chr10:100193697-100193848:-@exon:chr10:10...
# 4  exon:chr10:100195392-100195529:-@exon:chr10:10...

# %%
exon = v19db['exon:chr10:100189548-100189646:-']
exon.attributes['gene_name']
# Out:
# ['HPS1']

# %%
exon = v19db['exon:chr10:100189548-100189646:-']
exon.attributes['gene_id']
# Out:
# ['ENSG00000107521.14']

# %%
exon_cols = ['exon1', 'exon2', 'exon3']

# %%
exons_to_junctions['gencode_id'] = exons_to_junctions[exon_cols].apply(lambda x: ','.join(set(itertools.chain(*[v19db[i].attributes['gene_id'] for i in x]))), axis=1)

# %%
exons_to_junctions['gene_name'] = exons_to_junctions[exon_cols].apply(
    lambda x: ','.join(set(itertools.chain(*[v19db[i].attributes['gene_name'] for i in x]))), axis=1)

# %%
exons_to_junctions['ensembl_id'] = exons_to_junctions[exon_cols].apply(
    lambda x: ','.join(set(itertools.chain(*[map(lambda y: y.split('.')[0], v19db[i].attributes['gene_id']) for i in x]))), 
    axis=1)

# %%
from poshsplice.region import Region

# %%
exons_to_junctions['exon2_length'] = exons_to_junctions.exon2.map(lambda x: len(Region(x)))

# %%
ns = [1, 2, 3]
for n in ns:
    exons_to_junctions['exon{}_region'.format(n)] = exons_to_junctions['exon{}'.format(n)].map(Region)
    exons_to_junctions['exon{}_length'.format(n)] = exons_to_junctions['exon{}_region'.format(n)].map(len)

# %%
exons_to_junctions['strand'] = exons_to_junctions.exon1.str[-1]
exons_to_junctions.head()

# %%
positive_strand = exons_to_junctions.strand == '+'
exons_to_junctions['intron1_length'] = np.nan


exons_to_junctions.loc[positive_strand, 'intron1_length'] = \
    exons_to_junctions.loc[positive_strand].apply(lambda x: x.exon2_region._start - x.exon1_region._stop - 1, axis=1)
exons_to_junctions.loc[~positive_strand, 'intron1_length'] = \
    exons_to_junctions.loc[~positive_strand].apply(lambda x: x.exon1_region._start - x.exon2_region._stop - 1, axis=1)
exons_to_junctions.head()
# Out:
#                               exon1                             exon2  \
# 0  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 1  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 2  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 3  exon:chr10:100193697-100193848:-  exon:chr10:100190888-100191048:-
# 4  exon:chr10:100195392-100195529:-  exon:chr10:100195029-100195171:-
#
#                               exon3  \
# 0  exon:chr10:100188908-100189399:-
# 1  exon:chr10:100188913-100189399:-
# 2  exon:chr10:100189330-100189399:-
# 3  exon:chr10:100190328-100190427:-
# 4  exon:chr10:100193697-100193848:-
#
#                                            junctions  \
# 0  (chr10:100189647-100190327:-, chr10:100189400-...
# 1  (chr10:100189647-100190327:-, chr10:100189400-...
# 2  (chr10:100189647-100190327:-, chr10:100189400-...
# 3  (chr10:100191049-100193696:-, chr10:100190428-...
# 4  (chr10:100195172-100195391:-, chr10:100193849-...
#
#                                             event_id          gencode_id  \
# 0  exon:chr10:100190328-100190427:-@exon:chr10:10...  ENSG00000107521.14
# 1  exon:chr10:100190328-100190427:-@exon:chr10:10...  ENSG00000107521.14
# 2  exon:chr10:100190328-100190427:-@exon:chr10:10...  ENSG00000107521.14
# 3  exon:chr10:100193697-100193848:-@exon:chr10:10...  ENSG00000107521.14
# 4  exon:chr10:100195392-100195529:-@exon:chr10:10...  ENSG00000107521.14
#
#   gene_name       ensembl_id  exon2_length                      exon1_region  \
# 0      HPS1  ENSG00000107521            99  exon:chr10:100190328-100190427:-
# 1      HPS1  ENSG00000107521            99  exon:chr10:100190328-100190427:-
# 2      HPS1  ENSG00000107521            99  exon:chr10:100190328-100190427:-
# 3      HPS1  ENSG00000107521           161  exon:chr10:100193697-100193848:-
# 4      HPS1  ENSG00000107521           143  exon:chr10:100195392-100195529:-
#
#    exon1_length                      exon2_region  \
# 0           100  exon:chr10:100189548-100189646:-
# 1           100  exon:chr10:100189548-100189646:-
# 2           100  exon:chr10:100189548-100189646:-
# 3           152  exon:chr10:100190888-100191048:-
# 4           138  exon:chr10:100195029-100195171:-
#
#                        exon3_region  exon3_length strand  intron1_length
# 0  exon:chr10:100188908-100189399:-           492      -             681
# 1  exon:chr10:100188913-100189399:-           487      -             681
# 2  exon:chr10:100189330-100189399:-            70      -             681
# 3  exon:chr10:100190328-100190427:-           100      -            2648
# 4  exon:chr10:100193697-100193848:-           152      -             220

# %%
positive_strand = exons_to_junctions.strand == '+'
exons_to_junctions['intron2_length'] = np.nan


exons_to_junctions.loc[positive_strand, 'intron2_length'] = \
    exons_to_junctions.loc[positive_strand].apply(lambda x: x.exon3_region._start - x.exon2_region._stop - 1, axis=1)
exons_to_junctions.loc[~positive_strand, 'intron2_length'] = \
    exons_to_junctions.loc[~positive_strand].apply(lambda x: x.exon2_region._start - x.exon3_region._stop - 1, axis=1)
exons_to_junctions.head()
# Out:
#                               exon1                             exon2  \
# 0  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 1  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 2  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 3  exon:chr10:100193697-100193848:-  exon:chr10:100190888-100191048:-
# 4  exon:chr10:100195392-100195529:-  exon:chr10:100195029-100195171:-
#
#                               exon3  \
# 0  exon:chr10:100188908-100189399:-
# 1  exon:chr10:100188913-100189399:-
# 2  exon:chr10:100189330-100189399:-
# 3  exon:chr10:100190328-100190427:-
# 4  exon:chr10:100193697-100193848:-
#
#                                            junctions  \
# 0  (chr10:100189647-100190327:-, chr10:100189400-...
# 1  (chr10:100189647-100190327:-, chr10:100189400-...
# 2  (chr10:100189647-100190327:-, chr10:100189400-...
# 3  (chr10:100191049-100193696:-, chr10:100190428-...
# 4  (chr10:100195172-100195391:-, chr10:100193849-...
#
#                                             event_id          gencode_id  \
# 0  exon:chr10:100190328-100190427:-@exon:chr10:10...  ENSG00000107521.14
# 1  exon:chr10:100190328-100190427:-@exon:chr10:10...  ENSG00000107521.14
# 2  exon:chr10:100190328-100190427:-@exon:chr10:10...  ENSG00000107521.14
# 3  exon:chr10:100193697-100193848:-@exon:chr10:10...  ENSG00000107521.14
# 4  exon:chr10:100195392-100195529:-@exon:chr10:10...  ENSG00000107521.14
#
#   gene_name       ensembl_id  exon2_length                      exon1_region  \
# 0      HPS1  ENSG00000107521            99  exon:chr10:100190328-100190427:-
# 1      HPS1  ENSG00000107521            99  exon:chr10:100190328-100190427:-
# 2      HPS1  ENSG00000107521            99  exon:chr10:100190328-100190427:-
# 3      HPS1  ENSG00000107521           161  exon:chr10:100193697-100193848:-
# 4      HPS1  ENSG00000107521           143  exon:chr10:100195392-100195529:-
#
#    exon1_length                      exon2_region  \
# 0           100  exon:chr10:100189548-100189646:-
# 1           100  exon:chr10:100189548-100189646:-
# 2           100  exon:chr10:100189548-100189646:-
# 3           152  exon:chr10:100190888-100191048:-
# 4           138  exon:chr10:100195029-100195171:-
#
#                        exon3_region  exon3_length strand  intron1_length  \
# 0  exon:chr10:100188908-100189399:-           492      -             681
# 1  exon:chr10:100188913-100189399:-           487      -             681
# 2  exon:chr10:100189330-100189399:-            70      -             681
# 3  exon:chr10:100190328-100190427:-           100      -            2648
# 4  exon:chr10:100193697-100193848:-           152      -             220
#
#    intron2_length
# 0             148
# 1             148
# 2             148
# 3             460
# 4            1180

# %%
exons_to_junctions['intron12_length_summed'] = exons_to_junctions.intron1_length + exons_to_junctions.intron2_length
exons_to_junctions.head()
# Out:
#                               exon1                             exon2  \
# 0  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 1  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 2  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 3  exon:chr10:100193697-100193848:-  exon:chr10:100190888-100191048:-
# 4  exon:chr10:100195392-100195529:-  exon:chr10:100195029-100195171:-
#
#                               exon3  \
# 0  exon:chr10:100188908-100189399:-
# 1  exon:chr10:100188913-100189399:-
# 2  exon:chr10:100189330-100189399:-
# 3  exon:chr10:100190328-100190427:-
# 4  exon:chr10:100193697-100193848:-
#
#                                            junctions  \
# 0  (chr10:100189647-100190327:-, chr10:100189400-...
# 1  (chr10:100189647-100190327:-, chr10:100189400-...
# 2  (chr10:100189647-100190327:-, chr10:100189400-...
# 3  (chr10:100191049-100193696:-, chr10:100190428-...
# 4  (chr10:100195172-100195391:-, chr10:100193849-...
#
#                                             event_id          gencode_id  \
# 0  exon:chr10:100190328-100190427:-@exon:chr10:10...  ENSG00000107521.14
# 1  exon:chr10:100190328-100190427:-@exon:chr10:10...  ENSG00000107521.14
# 2  exon:chr10:100190328-100190427:-@exon:chr10:10...  ENSG00000107521.14
# 3  exon:chr10:100193697-100193848:-@exon:chr10:10...  ENSG00000107521.14
# 4  exon:chr10:100195392-100195529:-@exon:chr10:10...  ENSG00000107521.14
#
#   gene_name       ensembl_id  exon2_length                      exon1_region  \
# 0      HPS1  ENSG00000107521            99  exon:chr10:100190328-100190427:-
# 1      HPS1  ENSG00000107521            99  exon:chr10:100190328-100190427:-
# 2      HPS1  ENSG00000107521            99  exon:chr10:100190328-100190427:-
# 3      HPS1  ENSG00000107521           161  exon:chr10:100193697-100193848:-
# 4      HPS1  ENSG00000107521           143  exon:chr10:100195392-100195529:-
#
#    exon1_length                      exon2_region  \
# 0           100  exon:chr10:100189548-100189646:-
# 1           100  exon:chr10:100189548-100189646:-
# 2           100  exon:chr10:100189548-100189646:-
# 3           152  exon:chr10:100190888-100191048:-
# 4           138  exon:chr10:100195029-100195171:-
#
#                        exon3_region  exon3_length strand  intron1_length  \
# 0  exon:chr10:100188908-100189399:-           492      -             681
# 1  exon:chr10:100188913-100189399:-           487      -             681
# 2  exon:chr10:100189330-100189399:-            70      -             681
# 3  exon:chr10:100190328-100190427:-           100      -            2648
# 4  exon:chr10:100193697-100193848:-           152      -             220
#
#    intron2_length  intron12_length_summed
# 0             148                     829
# 1             148                     829
# 2             148                     829
# 3             460                    3108
# 4            1180                    1400

# %%
exons_to_junctions.dtypes
# Out:
# exon1                      object
# exon2                      object
# exon3                      object
# junctions                  object
# event_id                   object
# gencode_id                 object
# gene_name                  object
# ensembl_id                 object
# exon2_length                int64
# exon1_region               object
# exon1_length                int64
# exon2_region               object
# exon3_region               object
# exon3_length                int64
# strand                     object
# intron1_length            float64
# intron2_length            float64
# intron12_length_summed    float64
# exon2_divisible_by_3         bool
# dtype: object

# %%
exons_to_junctions['exon2_divisible_by_3'] = exons_to_junctions['exon2_length'].astype(int).mod(3) == 0
exons_to_junctions.head()
# Out:
#                               exon1                             exon2  \
# 0  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 1  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 2  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 3  exon:chr10:100193697-100193848:-  exon:chr10:100190888-100191048:-
# 4  exon:chr10:100195392-100195529:-  exon:chr10:100195029-100195171:-
#
#                               exon3  \
# 0  exon:chr10:100188908-100189399:-
# 1  exon:chr10:100188913-100189399:-
# 2  exon:chr10:100189330-100189399:-
# 3  exon:chr10:100190328-100190427:-
# 4  exon:chr10:100193697-100193848:-
#
#                                            junctions  \
# 0  (chr10:100189647-100190327:-, chr10:100189400-...
# 1  (chr10:100189647-100190327:-, chr10:100189400-...
# 2  (chr10:100189647-100190327:-, chr10:100189400-...
# 3  (chr10:100191049-100193696:-, chr10:100190428-...
# 4  (chr10:100195172-100195391:-, chr10:100193849-...
#
#                                             event_id          gencode_id  \
# 0  exon:chr10:100190328-100190427:-@exon:chr10:10...  ENSG00000107521.14
# 1  exon:chr10:100190328-100190427:-@exon:chr10:10...  ENSG00000107521.14
# 2  exon:chr10:100190328-100190427:-@exon:chr10:10...  ENSG00000107521.14
# 3  exon:chr10:100193697-100193848:-@exon:chr10:10...  ENSG00000107521.14
# 4  exon:chr10:100195392-100195529:-@exon:chr10:10...  ENSG00000107521.14
#
#   gene_name       ensembl_id  exon2_length                      exon1_region  \
# 0      HPS1  ENSG00000107521            99  exon:chr10:100190328-100190427:-
# 1      HPS1  ENSG00000107521            99  exon:chr10:100190328-100190427:-
# 2      HPS1  ENSG00000107521            99  exon:chr10:100190328-100190427:-
# 3      HPS1  ENSG00000107521           161  exon:chr10:100193697-100193848:-
# 4      HPS1  ENSG00000107521           143  exon:chr10:100195392-100195529:-
#
#    exon1_length                      exon2_region  \
# 0           100  exon:chr10:100189548-100189646:-
# 1           100  exon:chr10:100189548-100189646:-
# 2           100  exon:chr10:100189548-100189646:-
# 3           152  exon:chr10:100190888-100191048:-
# 4           138  exon:chr10:100195029-100195171:-
#
#                        exon3_region  exon3_length strand  intron1_length  \
# 0  exon:chr10:100188908-100189399:-           492      -             681
# 1  exon:chr10:100188913-100189399:-           487      -             681
# 2  exon:chr10:100189330-100189399:-            70      -             681
# 3  exon:chr10:100190328-100190427:-           100      -            2648
# 4  exon:chr10:100193697-100193848:-           152      -             220
#
#    intron2_length  intron12_length_summed exon2_divisible_by_3
# 0             148                     829                 True
# 1             148                     829                 True
# 2             148                     829                 True
# 3             460                    3108                False
# 4            1180                    1400                False

# %%
exons_to_junctions['exon2_divisible_by_3'].sum()/float(exons_to_junctions.shape[0])
# Out:
# 0.38737636382175999

# %%
cols = ['event_id', 'gencode_id', 'ensembl_id', 'gene_name', 'exon1_length', 
        'exon2_length', 'exon3_length', 'intron1_length', 
        'intron2_length', 'exon2_divisible_by_3', 'intron12_length_summed']
exon_metadata = exons_to_junctions[cols]
exon_metadata = exon_metadata.set_index('event_id')
exon_metadata.head()
# Out:
#                                                             gencode_id  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521.14
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521.14
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521.14
# exon:chr10:100193697-100193848:-@exon:chr10:100...  ENSG00000107521.14
# exon:chr10:100195392-100195529:-@exon:chr10:100...  ENSG00000107521.14
#
#                                                          ensembl_id gene_name  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521      HPS1
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521      HPS1
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521      HPS1
# exon:chr10:100193697-100193848:-@exon:chr10:100...  ENSG00000107521      HPS1
# exon:chr10:100195392-100195529:-@exon:chr10:100...  ENSG00000107521      HPS1
#
#                                                     exon1_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100193697-100193848:-@exon:chr10:100...           152
# exon:chr10:100195392-100195529:-@exon:chr10:100...           138
#
#                                                     exon2_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100193697-100193848:-@exon:chr10:100...           161
# exon:chr10:100195392-100195529:-@exon:chr10:100...           143
#
#                                                     exon3_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...           492
# exon:chr10:100190328-100190427:-@exon:chr10:100...           487
# exon:chr10:100190328-100190427:-@exon:chr10:100...            70
# exon:chr10:100193697-100193848:-@exon:chr10:100...           100
# exon:chr10:100195392-100195529:-@exon:chr10:100...           152
#
#                                                     intron1_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...             681
# exon:chr10:100190328-100190427:-@exon:chr10:100...             681
# exon:chr10:100190328-100190427:-@exon:chr10:100...             681
# exon:chr10:100193697-100193848:-@exon:chr10:100...            2648
# exon:chr10:100195392-100195529:-@exon:chr10:100...             220
#
#                                                     intron2_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...             148
# exon:chr10:100190328-100190427:-@exon:chr10:100...             148
# exon:chr10:100190328-100190427:-@exon:chr10:100...             148
# exon:chr10:100193697-100193848:-@exon:chr10:100...             460
# exon:chr10:100195392-100195529:-@exon:chr10:100...            1180
#
#                                                    exon2_divisible_by_3  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 True
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 True
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 True
# exon:chr10:100193697-100193848:-@exon:chr10:100...                False
# exon:chr10:100195392-100195529:-@exon:chr10:100...                False
#
#                                                     intron12_length_summed
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                     829
# exon:chr10:100190328-100190427:-@exon:chr10:100...                     829
# exon:chr10:100190328-100190427:-@exon:chr10:100...                     829
# exon:chr10:100193697-100193848:-@exon:chr10:100...                    3108
# exon:chr10:100195392-100195529:-@exon:chr10:100...                    1400

# %%
print exon_metadata.ensembl_id.str.contains(',').sum()
print exon_metadata.shape
# Out:
# 3928
# (58842, 10)

# %% [markdown]
# 3,928/58,842 splicing events have multiple gene ids associated with them. Since we want to intersect this information with existing gene annotations, we need a *single* id. To do this coarsely and simply, we will take the first gene ID for intersecting purposes.

# %%
exon_metadata['one_ensembl_id'] = exon_metadata.ensembl_id.str.split(',').str[0]
exon_metadata.head()
# Out:
#                                                             gencode_id  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521.14
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521.14
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521.14
# exon:chr10:100193697-100193848:-@exon:chr10:100...  ENSG00000107521.14
# exon:chr10:100195392-100195529:-@exon:chr10:100...  ENSG00000107521.14
#
#                                                          ensembl_id gene_name  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521      HPS1
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521      HPS1
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521      HPS1
# exon:chr10:100193697-100193848:-@exon:chr10:100...  ENSG00000107521      HPS1
# exon:chr10:100195392-100195529:-@exon:chr10:100...  ENSG00000107521      HPS1
#
#                                                     exon1_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100193697-100193848:-@exon:chr10:100...           152
# exon:chr10:100195392-100195529:-@exon:chr10:100...           138
#
#                                                     exon2_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100193697-100193848:-@exon:chr10:100...           161
# exon:chr10:100195392-100195529:-@exon:chr10:100...           143
#
#                                                     exon3_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...           492
# exon:chr10:100190328-100190427:-@exon:chr10:100...           487
# exon:chr10:100190328-100190427:-@exon:chr10:100...            70
# exon:chr10:100193697-100193848:-@exon:chr10:100...           100
# exon:chr10:100195392-100195529:-@exon:chr10:100...           152
#
#                                                     intron1_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...             681
# exon:chr10:100190328-100190427:-@exon:chr10:100...             681
# exon:chr10:100190328-100190427:-@exon:chr10:100...             681
# exon:chr10:100193697-100193848:-@exon:chr10:100...            2648
# exon:chr10:100195392-100195529:-@exon:chr10:100...             220
#
#                                                     intron2_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...             148
# exon:chr10:100190328-100190427:-@exon:chr10:100...             148
# exon:chr10:100190328-100190427:-@exon:chr10:100...             148
# exon:chr10:100193697-100193848:-@exon:chr10:100...             460
# exon:chr10:100195392-100195529:-@exon:chr10:100...            1180
#
#                                                    exon2_divisible_by_3  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 True
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 True
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 True
# exon:chr10:100193697-100193848:-@exon:chr10:100...                False
# exon:chr10:100195392-100195529:-@exon:chr10:100...                False
#
#                                                     intron12_length_summed  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                     829
# exon:chr10:100190328-100190427:-@exon:chr10:100...                     829
# exon:chr10:100190328-100190427:-@exon:chr10:100...                     829
# exon:chr10:100193697-100193848:-@exon:chr10:100...                    3108
# exon:chr10:100195392-100195529:-@exon:chr10:100...                    1400
#
#                                                      one_ensembl_id
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100193697-100193848:-@exon:chr10:100...  ENSG00000107521
# exon:chr10:100195392-100195529:-@exon:chr10:100...  ENSG00000107521

# %% [markdown]
# ### Write to a safe place

# %%
exon_metadata.to_csv('{}/splicing_feature_data.csv'.format(folder))
