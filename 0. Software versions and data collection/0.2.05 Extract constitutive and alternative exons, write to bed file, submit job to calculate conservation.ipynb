# %%
import pandas as pd
import gffutils
import pybedtools
import re
import numpy as np

v19db_filename = '/projects/ps-yeolab/genomes/hg19/gencode/v19/gencode.v19.annotation.gtf.db'
v19db = gffutils.FeatureDB(v19db_filename)

folder = '/projects/ps-yeolab/obotvinnik/singlecell_pnms'

exons_to_junctions = pd.read_csv('{}/exons_to_junctions_se.csv'.format(folder), index_col=[0, 1, 2], squeeze=True, header=None)
exons_to_junctions = exons_to_junctions.reset_index()
exons_to_junctions = exons_to_junctions.rename(columns={0: 'exon1', 1: 'exon2', 2: 'exon3', 3:'junctions'})
exons_to_junctions['junctions'] = exons_to_junctions.junctions.map(eval)
exons_to_junctions.head()
# Out:
#                               exon1                             exon2  \
# 0  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 1  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 2  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 3  exon:chr10:100193697-100193848:-  exon:chr10:100190888-100191048:-
# 4  exon:chr10:100195392-100195529:-  exon:chr10:100195029-100195171:-
#
#                               exon3  \
# 0  exon:chr10:100188908-100189399:-
# 1  exon:chr10:100188913-100189399:-
# 2  exon:chr10:100189330-100189399:-
# 3  exon:chr10:100190328-100190427:-
# 4  exon:chr10:100193697-100193848:-
#
#                                            junctions
# 0  (chr10:100189647-100190327:-, chr10:100189400-...
# 1  (chr10:100189647-100190327:-, chr10:100189400-...
# 2  (chr10:100189647-100190327:-, chr10:100189400-...
# 3  (chr10:100191049-100193696:-, chr10:100190428-...
# 4  (chr10:100195172-100195391:-, chr10:100193849-...

# %%
exons_to_junctions['event_id'] = exons_to_junctions['exon1'] + '@' \
    + exons_to_junctions['exon2'] + '@' + \
    exons_to_junctions['exon3']
exons_to_junctions.head()
# Out:
#                               exon1                             exon2  \
# 0  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 1  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 2  exon:chr10:100190328-100190427:-  exon:chr10:100189548-100189646:-
# 3  exon:chr10:100193697-100193848:-  exon:chr10:100190888-100191048:-
# 4  exon:chr10:100195392-100195529:-  exon:chr10:100195029-100195171:-
#
#                               exon3  \
# 0  exon:chr10:100188908-100189399:-
# 1  exon:chr10:100188913-100189399:-
# 2  exon:chr10:100189330-100189399:-
# 3  exon:chr10:100190328-100190427:-
# 4  exon:chr10:100193697-100193848:-
#
#                                            junctions  \
# 0  (chr10:100189647-100190327:-, chr10:100189400-...
# 1  (chr10:100189647-100190327:-, chr10:100189400-...
# 2  (chr10:100189647-100190327:-, chr10:100189400-...
# 3  (chr10:100191049-100193696:-, chr10:100190428-...
# 4  (chr10:100195172-100195391:-, chr10:100193849-...
#
#                                             event_id
# 0  exon:chr10:100190328-100190427:-@exon:chr10:10...
# 1  exon:chr10:100190328-100190427:-@exon:chr10:10...
# 2  exon:chr10:100190328-100190427:-@exon:chr10:10...
# 3  exon:chr10:100193697-100193848:-@exon:chr10:10...
# 4  exon:chr10:100195392-100195529:-@exon:chr10:10...

# %%
exon_junction_direction = pd.read_csv('{}/junction_exons.csv'.format(folder), index_col=0)
print exon_junction_direction.shape
exon_junction_direction.head()
# Out:
# (706732, 3)
#              junction_location                              exon direction
# 0  chr10:100008749-100010821:-  exon:chr10:100010822-100010933:-  upstream
# 1  chr10:100010934-100011322:-  exon:chr10:100011323-100011459:-  upstream
# 2  chr10:100143626-100144703:-  exon:chr10:100144704-100144824:-  upstream
# 3  chr10:100144825-100146957:-  exon:chr10:100146958-100147064:-  upstream
# 4  chr10:100147065-100155147:-  exon:chr10:100155148-100155209:-  upstream

# %% [markdown]
# ## Write alternative exons to bed file

# %%
from poshsplice.region import Region

exons_to_junctions['exon2_region'] = exons_to_junctions.exon2.map(Region)

exon2_bed = pd.DataFrame.from_records(exons_to_junctions.exon2_region.map(
    lambda x: pd.Series(dict(chrom=x.chrom, start=x._start, stop=x._stop, strand=x.strand, score=1000))))

exon2_bed['name'] = exons_to_junctions.event_id
exon2_bed = exon2_bed.reindex(columns=['chrom', 'start', 'stop', 'name', 'score', 'strand'])

print exon2_bed.shape
exon2_bed.head()
# Out:
# (58842, 6)
#    chrom      start       stop  \
# 0  chr10  100189548  100189646
# 1  chr10  100189548  100189646
# 2  chr10  100189548  100189646
# 3  chr10  100190888  100191048
# 4  chr10  100195029  100195171
#
#                                                 name  score strand
# 0  exon:chr10:100190328-100190427:-@exon:chr10:10...   1000      -
# 1  exon:chr10:100190328-100190427:-@exon:chr10:10...   1000      -
# 2  exon:chr10:100190328-100190427:-@exon:chr10:10...   1000      -
# 3  exon:chr10:100193697-100193848:-@exon:chr10:10...   1000      -
# 4  exon:chr10:100195392-100195529:-@exon:chr10:10...   1000      -

# %%
exon2_bed.to_csv('{}/skipped_exon_exon2.bed'.format(folder), index=False, header=False, sep='\t')

# %% [markdown]
# ## Get internal, constitutive exons
#
# ### Internal: have both downstream and upstream junctions

# %%
exon_direction = exon_junction_direction.groupby(['exon', 'direction']).size()
exon_direction.head()
# constitutive = constitutive[constitutive == 2]
# Out:
# exon                              direction
# exon:chr10:100003848-100004106:+  downstream    1
# exon:chr10:100003848-100004321:+  downstream    1
# exon:chr10:100003848-100004651:+  downstream    1
# exon:chr10:100003848-100004654:+  downstream    1
# exon:chr10:100007447-100008748:-  downstream    1
# dtype: int64

# %% [markdown]
# Group on the number of "direction" items they have. Must have two to be internal

# %%
internal_exons = exon_direction.groupby(level=0).size()
internal_exons = internal_exons[internal_exons == 2]
internal_exons.head()
# Out:
# exon
# exon:chr10:100010822-100010933:-    2
# exon:chr10:100144704-100144824:-    2
# exon:chr10:100146958-100147064:-    2
# exon:chr10:100155148-100155209:-    2
# exon:chr10:100157102-100157255:-    2
# dtype: int64

# %%
exon_juction_direction_internal = exon_junction_direction.loc[exon_junction_direction.exon.isin(internal_exons.index)]
exon_juction_direction_internal.head()
# Out:
#              junction_location                              exon direction
# 0  chr10:100008749-100010821:-  exon:chr10:100010822-100010933:-  upstream
# 2  chr10:100143626-100144703:-  exon:chr10:100144704-100144824:-  upstream
# 3  chr10:100144825-100146957:-  exon:chr10:100146958-100147064:-  upstream
# 4  chr10:100147065-100155147:-  exon:chr10:100155148-100155209:-  upstream
# 6  chr10:100155210-100157101:-  exon:chr10:100157102-100157255:-  upstream

# %%
single_upstream_downstream = exon_juction_direction_internal.groupby(['exon', 'direction']).size()
single_upstream_downstream = single_upstream_downstream[single_upstream_downstream == 1]
single_upstream_downstream = single_upstream_downstream.groupby(level=0).filter(lambda x: len(x) == 2)
print single_upstream_downstream.shape
single_upstream_downstream
# Out:
# (168130,)
# exon                              direction
# exon:chr10:100010822-100010933:-  downstream    1
#                                   upstream      1
# exon:chr10:100144704-100144824:-  downstream    1
#                                   upstream      1
# exon:chr10:100146958-100147064:-  downstream    1
#                                   upstream      1
# exon:chr10:100155148-100155209:-  downstream    1
#                                   upstream      1
# exon:chr10:100157102-100157255:-  downstream    1
#                                   upstream      1
# exon:chr10:100159859-100160014:-  downstream    1
#                                   upstream      1
# exon:chr10:100167339-100167412:-  downstream    1
#                                   upstream      1
# exon:chr10:100167661-100167754:-  downstream    1
#                                   upstream      1
# exon:chr10:100170696-100170715:-  downstream    1
#                                   upstream      1
# exon:chr10:100177932-100178014:-  downstream    1
#                                   upstream      1
# exon:chr10:100179802-100179915:-  downstream    1
#                                   upstream      1
# exon:chr10:100182126-100182270:-  downstream    1
#                                   upstream      1
# exon:chr10:100183360-100183425:-  downstream    1
#                                   upstream      1
# exon:chr10:100183510-100183644:-  downstream    1
#                                   upstream      1
# exon:chr10:100184070-100184131:-  downstream    1
#                                   upstream      1
#                                                ..
# exon:chrY:6846254-6846284:+       downstream    1
#                                   upstream      1
# exon:chrY:6863845-6863939:+       downstream    1
#                                   upstream      1
# exon:chrY:6893076-6893183:+       downstream    1
#                                   upstream      1
# exon:chrY:6911021-6911166:+       downstream    1
#                                   upstream      1
# exon:chrY:6938237-6938369:+       downstream    1
#                                   upstream      1
# exon:chrY:6938761-6938902:+       downstream    1
#                                   upstream      1
# exon:chrY:6939601-6939664:+       downstream    1
#                                   upstream      1
# exon:chrY:6939774-6939871:+       downstream    1
#                                   upstream      1
# exon:chrY:6942601-6942661:+       downstream    1
#                                   upstream      1
# exon:chrY:6948773-6948894:+       downstream    1
#                                   upstream      1
# exon:chrY:6953939-6954013:+       downstream    1
#                                   upstream      1
# exon:chrY:6954331-6954458:+       downstream    1
#                                   upstream      1
# exon:chrY:6955308-6955473:+       downstream    1
#                                   upstream      1
# exon:chrY:7235397-7235474:+       downstream    1
#                                   upstream      1
# exon:chrY:7239784-7239930:+       downstream    1
#                                   upstream      1
# dtype: int64

# %%
single_upstream_downstream = single_upstream_downstream.reset_index()
single_upstream_downstream.tail()
# Out:
#                                exon   direction  0
# 168125  exon:chrY:6955308-6955473:+    upstream  1
# 168126  exon:chrY:7235397-7235474:+  downstream  1
# 168127  exon:chrY:7235397-7235474:+    upstream  1
# 168128  exon:chrY:7239784-7239930:+  downstream  1
# 168129  exon:chrY:7239784-7239930:+    upstream  1

# %%
single_upstream_downstream.exon.unique().shape
# Out:
# (84065,)

# %% [markdown]
# ### Remove all exons that appear as exon2 in alternative annotations

# %%
constitutive = single_upstream_downstream.loc[~single_upstream_downstream.exon.isin(exons_to_junctions.exon2)]
print constitutive.exon.unique().shape
constitutive.head()
# Out:
# (74549,)
#                                exon   direction  0
# 0  exon:chr10:100010822-100010933:-  downstream  1
# 1  exon:chr10:100010822-100010933:-    upstream  1
# 2  exon:chr10:100144704-100144824:-  downstream  1
# 3  exon:chr10:100144704-100144824:-    upstream  1
# 4  exon:chr10:100146958-100147064:-  downstream  1

# %%
from poshsplice.region import Region
constitutive_regions = pd.Series(constitutive.exon.unique()).map(Region)
constitutive_regions.head()
# Out:
# 0    exon:chr10:100010822-100010933:-
# 1    exon:chr10:100144704-100144824:-
# 2    exon:chr10:100146958-100147064:-
# 3    exon:chr10:100155148-100155209:-
# 4    exon:chr10:100157102-100157255:-
# dtype: object

# %% [markdown]
# Check that the junctions for these exons are seen in 20+ single cells per celltype

# %%
csv_folder = '/home/obotvinnik/projects/singlecell_pnms/analysis/csvs_for_paper'
psi3_psi5 = pd.read_hdf('{}/psi5_psi3_combined.hdf'.format(csv_folder), 'psi')
# psi3_psi5 = pd.read_csv('{}/psi5_psi3_combined.csv'.format(csv_folder), index_col=0)
print psi3_psi5.shape
psi3_psi5.head()
# Out:
# (214, 573064)
#            chr10:100008749-100010821:-|5p  chr10:100010934-100011322:-|5p  \
# sample_id
# CVN_01                                NaN                             NaN
# CVN_02                                NaN                             NaN
# CVN_03                                NaN                             NaN
# CVN_04                                NaN                             NaN
# CVN_05                                NaN                             NaN
#
#            chr10:100143626-100144703:-|5p  chr10:100144825-100146957:-|5p  \
# sample_id
# CVN_01                                NaN                             NaN
# CVN_02                                NaN                             NaN
# CVN_03                                NaN                             NaN
# CVN_04                                NaN                             NaN
# CVN_05                                NaN                             NaN
#
#            chr10:100147065-100155147:-|5p  chr10:100150512-100150766:-|5p  \
# sample_id
# CVN_01                                NaN                             NaN
# CVN_02                                NaN                             NaN
# CVN_03                                NaN                             NaN
# CVN_04                                NaN                             NaN
# CVN_05                                NaN                             NaN
#
#            chr10:100155210-100157101:-|5p  chr10:100157256-100159858:-|5p  \
# sample_id
# CVN_01                                NaN                             NaN
# CVN_02                                NaN                             NaN
# CVN_03                                NaN                             NaN
# CVN_04                                NaN                             NaN
# CVN_05                                NaN                             NaN
#
#            chr10:100160015-100167338:-|5p  chr10:100167413-100167660:-|5p  \
# sample_id
# CVN_01                                NaN                             NaN
# CVN_02                                NaN                             NaN
# CVN_03                                NaN                             NaN
# CVN_04                                NaN                             NaN
# CVN_05                                NaN                             NaN
#
#                      ...              chrY:7194211-7209155:+|3p  \
# sample_id            ...
# CVN_01               ...                                    NaN
# CVN_02               ...                                      0
# CVN_03               ...                                    NaN
# CVN_04               ...                                    NaN
# CVN_05               ...                                    NaN
#
#            chrY:7194211-7224175:+|3p  chrY:7198575-7201095:+|3p  \
# sample_id
# CVN_01                           NaN                        NaN
# CVN_02                             0                        NaN
# CVN_03                           NaN                        NaN
# CVN_04                           NaN                        NaN
# CVN_05                           NaN                        NaN
#
#            chrY:7208064-7209155:+|3p  chrY:7209276-7224175:+|3p  \
# sample_id
# CVN_01                           NaN                        NaN
# CVN_02                             1                          1
# CVN_03                           NaN                        NaN
# CVN_04                           NaN                        NaN
# CVN_05                           NaN                        NaN
#
#            chrY:7223339-7223437:+|3p  chrY:7224272-7235396:+|3p  \
# sample_id
# CVN_01                           NaN                        NaN
# CVN_02                           NaN                          1
# CVN_03                           NaN                        NaN
# CVN_04                           NaN                        NaN
# CVN_05                           NaN                        NaN
#
#            chrY:7225609-7226951:+|3p  chrY:7235475-7239783:+|3p  \
# sample_id
# CVN_01                           NaN                        NaN
# CVN_02                           NaN                          1
# CVN_03                           NaN                        NaN
# CVN_04                           NaN                        NaN
# CVN_05                           NaN                        NaN
#
#            chrY:7239931-7243752:+|3p
# sample_id
# CVN_01                           NaN
# CVN_02                             1
# CVN_03                           NaN
# CVN_04                           NaN
# CVN_05                           NaN
#
# [5 rows x 573064 columns]

# %%
ls $csv_folder
# Out:
# expression.csv              psi5_psi3_combined.hdf
# expression_stressed.csv     psi5_psi3_combined_metadata.csv
# mapping_stats.csv           psi5_psi3_combined_metadata.hdf
# mapping_stats_stressed.csv  psi5_stressed.csv
# metadata.csv                sj_raw.csv
# metadata_stressed.csv       skipped_exon_psi_from_junctions.csv
# psi3.csv                    splice_junction_metadata.csv
# psi3_stressed.csv           splice_junctions_psi.csv
# psi5.csv                    splicing.csv
# psi5_psi3_combined.csv      splicing_stressed.csv

# %%
sj_metadata = pd.read_hdf('{}/psi5_psi3_combined_metadata.hdf'.format(csv_folder), 'metadata')
sj_metadata.head()
# Out:
#                         chrom  intron_start  intron_stop strand intron_motif  \
# intron_location
# chr1:120933-129054:-|5p  chr1        120933       129054      -        GT/AG
# chr1:135767-137718:-|5p  chr1        135767       137718      -        GC/AG
# chr1:326417-327587:+|5p  chr1        326417       327587      +        GC/AG
# chr1:334298-342391:+|5p  chr1        334298       342391      +        GT/AG
# chr1:566538-566579:-|5p  chr1        566538       566579      -        GC/AG
#
#                         annotated                           gencode_id  \
# intron_location
# chr1:120933-129054:-|5p      True                    ENSG00000238009.2
# chr1:135767-137718:-|5p     False                    ENSG00000237683.5
# chr1:326417-327587:+|5p     False  ENSG00000237094.7,ENSG00000250575.1
# chr1:334298-342391:+|5p      True                    ENSG00000237094.7
# chr1:566538-566579:-|5p     False                    ENSG00000230021.3
#
#                                               ensembl_id  \
# intron_location
# chr1:120933-129054:-|5p                  ENSG00000238009
# chr1:135767-137718:-|5p                  ENSG00000237683
# chr1:326417-327587:+|5p  ENSG00000237094,ENSG00000250575
# chr1:334298-342391:+|5p                  ENSG00000237094
# chr1:566538-566579:-|5p                  ENSG00000230021
#
#                                                      gene_id  \
# intron_location
# chr1:120933-129054:-|5p                    ENSG00000238009.2
# chr1:135767-137718:-|5p                    ENSG00000237683.5
# chr1:326417-327587:+|5p  ENSG00000237094.7,ENSG00000250575.1
# chr1:334298-342391:+|5p                    ENSG00000237094.7
# chr1:566538-566579:-|5p                    ENSG00000230021.3
#
#                                           gene_name      ...       \
# intron_location                                          ...
# chr1:120933-129054:-|5p                RP11-34P13.7      ...
# chr1:135767-137718:-|5p                  AL627309.1      ...
# chr1:326417-327587:+|5p  RP4-669L17.10,RP4-669L17.8      ...
# chr1:334298-342391:+|5p               RP4-669L17.10      ...
# chr1:566538-566579:-|5p                RP5-857K21.4      ...
#
#                         gerstberger2014_rbp_target_ncrna  \
# intron_location
# chr1:120933-129054:-|5p                            False
# chr1:135767-137718:-|5p                            False
# chr1:326417-327587:+|5p                            False
# chr1:334298-342391:+|5p                            False
# chr1:566538-566579:-|5p                            False
#
#                         gerstberger2014_rbp_target_ribosome  \
# intron_location
# chr1:120933-129054:-|5p                               False
# chr1:135767-137718:-|5p                               False
# chr1:326417-327587:+|5p                               False
# chr1:334298-342391:+|5p                               False
# chr1:566538-566579:-|5p                               False
#
#                         gerstberger2014_rbp_target_trna gerstberger2014_tf  \
# intron_location
# chr1:120933-129054:-|5p                           False              False
# chr1:135767-137718:-|5p                           False              False
# chr1:326417-327587:+|5p                           False              False
# chr1:334298-342391:+|5p                           False              False
# chr1:566538-566579:-|5p                           False              False
#
#                            rbp ribosomal ribosomal_subunit synapse  \
# intron_location
# chr1:120933-129054:-|5p  False     False             False   False
# chr1:135767-137718:-|5p  False     False             False   False
# chr1:326417-327587:+|5p  False     False             False   False
# chr1:334298-342391:+|5p  False     False             False   False
# chr1:566538-566579:-|5p  False     False             False   False
#
#                         transcription_factor intron_length
# intron_location
# chr1:120933-129054:-|5p                False          8121
# chr1:135767-137718:-|5p                False          1951
# chr1:326417-327587:+|5p                False          1170
# chr1:334298-342391:+|5p                False          8093
# chr1:566538-566579:-|5p                False            41
#
# [5 rows x 41 columns]

# %%
sj_metadata['exon_stop'] = sj_metadata['intron_start'] - 1
sj_metadata['exon_start'] = sj_metadata['intron_stop'] + 1

# %%
metadata = pd.read_csv('{}/metadata.csv'.format(csv_folder), index_col=0)
metadata.head()
# Out:
#        single pooled phenotype neuron progenitor stressed craig_venter  \
# CVN_01   True  False       NPC  False       True    False         True
# CVN_02   True  False       NPC  False       True    False         True
# CVN_03   True  False       NPC  False       True    False         True
# CVN_04   True  False       NPC  False       True    False         True
# CVN_05   True  False       NPC  False       True    False         True
#
#        differentiation_batch split
# CVN_01                   NaN   NaN
# CVN_02                   NaN   NaN
# CVN_03                   NaN   NaN
# CVN_04                   NaN   NaN
# CVN_05                   NaN   NaN

# %%
phenotype = metadata.phenotype[metadata.single]

# %%
psi3_psi5.shape
# Out:
# (214, 573064)

# %%
psi20_all = psi3_psi5.loc[:, (psi3_psi5.groupby(phenotype).count() >= 20).all()]
psi20_all.head()
# Out:
#            chr10:101157444-101162336:-|5p  chr10:101162480-101163225:-|5p  \
# sample_id
# CVN_01                                  1                               1
# CVN_02                                  1                               1
# CVN_03                                  1                               1
# CVN_04                                NaN                             NaN
# CVN_05                                  1                               1
#
#            chr10:101163392-101163480:-|5p  chr10:101163392-101165512:-|5p  \
# sample_id
# CVN_01                                  1                               0
# CVN_02                                  1                               0
# CVN_03                                  1                               0
# CVN_04                                NaN                             NaN
# CVN_05                                  1                               0
#
#            chr10:101163632-101165512:-|5p  chr10:101166007-101190204:-|5p  \
# sample_id
# CVN_01                                  1                               0
# CVN_02                                  1                               0
# CVN_03                                  1                               0
# CVN_04                                NaN                             NaN
# CVN_05                                  1                               0
#
#            chr10:101437763-101476104:-|5p  chr10:101456299-101476104:-|5p  \
# sample_id
# CVN_01                                NaN                             NaN
# CVN_02                                NaN                             NaN
# CVN_03                                NaN                             NaN
# CVN_04                                NaN                             NaN
# CVN_05                                  0                               1
#
#            chr10:101473237-101476104:-|5p  chr10:101474476-101476104:-|5p  \
# sample_id
# CVN_01                                NaN                             NaN
# CVN_02                                NaN                             NaN
# CVN_03                                NaN                             NaN
# CVN_04                                NaN                             NaN
# CVN_05                                  0                               1
#
#                      ...              chrY:2713785-2734833:+|3p  \
# sample_id            ...
# CVN_01               ...                                      0
# CVN_02               ...                                    NaN
# CVN_03               ...                                    NaN
# CVN_04               ...                                      0
# CVN_05               ...                                      0
#
#            chrY:2714508-2722640:+|3p  chrY:2721733-2722640:+|3p  \
# sample_id
# CVN_01                             0                          0
# CVN_02                           NaN                        NaN
# CVN_03                           NaN                        NaN
# CVN_04                             0                          0
# CVN_05                             0                          0
#
#            chrY:2722746-2734833:+|3p  chrY:2722813-2733128:+|3p  \
# sample_id
# CVN_01                             0                          1
# CVN_02                           NaN                        NaN
# CVN_03                           NaN                        NaN
# CVN_04                             0                          1
# CVN_05                             0                          1
#
#            chrY:2722813-2734833:+|3p  chrY:2722813-2789783:+|3p  \
# sample_id
# CVN_01                             0                          0
# CVN_02                           NaN                        NaN
# CVN_03                           NaN                        NaN
# CVN_04                             0                          0
# CVN_05                             0                          0
#
#            chrY:2722813-2796904:+|3p  chrY:2733287-2734833:+|3p  \
# sample_id
# CVN_01                             0                          1
# CVN_02                           NaN                        NaN
# CVN_03                           NaN                        NaN
# CVN_04                             0                          1
# CVN_05                             0                          1
#
#            chrY:2733362-2734833:+|3p
# sample_id
# CVN_01                             0
# CVN_02                           NaN
# CVN_03                           NaN
# CVN_04                             0
# CVN_05                             0
#
# [5 rows x 61766 columns]

# %% [markdown]
# Get Junctions whose psi score is equal to 1 in all celltypes

# %%
psi_is_1 = psi20_all.groupby(phenotype).apply(lambda x: (x == 1)[x.notnull()].all(axis=0))
psi_is_1.head()
# Out:
#           chr10:101157444-101162336:-|5p chr10:101162480-101163225:-|5p  \
# phenotype
# MN                                  True                           True
# NPC                                 True                           True
# iPSC                                True                           True
#
#           chr10:101163392-101163480:-|5p chr10:101163392-101165512:-|5p  \
# phenotype
# MN                                 False                          False
# NPC                                 True                          False
# iPSC                               False                          False
#
#           chr10:101163632-101165512:-|5p chr10:101166007-101190204:-|5p  \
# phenotype
# MN                                  True                          False
# NPC                                 True                          False
# iPSC                                True                          False
#
#           chr10:101437763-101476104:-|5p chr10:101456299-101476104:-|5p  \
# phenotype
# MN                                 False                          False
# NPC                                False                          False
# iPSC                               False                          False
#
#           chr10:101473237-101476104:-|5p chr10:101474476-101476104:-|5p  \
# phenotype
# MN                                 False                          False
# NPC                                False                          False
# iPSC                               False                          False
#
#                      ...            chrY:2713785-2734833:+|3p  \
# phenotype            ...
# MN                   ...                                False
# NPC                  ...                                False
# iPSC                 ...                                False
#
#           chrY:2714508-2722640:+|3p chrY:2721733-2722640:+|3p  \
# phenotype
# MN                            False                     False
# NPC                           False                     False
# iPSC                          False                     False
#
#           chrY:2722746-2734833:+|3p chrY:2722813-2733128:+|3p  \
# phenotype
# MN                            False                      True
# NPC                           False                      True
# iPSC                          False                     False
#
#           chrY:2722813-2734833:+|3p chrY:2722813-2789783:+|3p  \
# phenotype
# MN                            False                     False
# NPC                           False                     False
# iPSC                          False                     False
#
#           chrY:2722813-2796904:+|3p chrY:2733287-2734833:+|3p  \
# phenotype
# MN                            False                     False
# NPC                           False                      True
# iPSC                          False                     False
#
#           chrY:2733362-2734833:+|3p
# phenotype
# MN                            False
# NPC                           False
# iPSC                          False
#
# [3 rows x 61766 columns]

# %%
psi20_is_1_all = psi20_all.loc[:, psi_is_1.all()]
psi20_is_1_all.head()
# Out:
#            chr10:101157444-101162336:-|5p  chr10:101162480-101163225:-|5p  \
# sample_id
# CVN_01                                  1                               1
# CVN_02                                  1                               1
# CVN_03                                  1                               1
# CVN_04                                NaN                             NaN
# CVN_05                                  1                               1
#
#            chr10:101163632-101165512:-|5p  chr10:101480826-101483712:-|5p  \
# sample_id
# CVN_01                                  1                             NaN
# CVN_02                                  1                             NaN
# CVN_03                                  1                             NaN
# CVN_04                                NaN                             NaN
# CVN_05                                  1                               1
#
#            chr10:101483881-101486724:-|5p  chr10:101487321-101489309:-|5p  \
# sample_id
# CVN_01                                NaN                             NaN
# CVN_02                                NaN                             NaN
# CVN_03                                NaN                             NaN
# CVN_04                                NaN                             NaN
# CVN_05                                  1                               1
#
#            chr10:101489492-101491716:-|5p  chr10:102035251-102039880:-|5p  \
# sample_id
# CVN_01                                NaN                               1
# CVN_02                                NaN                             NaN
# CVN_03                                NaN                               1
# CVN_04                                NaN                             NaN
# CVN_05                                  1                             NaN
#
#            chr10:102107289-102107820:+|5p  chr10:102286312-102286731:-|5p  \
# sample_id
# CVN_01                                NaN                               1
# CVN_02                                  1                               1
# CVN_03                                  1                               1
# CVN_04                                NaN                               1
# CVN_05                                NaN                               1
#
#                      ...              chrX:77378872-77380370:+|3p  \
# sample_id            ...
# CVN_01               ...                                        1
# CVN_02               ...                                        1
# CVN_03               ...                                      NaN
# CVN_04               ...                                        1
# CVN_05               ...                                        1
#
#            chrX:77380923-77381286:+|3p  chrX:80532669-80533829:+|3p  \
# sample_id
# CVN_01                               1                            1
# CVN_02                               1                            1
# CVN_03                             NaN                            1
# CVN_04                               1                            1
# CVN_05                               1                            1
#
#            chrX:80533911-80552693:+|3p  chrX:99887566-99888401:-|3p  \
# sample_id
# CVN_01                               1                            1
# CVN_02                               1                            1
# CVN_03                               1                          NaN
# CVN_04                               1                            1
# CVN_05                               1                            1
#
#            chrX:99890250-99890554:-|3p  chrY:1455653-1456171:-|3p  \
# sample_id
# CVN_01                               1                          1
# CVN_02                               1                          1
# CVN_03                             NaN                          1
# CVN_04                               1                          1
# CVN_05                               1                          1
#
#            chrY:1456313-1458133:-|3p  chrY:14774638-14776570:+|3p  \
# sample_id
# CVN_01                             1                            1
# CVN_02                             1                          NaN
# CVN_03                             1                            1
# CVN_04                             1                            1
# CVN_05                             1                            1
#
#            chrY:2710284-2712117:+|3p
# sample_id
# CVN_01                             1
# CVN_02                           NaN
# CVN_03                           NaN
# CVN_04                             1
# CVN_05                             1
#
# [5 rows x 9313 columns]

# %%
sj20_is_1_all = sj_metadata.loc[psi20_is_1_all.columns, :]
print sj20_is_1_all.shape
sj20_is_1_all.head()
# Out:
# (9313, 43)
#                                 chrom  intron_start  intron_stop strand  \
# chr10:101157444-101162336:-|5p  chr10     101157444    101162336      -
# chr10:101162480-101163225:-|5p  chr10     101162480    101163225      -
# chr10:101163632-101165512:-|5p  chr10     101163632    101165512      -
# chr10:101480826-101483712:-|5p  chr10     101480826    101483712      -
# chr10:101483881-101486724:-|5p  chr10     101483881    101486724      -
#
#                                intron_motif annotated         gencode_id  \
# chr10:101157444-101162336:-|5p        GT/AG      True  ENSG00000120053.9
# chr10:101162480-101163225:-|5p        GT/AG      True  ENSG00000120053.9
# chr10:101163632-101165512:-|5p        GT/AG      True  ENSG00000120053.9
# chr10:101480826-101483712:-|5p        GT/AG      True  ENSG00000014919.8
# chr10:101483881-101486724:-|5p        GT/AG      True  ENSG00000014919.8
#
#                                      ensembl_id            gene_id gene_name  \
# chr10:101157444-101162336:-|5p  ENSG00000120053  ENSG00000120053.9      GOT1
# chr10:101162480-101163225:-|5p  ENSG00000120053  ENSG00000120053.9      GOT1
# chr10:101163632-101165512:-|5p  ENSG00000120053  ENSG00000120053.9      GOT1
# chr10:101480826-101483712:-|5p  ENSG00000014919  ENSG00000014919.8     COX15
# chr10:101483881-101486724:-|5p  ENSG00000014919  ENSG00000014919.8     COX15
#
#                                   ...     gerstberger2014_rbp_target_trna  \
# chr10:101157444-101162336:-|5p    ...                               False
# chr10:101162480-101163225:-|5p    ...                               False
# chr10:101163632-101165512:-|5p    ...                               False
# chr10:101480826-101483712:-|5p    ...                               False
# chr10:101483881-101486724:-|5p    ...                               False
#
#                                gerstberger2014_tf    rbp ribosomal  \
# chr10:101157444-101162336:-|5p              False  False     False
# chr10:101162480-101163225:-|5p              False  False     False
# chr10:101163632-101165512:-|5p              False  False     False
# chr10:101480826-101483712:-|5p              False  False     False
# chr10:101483881-101486724:-|5p              False  False     False
#
#                                ribosomal_subunit synapse transcription_factor  \
# chr10:101157444-101162336:-|5p             False   False                False
# chr10:101162480-101163225:-|5p             False   False                False
# chr10:101163632-101165512:-|5p             False   False                False
# chr10:101480826-101483712:-|5p             False   False                False
# chr10:101483881-101486724:-|5p             False   False                False
#
#                                intron_length  exon_stop exon_start
# chr10:101157444-101162336:-|5p          4892  101157443  101162337
# chr10:101162480-101163225:-|5p           745  101162479  101163226
# chr10:101163632-101165512:-|5p          1880  101163631  101165513
# chr10:101480826-101483712:-|5p          2886  101480825  101483713
# chr10:101483881-101486724:-|5p          2843  101483880  101486725
#
# [5 rows x 43 columns]

# %%
records = constitutive_regions.map(
    lambda x: pd.Series(dict(chrom=x.chrom, start=x._start, stop=x._stop, strand=x.strand, score=1000, name=x.name)))
constitutive_bed = pd.DataFrame.from_records(records)
constitutive_bed = constitutive_bed.reindex(columns=['chrom', 'start', 'stop', 'name', 'score', 'strand'])
constitutive_bed.head()
# Out:
#    chrom      start       stop                              name  score strand
# 0  chr10  100010822  100010933  exon:chr10:100010822-100010933:-   1000      -
# 1  chr10  100144704  100144824  exon:chr10:100144704-100144824:-   1000      -
# 2  chr10  100146958  100147064  exon:chr10:100146958-100147064:-   1000      -
# 3  chr10  100155148  100155209  exon:chr10:100155148-100155209:-   1000      -
# 4  chr10  100157102  100157255  exon:chr10:100157102-100157255:-   1000      -

# %%
constitutive_exon_start.merge?

# %%
constitutive_exon_stop = constitutive_bed.merge(sj20_is_1_all, 
                                                right_on=['chrom', 'exon_stop', 'strand'], 
                                                left_on=['chrom', 'stop', 'strand'])
print 'constitutive_exon_stop', constitutive_exon_stop.shape
constitutive_exon_start = constitutive_bed.merge(sj20_is_1_all, 
                                                right_on=['chrom', 'exon_start', 'strand'], 
                                                left_on=['chrom', 'start', 'strand'])
print 'constitutive_exon_start', constitutive_exon_start.shape
# Out:
# constitutive_exon_stop (3501, 47)
# constitutive_exon_start (3420, 47)

# %%
constitutive_exon_start.head()
# Out:
#    chrom      start       stop                              name  score  \
# 0  chr10  101162337  101162479  exon:chr10:101162337-101162479:-   1000
# 1  chr10  101162337  101162479  exon:chr10:101162337-101162479:-   1000
# 2  chr10  101483713  101483880  exon:chr10:101483713-101483880:-   1000
# 3  chr10  101483713  101483880  exon:chr10:101483713-101483880:-   1000
# 4  chr10  101486725  101486911  exon:chr10:101486725-101486911:-   1000
#
#   strand  intron_start  intron_stop intron_motif annotated    ...      \
# 0      -     101157444    101162336        GT/AG      True    ...
# 1      -     101157444    101162336        GT/AG      True    ...
# 2      -     101480826    101483712        GT/AG      True    ...
# 3      -     101480826    101483712        GT/AG      True    ...
# 4      -     101483881    101486724        GT/AG      True    ...
#
#   gerstberger2014_rbp_target_trna gerstberger2014_tf    rbp ribosomal  \
# 0                           False              False  False     False
# 1                           False              False  False     False
# 2                           False              False  False     False
# 3                           False              False  False     False
# 4                           False              False  False     False
#
#   ribosomal_subunit synapse transcription_factor intron_length  exon_stop  \
# 0             False   False                False          4892  101157443
# 1             False   False                False          4892  101157443
# 2             False   False                False          2886  101480825
# 3             False   False                False          2886  101480825
# 4             False   False                False          2843  101483880
#
#   exon_start
# 0  101162337
# 1  101162337
# 2  101483713
# 3  101483713
# 4  101486725
#
# [5 rows x 47 columns]

# %%
constitutive_exons = constitutive_exon_start.merge(constitutive_exon_stop, left_on='name', right_on='name')
print constitutive_exons.shape
constitutive_exons.head()
# Out:
# (5229, 93)
#   chrom_x    start_x     stop_x                              name  score_x  \
# 0   chr10  101162337  101162479  exon:chr10:101162337-101162479:-     1000
# 1   chr10  101162337  101162479  exon:chr10:101162337-101162479:-     1000
# 2   chr10  101162337  101162479  exon:chr10:101162337-101162479:-     1000
# 3   chr10  101162337  101162479  exon:chr10:101162337-101162479:-     1000
# 4   chr10  101483713  101483880  exon:chr10:101483713-101483880:-     1000
#
#   strand_x  intron_start_x  intron_stop_x intron_motif_x annotated_x  \
# 0        -       101157444      101162336          GT/AG        True
# 1        -       101157444      101162336          GT/AG        True
# 2        -       101157444      101162336          GT/AG        True
# 3        -       101157444      101162336          GT/AG        True
# 4        -       101480826      101483712          GT/AG        True
#
#       ...      gerstberger2014_rbp_target_trna_y gerstberger2014_tf_y  rbp_y  \
# 0     ...                                  False                False  False
# 1     ...                                  False                False  False
# 2     ...                                  False                False  False
# 3     ...                                  False                False  False
# 4     ...                                  False                False  False
#
#   ribosomal_y ribosomal_subunit_y synapse_y transcription_factor_y  \
# 0       False               False     False                  False
# 1       False               False     False                  False
# 2       False               False     False                  False
# 3       False               False     False                  False
# 4       False               False     False                  False
#
#   intron_length_y exon_stop_y exon_start_y
# 0             745   101162479    101163226
# 1             745   101162479    101163226
# 2             745   101162479    101163226
# 3             745   101162479    101163226
# 4            2843   101483880    101486725
#
# [5 rows x 93 columns]

# %%
bed = constitutive_exons[['chrom_x', 'start_x', 'stop_x', 'name', 'score_x', 'strand_x']]
bed = bed.drop_duplicates()
print bed.shape
bed.columns = bed.columns.map(lambda x: x.split('_')[0])
bed.head()
# Out:
# (1449, 6)
#     chrom      start       stop                              name  score  \
# 0   chr10  101162337  101162479  exon:chr10:101162337-101162479:-   1000
# 4   chr10  101483713  101483880  exon:chr10:101483713-101483880:-   1000
# 8   chr10  101489310  101489491  exon:chr10:101489310-101489491:-   1000
# 12  chr10  104183414  104183474  exon:chr10:104183414-104183474:-   1000
# 16  chr10  104245366  104245490  exon:chr10:104245366-104245490:-   1000
#
#    strand
# 0       -
# 4       -
# 8       -
# 12      -
# 16      -

# %%
bed.to_csv('{}/constitutive_exons.bed'.format(folder), index=False, header=False, sep='\t')

# %% [markdown]
# ## Submit compute job to calculate exon conservation

# %%
folder = '/projects/ps-yeolab/obotvinnik/singlecell_pnms'

alt_exons_bedfile = '{}/skipped_exon_exon2.bed'.format(folder)
constitutive_bedfile = '{}/constitutive_exons.bed'.format(folder)

bedfiles = alt_exons_bedfile, constitutive_bedfile

# %%
import os
import glob

from gscripts.qtools import Submitter

commands = []

bw = '/projects/ps-yeolab/genomes/hg19/hg19_phastcons_placental_mammal.bw'

for bedfile in bedfiles:
    basename = os.path.basename(bedfile)
    
    prefix = basename.split('.bed')[0]
    
    prefix += '_phastcons_placental_mammal'
    bedout = '{}/{}'.format(folder, prefix + '.bed')
    outtab = '{}/{}'.format(folder, prefix + '.txt')
    command = 'bigWigAverageOverBed {} {} {} -bedOut={}'.format(bw, bedfile, outtab, bedout)
    print command
    commands.append(command)

jobname = 'exonbody_conservation'
Submitter(commands, jobname, array=True, walltime='2:00:00', write_and_submit=True,
          err_filename='{}/{}.err'.format(folder, jobname),
          out_filename='{}/{}.out'.format(folder, jobname))
# Out:
# 1449
