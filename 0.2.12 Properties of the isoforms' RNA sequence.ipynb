# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import gffutils
import pybedtools
import re
import numpy as np

v19db_filename = '/projects/ps-yeolab/genomes/hg19/gencode/v19/gencode.v19.annotation.gtf.db'
v19db = gffutils.FeatureDB(v19db_filename)

folder = '/projects/ps-yeolab/obotvinnik/singlecell_pnms'

splicing_feature_data = pd.read_csv('{}/splicing_feature_data.csv'.format(folder), index_col=0)
splicing_feature_data.head()
# Out:
#                                                             gencode_id  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521.14
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521.14
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521.14
# exon:chr10:100193697-100193848:-@exon:chr10:100...  ENSG00000107521.14
# exon:chr10:100195392-100195529:-@exon:chr10:100...  ENSG00000107521.14
#
#                                                          ensembl_id gene_name  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521      HPS1
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521      HPS1
# exon:chr10:100190328-100190427:-@exon:chr10:100...  ENSG00000107521      HPS1
# exon:chr10:100193697-100193848:-@exon:chr10:100...  ENSG00000107521      HPS1
# exon:chr10:100195392-100195529:-@exon:chr10:100...  ENSG00000107521      HPS1
#
#                                                     exon1_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100190328-100190427:-@exon:chr10:100...           100
# exon:chr10:100193697-100193848:-@exon:chr10:100...           152
# exon:chr10:100195392-100195529:-@exon:chr10:100...           138
#
#                                                     exon2_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100190328-100190427:-@exon:chr10:100...            99
# exon:chr10:100193697-100193848:-@exon:chr10:100...           161
# exon:chr10:100195392-100195529:-@exon:chr10:100...           143
#
#                                                     exon3_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...           492
# exon:chr10:100190328-100190427:-@exon:chr10:100...           487
# exon:chr10:100190328-100190427:-@exon:chr10:100...            70
# exon:chr10:100193697-100193848:-@exon:chr10:100...           100
# exon:chr10:100195392-100195529:-@exon:chr10:100...           152
#
#                                                     intron1_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...             681
# exon:chr10:100190328-100190427:-@exon:chr10:100...             681
# exon:chr10:100190328-100190427:-@exon:chr10:100...             681
# exon:chr10:100193697-100193848:-@exon:chr10:100...            2648
# exon:chr10:100195392-100195529:-@exon:chr10:100...             220
#
#                                                     intron2_length  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...             148
# exon:chr10:100190328-100190427:-@exon:chr10:100...             148
# exon:chr10:100190328-100190427:-@exon:chr10:100...             148
# exon:chr10:100193697-100193848:-@exon:chr10:100...             460
# exon:chr10:100195392-100195529:-@exon:chr10:100...            1180
#
#                                                    exon2_divisible_by_3  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 True
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 True
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 True
# exon:chr10:100193697-100193848:-@exon:chr10:100...                False
# exon:chr10:100195392-100195529:-@exon:chr10:100...                False
#
#                                                     intron12_length_summed  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                     829
# exon:chr10:100190328-100190427:-@exon:chr10:100...                     829
# exon:chr10:100190328-100190427:-@exon:chr10:100...                     829
# exon:chr10:100193697-100193848:-@exon:chr10:100...                    3108
# exon:chr10:100195392-100195529:-@exon:chr10:100...                    1400
#
#                                                            ...           \
# event_id                                                   ...
# exon:chr10:100190328-100190427:-@exon:chr10:100...         ...
# exon:chr10:100190328-100190427:-@exon:chr10:100...         ...
# exon:chr10:100190328-100190427:-@exon:chr10:100...         ...
# exon:chr10:100193697-100193848:-@exon:chr10:100...         ...
# exon:chr10:100195392-100195529:-@exon:chr10:100...         ...
#
#                                                    isoform2_molecular_weight  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...         9467.055499999997
# exon:chr10:100190328-100190427:-@exon:chr10:100...         9467.055499999997
# exon:chr10:100190328-100190427:-@exon:chr10:100...         9467.055499999997
# exon:chr10:100193697-100193848:-@exon:chr10:100...         14073.84609999998
# exon:chr10:100195392-100195529:-@exon:chr10:100...        15151.241699999982
#
#                                                                                isoform_domain_effects  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...  No annotated reading frame --> Protein +/- domain
# exon:chr10:100190328-100190427:-@exon:chr10:100...                                        Same status
# exon:chr10:100190328-100190427:-@exon:chr10:100...                                        Same status
# exon:chr10:100193697-100193848:-@exon:chr10:100...  No annotated reading frame --> Protein +/- domain
# exon:chr10:100195392-100195529:-@exon:chr10:100...  No annotated reading frame --> Protein +/- domain
#
#                                                    isoform1_pfam_accession  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                     NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                     NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                     NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                     NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                     NaN
#
#                                                     isoform2_pfam_accession  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                      NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                      NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                      NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                      NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                      NaN
#
#                                                    isoform1_pfam_name  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                NaN
#
#                                                     isoform2_pfam_name  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                 NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                 NaN
#
#                                                    isoform1_pfam_go_name  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                   NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                   NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                   NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                   NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                   NaN
#
#                                                     isoform2_pfam_go_name  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                    NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                    NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                    NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                    NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                    NaN
#
#                                                    isoform1_pfam_go_id  \
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                 NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                 NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                 NaN
#
#                                                     isoform2_pfam_go_id
# event_id
# exon:chr10:100190328-100190427:-@exon:chr10:100...                  NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                  NaN
# exon:chr10:100190328-100190427:-@exon:chr10:100...                  NaN
# exon:chr10:100193697-100193848:-@exon:chr10:100...                  NaN
# exon:chr10:100195392-100195529:-@exon:chr10:100...                  NaN
#
# [5 rows x 50 columns]

# %%
figure_folder = '/home/obotvinnik/Dropbox/figures2/singlecell_pnms/isoform_rna_properties'
! mkdir $figure_folder
# Out:
# mkdir: cannot create directory `/home/obotvinnik/Dropbox/figures2/singlecell_pnms/isoform_rna_properties': File exists

# %% [markdown]
# ## Calculate GC Content

# %%
prefix = 'skipped_exon_isoform_transcriptions'
transcribed_fasta = '{}/{}.fa'.format(folder, prefix)

# %%
import pandas as pd

# %%
from Bio import SeqIO
from collections import defaultdict
from Bio import SeqUtils

transcripts = SeqIO.parse(transcribed_fasta, 'fasta')

data = []

for record in transcripts:
    event_id, isoform = record.id.split('|')
    
    gc123 = list(SeqUtils.GC123(record.seq))
    data.append([event_id, isoform] + gc123)
gc_content = pd.DataFrame(data, columns=['event_name', 'isoform', 'gc', 'gc_position1', 'gc_position2', 'gc_position3'])
gc_content.head()
#     gc[isoform][event_id] =
# Out:
#                                           event_name   isoform         gc  \
# 0  exon:chr10:100190328-100190427:-@exon:chr10:10...  isoform2  65.977444
# 1  exon:chr10:100190328-100190427:-@exon:chr10:10...  isoform1  63.205418
# 2  exon:chr10:100190328-100190427:-@exon:chr10:10...  isoform2  66.477273
# 3  exon:chr10:100190328-100190427:-@exon:chr10:10...  isoform1  63.781321
# 4  exon:chr10:100190328-100190427:-@exon:chr10:10...  isoform2  77.292576
#
#    gc_position1  gc_position2  gc_position3
# 0     67.613636     64.285714     66.091954
# 1     62.585034     64.052288     62.937063
# 2     68.390805     64.640884     66.473988
# 3     63.448276     64.473684     63.380282
# 4     89.610390     73.076923     68.918919

# %% [markdown]
# ### Create 2d version of the tidy data, with new column names, for merging with splicing feature data

# %%
value_cols = ['gc', 'gc_position1', 'gc_position2', 'gc_position3']

# %%
dfs = []

for value_col in value_cols:
    df = gc_content.pivot(index='event_name', columns='isoform', values=value_col)
    df.columns = df.columns.map(lambda x: x + '_' + value_col)
    dfs.append(df)
gc_content_2d = pd.concat(dfs, axis=1)
gc_content_2d.head()
# Out:
#                                                     isoform1_gc  isoform2_gc  \
# event_name
# exon:chr10:100190328-100190427:-@exon:chr10:100...    63.205418    65.977444
# exon:chr10:100190328-100190427:-@exon:chr10:100...    63.781321    66.477273
# exon:chr10:100190328-100190427:-@exon:chr10:100...    75.714286    77.292576
# exon:chr10:100193697-100193848:-@exon:chr10:100...    79.523810    79.178886
# exon:chr10:100195392-100195529:-@exon:chr10:100...    78.111588    75.882353
#
#                                                     isoform1_gc_position1  \
# event_name
# exon:chr10:100190328-100190427:-@exon:chr10:100...              62.585034
# exon:chr10:100190328-100190427:-@exon:chr10:100...              63.448276
# exon:chr10:100190328-100190427:-@exon:chr10:100...              87.500000
# exon:chr10:100193697-100193848:-@exon:chr10:100...              88.311688
# exon:chr10:100195392-100195529:-@exon:chr10:100...              81.927711
#
#                                                     isoform2_gc_position1  \
# event_name
# exon:chr10:100190328-100190427:-@exon:chr10:100...              67.613636
# exon:chr10:100190328-100190427:-@exon:chr10:100...              68.390805
# exon:chr10:100190328-100190427:-@exon:chr10:100...              89.610390
# exon:chr10:100193697-100193848:-@exon:chr10:100...              73.333333
# exon:chr10:100195392-100195529:-@exon:chr10:100...              75.206612
#
#                                                     isoform1_gc_position2  \
# event_name
# exon:chr10:100190328-100190427:-@exon:chr10:100...              64.052288
# exon:chr10:100190328-100190427:-@exon:chr10:100...              64.473684
# exon:chr10:100190328-100190427:-@exon:chr10:100...              77.551020
# exon:chr10:100193697-100193848:-@exon:chr10:100...              74.242424
# exon:chr10:100195392-100195529:-@exon:chr10:100...              73.239437
#
#                                                     isoform2_gc_position2  \
# event_name
# exon:chr10:100190328-100190427:-@exon:chr10:100...              64.285714
# exon:chr10:100190328-100190427:-@exon:chr10:100...              64.640884
# exon:chr10:100190328-100190427:-@exon:chr10:100...              73.076923
# exon:chr10:100193697-100193848:-@exon:chr10:100...              89.256198
# exon:chr10:100195392-100195529:-@exon:chr10:100...              53.684211
#
#                                                     isoform1_gc_position3  \
# event_name
# exon:chr10:100190328-100190427:-@exon:chr10:100...              62.937063
# exon:chr10:100190328-100190427:-@exon:chr10:100...              63.380282
# exon:chr10:100190328-100190427:-@exon:chr10:100...              60.465116
# exon:chr10:100193697-100193848:-@exon:chr10:100...              74.626866
# exon:chr10:100195392-100195529:-@exon:chr10:100...              78.481013
#
#                                                     isoform2_gc_position3
# event_name
# exon:chr10:100190328-100190427:-@exon:chr10:100...              66.091954
# exon:chr10:100190328-100190427:-@exon:chr10:100...              66.473988
# exon:chr10:100190328-100190427:-@exon:chr10:100...              68.918919
# exon:chr10:100193697-100193848:-@exon:chr10:100...              73.913043
# exon:chr10:100195392-100195529:-@exon:chr10:100...              93.548387

# %%
import seaborn as sns
# %matplotlib inline
sns.set(style='ticks', context='talk')

for value_col in value_cols:
    g = sns.jointplot('isoform1_{}'.format(value_col), 'isoform2_{}'.format(value_col), 
                  gc_content_2d, kind='hex', joint_kws=dict(mincnt=1), color='black', size=4)
    g.ax_joint.locator_params(nbins=4)
    g.savefig('{}/{}_jointplot.pdf'.format(figure_folder, value_col))

# %% [markdown]
# ## Calculate miRNA hybridization
#
# For RNA targets, James Broughton from the Pasquinelli lab recommends `RNAhybrid`, and to use just the first 17 nt of the mature miRNA. Wanted to use `fastx-trimmer` but it only takes DNA sequences  - `U`'s are illegal :(

# %%
from Bio import SeqIO
import sys
import os

result_seq = []
filename = '/projects/ps-yeolab/genomes/mirbase/release_21/human_mature.fa'
with open(filename) as infile:
    for seq in SeqIO.parse(infile, 'fasta'):
        result_seq.append(seq[:17])

trimmed_filename = '/projects/ps-yeolab/genomes/mirbase/release_21/human_mature_17bp.fa'
with open(trimmed_filename, 'w') as outfile:
    SeqIO.write(result_seq, outfile, 'fasta')

# %% [markdown]
# Submit a compute job to calculate microRNA hybridization.

# %%
from gscripts.qtools import Submitter

mirna_seqs = '/projects/ps-yeolab/genomes/mirbase/release_21/human_mature_17bp.fa'
rnahybrid_results = '/projects/ps-yeolab/obotvinnik/miso_helpers/hg19/se_exon2_RNAhybrid_mirbase_human_mature_17bp.txt'
command = 'RNAhybrid -c -s 3utr_human -q {} -t {} > {}'.format(mirna_seqs, transcribed_fasta, rnahybrid_results)
sub = Submitter([command], 'RNAhybrid', walltime='120:00:00', write_and_submit=True)
# Out:
# job ID: 3309712

# %% [markdown]
# Reading the output takes a LONG time

# %%
# %%time
import pandas as pd
from collections import Counter

rnahybrid = pd.read_csv('/projects/ps-yeolab/obotvinnik/miso_helpers/hg19/se_exon2_RNAhybrid_mirbase_human_mature_17bp.txt', 
                        sep=':', 
#                         index_col=[0, 1, 3], 
                        header=None,
                        names=['chrom', 'start-stop', 'exon_length', 'mirna', 'mirna_length',
                                                                 'minimum_free_energy', 'p_value', 'target_bound_start', 'mirna_unbound',
                                                                 'mirna_bound', 'exon_bound', 'exon_bound'])
rnahybrid = rnahybrid.ix[rnahybrid.minimum_free_energy < -28]
grouped = rnahybrid.groupby(['chrom', 'start-stop'])
chrom_startstop_mirna = grouped.mirna.apply(lambda x: ','.join('{}[{}]'.format(k, v) for k,v in Counter(x).items()))
chrom_startstop_mirna.head()
