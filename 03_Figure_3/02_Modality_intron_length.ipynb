# %%
from __future__ import print_function

import seaborn as sns
sns.set(style='ticks', context='paper', rc={'font.sans-serif':'Arial', 'pdf.fonttype': 42})

# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


# %matplotlib inline

import anchor
modality_to_color = anchor.MODALITY_TO_COLOR.copy()
modality_to_color['constitutive'] = '#262626'
modality_order = ['excluded', 'bimodal', 'included', 'constitutive']
modality_palette = [modality_to_color[m] for m in modality_order]
modality_palette



import flotilla
flotilla_dir = '/projects/ps-yeolab/obotvinnik/flotilla_projects'

study = flotilla.embark('singlecell_pnm_figure2_modalities_bayesian', flotilla_dir=flotilla_dir)

not_outliers = study.splicing.singles.index.difference(study.splicing.outliers.index)

import pybedtools

folder = '/projects/ps-yeolab/obotvinnik/singlecell_pnms'
csv_folder = '{}/csvs_for_paper/'.format(folder)
bed_folder = '{}/bed'.format(folder)



splicing_feature_folder = '{}/splicing_feature_data'.format(csv_folder)
alternative_feature_folder = '{}/alternative'.format(splicing_feature_folder)
constitutive_feature_folder = '{}/constitutive'.format(splicing_feature_folder)
# Out:
# 2017-01-14 10:25:04	Reading datapackage from /projects/ps-yeolab/obotvinnik/flotilla_projects/singlecell_pnm_figure2_modalities_bayesian/datapackage.json
# 2017-01-14 10:25:04	Parsing datapackage to create a Study object
# https://s3-us-west-2.amazonaws.com/flotilla-projects/ercc/ERCC_Controls.txt has not been downloaded before.
# 	Downloading now to /home/obotvinnik/flotilla_projects/hg19/ERCC_Controls.txt
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Error loading species hg19 data: HTTP Error 404: Not Found
# 2017-01-14 10:26:03 	Initializing Study
# 2017-01-14 10:26:03 	Initializing Predictor configuration manager for Study
# 2017-01-14 10:26:03	Predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# 2017-01-14 10:26:03	Added ExtraTreesClassifier to default predictors
# 2017-01-14 10:26:03	Predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# 2017-01-14 10:26:03	Added ExtraTreesRegressor to default predictors
# 2017-01-14 10:26:03	Predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# 2017-01-14 10:26:03	Added GradientBoostingClassifier to default predictors
# 2017-01-14 10:26:03	Predictor GradientBoostingRegressor is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# 2017-01-14 10:26:03	Added GradientBoostingRegressor to default predictors
# 2017-01-14 10:26:03 	Loading metadata
# 2017-01-14 10:26:03	Loading expression data
# 2017-01-14 10:26:03	Initializing expression
# 2017-01-14 10:26:03	Done initializing expression
# 2017-01-14 10:26:06	Loading splicing data
# 2017-01-14 10:26:06	Initializing splicing
# 2017-01-14 10:26:06	Done initializing splicing
# 2017-01-14 10:26:06	Successfully initialized a Study object!

# %%
study.expression.maybe_renamed_to_feature_id('CDH8')
# Out:
# Index([u'ENSG00000150394'], dtype='object')

# %%
def make_phenotype_modality_format(constitutive_df):
    constitutive_df = constitutive_df.copy().reset_index()
    constitutive_df['modality'] = 'constitutive'
    dfs = []
    for phenotype in study.phenotype_order:
        df = constitutive_df.copy()#.reset_index()
        df['phenotype'] = phenotype
        dfs.append(df)
    df = pd.concat(dfs)
    print(df.shape)
#     df.head()
    return df

# %%
sns.set(style='ticks', context='paper', rc={'font.sans-serif':'Arial', 'pdf.fonttype': 42})

# %%
figure_folder = 'figures/02_Modality_intron_length' #'/home/obotvinnik/Dropbox/figures2/singlecell_pnm/figure2_modalities/bayesian/gene_transcript_features'
! mkdir $figure_folder
# Out:
# mkdir: cannot create directory `figures/02_Modality_intron_length': File exists

# %%
facet_kws = dict(col='phenotype', hue='modality', hue_order=modality_order, palette=modality_palette,
                 col_order=study.phenotype_order, size=2)

# %%
plot_kws = dict(x='phenotype', hue='modality', hue_order=modality_order, palette=modality_palette,
                 order=study.phenotype_order)

# %% [markdown]
# ## Intron length

# %%
prefix = 'intron_length'
csv = '{}.csv'.format(prefix)

# %%
constitutive_values = pd.read_csv('{}/{}'.format(constitutive_feature_folder, csv), 
                                          index_col=0, header=None, squeeze=True)
constitutive_values.name = prefix
constitutive_values.index.name = 'event_id'
constitutive_values.head()
# Out:
# event_id
# exon:chr10:102039881-102039985:-     5441.500000
# exon:chr10:102040691-102040810:-     4245.500000
# exon:chr10:102045854-102045970:-    11091.666667
# exon:chr10:102045854-102046089:-    11227.666667
# exon:chr10:102286732-102286831:-     4130.500000
# Name: intron_length, dtype: float64

# %%
constitutive_values_modalities = make_phenotype_modality_format(constitutive_values)
constitutive_values_modalities.head()
# Out:
# (18204, 4)
#                            event_id  intron_length      modality phenotype
# 0  exon:chr10:102039881-102039985:-    5441.500000  constitutive      iPSC
# 1  exon:chr10:102040691-102040810:-    4245.500000  constitutive      iPSC
# 2  exon:chr10:102045854-102045970:-   11091.666667  constitutive      iPSC
# 3  exon:chr10:102045854-102046089:-   11227.666667  constitutive      iPSC
# 4  exon:chr10:102286732-102286831:-    4130.500000  constitutive      iPSC

# %%
study.splicing.feature_data.shape
# Out:
# (5821777, 32)

# %%
study.splicing.feature_data.tail()
# Out:
#                                                          ensembl_id  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  ENSG00000129824
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  ENSG00000129824
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  ENSG00000129824
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  ENSG00000129824
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  ENSG00000129824
#
#                                                     event_length  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...           NaN
# isoform1=junction:chrY:2712299-2722640:+@exon:c...           NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           NaN
#
#                                                    event_location  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...            NaN
# isoform1=junction:chrY:2712299-2722640:+@exon:c...            NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...            NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...            NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...            NaN
#
#                                                                           exon1  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  exon:chrY:2712117-2712298:+
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  exon:chrY:2712117-2712298:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  exon:chrY:2713686-2713784:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  exon:chrY:2713686-2713784:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  exon:chrY:2713686-2713784:+
#
#                                                     exon1_length  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...           NaN
# isoform1=junction:chrY:2712299-2722640:+@exon:c...           NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           NaN
#
#                                                                           exon2  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  exon:chrY:2713686-2713784:+
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  exon:chrY:2713686-2713784:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  exon:chrY:2722640-2722812:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  exon:chrY:2722640-2722812:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  exon:chrY:2722640-2722812:+
#
#                                                     exon2_length  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...           NaN
# isoform1=junction:chrY:2712299-2722640:+@exon:c...           NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           NaN
#
#                                                                           exon3  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  exon:chrY:2722640-2722812:+
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  exon:chrY:2722640-2722812:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  exon:chrY:2733128-2733286:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  exon:chrY:2733128-2733286:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  exon:chrY:2733128-2733286:+
#
#                                                     exon3_length  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...           NaN
# isoform1=junction:chrY:2712299-2722640:+@exon:c...           NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           NaN
#
#                                                                           exon4  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  exon:chrY:2734833-2734903:+
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  exon:chrY:2734833-2734997:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  exon:chrY:2734833-2735309:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  exon:chrY:2734833-2734997:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  exon:chrY:2734833-2734903:+
#
#                                                          ...        \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...       ...
# isoform1=junction:chrY:2712299-2722640:+@exon:c...       ...
# isoform1=junction:chrY:2713785-2733128:+@exon:c...       ...
# isoform1=junction:chrY:2713785-2733128:+@exon:c...       ...
# isoform1=junction:chrY:2713785-2733128:+@exon:c...       ...
#
#                                                                          junction24  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  junction:chrY:2713785-2734833:+
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  junction:chrY:2713785-2734833:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  junction:chrY:2722813-2734833:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  junction:chrY:2722813-2734833:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  junction:chrY:2722813-2734833:+
#
#                                                                          junction34  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  junction:chrY:2722813-2734833:+
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  junction:chrY:2722813-2734833:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  junction:chrY:2733287-2734833:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  junction:chrY:2733287-2734833:+
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  junction:chrY:2733287-2734833:+
#
#                                                    junctions level strand  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...       NaN   2.0    NaN
# isoform1=junction:chrY:2712299-2722640:+@exon:c...       NaN   2.0    NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...       NaN   2.0    NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...       NaN   2.0    NaN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...       NaN   2.0    NaN
#
#                                                     tag       transcript_id  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  NaN  ENSG00000129824.11
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  NaN  ENSG00000129824.11
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  NaN  ENSG00000129824.11
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  NaN  ENSG00000129824.11
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  NaN  ENSG00000129824.11
#
#                                                     transcript_name  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...           RPS4Y1
# isoform1=junction:chrY:2712299-2722640:+@exon:c...           RPS4Y1
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           RPS4Y1
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           RPS4Y1
# isoform1=junction:chrY:2713785-2733128:+@exon:c...           RPS4Y1
#
#                                                    transcript_status  \
# isoform1=junction:chrY:2712299-2722640:+@exon:c...             KNOWN
# isoform1=junction:chrY:2712299-2722640:+@exon:c...             KNOWN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...             KNOWN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...             KNOWN
# isoform1=junction:chrY:2713785-2733128:+@exon:c...             KNOWN
#
#                                                    transcript_type
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  protein_coding
# isoform1=junction:chrY:2712299-2722640:+@exon:c...  protein_coding
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  protein_coding
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  protein_coding
# isoform1=junction:chrY:2713785-2733128:+@exon:c...  protein_coding
#
# [5 rows x 32 columns]

# %%
study.splicing.feature_data[col].groupby(study.splicing.feature_data['splice_type']).size()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-1e884796ce6e> in <module>()
# ----> 1 study.splicing.feature_data[col].groupby(study.splicing.feature_data['splice_type']).size()
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3539
#    3540             if not isnull(item):
# -> 3541                 loc = self.items.get_loc(item)
#    3542             else:
#    3543                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4443)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4289)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13733)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13687)()
#
# KeyError: 'splice_type'

# %%
col = 'intron_length'
log_col = '$\log_{10}$ Intron Length'
modality_values = study.supplemental.modalities_tidy.join(study.splicing.feature_data[col], on='event_id')
modality_values = pd.concat([modality_values, constitutive_values_modalities])
modality_values[log_col] = np.log10(modality_values[col])
modality_values.head()
# Out:
#                                             event_id  intron_length  modality  \
# 0  isoform1=junction:chr10:101163392-101165512:-|...         2123.0  included
# 1  isoform1=junction:chr10:101476219-101480743:-|...         4527.0   bimodal
# 2  isoform1=junction:chr10:102114390-102120490:+|...         6103.0  included
# 2  isoform1=junction:chr10:102114390-102120490:+|...         6103.0  included
# 2  isoform1=junction:chr10:102114390-102120490:+|...         6103.0  included
#
#   phenotype  $\log_{10}$ Intron Length
# 0        MN                   3.326950
# 1        MN                   3.655810
# 2        MN                   3.785543
# 2        MN                   3.785543
# 2        MN                   3.785543

# %%
fig, ax = plt.subplots(figsize=(2, 1.5))
plt.yscale('log')
sns.boxplot(data=modality_values, y=col, linewidth=1, fliersize=2, **plot_kws)
ax.legend_.set_visible(False)
# ax.locator_params('y', nbins=4)
sns.despine()
fig.savefig('{}/{}_boxplot.pdf'.format(figure_folder, col))

# %%
from flotilla.visualize.generic import cdfplot

g = sns.FacetGrid(modality_values, **facet_kws)
plt.xscale('log')
g.map(cdfplot, col)

# %%
import itertools

from scipy.stats.mstats import mannwhitneyu

lines = []

for phenotype, phenotype_df in modality_values.groupby(['phenotype']):
    six.print_(phenotype)
    grouped = phenotype_df.groupby('modality')
#     constitutive = grouped.get_group('constitutive')
    
    for (modality1, df1), (modality2, df2) in itertools.combinations(grouped, 2):
#         if modality == 'constitutive':
#             continue
#         six.print_('\t', modality1, modality2)

        result = mannwhitneyu(df1[col], df2[col])
#         six.print_('\t\t', result)
#         results.loc[modality1, modality2] = result.pvalue
        lines.append([phenotype, modality1, modality2, result.pvalue, result.statistic])
enrichment = pd.DataFrame(lines, columns=['phenotype', 'modality1', 'modality2', 'p_value', 'statistic'])

# multiple testing correction
enrichment['bonferonni_p_value'] = enrichment['p_value'] * enrichment.shape[0]
enrichment.head()

# Transform tidy dataframe into 2d matrix
enrichment_2d = enrichment.groupby('phenotype').apply(
    lambda x: x.pivot(index='modality1', columns='modality2', values='bonferonni_p_value'))
enrichment_2d = enrichment_2d.loc[:, modality_order]
enrichment_2d_log10 = -np.log10(enrichment_2d)

# Plot p-value heatmap
fig, ax = plt.subplots(figsize=(.5, .75))
ipsc = enrichment_2d_log10.loc['iPSC']
ipsc = ipsc.loc[modality_order]
ipsc = ipsc.T.fillna(0) + ipsc.fillna(0)
ipsc = ipsc.replace(0, np.nan)
sns.heatmap(ipsc, vmin=0, linewidth=0.5, linecolor='grey', cbar_kws=dict(orientation='horizontal'))
ax.set(xticks=[], yticks=[], xlabel='', ylabel='');
sns.despine(left=False, bottom=False, right=False, top=False)
fig.savefig('{}/{}_p_value_heatmap.pdf'.format(figure_folder, col))

six.print_(ipsc)

# %% [markdown]
# ## Gene expression

# %%
study.splicing.feature_expression_id_col = 'ensembl_id'
splicing_tidy = study.tidy_splicing_with_expression.copy()
six.print_(splicing_tidy.shape)
singles_not_outliers = study.splicing.singles.index.difference(study.splicing.outliers.index)
splicing_tidy_singles = splicing_tidy.ix[splicing_tidy.sample_id.isin(singles_not_outliers)]
six.print_(splicing_tidy_singles.shape)
splicing_tidy_singles = splicing_tidy_singles.join(study.sample_id_to_phenotype, on='sample_id')

# %%
splicing_tidy_singles.head()

# %%
constitutive_genes = pd.read_csv('{}/genes_expanded.csv'.format(constitutive_feature_folder), 
                                 header=None, index_col=0, squeeze=True)
constitutive_genes.name = 'common_id'
constitutive_genes.index.name = 'event_id'
constitutive_genes.head()
# Out:
# event_id
# exon:chr10:102039881-102039985:-    ENSG00000196072
# exon:chr10:102040691-102040810:-    ENSG00000196072
# exon:chr10:102045854-102045970:-    ENSG00000196072
# exon:chr10:102045854-102046089:-    ENSG00000196072
# exon:chr10:102286732-102286831:-    ENSG00000075826
# Name: common_id, dtype: object

# %%
constitutive_genes_modalities = make_phenotype_modality_format(constitutive_genes)
constitutive_genes_modalities.head()
# Out:
# (19398, 4)
#                            event_id        common_id      modality phenotype
# 0  exon:chr10:102039881-102039985:-  ENSG00000196072  constitutive      iPSC
# 1  exon:chr10:102040691-102040810:-  ENSG00000196072  constitutive      iPSC
# 2  exon:chr10:102045854-102045970:-  ENSG00000196072  constitutive      iPSC
# 3  exon:chr10:102045854-102046089:-  ENSG00000196072  constitutive      iPSC
# 4  exon:chr10:102286732-102286831:-  ENSG00000075826  constitutive      iPSC

# %%
splicing_tidy_singles.head()
# Out:
#                                           event_name sample_id  psi  \
# 3  exon:chr10:100190328-100190427:-@exon:chr10:10...     P1_06    1
# 4  exon:chr10:100193697-100193848:-@exon:chr10:10...     P1_06    1
# 5  exon:chr10:100195392-100195529:-@exon:chr10:10...     P1_06    0
# 6  exon:chr10:100190328-100190427:-@exon:chr10:10...     P1_10    0
# 7  exon:chr10:100195392-100195529:-@exon:chr10:10...     P1_10    1
#
#          common_id  expression phenotype
# 3  ENSG00000107521     3.08626      iPSC
# 4  ENSG00000107521     3.08626      iPSC
# 5  ENSG00000107521     3.08626      iPSC
# 6  ENSG00000107521    22.27229      iPSC
# 7  ENSG00000107521    22.27229      iPSC

# %%
constitutive_genes_modalities_expression = constitutive_genes_modalities.merge(
    splicing_tidy_singles, left_on=['common_id', 'phenotype'], right_on=['common_id', 'phenotype'])
constitutive_genes_modalities_expression.head()
# Out:
#                            event_id        common_id      modality phenotype  \
# 0  exon:chr10:102286732-102286831:-  ENSG00000075826  constitutive      iPSC
# 1  exon:chr10:102286732-102286831:-  ENSG00000075826  constitutive      iPSC
# 2  exon:chr10:102286732-102286831:-  ENSG00000075826  constitutive      iPSC
# 3  exon:chr10:102286732-102286831:-  ENSG00000075826  constitutive      iPSC
# 4  exon:chr10:102286732-102286831:-  ENSG00000075826  constitutive      iPSC
#
#                                           event_name sample_id  psi  \
# 0  exon:chr10:102286732-102286831:-@exon:chr10:10...     P1_01    1
# 1  exon:chr10:102286732-102286831:-@exon:chr10:10...     P1_01    1
# 2  exon:chr10:102286732-102286831:-@exon:chr10:10...     P1_01    1
# 3  exon:chr10:102286732-102286831:-@exon:chr10:10...     P1_02    1
# 4  exon:chr10:102286732-102286831:-@exon:chr10:10...     P1_02    1
#
#    expression
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
modalities_expression = study.supplemental.modalities_tidy.merge(
    splicing_tidy_singles, left_on=['event_id', 'phenotype'], right_on=['event_name', 'phenotype'])
modalities_expression = modalities_expression.drop('event_name', axis=1, errors='ignore')
modalities_expression = pd.concat([modalities_expression, constitutive_genes_modalities_expression])
six.print_(modalities_expression.shape)
modalities_expression = modalities_expression.join(modalities_expression.groupby(['event_id', 'sample_id']).expression.sum(),
                           on=['event_id', 'sample_id'], rsuffix='_summed', lsuffix='_original')

modalities_expression['log2(TPM+1)'] = np.log2(modalities_expression.expression_summed+1)
modalities_expression.head()
# Out:
# (3126655, 8)
#          common_id                                           event_id  \
# 0  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
# 1  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
# 2  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
# 3  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
# 4  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
#
#   event_name  expression_original  modality phenotype       psi sample_id  \
# 0        NaN              93.8797  included        MN  1.000000     M1_02
# 1        NaN             241.1150  included        MN  1.000000     M1_07
# 2        NaN            1034.7762  included        MN  1.000000     M1_10
# 3        NaN             308.3360  included        MN  1.000000     M2_03
# 4        NaN             295.4470  included        MN  0.952381     M2_10
#
#    expression_summed  log2(TPM+1)
# 0            93.8797     6.568028
# 1           241.1150     7.919549
# 2          1034.7762    10.016497
# 3           308.3360     8.273031
# 4           295.4470     8.211630

# %%
mean_expression = modalities_expression.groupby(['event_id', 'sample_id'])['expression_original'].mean()

mean_expression.name = 'expression_mean'


modalities_expression = modalities_expression.join(mean_expression, on=['event_id', 'sample_id'])
modalities_expression.head()
# Out:
#          common_id                                           event_id  \
# 0  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
# 1  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
# 2  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
# 3  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
# 4  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
#
#   event_name  expression_original  modality phenotype       psi sample_id  \
# 0        NaN              93.8797  included        MN  1.000000     M1_02
# 1        NaN             241.1150  included        MN  1.000000     M1_07
# 2        NaN            1034.7762  included        MN  1.000000     M1_10
# 3        NaN             308.3360  included        MN  1.000000     M2_03
# 4        NaN             295.4470  included        MN  0.952381     M2_10
#
#    expression_summed  log2(TPM+1)  expression_mean
# 0            93.8797     6.568028          93.8797
# 1           241.1150     7.919549         241.1150
# 2          1034.7762    10.016497        1034.7762
# 3           308.3360     8.273031         308.3360
# 4           295.4470     8.211630         295.4470

# %%
modalities_expression['expression_mean_log2_plus1'] = np.log2(modalities_expression.expression_mean+1)
modalities_expression.head()
# Out:
#          common_id                                           event_id  \
# 0  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
# 1  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
# 2  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
# 3  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
# 4  ENSG00000120053  exon:chr10:101165513-101165617:-@exon:chr10:10...
#
#   event_name  expression_original  modality phenotype       psi sample_id  \
# 0        NaN              93.8797  included        MN  1.000000     M1_02
# 1        NaN             241.1150  included        MN  1.000000     M1_07
# 2        NaN            1034.7762  included        MN  1.000000     M1_10
# 3        NaN             308.3360  included        MN  1.000000     M2_03
# 4        NaN             295.4470  included        MN  0.952381     M2_10
#
#    expression_summed  log2(TPM+1)  expression_mean  expression_mean_log2_plus1
# 0            93.8797     6.568028          93.8797                    6.568028
# 1           241.1150     7.919549         241.1150                    7.919549
# 2          1034.7762    10.016497        1034.7762                   10.016497
# 3           308.3360     8.273031         308.3360                    8.273031
# 4           295.4470     8.211630         295.4470                    8.211630

# %%
fig, ax = plt.subplots(figsize=(2, 1.5))
sns.boxplot(y='expression_mean_log2_plus1', data=modalities_expression, linewidth=1, fliersize=3, **plot_kws)
ax.legend_.set_visible(False)
sns.despine()
ax.set(xlabel='', ylabel='$\log_{2}(\mathrm{TPM} + 1)$', ylim=(0, 16))
ax.locator_params('y', nbins=4)
fig.savefig('{}/expression.pdf'.format(figure_folder))

# %%
modalities_expression_phenotype_mean = modalities_expression.groupby(
    ['phenotype', 'modality', 'common_id'])['log2(TPM+1)'].mean()
modalities_expression_phenotype_mean = modalities_expression_phenotype_mean.reset_index()
modalities_expression_phenotype_mean = modalities_expression_phenotype_mean.rename(columns={'log2(TPM+1)': 'mean(log2(TPM+1))'})
modalities_expression_phenotype_mean.head()
# Out:
#   phenotype modality        common_id  mean(log2(TPM+1))
# 0        MN  bimodal  ENSG00000002933           6.252429
# 1        MN  bimodal  ENSG00000003756           8.257622
# 2        MN  bimodal  ENSG00000004455           6.096512
# 3        MN  bimodal  ENSG00000004487           8.885616
# 4        MN  bimodal  ENSG00000004866           7.850198

# %%
modalities_expression_phenotype_var = modalities_expression.groupby(
    ['phenotype', 'modality', 'common_id'])['log2(TPM+1)'].var()
modalities_expression_phenotype_var.name = 'var(log2(TPM+1))'
modalities_expression_phenotype_var.head()
# Out:
# phenotype  modality  common_id
# MN         bimodal   ENSG00000002933    1.494761
#                      ENSG00000003756    1.279694
#                      ENSG00000004455    4.607025
#                      ENSG00000004487    0.931608
#                      ENSG00000004866    0.881394
# Name: var(log2(TPM+1)), dtype: float64

# %%
modalities_expresion_phenotype = modalities_expression_phenotype_mean.join(
    modalities_expression_phenotype_var, on=['phenotype', 'modality', 'common_id'])
modalities_expresion_phenotype.head()
# Out:
#   phenotype modality        common_id  mean(log2(TPM+1))  var(log2(TPM+1))
# 0        MN  bimodal  ENSG00000002933           6.252429          1.494761
# 1        MN  bimodal  ENSG00000003756           8.257622          1.279694
# 2        MN  bimodal  ENSG00000004455           6.096512          4.607025
# 3        MN  bimodal  ENSG00000004487           8.885616          0.931608
# 4        MN  bimodal  ENSG00000004866           7.850198          0.881394

# %%
fig, ax = plt.subplots(figsize=(2, 1.5))
sns.boxplot(y='mean(log2(TPM+1))', data=modalities_expresion_phenotype, linewidth=1, fliersize=3, **plot_kws)
ax.legend_.set_visible(False)
sns.despine()
ax.set(xlabel='', ylabel=r'$\mathrm{mean}\left(\log_{2}(\mathrm{TPM} + 1)\right)$')
ax.locator_params('y', nbins=4)
fig.savefig('{}/expression_mean_within_phenotype.pdf'.format(figure_folder))

# %%
from scipy.stats.mstats import kruskalwallis

col = 'mean(log2(TPM+1))'

lines = []

for phenotype, phenotype_df in modalities_expresion_phenotype.groupby(['phenotype']):
    six.print_(phenotype)
    grouped = phenotype_df.groupby('modality')
    constitutive = grouped.get_group('constitutive')
    
    for modality, modality_df in grouped:
        if modality == 'constitutive':
            continue
#         six.print_('\t', modality)

        result = kruskalwallis(modality_df[col], constitutive[col])
#         six.print_('\t\t', result)
        lines.append([phenotype, modality, result[0], result[1]])
expression_significance = pd.DataFrame(lines, columns=['phenotype', 'modality', 'statistic', 'p-value'])
expression_significance['q-value'] = expression_significance['p-value'] * expression_significance.shape[0]
expression_significance.loc[expression_significance['q-value'] < 1e-3]
# Out:
# MN
# NPC
# iPSC
#    phenotype  modality    statistic        p-value        q-value
# 0         MN   bimodal   546.396290  7.655053e-121  9.951568e-120
# 1         MN  excluded   320.183608   1.321014e-71   1.717318e-70
# 2         MN  included   428.045436   4.328137e-95   5.626578e-94
# 4        NPC   bimodal   937.676127  6.333852e-206  8.234007e-205
# 5        NPC  excluded   558.235482  2.034520e-123  2.644877e-122
# 6        NPC  included   743.039195  1.309003e-163  1.701704e-162
# 8       iPSC   bimodal  1342.135838  7.881786e-294  1.024632e-292
# 9       iPSC  excluded   732.648182  2.378867e-161  3.092528e-160
# 10      iPSC  included  1021.771314  3.326729e-224  4.324748e-223

# %% [markdown]
# ### Plot significance as heatmap

# %%
import itertools

from scipy.stats.mstats import mannwhitneyu

col = 'mean(log2(TPM+1))'


lines = []

for phenotype, phenotype_df in modalities_expresion_phenotype.groupby(['phenotype']):
    six.print_(phenotype)
    grouped = phenotype_df.groupby('modality')
#     constitutive = grouped.get_group('constitutive')
    
    for (modality1, df1), (modality2, df2) in itertools.combinations(grouped, 2):
#         if modality == 'constitutive':
#             continue
#         six.print_('\t', modality1, modality2)

        result = mannwhitneyu(df1[col], df2[col])
#         six.print_('\t\t', result)
#         results.loc[modality1, modality2] = result.pvalue
        lines.append([phenotype, modality1, modality2, result.pvalue, result.statistic])
enrichment = pd.DataFrame(lines, columns=['phenotype', 'modality1', 'modality2', 'p_value', 'statistic'])

# multiple testing correction
enrichment['bonferonni_p_value'] = enrichment['p_value'] * enrichment.shape[0]
enrichment.head()

# Transform tidy dataframe into 2d matrix
enrichment_2d = enrichment.groupby('phenotype').apply(
    lambda x: x.pivot(index='modality1', columns='modality2', values='bonferonni_p_value'))
enrichment_2d = enrichment_2d.loc[:, modality_order]
enrichment_2d_log10 = -np.log10(enrichment_2d)

# Plot p-value heatmap
fig, ax = plt.subplots(figsize=(.5, .75))
ipsc = enrichment_2d_log10.loc['iPSC']
ipsc = ipsc.loc[modality_order]
ipsc = ipsc.T.fillna(0) + ipsc.fillna(0)
ipsc = ipsc.replace(0, np.nan)
sns.heatmap(ipsc, vmin=0, linewidth=0.5, linecolor='grey', cbar_kws=dict(orientation='horizontal'))
ax.set(xticks=[], yticks=[], xlabel='', ylabel='');
sns.despine(left=False, bottom=False, right=False, top=False)
fig.savefig('{}/{}_p_value_heatmap.pdf'.format(figure_folder, col))
# Out:
# MN
# NPC
# iPSC

# %%
sns.boxplot(y='var(log2(TPM+1))', data=modalities_expresion_phenotype, linewidth=1, fliersize=3, **plot_kws)

# %%
fig, axes = plt.subplots(figsize=(2, 1.5), nrows=2, gridspec_kw=dict(height_ratios=(0.2, 0.8), hspace=0.2))
ax = axes[0]
sns.boxplot(y='var(log2(TPM+1))', data=modalities_expresion_phenotype, linewidth=1, fliersize=3, ax=ax, **plot_kws)
ax.legend_.set_visible(False)
ax.locator_params('y', nbins=4)
# sns.despine(ax=ax, bottom=True)
ax.set(ylim=(10, 20), ylabel='')
ax.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off

ax = axes[1]
sns.boxplot(y='var(log2(TPM+1))', data=modalities_expresion_phenotype, linewidth=1, fliersize=3, ax=ax, **plot_kws)
ax.legend_.set_visible(False)
ax.locator_params('y', nbins=4)
sns.despine()

ax.set(xlabel='', ylabel=r'$\mathrm{var}\left(\log_{2}(\mathrm{TPM} + 1)\right)$', ylim=(0, 5))

fig.savefig('{}/expression_var_within_phenotype.pdf'.format(figure_folder))

# %% [markdown]
# ## Exon splice site scores

# %%
prefix = 'maxentscan'
csv = '{}.csv'.format(prefix)

# %%
constitutive_maxentscan = pd.read_csv('{}/{}'.format(constitutive_feature_folder, csv), index_col=0)
constitutive_maxentscan.index.name = 'event_id'
constitutive_maxentscan.head()
# Out:
#                                   splice_site_3p_score  \
# event_id
# exon:chr10:102039881-102039985:-                  8.01
# exon:chr10:102040691-102040810:-                  5.71
# exon:chr10:102045854-102045970:-                  5.19
# exon:chr10:102286732-102286831:-                  9.47
# exon:chr10:102289123-102289263:-                  8.05
#
#                                        splice_site_3p_seq  \
# event_id
# exon:chr10:102039881-102039985:-  GTTTTTCTTTGTTTTTAAAGATG
# exon:chr10:102040691-102040810:-  TCTTCTGTTTAATTTTCAAGCCA
# exon:chr10:102045854-102045970:-  GTCATTCTCCCTTGGCCCAGACG
# exon:chr10:102286732-102286831:-  AAGTTCTTGCTGTCTTTCAGGTA
# exon:chr10:102289123-102289263:-  TGTTCTCTTCTGCGTTCTAGCCT
#
#                                   splice_site_5p_score splice_site_5p_seq
# event_id
# exon:chr10:102039881-102039985:-                  3.95          TGGGTAACC
# exon:chr10:102040691-102040810:-                  8.62          AATGTAAGT
# exon:chr10:102045854-102045970:-                  8.48          CGGGTGAGG
# exon:chr10:102286732-102286831:-                 10.10          CCGGTAAGA
# exon:chr10:102289123-102289263:-                  7.47          AGGGTATGC

# %%
score_cols = constitutive_maxentscan.describe().columns
constitutive_maxentscan.describe()
# Out:
#        splice_site_3p_score  splice_site_5p_score
# count           5893.000000           5893.000000
# mean               7.990557              8.108286
# std                3.712458              3.148625
# min              -32.040000            -31.740000
# 25%                6.720000              7.390000
# 50%                8.500000              8.780000
# 75%               10.130000              9.880000
# max               14.850000             11.810000

# %%
constitutive_maxentscan.loc[(constitutive_maxentscan[score_cols] < 0).any(axis=1)].head()
# Out:
#                                   splice_site_3p_score  \
# event_id
# exon:chr10:112359412-112359570:+                 -0.42
# exon:chr10:126092367-126092489:-                  9.83
# exon:chr10:133786538-133786622:-                 -1.37
# exon:chr10:33218769-33218972:-                    4.60
# exon:chr10:33221434-33221528:-                   11.35
#
#                                        splice_site_3p_seq  \
# event_id
# exon:chr10:112359412-112359570:+  AAATGGATAATGTCATATAGCAA
# exon:chr10:126092367-126092489:-  TATTCCTGTTTCTTCTGTAGCGT
# exon:chr10:133786538-133786622:-  ATTCTATTCACATCGCCAAGCCC
# exon:chr10:33218769-33218972:-    ATATTTTATATGTCATTTAGACA
# exon:chr10:33221434-33221528:-    TTCTTTCTTCTTTCTGACAGATG
#
#                                   splice_site_5p_score splice_site_5p_seq
# event_id
# exon:chr10:112359412-112359570:+                 10.86          CAGGTAAGT
# exon:chr10:126092367-126092489:-                 -1.28          CAGGTTGTC
# exon:chr10:133786538-133786622:-                  9.88          CAGGTAAGC
# exon:chr10:33218769-33218972:-                   -7.95          TTGGTTTTG
# exon:chr10:33221434-33221528:-                   -0.35          AAGGTTGCT

# %%
constitutive_maxentscan_modalities = make_phenotype_modality_format(constitutive_maxentscan)
constitutive_maxentscan_modalities.head()
# Out:
# (17679, 7)
#                            event_id  splice_site_3p_score  \
# 0  exon:chr10:102039881-102039985:-                  8.01
# 1  exon:chr10:102040691-102040810:-                  5.71
# 2  exon:chr10:102045854-102045970:-                  5.19
# 3  exon:chr10:102286732-102286831:-                  9.47
# 4  exon:chr10:102289123-102289263:-                  8.05
#
#         splice_site_3p_seq  splice_site_5p_score splice_site_5p_seq  \
# 0  GTTTTTCTTTGTTTTTAAAGATG                  3.95          TGGGTAACC
# 1  TCTTCTGTTTAATTTTCAAGCCA                  8.62          AATGTAAGT
# 2  GTCATTCTCCCTTGGCCCAGACG                  8.48          CGGGTGAGG
# 3  AAGTTCTTGCTGTCTTTCAGGTA                 10.10          CCGGTAAGA
# 4  TGTTCTCTTCTGCGTTCTAGCCT                  7.47          AGGGTATGC
#
#        modality phenotype
# 0  constitutive      iPSC
# 1  constitutive      iPSC
# 2  constitutive      iPSC
# 3  constitutive      iPSC
# 4  constitutive      iPSC

# %%
constitutive_maxentscan.loc[(constitutive_maxentscan[score_cols] < 0).all(axis=1)]
# Out:
#                                 splice_site_3p_score       splice_site_3p_seq  \
# event_id
# exon:chr15:66795029-66795088:-                 -2.26  ATTCTTGACTGGAAAAATAGATG
# exon:chr7:87839398-87839445:-                  -2.20  AATCCTTGATTACAGTTCAGAGA
#
#                                 splice_site_5p_score splice_site_5p_seq
# event_id
# exon:chr15:66795029-66795088:-                 -5.89          AGAGTGAAC
# exon:chr7:87839398-87839445:-                 -19.00          TGGGCTGTA

# %%
alternative_maxentscan = pd.read_csv('{}/{}'.format(alternative_feature_folder, csv), index_col=0)
alternative_maxentscan.index.name = 'event_id'
alternative_maxentscan.head()
# Out:
#                                                     splice_site_3p_score  \
# event_id
# exon:chr10:102003455-102003534:-@exon:chr10:101...                  7.84
# exon:chr10:102013178-102013296:-@exon:chr10:102...                  6.56
# exon:chr10:102020723-102020801:-@exon:chr10:102...                  8.47
# exon:chr10:102021736-102021820:-@exon:chr10:102...                  8.47
# exon:chr10:102021736-102021820:-@exon:chr10:102...                  7.14
#
#                                                          splice_site_3p_seq  \
# event_id
# exon:chr10:102003455-102003534:-@exon:chr10:101...  TCTGTGTGCTGCTTCTTCAGTGC
# exon:chr10:102013178-102013296:-@exon:chr10:102...  GTCTCTCAAATATGTTGTAGAAA
# exon:chr10:102020723-102020801:-@exon:chr10:102...  ATGTCTGTTTCCCTCACTAGCTC
# exon:chr10:102021736-102021820:-@exon:chr10:102...  ATGTCTGTTTCCCTCACTAGCTC
# exon:chr10:102021736-102021820:-@exon:chr10:102...  TTAGCTGCTGTTGTGTGTAGGAA
#
#                                                     splice_site_5p_score  \
# event_id
# exon:chr10:102003455-102003534:-@exon:chr10:101...                 10.28
# exon:chr10:102013178-102013296:-@exon:chr10:102...                  9.06
# exon:chr10:102020723-102020801:-@exon:chr10:102...                  8.84
# exon:chr10:102021736-102021820:-@exon:chr10:102...                  8.84
# exon:chr10:102021736-102021820:-@exon:chr10:102...                  7.98
#
#                                                    splice_site_5p_seq
# event_id
# exon:chr10:102003455-102003534:-@exon:chr10:101...          CAGGTAGGT
# exon:chr10:102013178-102013296:-@exon:chr10:102...          AAGGTAAAG
# exon:chr10:102020723-102020801:-@exon:chr10:102...          TGGGTAAGC
# exon:chr10:102021736-102021820:-@exon:chr10:102...          TGGGTAAGC
# exon:chr10:102021736-102021820:-@exon:chr10:102...          AAGGTATAG

# %%
modalities_maxentscan = study.supplemental.modalities_tidy.join(alternative_maxentscan, on='event_id')
modalities_maxentscan = pd.concat([modalities_maxentscan, constitutive_maxentscan_modalities])
modalities_maxentscan.tail()
# Out:
#                            event_id      modality phenotype  \
# 5888  exon:chrX:80532483-80532668:+  constitutive        MN
# 5889  exon:chrX:80533830-80533910:+  constitutive        MN
# 5890  exon:chrX:99887482-99887565:-  constitutive        MN
# 5891  exon:chrX:99890175-99890249:-  constitutive        MN
# 5892  exon:chrX:99890555-99890743:-  constitutive        MN
#
#       splice_site_3p_score       splice_site_3p_seq  splice_site_5p_score  \
# 5888                  8.56  TTCTTGTCCTTTGGTCCTAGATT                  7.83
# 5889                  7.00  CTTATCTTCTTTTCATCAAGGAC                  9.11
# 5890                 11.13  TGTTTTTTTCCTCCCATTAGGGT                 10.08
# 5891                 10.90  CTTTCTTTCTTATCCTGCAGTAT                  9.85
# 5892                  6.84  TTCTCTGAATTCCCACATAGATC                 10.10
#
#      splice_site_5p_seq
# 5888          GGGGTAAGA
# 5889          AAGGTATGA
# 5890          CAAGTAAGT
# 5891          GAGGTAAGC
# 5892          CTGGTGAGT

# %%
score_cols
# Out:
# Index([u'splice_site_3p_score', u'splice_site_5p_score'], dtype='object')

# %%
modalities_maxentscan.head()
# Out:
#                                             event_id  modality phenotype  \
# 0  exon:chr10:101165513-101165617:-@exon:chr10:10...  included        MN
# 1  exon:chr10:101480744-101480825:-@exon:chr10:10...   bimodal        MN
# 2  exon:chr10:102114184-102114389:+@exon:chr10:10...  included        MN
# 3  exon:chr10:102286732-102286831:-@exon:chr10:10...  included        MN
# 4  exon:chr10:102747070-102747240:-@exon:chr10:10...   bimodal        MN
#
#    splice_site_3p_score       splice_site_3p_seq  splice_site_5p_score  \
# 0                 10.79  CTCACTTTGCTTCCCCGCAGCAC                  8.34
# 1                  2.71  CCATTTACCTTGGAATACAGGGG                 10.65
# 2                  7.55  TGTCTGGTCTGTCAATGTAGGTA                 10.24
# 3                  9.49  TATTTGTCTTTCTGCCTCAGATG                  8.95
# 4                  3.77  CACTGTCCCGGGTCGCTTAGGGA                  9.40
#
#   splice_site_5p_seq
# 0          ACAGTGAGT
# 1          CTGGTAAGT
# 2          TGGGTAAGT
# 3          GTGGTGAGT
# 4          ACCGTGAGT

# %%
for col in score_cols:

    fig, ax = plt.subplots(figsize=(2, 1.5))
    sns.boxplot(data=modalities_maxentscan, y=col, linewidth=1, fliersize=2, **plot_kws)
    ax.set(ylim=(-10, 16), xlabel='')
    ax.legend_.set_visible(False)
    sns.despine()
    fig.tight_layout()
    fig.savefig('{}/{}.pdf'.format(figure_folder, col))

# %%
from scipy.stats.mstats import kruskalwallis

lines = []

for col in score_cols:
#     six.print_('--- {} ---'.format(col))
    for phenotype, phenotype_df in modalities_maxentscan.groupby(['phenotype']):
#         six.print_(phenotype)
        grouped = phenotype_df.groupby('modality')

        for (modality1, df1), (modality2, df2) in itertools.combinations(grouped, 2):
            result = mannwhitneyu(df1[col], df2[col])
            lines.append([phenotype, col, modality1, modality2, result.pvalue, result.statistic])
splice_site_significance = pd.DataFrame(lines, columns=['phenotype', 'splice_site', 
                                                        'modality1', 'modality2', 'p_value', 'statistic'])

# multiple testing correction
splice_site_significance['bonferonni_p_value'] = splice_site_significance['p_value'] * splice_site_significance.shape[0]
splice_site_significance.head()
# Out:
#   phenotype           splice_site     modality1      modality2       p_value  \
# 0        MN  splice_site_3p_score       bimodal   constitutive  5.800944e-06
# 1        MN  splice_site_3p_score       bimodal       excluded  3.131658e-18
# 2        MN  splice_site_3p_score       bimodal       included  5.484733e-07
# 3        MN  splice_site_3p_score       bimodal  uncategorized  4.537018e-01
# 4        MN  splice_site_3p_score  constitutive       excluded  1.171657e-48
#
#    statistic  bonferonni_p_value
# 0  3568131.0        4.060661e-04
# 1   617130.5        2.192161e-16
# 2  1782221.0        3.839313e-05
# 3      912.5        3.175913e+01
# 4  2525883.0        8.201601e-47

# %%
for splice_site, enrichment in splice_site_significance.groupby('splice_site'):
    # Transform tidy dataframe into 2d matrix
    enrichment_2d = enrichment.groupby('phenotype').apply(
        lambda x: x.pivot(index='modality1', columns='modality2', values='bonferonni_p_value'))
    enrichment_2d = enrichment_2d.loc[:, modality_order]
    enrichment_2d_log10 = -np.log10(enrichment_2d)

    # Plot p-value heatmap of just iPSC
    fig, ax = plt.subplots(figsize=(.5, .75))
    ipsc = enrichment_2d_log10.loc['iPSC']
    ipsc = ipsc.loc[modality_order]
    ipsc = ipsc.T.fillna(0) + ipsc.fillna(0)
    ipsc = ipsc.replace(0, np.nan)
    sns.heatmap(ipsc, vmin=0, linewidth=0.5, linecolor='grey', cbar_kws=dict(orientation='horizontal'))
    ax.set(xticks=[], yticks=[], xlabel='', ylabel='');
    sns.despine(left=False, bottom=False, right=False, top=False)
    fig.savefig('{}/{}_p_value_heatmap.pdf'.format(figure_folder, splice_site))

# %% [markdown]
# ## Splice site sequences

# %%
modalities_maxentscan['splice_site_3p_seq_2bp'] = modalities_maxentscan['splice_site_3p_seq'].str[-5:-3]
modalities_maxentscan['splice_site_5p_seq_2bp'] = modalities_maxentscan['splice_site_5p_seq'].str[3:5]
modalities_maxentscan
# Out:
#                                                event_id      modality  \
# 0     exon:chr10:101165513-101165617:-@exon:chr10:10...      included
# 1     exon:chr10:101480744-101480825:-@exon:chr10:10...       bimodal
# 2     exon:chr10:102114184-102114389:+@exon:chr10:10...      included
# 3     exon:chr10:102286732-102286831:-@exon:chr10:10...      included
# 4     exon:chr10:102747070-102747240:-@exon:chr10:10...       bimodal
# 5     exon:chr10:103113820-103113985:+@exon:chr10:10...      included
# 6     exon:chr10:103113864-103113985:+@exon:chr10:10...       bimodal
# 7     exon:chr10:103190102-103190209:+@exon:chr10:10...      excluded
# 8     exon:chr10:103190102-103190209:+@exon:chr10:10...      included
# 9     exon:chr10:103348082-103348157:+@exon:chr10:10...      included
# 10    exon:chr10:103360960-103361093:+@exon:chr10:10...       bimodal
# 11    exon:chr10:103360960-103361093:+@exon:chr10:10...      excluded
# 12    exon:chr10:103360960-103361093:+@exon:chr10:10...       bimodal
# 13    exon:chr10:1034338-1034467:+@exon:chr10:103842...      included
# 14    exon:chr10:103557737-103557911:-@exon:chr10:10...       bimodal
# 15    exon:chr10:103563492-103563776:-@exon:chr10:10...       bimodal
# 16    exon:chr10:103567487-103567658:-@exon:chr10:10...      included
# 17    exon:chr10:1038429-1038599:+@exon:chr10:104186...      included
# 18    exon:chr10:103912161-103912287:+@exon:chr10:10...      included
# 19    exon:chr10:103919653-103919781:+@exon:chr10:10...      included
# 20    exon:chr10:104192283-104192418:-@exon:chr10:10...      included
# 21    exon:chr10:1042046-1043248:+@exon:chr10:104494...      included
# 22    exon:chr10:104209950-104210087:+@exon:chr10:10...       bimodal
# 23    exon:chr10:104209950-104210087:+@exon:chr10:10...       bimodal
# 24    exon:chr10:104241758-104241932:-@exon:chr10:10...      included
# 25    exon:chr10:104243917-104244133:-@exon:chr10:10...      included
# 26    exon:chr10:104262357-104262466:-@exon:chr10:10...      included
# 27    exon:chr10:104459130-104459246:-@exon:chr10:10...      included
# 28    exon:chr10:104465103-104465246:-@exon:chr10:10...      included
# 29    exon:chr10:104474030-104474164:-@exon:chr10:10...      included
# ...                                                 ...           ...
# 5863                      exon:chrX:75394725-75394784:+  constitutive
# 5864                      exon:chrX:75395308-75395448:+  constitutive
# 5865                      exon:chrX:76855201-76855289:-  constitutive
# 5866                      exon:chrX:76855903-76856033:-  constitutive
# 5867                      exon:chrX:76872081-76872198:-  constitutive
# 5868                      exon:chrX:76874274-76874449:-  constitutive
# 5869                      exon:chrX:76875863-76876000:-  constitutive
# 5870                      exon:chrX:76888695-76888872:-  constitutive
# 5871                      exon:chrX:76889054-76889200:-  constitutive
# 5872                      exon:chrX:76918871-76919047:-  constitutive
# 5873                      exon:chrX:76920134-76920267:-  constitutive
# 5874                      exon:chrX:76937012-76940085:-  constitutive
# 5875                      exon:chrX:76944311-76944420:-  constitutive
# 5876                      exon:chrX:76953071-76953123:-  constitutive
# 5877                      exon:chrX:76954062-76954117:-  constitutive
# 5878                      exon:chrX:77365364-77365414:+  constitutive
# 5879                      exon:chrX:77369241-77369331:+  constitutive
# 5880                      exon:chrX:77369241-77369396:+  constitutive
# 5881                      exon:chrX:77369513-77369657:+  constitutive
# 5882                      exon:chrX:77372809-77372912:+  constitutive
# 5883                      exon:chrX:77373642-77373667:+  constitutive
# 5884                      exon:chrX:77378332-77378446:+  constitutive
# 5885                      exon:chrX:77378692-77378871:+  constitutive
# 5886                      exon:chrX:77380371-77380548:+  constitutive
# 5887                      exon:chrX:77380824-77380922:+  constitutive
# 5888                      exon:chrX:80532483-80532668:+  constitutive
# 5889                      exon:chrX:80533830-80533910:+  constitutive
# 5890                      exon:chrX:99887482-99887565:-  constitutive
# 5891                      exon:chrX:99890175-99890249:-  constitutive
# 5892                      exon:chrX:99890555-99890743:-  constitutive
#
#      phenotype  splice_site_3p_score       splice_site_3p_seq  \
# 0           MN                 10.79  CTCACTTTGCTTCCCCGCAGCAC
# 1           MN                  2.71  CCATTTACCTTGGAATACAGGGG
# 2           MN                  7.55  TGTCTGGTCTGTCAATGTAGGTA
# 3           MN                  9.49  TATTTGTCTTTCTGCCTCAGATG
# 4           MN                  3.77  CACTGTCCCGGGTCGCTTAGGGA
# 5           MN                  8.23  TAGTTGTCCTCTCTCTGCAGTGC
# 6           MN                  8.23  TAGTTGTCCTCTCTCTGCAGTGC
# 7           MN                  8.12  ACAGATGTCTCTTCAAACAGGTT
# 8           MN                  7.26  AAGCTTACTTTCTTTCACAGAAT
# 9           MN                  9.26  ATTCTCTGTTTTGTGCATAGGGA
# 10          MN                  5.57  TGCTTGCTGCTTTTCTAAAGGCG
# 11          MN                  5.57  TGCTTGCTGCTTTTCTAAAGGCG
# 12          MN                 12.02  GCCTCTCGGTGTCCCCACAGGTA
# 13          MN                 10.04  TTTATTTTCTTTAATTGCAGGAC
# 14          MN                  6.68  CTTGGATCTGATCTCAACAGGGT
# 15          MN                 10.31  TTTTATTTTATTTTTTGCAGCTG
# 16          MN                  9.11  ACTTTTCTCCCTACATTTAGAAT
# 17          MN                 11.86  TGTGCTTTTGTTTGTTACAGGAT
# 18          MN                  8.83  CAGCTCTTTTTCTTCTACAGACA
# 19          MN                  2.70  ATGCTACAGGTTCTCCTCAGATT
# 20          MN                 10.74  TCCTGTCTGTGTCCCTTCAGAAG
# 21          MN                  7.66  AAAGTTCTCACTTGTTCCAGGTG
# 22          MN                  7.12  CACTCACTTGTCTCCTTCAGCCT
# 23          MN                  5.49  GGTCTTGCTCTGTTGTCTAGGCT
# 24          MN                 11.60  TCTCCTCTTTGCCCATTCAGGTT
# 25          MN                  6.71  TGTCTTGCTTGGATCTGCAGAGA
# 26          MN                 11.97  TCTCTCTCCTCTTTCCTCAGGGA
# 27          MN                 11.85  CTTCTTCTTTTCCTTTATAGATA
# 28          MN                 11.45  TGTTTTTGTCCCTGTTTCAGGGT
# 29          MN                  4.93  CTCCTTTGTGGTTGTTGAAGGGC
# ...        ...                   ...                      ...
# 5863        MN                  8.57  CATTCTTCACTCCTTTGCAGCCT
# 5864        MN                  8.27  GTTGTCTTACTGTTTCGCAGCTG
# 5865        MN                  9.28  GGTCATTTTTTTTTCTCTAGGGT
# 5866        MN                  8.52  ACCATATTTCTTTTGATCAGGTG
# 5867        MN                  7.11  CTCTTTCTTGTTAATTACAGAGG
# 5868        MN                  9.21  AATAATGTCTTCTCTCTTAGATC
# 5869        MN                 10.04  TTTTCTGTTTATTTTTGTAGGCC
# 5870        MN                  5.37  TCTTTATTTCCCCACAAAAGGTT
# 5871        MN                 10.68  GACAATCTGTTTTCTTATAGGTG
# 5872        MN                  6.60  GATTTATTTCCTTCATTTAGAAG
# 5873        MN                  4.55  TATTGTTTTTTACTCTCAAGAAT
# 5874        MN                  6.40  TAATCTTTAAAACATTTCAGGTG
# 5875        MN                  5.08  TAGCCACTCCTTTCTCCTAGAAG
# 5876        MN                  8.55  TATTTATGTCTCACATCTAGGGA
# 5877        MN                 11.28  CTTTATTTCTTCTTTTTTAGATA
# 5878        MN                 11.09  CTTGCATCTTTCTTTTTTAGAGT
# 5879        MN                 10.73  TTGTCTCTCTTTGGTTGCAGGAT
# 5880        MN                 10.73  TTGTCTCTCTTTGGTTGCAGGAT
# 5881        MN                 10.19  TCATCTCTTCCTCTTCTCAGGGA
# 5882        MN                 12.48  GTTTTTGTTTTTCTCTATAGGTT
# 5883        MN                -28.41  AGGCCTTGGAGAGCCCAGAGCGA
# 5884        MN                  9.97  ATTCTTGCTTTCTCTTGTAGAGC
# 5885        MN                  8.24  ATTTTGGCTCCCCTGTGTAGATT
# 5886        MN                  8.90  CTTTCACCTCTACCCCTCAGGGC
# 5887        MN                 10.40  ACCTGGCTTTCATTCAACAGGTG
# 5888        MN                  8.56  TTCTTGTCCTTTGGTCCTAGATT
# 5889        MN                  7.00  CTTATCTTCTTTTCATCAAGGAC
# 5890        MN                 11.13  TGTTTTTTTCCTCCCATTAGGGT
# 5891        MN                 10.90  CTTTCTTTCTTATCCTGCAGTAT
# 5892        MN                  6.84  TTCTCTGAATTCCCACATAGATC
#
#       splice_site_5p_score splice_site_5p_seq splice_site_3p_seq_2bp  \
# 0                     8.34          ACAGTGAGT                     AG
# 1                    10.65          CTGGTAAGT                     AG
# 2                    10.24          TGGGTAAGT                     AG
# 3                     8.95          GTGGTGAGT                     AG
# 4                     9.40          ACCGTGAGT                     AG
# 5                     8.17          CAGGTACTT                     AG
# 6                     8.17          CAGGTACTT                     AG
# 7                     8.54          ATTGTAAGT                     AG
# 8                     9.46          CAGGTATGA                     AG
# 9                    10.47          TTGGTAAGT                     AG
# 10                    9.81          GAGGTATGT                     AG
# 11                    9.81          GAGGTATGT                     AG
# 12                    4.08          TCTGTAAGA                     AG
# 13                    9.11          GATGTAAGT                     AG
# 14                    7.33          CAGGTATCA                     AG
# 15                    7.39          GCAGTGAGT                     AG
# 16                   10.86          CAGGTAAGT                     AG
# 17                    7.66          CAAGTAAGG                     AG
# 18                    7.47          CAAGTAAGC                     AG
# 19                   11.08          CAGGTAAGG                     AG
# 20                    7.10          CAGGTAGAG                     AG
# 21                    9.22          CAGGTGAGA                     AG
# 22                    7.23          TGGGTGAGC                     AG
# 23                    4.29          CAGGTGCAC                     AG
# 24                    6.45          AGGGTAGGA                     AG
# 25                    9.65          GAGGTAGGT                     AG
# 26                    8.78          CTAGTAAGT                     AG
# 27                    8.76          CAGGTAAAT                     AG
# 28                    8.00          CTTGTAAGT                     AG
# 29                    9.60          CAGGTGAGC                     AG
# ...                    ...                ...                    ...
# 5863                 10.47          AAGGTGAGT                     AG
# 5864                  7.30          GAGGTAAAA                     AG
# 5865                  4.06          AAAGTAAAT                     AG
# 5866                 11.00          AAGGTAAGT                     AG
# 5867                  7.82          CAGGTAAAC                     AG
# 5868                  7.09          CAGGTACAA                     AG
# 5869                  6.96          AGTGTGAGT                     AG
# 5870                 11.08          CAGGTAAGG                     AG
# 5871                  8.77          GAGGTAACT                     AG
# 5872                  9.21          AGGGTAAGA                     AG
# 5873                  7.75          AGGGTGAGC                     AG
# 5874                  9.37          CAGGTATGC                     AG
# 5875                  9.79          AAGGTATGT                     AG
# 5876                  6.36          GAGGTTGGT                     AG
# 5877                 10.28          GAGGTAAGG                     AG
# 5878                 10.28          GAGGTAAGG                     AG
# 5879                 -8.42          GGTGTGCCC                     AG
# 5880                 10.08          CAAGTAAGT                     AG
# 5881                  9.45          AAGGTAGGA                     AG
# 5882                  7.88          CAGGTACCA                     AG
# 5883                  7.63          CGGGTATGA                     AG
# 5884                  8.24          GAGGTAGGA                     AG
# 5885                 10.13          ATGGTGAGT                     AG
# 5886                  8.89          TAGGTAAGC                     AG
# 5887                  9.16          AAGGTGAGG                     AG
# 5888                  7.83          GGGGTAAGA                     AG
# 5889                  9.11          AAGGTATGA                     AG
# 5890                 10.08          CAAGTAAGT                     AG
# 5891                  9.85          GAGGTAAGC                     AG
# 5892                 10.10          CTGGTGAGT                     AG
#
#      splice_site_5p_seq_2bp
# 0                        GT
# 1                        GT
# 2                        GT
# 3                        GT
# 4                        GT
# 5                        GT
# 6                        GT
# 7                        GT
# 8                        GT
# 9                        GT
# 10                       GT
# 11                       GT
# 12                       GT
# 13                       GT
# 14                       GT
# 15                       GT
# 16                       GT
# 17                       GT
# 18                       GT
# 19                       GT
# 20                       GT
# 21                       GT
# 22                       GT
# 23                       GT
# 24                       GT
# 25                       GT
# 26                       GT
# 27                       GT
# 28                       GT
# 29                       GT
# ...                     ...
# 5863                     GT
# 5864                     GT
# 5865                     GT
# 5866                     GT
# 5867                     GT
# 5868                     GT
# 5869                     GT
# 5870                     GT
# 5871                     GT
# 5872                     GT
# 5873                     GT
# 5874                     GT
# 5875                     GT
# 5876                     GT
# 5877                     GT
# 5878                     GT
# 5879                     GT
# 5880                     GT
# 5881                     GT
# 5882                     GT
# 5883                     GT
# 5884                     GT
# 5885                     GT
# 5886                     GT
# 5887                     GT
# 5888                     GT
# 5889                     GT
# 5890                     GT
# 5891                     GT
# 5892                     GT
#
# [43696 rows x 9 columns]

# %%
splice_site_seq_cols = 'splice_site_5p_seq_2bp', 'splice_site_3p_seq_2bp'

for col in splice_site_seq_cols:
    modalities_splice_sites = modalities_maxentscan.groupby(['phenotype', 'modality', col]).size()
    modalities_splice_sites = modalities_splice_sites.reset_index()
    modalities_splice_sites = modalities_splice_sites.rename(columns={0:'counts'})
    modalities_splice_sites['% AS Exons'] = 100 *modalities_splice_sites.groupby(
        ['phenotype', 'modality'])['counts'].apply(lambda x: x/x.sum())
    
    saturation = 0.8 if col == 'splice_site_5p_seq_2bp' else 0.4
    
    palette = sns.husl_palette(s=saturation, n_colors=3)
    
    for phenotype, phenotype_df in modalities_splice_sites.groupby('phenotype'):
        width_ratios = (0.2, 0.8) if col == 'splice_site_5p_seq_2bp' else (0.8, 0.2)
        fig, axes = plt.subplots(figsize=(2, 1.5), ncols=2, 
                                 gridspec_kw=dict(width_ratios=width_ratios, wspace=0.1))
        ax = axes[0]
        sns.barplot(data=phenotype_df, x='% AS Exons', ax=ax, ci=False, 
                    y='modality', hue=col, order=modality_order, palette=palette)
        ax.legend_.set_visible(False)
        ax.locator_params('x', nbins=4)
#         ax.xaxis.set_tick_params('off')
        if col == 'splice_site_5p_seq_2bp':
            ax.set(xlim=(10, 100), ylabel='', yticks=[], xlabel='', xticks=[10, 100])
            ax.invert_xaxis()
            sns.despine(ax=ax, left=True)

        else:
            ax.set(xlim=(0, 0.5), ylabel='', xlabel='% AS Exons')
            sns.despine(ax=ax)
            ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=2)


        ax = axes[1]
        sns.barplot(data=phenotype_df, x='% AS Exons', ax=ax, ci=False, y='modality', 
                    order=modality_order, hue=col, orient='h', palette=palette)
        ax.locator_params('x', nbins=4)
        ax.legend_.set_visible(False)

        if col == 'splice_site_5p_seq_2bp':
            # Somehow these "put the y-axis ticks on the right" functions 
            # only work in combination
            ax.yaxis.tick_right()
            ax.set(xlim=(0, 5), ylabel='', xlabel='% AS Exons')
            ax.invert_xaxis()
            ax.yaxis.set_ticks_position('right')
            sns.despine(ax=ax, left=True, right=False)
            ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=3)
        else:
            ax.set(xlim=(10, 100), ylabel='', yticks=[], xlabel='', xticks=[10, 100])
            sns.despine(ax=ax, left=True)

#         legend_fig, legend_ax = plt.subplots(figsize=(0.5, 0.5))
#         legend_ax.legend(*ax.get_legend_handles_labels())

        fig.savefig('{}/{}_{}_barplot.pdf'.format(figure_folder, col, phenotype))

# %%
modalities_splice_sites = modalities_maxentscan.groupby(['phenotype', 'modality', col]).size()
modalities_splice_sites = modalities_splice_sites.reset_index()
modalities_splice_sites = modalities_splice_sites.rename(columns={0:'counts'})
modalities_splice_sites['% AS Exons'] = 100 *modalities_splice_sites.groupby(
    ['phenotype', 'modality'])['counts'].apply(lambda x: x/x.sum())

modalities_splice_sites.head()
# Out:
#   phenotype      modality splice_site_3p_seq_2bp  counts  % AS Exons
# 0        MN       bimodal                     AG    1316  100.000000
# 1        MN  constitutive                     AC      17    0.288478
# 2        MN  constitutive                     AG    5876   99.711522
# 3        MN      excluded                     AC       1    0.085106
# 4        MN      excluded                     AG    1174   99.914894

# %%
modalities_splice_sites
# Out:
#    phenotype       modality splice_site_3p_seq_2bp  counts  % AS Exons
# 0         MN        bimodal                     AG    1316  100.000000
# 1         MN   constitutive                     AC      17    0.288478
# 2         MN   constitutive                     AG    5876   99.711522
# 3         MN       excluded                     AC       1    0.085106
# 4         MN       excluded                     AG    1174   99.914894
# 5         MN       included                     AG    2995  100.000000
# 6         MN  uncategorized                     AG       2  100.000000
# 7        NPC        bimodal                     AG    2325  100.000000
# 8        NPC   constitutive                     AC      17    0.288478
# 9        NPC   constitutive                     AG    5876   99.711522
# 10       NPC       excluded                     AC       1    0.057737
# 11       NPC       excluded                     AG    1731   99.942263
# 12       NPC       included                     AG    4597  100.000000
# 13       NPC  uncategorized                     AG       4  100.000000
# 14      iPSC        bimodal                     AG    3438  100.000000
# 15      iPSC   constitutive                     AC      17    0.288478
# 16      iPSC   constitutive                     AG    5876   99.711522
# 17      iPSC       excluded                     AC       1    0.043611
# 18      iPSC       excluded                     AG    2292   99.956389
# 19      iPSC       included                     AG    6105  100.000000
# 20      iPSC         middle                     AG       1  100.000000
# 21      iPSC  uncategorized                     AG      34  100.000000

# %%
sns.barplot(y='modality', x='% AS Exons', data=modalities_splice_sites, hue=col, orient='h')

# %%
modalities_splice_sites
# Out:
#    phenotype       modality splice_site_3p_seq_2bp  counts  % AS Exons
# 0         MN        bimodal                     AG    1316  100.000000
# 1         MN   constitutive                     AC      17    0.288478
# 2         MN   constitutive                     AG    5876   99.711522
# 3         MN       excluded                     AC       1    0.085106
# 4         MN       excluded                     AG    1174   99.914894
# 5         MN       included                     AG    2995  100.000000
# 6         MN  uncategorized                     AG       2  100.000000
# 7        NPC        bimodal                     AG    2325  100.000000
# 8        NPC   constitutive                     AC      17    0.288478
# 9        NPC   constitutive                     AG    5876   99.711522
# 10       NPC       excluded                     AC       1    0.057737
# 11       NPC       excluded                     AG    1731   99.942263
# 12       NPC       included                     AG    4597  100.000000
# 13       NPC  uncategorized                     AG       4  100.000000
# 14      iPSC        bimodal                     AG    3438  100.000000
# 15      iPSC   constitutive                     AC      17    0.288478
# 16      iPSC   constitutive                     AG    5876   99.711522
# 17      iPSC       excluded                     AC       1    0.043611
# 18      iPSC       excluded                     AG    2292   99.956389
# 19      iPSC       included                     AG    6105  100.000000
# 20      iPSC         middle                     AG       1  100.000000
# 21      iPSC  uncategorized                     AG      34  100.000000

# %%
ls /projects/ps-yeolab/obotvinnik/singlecell_pnms/csvs_for_paper/splicing_feature_data/alternative/
# Out:
# downstream400_placental_mammal_conservation.csv
# exon2_merkin2012_ancient.csv
# exon2_phastcons_placental_mammal.bed
# exon2_phastcons_placental_mammal.txt
# exons.bed
# exons.fasta
# exons_downstream200nt.bed
# exons_merkin2012_ancient_alt_exons.bed
# exons_phastcons_placental_mammal.bed
# exons_phastcons_placental_mammal.txt
# exons_stop_plus1.bed
# exons_upstream200_foreground.bed
# exons_upstream200_placental_foreground.bed
# exons_upstream200nt.bed
# gc_content.csv
# genes_expanded.csv
# isoform_domain_effects.csv
# isoform_domain_pfam_accession.csv
# isoform_domain_pfam_go_id.csv
# isoform_domain_pfam_go_name.csv
# isoform_domain_pfam_name.csv
# isoform_protein_properties/
# isoform_translations.csv@
# isoform_translations.fa
# isoform_translations.fa_iupred_out
# isoform_translations.fa_iupred_tmp
# isoform_translations_hmmscan_pfamA.txt
# isoform_translations_hmmscan_pfamA.txt.err
# isoform_translations_hmmscan_pfamA.txt.out
# maxentscan.csv
# nucleotide_content/
# phastcons_placental_mammal.txt@
# protein_translations.csv
# repetitive_element_overlap.csv
# test.bed
# upstream400_placental_mammal_conservation.csv

# %%
ls -lha /projects/ps-yeolab/obotvinnik/singlecell_pnms/csvs_for_paper/splicing_feature_data/alternative/isoform_translations.csv
# Out:
# lrwxrwxrwx 1 obotvinnik yeo-group 121 Apr 14  2016 /projects/ps-yeolab/obotvinnik/singlecell_pnms/csvs_for_paper/splicing_feature_data/alternative/isoform_translations.csv -> /projects/ps-yeolab/obotvinnik/singlecell_pnms/csvs_for_paper//splicing_feature_data/alternative/protein_translations.csv

# %%
ls /projects/ps-yeolab/obotvinnik/singlecell_pnms/csvs_for_paper/splicing_feature_data/alternative/isoform_protein_properties/
# Out:
# isoelectric_point.pdf  molecular_weight_log10.pdf

# %%
event_to_gene = pd.read_csv(
    '/projects/ps-yeolab/obotvinnik/singlecell_pnms/csvs_for_paper/splicing_feature_data/alternative/genes_expanded.csv',
    header=None, squeeze=True, index_col=0)
event_to_gene.name = 'ensembl_id'
event_to_gene.head()
# Out:
# 0
# exon:chr10:100190328-100190427:-@exon:chr10:100189548-100189646:-@exon:chr10:100189330-100189399:-    ENSG00000107521
# exon:chr10:100193697-100193848:-@exon:chr10:100190888-100191048:-@exon:chr10:100190328-100190427:-    ENSG00000107521
# exon:chr10:100195392-100195529:-@exon:chr10:100195029-100195171:-@exon:chr10:100193697-100193848:-    ENSG00000107521
# exon:chr10:101165513-101165617:-@exon:chr10:101163481-101163631:-@exon:chr10:101163226-101163391:-    ENSG00000120053
# exon:chr10:101419263-101419345:+@exon:chr10:101419619-101419721:+@exon:chr10:101421203-101421385:+    ENSG00000198018
# Name: ensembl_id, dtype: object

# %%
modalities_genes = study.supplemental.modalities_tidy.join(event_to_gene, on='event_id')
modalities_genes.head()
# Out:
#   phenotype                                           event_id  modality  \
# 0        MN  exon:chr10:101165513-101165617:-@exon:chr10:10...  included
# 1        MN  exon:chr10:101480744-101480825:-@exon:chr10:10...   bimodal
# 2        MN  exon:chr10:102114184-102114389:+@exon:chr10:10...  included
# 3        MN  exon:chr10:102286732-102286831:-@exon:chr10:10...  included
# 4        MN  exon:chr10:102747070-102747240:-@exon:chr10:10...   bimodal
#
#         ensembl_id
# 0  ENSG00000120053
# 1  ENSG00000014919
# 2  ENSG00000099194
# 3  ENSG00000255339
# 4  ENSG00000055950

# %%
modalities_genes = modalities_genes.join(study.expression.feature_data, on='ensembl_id')
modalities_genes.head()
# Out:
#   phenotype                                           event_id  modality  \
# 0        MN  exon:chr10:101165513-101165617:-@exon:chr10:10...  included
# 1        MN  exon:chr10:101480744-101480825:-@exon:chr10:10...   bimodal
# 2        MN  exon:chr10:102114184-102114389:+@exon:chr10:10...  included
# 3        MN  exon:chr10:102286732-102286831:-@exon:chr10:10...  included
# 4        MN  exon:chr10:102747070-102747240:-@exon:chr10:10...   bimodal
#
#         ensembl_id biomark_neural_panel confident_rbp          gencode_id  \
# 0  ENSG00000120053                False         False   ENSG00000120053.9
# 1  ENSG00000014919                False         False   ENSG00000014919.8
# 2  ENSG00000099194                False         False   ENSG00000099194.5
# 3  ENSG00000255339                False         False   ENSG00000255339.2
# 4  ENSG00000055950                False         False  ENSG00000055950.12
#
#   gene_name gene_status       gene_type        ...          \
# 0      GOT1       KNOWN  protein_coding        ...
# 1     COX15       KNOWN  protein_coding        ...
# 2       SCD       KNOWN  protein_coding        ...
# 3    NDUFB8       NOVEL  protein_coding        ...
# 4    MRPL43       KNOWN  protein_coding        ...
#
#   gerstberger2014_rbp_target_diverse  gerstberger2014_rbp_family_targets  \
# 0                              False                                 NaN
# 1                              False                                 NaN
# 2                              False                                 NaN
# 3                              False                                 NaN
# 4                              False                            ribosome
#
#   cell_surface_markers gerstberger2014_tf cell_cycle  \
# 0                False              False      False
# 1                False              False      False
# 2                False              False      False
# 3                False              False      False
# 4                False              False      False
#
#   domazetloso2008_phylostratum bioguo_animaltfdb_tf  \
# 0                            1                False
# 1                            1                False
# 2                            1                False
# 3                          NaN                False
# 4                            2                False
#
#   bioguo_animaltfdb_chromatin_remodeler bioguo_animaltfdb_cofactor  \
# 0                                 False                      False
# 1                                 False                      False
# 2                                 False                      False
# 3                                 False                      False
# 4                                 False                      False
#
#   max_exons_per_gene
# 0                  9
# 1                  9
# 2                  6
# 3                 12
# 4                  6
#
# [5 rows x 40 columns]

# %%
modalities_genes.columns
# Out:
# Index([u'phenotype', u'event_id', u'modality', u'ensembl_id',
#        u'biomark_neural_panel', u'confident_rbp', u'gencode_id', u'gene_name',
#        u'gene_status', u'gene_type', u'havana_gene', u'level', u'rbp',
#        u'ribosomal', u'ribosomal_subunit', u'synapse', u'tag',
#        u'transcript_id', u'transcript_name', u'transcript_status',
#        u'transcript_type', u'transcription_factor', u'gerstberger2014_rbp',
#        u'gerstberger2014_rbp_domains[count]',
#        u'gerstberger2014_rbp_consensus_rna_target',
#        u'gerstberger2014_rbp_parologous_family_id',
#        u'gerstberger2014_rbp_target_mrna',
#        u'gerstberger2014_rbp_target_ribosome',
#        u'gerstberger2014_rbp_target_trna', u'gerstberger2014_rbp_target_ncrna',
#        u'gerstberger2014_rbp_target_diverse',
#        u'gerstberger2014_rbp_family_targets', u'cell_surface_markers',
#        u'gerstberger2014_tf', u'cell_cycle', u'domazetloso2008_phylostratum',
#        u'bioguo_animaltfdb_tf', u'bioguo_animaltfdb_chromatin_remodeler',
#        u'bioguo_animaltfdb_cofactor', u'max_exons_per_gene'],
#       dtype='object')

# %%
modalities_genes = modalities_genes.convert_objects()
modalities_genes.dtypes
# Out:
# /home/obotvinnik/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# phenotype                                    object
# event_id                                     object
# modality                                     object
# ensembl_id                                   object
# biomark_neural_panel                           bool
# confident_rbp                                  bool
# gencode_id                                   object
# gene_name                                    object
# gene_status                                  object
# gene_type                                    object
# havana_gene                                  object
# level                                         int64
# rbp                                            bool
# ribosomal                                      bool
# ribosomal_subunit                              bool
# synapse                                        bool
# tag                                          object
# transcript_id                                object
# transcript_name                              object
# transcript_status                            object
# transcript_type                              object
# transcription_factor                           bool
# gerstberger2014_rbp                            bool
# gerstberger2014_rbp_domains[count]           object
# gerstberger2014_rbp_consensus_rna_target     object
# gerstberger2014_rbp_parologous_family_id     object
# gerstberger2014_rbp_target_mrna                bool
# gerstberger2014_rbp_target_ribosome            bool
# gerstberger2014_rbp_target_trna                bool
# gerstberger2014_rbp_target_ncrna               bool
# gerstberger2014_rbp_target_diverse             bool
# gerstberger2014_rbp_family_targets           object
# cell_surface_markers                           bool
# gerstberger2014_tf                             bool
# cell_cycle                                     bool
# domazetloso2008_phylostratum                float64
# bioguo_animaltfdb_tf                           bool
# bioguo_animaltfdb_chromatin_remodeler          bool
# bioguo_animaltfdb_cofactor                     bool
# max_exons_per_gene                            int64
# dtype: object

# %%
boolean_cols = modalities_genes.columns[modalities_genes.dtypes == bool]

# %%
from anchor import MODALITY_ORDER, MODALITY_PALETTE

# %%
figure_folder
# Out:
# 'figures'

# %%
col
# Out:
# 'splice_site_3p_seq_2bp'

# %%
boolean_folder = '{}/boolean'.format(figure_folder)
# !mkdir $boolean_folder
# Out:
# mkdir: cannot create directory `figures/boolean': File exists

# %%
for col in boolean_cols:
    six.print_(col)
    fig, ax = plt.subplots(figsize=(2, 1.5))
    sns.barplot(x='phenotype', hue='modality', hue_order=MODALITY_ORDER, palette=MODALITY_PALETTE, data=modalities_genes,
               y=col, ci=None, order=study.phenotype_order)
    ax.locator_params('y', nbins=4)
    yticks = ax.get_yticks()
    yticklabels = 100 * yticks
    ax.set(ylabel=col, yticklabels=yticklabels)
    ax.legend_.set_visible(False)
    sns.despine()
    fig.savefig('{}/{}.pdf'.format(boolean_folder, col))
# Out:
# biomark_neural_panel
# confident_rbp
# rbp
# ribosomal
# ribosomal_subunit
# synapse
# transcription_factor
# gerstberger2014_rbp
# gerstberger2014_rbp_target_mrna
# gerstberger2014_rbp_target_ribosome
# gerstberger2014_rbp_target_trna
# gerstberger2014_rbp_target_ncrna
# gerstberger2014_rbp_target_diverse
# cell_surface_markers
# gerstberger2014_tf
# cell_cycle
# bioguo_animaltfdb_tf
# bioguo_animaltfdb_chromatin_remodeler
# bioguo_animaltfdb_cofactor

# %%
from scipy.stats import hypergeom

lines = []

for col in boolean_cols:
    for phenotype, phenotype_df in modalities_genes.groupby(['phenotype']):
#         six.print_(phenotype)
        M = phenotype_df.shape[0]
        n = phenotype_df[col].sum()
        for modality, modality_df in phenotype_df.groupby('modality'):
#             six.print_('\t', modality)
            N = modality_df.shape[0]
            x = modality_df[col].sum()
            p_value = hypergeom.sf(x, M, n, N)
#             six.print_('\t\t', result)
            lines.append([col, phenotype, modality, p_value])
            
boolean_feature_significance = pd.DataFrame(lines, columns=['feature', 'phenotype', 'modality', 'p-value'])
boolean_feature_significance['q-value'] = boolean_feature_significance['p-value'] * boolean_feature_significance.shape[0]
boolean_feature_significance.loc[boolean_feature_significance['q-value'] < 1e-3]
# Out:
#                                  feature phenotype  modality       p-value  \
# 41                             ribosomal        MN  included  8.762574e-11
# 45                             ribosomal       NPC  included  1.331888e-11
# 49                             ribosomal      iPSC  included  7.941507e-11
# 50                             ribosomal      iPSC    middle  0.000000e+00
# 54                     ribosomal_subunit        MN  included  2.487327e-07
# 58                     ribosomal_subunit       NPC  included  3.624574e-09
# 62                     ribosomal_subunit      iPSC  included  4.457327e-07
# 63                     ribosomal_subunit      iPSC    middle  0.000000e+00
# 78                  transcription_factor        MN   bimodal  3.470203e-07
# 82                  transcription_factor       NPC   bimodal  2.518435e-06
# 86                  transcription_factor      iPSC   bimodal  1.654814e-13
# 97                   gerstberger2014_rbp       NPC  included  1.669750e-10
# 101                  gerstberger2014_rbp      iPSC  included  1.611511e-13
# 102                  gerstberger2014_rbp      iPSC    middle  0.000000e+00
# 119  gerstberger2014_rbp_target_ribosome        MN  included  1.379516e-06
# 123  gerstberger2014_rbp_target_ribosome       NPC  included  1.620943e-08
# 127  gerstberger2014_rbp_target_ribosome      iPSC  included  2.308813e-06
# 128  gerstberger2014_rbp_target_ribosome      iPSC    middle  0.000000e+00
# 190                   gerstberger2014_tf      iPSC   bimodal  1.110301e-10
# 208                 bioguo_animaltfdb_tf        MN   bimodal  2.112521e-06
# 212                 bioguo_animaltfdb_tf       NPC   bimodal  1.616714e-06
# 216                 bioguo_animaltfdb_tf      iPSC   bimodal  1.922651e-12
#
#           q-value
# 41   2.164356e-08
# 45   3.289764e-09
# 49   1.961552e-08
# 50   0.000000e+00
# 54   6.143698e-05
# 58   8.952697e-07
# 62   1.100960e-04
# 63   0.000000e+00
# 78   8.571401e-05
# 82   6.220534e-04
# 86   4.087392e-11
# 97   4.124284e-08
# 101  3.980432e-11
# 102  0.000000e+00
# 119  3.407405e-04
# 123  4.003730e-06
# 127  5.702769e-04
# 128  0.000000e+00
# 190  2.742444e-08
# 208  5.217927e-04
# 212  3.993283e-04
# 216  4.748948e-10

# %%
boolean_feature_significance.loc[boolean_feature_significance['p-value'] < 1e-3]
# Out:
#                                  feature phenotype       modality  \
# 25                         confident_rbp      iPSC  uncategorized
# 38                                   rbp      iPSC  uncategorized
# 41                             ribosomal        MN       included
# 45                             ribosomal       NPC       included
# 49                             ribosomal      iPSC       included
# 50                             ribosomal      iPSC         middle
# 54                     ribosomal_subunit        MN       included
# 58                     ribosomal_subunit       NPC       included
# 62                     ribosomal_subunit      iPSC       included
# 63                     ribosomal_subunit      iPSC         middle
# 70                               synapse       NPC       excluded
# 74                               synapse      iPSC       excluded
# 78                  transcription_factor        MN        bimodal
# 82                  transcription_factor       NPC        bimodal
# 86                  transcription_factor      iPSC        bimodal
# 93                   gerstberger2014_rbp        MN       included
# 97                   gerstberger2014_rbp       NPC       included
# 101                  gerstberger2014_rbp      iPSC       included
# 102                  gerstberger2014_rbp      iPSC         middle
# 116      gerstberger2014_rbp_target_mrna      iPSC  uncategorized
# 119  gerstberger2014_rbp_target_ribosome        MN       included
# 123  gerstberger2014_rbp_target_ribosome       NPC       included
# 127  gerstberger2014_rbp_target_ribosome      iPSC       included
# 128  gerstberger2014_rbp_target_ribosome      iPSC         middle
# 133      gerstberger2014_rbp_target_trna        MN  uncategorized
# 182                   gerstberger2014_tf        MN        bimodal
# 186                   gerstberger2014_tf       NPC        bimodal
# 190                   gerstberger2014_tf      iPSC        bimodal
# 195                           cell_cycle        MN        bimodal
# 208                 bioguo_animaltfdb_tf        MN        bimodal
# 212                 bioguo_animaltfdb_tf       NPC        bimodal
# 216                 bioguo_animaltfdb_tf      iPSC        bimodal
#
#           p-value       q-value
# 25   9.462446e-05  2.337224e-02
# 38   9.462446e-05  2.337224e-02
# 41   8.762574e-11  2.164356e-08
# 45   1.331888e-11  3.289764e-09
# 49   7.941507e-11  1.961552e-08
# 50   0.000000e+00  0.000000e+00
# 54   2.487327e-07  6.143698e-05
# 58   3.624574e-09  8.952697e-07
# 62   4.457327e-07  1.100960e-04
# 63   0.000000e+00  0.000000e+00
# 70   4.315606e-05  1.065955e-02
# 74   3.627843e-05  8.960772e-03
# 78   3.470203e-07  8.571401e-05
# 82   2.518435e-06  6.220534e-04
# 86   1.654814e-13  4.087392e-11
# 93   1.262078e-04  3.117332e-02
# 97   1.669750e-10  4.124284e-08
# 101  1.611511e-13  3.980432e-11
# 102  0.000000e+00  0.000000e+00
# 116  2.604186e-04  6.432339e-02
# 119  1.379516e-06  3.407405e-04
# 123  1.620943e-08  4.003730e-06
# 127  2.308813e-06  5.702769e-04
# 128  0.000000e+00  0.000000e+00
# 133  4.128497e-04  1.019739e-01
# 182  6.707723e-04  1.656808e-01
# 186  6.286363e-05  1.552732e-02
# 190  1.110301e-10  2.742444e-08
# 195  3.119046e-04  7.704043e-02
# 208  2.112521e-06  5.217927e-04
# 212  1.616714e-06  3.993283e-04
# 216  1.922651e-12  4.748948e-10

# %%
x, M, n, N
# Out:
# (0, 11871, 300, 34)

# %%
result
# Out:
# MannwhitneyuResult(statistic=13.0, pvalue=0.72881870743475674)

# %%
100 * yticks
# Out:
# array([ 0.,  1.,  2.,  3.,  4.])

# %% [markdown]
# ## (maximum) Number of exons per gene

# %%
col = 'max_exons_per_gene'

# %%
event_to_gene = pd.read_csv('{}/genes_expanded.csv'.format(alternative_feature_folder), index_col=0, header=None, squeeze=True)
event_to_gene.head()
# Out:
# 0
# exon:chr10:100190328-100190427:-@exon:chr10:100189548-100189646:-@exon:chr10:100189330-100189399:-    ENSG00000107521
# exon:chr10:100193697-100193848:-@exon:chr10:100190888-100191048:-@exon:chr10:100190328-100190427:-    ENSG00000107521
# exon:chr10:100195392-100195529:-@exon:chr10:100195029-100195171:-@exon:chr10:100193697-100193848:-    ENSG00000107521
# exon:chr10:101165513-101165617:-@exon:chr10:101163481-101163631:-@exon:chr10:101163226-101163391:-    ENSG00000120053
# exon:chr10:101419263-101419345:+@exon:chr10:101419619-101419721:+@exon:chr10:101421203-101421385:+    ENSG00000198018
# Name: 1, dtype: object

# %%
constitutive_to_gene = pd.read_csv('{}/genes_expanded.csv'.format(constitutive_feature_folder), index_col=0, header=None, squeeze=True)
constitutive_to_gene.head()
# Out:
# 0
# exon:chr10:102039881-102039985:-    ENSG00000196072
# exon:chr10:102040691-102040810:-    ENSG00000196072
# exon:chr10:102045854-102045970:-    ENSG00000196072
# exon:chr10:102045854-102046089:-    ENSG00000196072
# exon:chr10:102286732-102286831:-    ENSG00000075826
# Name: 1, dtype: object

# %%
modalities_genes.head()
# Out:
#   phenotype                                           event_id  modality  \
# 0        MN  exon:chr10:101165513-101165617:-@exon:chr10:10...  included
# 1        MN  exon:chr10:101480744-101480825:-@exon:chr10:10...   bimodal
# 2        MN  exon:chr10:102114184-102114389:+@exon:chr10:10...  included
# 3        MN  exon:chr10:102286732-102286831:-@exon:chr10:10...  included
# 4        MN  exon:chr10:102747070-102747240:-@exon:chr10:10...   bimodal
#
#         ensembl_id biomark_neural_panel confident_rbp          gencode_id  \
# 0  ENSG00000120053                False         False   ENSG00000120053.9
# 1  ENSG00000014919                False         False   ENSG00000014919.8
# 2  ENSG00000099194                False         False   ENSG00000099194.5
# 3  ENSG00000255339                False         False   ENSG00000255339.2
# 4  ENSG00000055950                False         False  ENSG00000055950.12
#
#   gene_name gene_status       gene_type        ...          \
# 0      GOT1       KNOWN  protein_coding        ...
# 1     COX15       KNOWN  protein_coding        ...
# 2       SCD       KNOWN  protein_coding        ...
# 3    NDUFB8       NOVEL  protein_coding        ...
# 4    MRPL43       KNOWN  protein_coding        ...
#
#   gerstberger2014_rbp_target_diverse  gerstberger2014_rbp_family_targets  \
# 0                              False                                 NaN
# 1                              False                                 NaN
# 2                              False                                 NaN
# 3                              False                                 NaN
# 4                              False                            ribosome
#
#   cell_surface_markers gerstberger2014_tf cell_cycle  \
# 0                False              False      False
# 1                False              False      False
# 2                False              False      False
# 3                False              False      False
# 4                False              False      False
#
#   domazetloso2008_phylostratum bioguo_animaltfdb_tf  \
# 0                            1                False
# 1                            1                False
# 2                            1                False
# 3                          NaN                False
# 4                            2                False
#
#   bioguo_animaltfdb_chromatin_remodeler bioguo_animaltfdb_cofactor  \
# 0                                 False                      False
# 1                                 False                      False
# 2                                 False                      False
# 3                                 False                      False
# 4                                 False                      False
#
#   max_exons_per_gene
# 0                  9
# 1                  9
# 2                  6
# 3                 12
# 4                  6
#
# [5 rows x 40 columns]

# %%
prefix = col

# %%
constitutive_genes_modalities_annotated = constitutive_genes_modalities.join(study.expression.feature_data, on='common_id')
constitutive_genes_modalities_annotated.head()
# Out:
#                            event_id        common_id      modality phenotype  \
# 0  exon:chr10:102039881-102039985:-  ENSG00000196072  constitutive      iPSC
# 1  exon:chr10:102040691-102040810:-  ENSG00000196072  constitutive      iPSC
# 2  exon:chr10:102045854-102045970:-  ENSG00000196072  constitutive      iPSC
# 3  exon:chr10:102045854-102046089:-  ENSG00000196072  constitutive      iPSC
# 4  exon:chr10:102286732-102286831:-  ENSG00000075826  constitutive      iPSC
#
#   biomark_neural_panel confident_rbp          gencode_id gene_name  \
# 0                False         False   ENSG00000196072.7   BLOC1S2
# 1                False         False   ENSG00000196072.7   BLOC1S2
# 2                False         False   ENSG00000196072.7   BLOC1S2
# 3                False         False   ENSG00000196072.7   BLOC1S2
# 4                False         False  ENSG00000075826.12    SEC31B
#
#   gene_status       gene_type        ...          \
# 0       KNOWN  protein_coding        ...
# 1       KNOWN  protein_coding        ...
# 2       KNOWN  protein_coding        ...
# 3       KNOWN  protein_coding        ...
# 4       KNOWN  protein_coding        ...
#
#   gerstberger2014_rbp_target_diverse  gerstberger2014_rbp_family_targets  \
# 0                              False                                 NaN
# 1                              False                                 NaN
# 2                              False                                 NaN
# 3                              False                                 NaN
# 4                              False                                 NaN
#
#   cell_surface_markers gerstberger2014_tf cell_cycle  \
# 0                False              False      False
# 1                False              False      False
# 2                False              False      False
# 3                False              False      False
# 4                False              False      False
#
#   domazetloso2008_phylostratum bioguo_animaltfdb_tf  \
# 0                            2                False
# 1                            2                False
# 2                            2                False
# 3                            2                False
# 4                            1                False
#
#   bioguo_animaltfdb_chromatin_remodeler bioguo_animaltfdb_cofactor  \
# 0                                 False                      False
# 1                                 False                      False
# 2                                 False                      False
# 3                                 False                      False
# 4                                 False                      False
#
#   max_exons_per_gene
# 0                  5
# 1                  5
# 2                  5
# 3                  5
# 4                 26
#
# [5 rows x 40 columns]

# %%
modalities_genes_annotated_plus_constitutive = pd.concat([modalities_genes, constitutive_genes_modalities_annotated])
modalities_genes_annotated_plus_constitutive.head()
# Out:
#   bioguo_animaltfdb_chromatin_remodeler bioguo_animaltfdb_cofactor  \
# 0                                 False                      False
# 1                                 False                      False
# 2                                 False                      False
# 3                                 False                      False
# 4                                 False                      False
#
#   bioguo_animaltfdb_tf biomark_neural_panel cell_cycle cell_surface_markers  \
# 0                False                False      False                False
# 1                False                False      False                False
# 2                False                False      False                False
# 3                False                False      False                False
# 4                False                False      False                False
#
#   common_id confident_rbp  domazetloso2008_phylostratum       ensembl_id  \
# 0       NaN         False                             1  ENSG00000120053
# 1       NaN         False                             1  ENSG00000014919
# 2       NaN         False                             1  ENSG00000099194
# 3       NaN         False                           NaN  ENSG00000255339
# 4       NaN         False                             2  ENSG00000055950
#
#           ...             rbp ribosomal ribosomal_subunit synapse  tag  \
# 0         ...           False     False             False   False  NaN
# 1         ...           False     False             False   False  NaN
# 2         ...           False     False             False   False  NaN
# 3         ...           False     False             False   False  NaN
# 4         ...           False      True              True   False  NaN
#
#         transcript_id transcript_name transcript_status transcript_type  \
# 0   ENSG00000120053.9            GOT1             KNOWN  protein_coding
# 1   ENSG00000014919.8           COX15             KNOWN  protein_coding
# 2   ENSG00000099194.5             SCD             KNOWN  protein_coding
# 3   ENSG00000255339.2          NDUFB8             NOVEL  protein_coding
# 4  ENSG00000055950.12          MRPL43             KNOWN  protein_coding
#
#   transcription_factor
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
#
# [5 rows x 41 columns]

# %%
fig, ax = plt.subplots(figsize=(2, 1.5))
plt.yscale('log')
sns.boxplot(data=modalities_genes_annotated_plus_constitutive, y=col, linewidth=1, fliersize=2, **plot_kws)
ax.legend_.set_visible(False)
ax.set(ylim=(1e0, 1e2), xlabel='', ylabel='Max # Exons/Gene')
# ax.locator_params('y', nbins=4)
sns.despine()
fig.savefig('{}/{}_boxplots.pdf'.format(figure_folder, prefix))

# %% [markdown]
# ### Plot p-value heatmap of enrichment (pairwise mann whitney U test)

# %%
import itertools
from scipy.stats.mstats import mannwhitneyu


lines = []

for phenotype, phenotype_df in modalities_genes_annotated_plus_constitutive.groupby(['phenotype']):
    six.print_(phenotype)
    grouped = phenotype_df.groupby('modality')
#     constitutive = grouped.get_group('constitutive')
    
    for (modality1, df1), (modality2, df2) in itertools.combinations(grouped, 2):
#         if modality == 'constitutive':
#             continue
#         six.print_('\t', modality1, modality2)

        result = mannwhitneyu(df1[col], df2[col])
#         six.print_('\t\t', result)
#         results.loc[modality1, modality2] = result.pvalue
        lines.append([phenotype, modality1, modality2, result.pvalue, result.statistic])
enrichment = pd.DataFrame(lines, columns=['phenotype', 'modality1', 'modality2', 'p_value', 'statistic'])

# multiple testing correction
enrichment['bonferonni_p_value'] = enrichment['p_value'] * enrichment.shape[0]
enrichment.head()

# Transform tidy dataframe into 2d matrix
enrichment_2d = enrichment.groupby('phenotype').apply(
    lambda x: x.pivot(index='modality1', columns='modality2', values='bonferonni_p_value'))
enrichment_2d = enrichment_2d.loc[:, modality_order]
enrichment_2d_log10 = -np.log10(enrichment_2d)

# Plot p-value heatmap
fig, ax = plt.subplots(figsize=(.5, .75))
ipsc = enrichment_2d_log10.loc['iPSC']
ipsc = ipsc.loc[modality_order]
ipsc = ipsc.T.fillna(0) + ipsc.fillna(0)
ipsc = ipsc.replace(0, np.nan)
sns.heatmap(ipsc, vmin=0, linewidth=0.5, linecolor='grey', cbar_kws=dict(orientation='horizontal'))
ax.set(xticks=[], yticks=[], xlabel='', ylabel='');
sns.despine(left=False, bottom=False, right=False, top=False)
fig.savefig('{}/{}_p_value_heatmap.pdf'.format(figure_folder, col))
# Out:
# MN
# NPC
# iPSC
